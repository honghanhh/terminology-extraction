# %%
import pandas as pd
import pickle as pkl
import re
from collections import Counter
import nltk
nltk.download('stopwords')
from nltk.corpus import stopwords 

import stanza
# stanza.download('en')
nlp = stanza.Pipeline(lang='en', processors='tokenize,mwt,pos,lemma')
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     /Users/hanhtran/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# 2021-05-12 10:18:07 WARNING: Can not find mwt: default from official model list. Ignoring it.
# 2021-05-12 10:18:07 INFO: Loading these models for language: en (English):
# ========================
# | Processor | Package  |
# ------------------------
# | tokenize  | combined |
# | pos       | combined |
# | lemma     | combined |
# ========================
#
# 2021-05-12 10:18:07 INFO: Use device: cpu
# 2021-05-12 10:18:07 INFO: Loading: tokenize
# 2021-05-12 10:18:07 INFO: Loading: pos
# 2021-05-12 10:18:07 INFO: Loading: lemma
# 2021-05-12 10:18:07 INFO: Done loading processors!

# %%
def count_freq(preds, gts):
    preds_len = [len(x.split(' ')) for x in preds]
    gts_len = [len(x.split(' ')) for x in gts]
    print(Counter(preds_len))
    print(Counter(gts_len))

def evaluation_metrics(pred, gt):
    print("Prediction: ", len(set(pred)))
    print("GT: ",len(set(gt)))
    TP = len(set(pred) & set(gt)) 
    FP = len(set(pred)-set(gt))
    FN = len(set(gt)-set(pred))
    print(TP,FP,FN)
    precision = round((TP/(TP+FP))*100, 2)
    recall = round((TP/(TP+FN))*100,2)
    f1_score = round((2 * precision * recall) / (precision + recall),2)
    return precision, recall, f1_score 

def lemma(li):
    new_list = []
    for t in li:
        doc = nlp(str(t))
        doc1 = ' '.join([word.lemma for sent in doc.sentences for word in sent.words])
        doc1 = re.sub('-',' ',doc1)
        doc1 = re.sub(' +', ' ',doc1)
        new_list.append(doc1)
    new_list = [s for s in new_list if len(s) >= 2]
    return new_list

def get_term(predictions):
    all_term = []
    for sentence in predictions:
        tokens = []
        labels = []
        for d in sentence:
            tokens.extend(d.keys())
            labels.extend(d.values())

        for i, label in enumerate(labels):
            if labels[i] == 'I' and (i == 0 or labels[i - 1] == 'O'):
                labels[i] = 'O'

        terms = []
        term = []
        for i, (token, label) in enumerate(zip(tokens, labels)):
            if label == 'B': 
                #Lưu vị trí B
                b_pos = i
                term = [token]
            elif label == 'I':
                term.append(token)
            elif len(term) > 0:
                terms.append(' '.join(term))
                # Check b_pos = 0 không
                if b_pos != 0:
                    if (tokens[b_pos - 1] != '') and (tokens[b_pos - 1] != ' '):
                        if len(nlp(str(tokens[b_pos - 1])).sentences) > 0:
                            b_word = nlp(str(tokens[b_pos - 1])).sentences[0].words[0]
                            if len(nlp(str(tokens[b_pos])).sentences) > 0:
                                c_word = nlp(str(tokens[b_pos])).sentences[0].words[0]
                                # Check vị trí b_pos - 1: terms.append()
                                if (c_word.upos == 'NOUN') and (c_word.text != 'None') and (b_word.text != 'None') and ((b_word.upos == 'NOUN') or (b_word.upos == 'ADJ')):
                                    terms.append(' '.join([b_word.text] + term))
#                                     print(terms)
                    if (tokens[i] != '') and (tokens[i] != ' '):
                        # Check vị trí i: terms.append()
                        if len(nlp(str(tokens[i])).sentences) > 0:
                            a_word = nlp(str(tokens[i])).sentences[0].words[0]
                            if (a_word.text != 'None') and (a_word.upos == 'NOUN'):
                                terms.append(' '.join(term + [a_word.text]))
#                                 print(terms)
                    
                    #ADJ NOUN NOUN
                    if (tokens[i] != '') and (tokens[i] != ' ') and (tokens[b_pos - 1] != '') and (tokens[b_pos - 1] != ' '):
                        if len(nlp(str(tokens[b_pos - 1])).sentences) > 0 and len(nlp(str(tokens[i])).sentences) > 0:
                            a_word = nlp(str(tokens[i])).sentences[0].words[0]
                            b_word = nlp(str(tokens[b_pos - 1])).sentences[0].words[0]
                            if len(nlp(str(tokens[b_pos])).sentences) > 0:
                                c_word = nlp(str(tokens[b_pos])).sentences[0].words[0]
                                # Check vị trí b_pos - 1: terms.append()
                                if (c_word.text != 'None') and (c_word.upos == 'NOUN') and (b_word.text != 'None') and ((b_word.upos == 'ADJ') and (a_word.upos == 'NOUN')):
                                    terms.append(' '.join([b_word.text] + term + [a_word.text]))
#                                     print(terms)
                    #ADJ ADJ NOUN              
                    if (tokens[b_pos - 2] != '') and (tokens[b_pos - 2] != ' ') and (tokens[b_pos - 1] != '') and (tokens[b_pos - 1] != ' '):
                        if (len(nlp(str(tokens[b_pos - 2])).sentences) > 0 and len(nlp(str(tokens[b_pos - 1])).sentences) > 0 and len(nlp(str(tokens[b_pos])).sentences) > 0):
                            b1_word = nlp(str(tokens[b_pos - 2])).sentences[0].words[0] 
                            b_word = nlp(str(tokens[b_pos - 1])).sentences[0].words[0]
                            c_word = nlp(str(tokens[b_pos])).sentences[0].words[0]
                            # Check vị trí b_pos - 1: terms.append()
                            if (c_word.upos == 'NOUN') and (c_word.text != 'None') and (b_word.text != 'None') and (b1_word.text != 'None') and ((b_word.upos == 'ADJ') and (b1_word.upos == 'ADJ')):
                                terms.append(' '.join([b1_word.text] +[b_word.text] + term))
#                                 print(terms)
                    #NOUN ADJ NOUN
                    if (tokens[b_pos - 2] != '') and (tokens[b_pos - 2] != ' ') and (tokens[b_pos - 1] != '') and (tokens[b_pos - 1] != ' '):
                        if (len(nlp(str(tokens[b_pos - 2])).sentences) > 0 and len(nlp(str(tokens[b_pos - 1])).sentences) > 0 and len(nlp(str(tokens[b_pos])).sentences) > 0):
                            b1_word = nlp(str(tokens[b_pos - 2])).sentences[0].words[0] 
                            b_word = nlp(str(tokens[b_pos - 1])).sentences[0].words[0]
                            c_word = nlp(str(tokens[b_pos])).sentences[0].words[0]
                            # Check vị trí b_pos - 1: terms.append()
                            if (c_word.upos == 'NOUN') and (c_word.text != 'None') and (b_word.text != 'None') and (b1_word.text != 'None') and ((b_word.upos == 'ADJ') and (b1_word.upos == 'NOUN')):
                                terms.append(' '.join([b1_word.text] +[b_word.text] + term))
#                                 print(terms)
                                
                # NOUN NOUN NOUN
                if b_pos != 0 and i + 1 < len(tokens):
                    if (tokens[i] != '') and (tokens[i] != ' ') and (tokens[i+1] != '') and (tokens[i+1] != ' '):
                        if (len(nlp(str(tokens[i])).sentences) > 0 and len(nlp(str(tokens[i+1])).sentences) > 0 and len(nlp(str(tokens[b_pos])).sentences) > 0):
                            a1_word = nlp(str(tokens[i+1])).sentences[0].words[0] 
                            a_word = nlp(str(tokens[i])).sentences[0].words[0]
                            c_word = nlp(str(tokens[b_pos])).sentences[0].words[0]
                            if (c_word.text != 'None') and (c_word.upos == 'NOUN') and (a_word.text != 'None') and (a1_word.text != 'None') and ((a_word.upos == 'NOUN') and (a1_word.upos == 'NOUN')):
                                terms.append(' '.join( term + [a_word.text] +[a1_word.text]))
#                                 print(terms)
                if b_pos != 0:
                    # RULE 1
#                     if (tokens[i] != '') and (tokens[i] != ' ') and (tokens[b_pos - 1] != '') and (tokens[b_pos - 1] != ' '):
#                         if len(nlp(str(tokens[b_pos - 1])).sentences) > 0 and len(nlp(str(tokens[i])).sentences) > 0:
#                             b_word = nlp(str(tokens[b_pos - 1])).sentences[0].words[0]
#                             a_word = nlp(str(tokens[i])).sentences[0].words[0]
#                             if  (b_word.text != 'None') and (a_word.text != 'None') and tokens[b_pos] == '-':
#                                 terms.append(' '.join([b_word.text] + term + [a_word.text]))
#                                 print(terms)
                    # RULE 2
                    if (tokens[b_pos-2] != '') and (tokens[b_pos -2] != ' ') and (tokens[b_pos - 1] != '') and (tokens[b_pos - 1] != ' '):
                        if len(nlp(str(tokens[b_pos - 1])).sentences) > 0 and len(nlp(str(tokens[b_pos-2])).sentences) > 0:
                            b_word = nlp(str(tokens[b_pos - 1])).sentences[0].words[0]
                            b1_word = nlp(str(tokens[b_pos - 2])).sentences[0].words[0]
                            # Check vị trí b_pos - 1: terms.append()
                            if  (b_word.text == '-') and (b1_word.text != 'None'):
                                terms.append(' '.join([b1_word.text] + [b_word.text] + term))
                                print(terms)
#                 if b_pos != 0 and i + 1 < len(tokens):
#                 # RULE 3
#                     if (tokens[i] != '') and (tokens[i] != ' ') and (tokens[i+1] != '') and (tokens[i+1] != ' '):
#                         if len(nlp(str(tokens[i])).sentences) > 0 and len(nlp(str(tokens[i+1])).sentences) > 0:
#                             a_word = nlp(str(tokens[i])).sentences[0].words[0]
#                             a1_word = nlp(str(tokens[i+1])).sentences[0].words[0]
#                             if  (a_word.text == '-') and (a1_word.text != 'None'):
#                                 terms.append(' '.join(term + [a_word.text] + [a1_word.text]))
#                                 print(terms)
                    
                term = []
        if len(term) > 0:
            terms.append(' '.join(term))
            # check b_pos - 1
        all_term.append(terms)
    
    final_terms = []
    for i in all_term:
        final_terms.extend(i)

    final_terms = [x.lower() for x in final_terms]
    return final_terms

# %%
groundtruth = pd.read_csv('/Users/hanhtran/Documents/terminology-extraction/ACTER/en/htfl/annotations/htfl_en_terms.ann', sep='	', engine='python',header=None)
gt = list(groundtruth[0]) 

pkl_file = open('final_preds_sklearn.pkl', 'rb')
predictions = pkl.load(pkl_file)

# %%
preds =  get_term(predictions)
# Out:
# ['lipoprotein', 'density lipoprotein', 'HDL', 'endothelial', 'endothelial - protective']
# ['the', 'the impact', 'HDL', 'HDL - mediated']
# ['HDL', 'Thr(495', 'eNOS - Thr(495']
# ['HDL', 'Thr(495', 'eNOS - Thr(495', 'HDL', 'HDL - bound']
# ['HDL', 'Thr(495', 'eNOS - Thr(495', 'HDL', 'HDL - bound', 'malondialdehyde', 'Endothelial function', 'flow', 'flow - mediated']
# ['HDL', 'Thr(495', 'eNOS - Thr(495', 'HDL', 'HDL - bound', 'malondialdehyde', 'Endothelial function', 'flow', 'flow - mediated', 'proteome', 'LC', 'LC - MS']
# ['HDL', 'Thr(495', 'eNOS - Thr(495', 'HDL', 'HDL - bound', 'malondialdehyde', 'Endothelial function', 'flow', 'flow - mediated', 'proteome', 'LC', 'LC - MS', 'Thr(495', 'eNOS - Thr(495']
# ['HDL', 'Thr(495', 'eNOS - Thr(495', 'HDL', 'HDL - bound', 'malondialdehyde', 'Endothelial function', 'flow', 'flow - mediated', 'proteome', 'LC', 'LC - MS', 'Thr(495', 'eNOS - Thr(495', 'elevated activation', 'malondialdehyde', 'flow', 'flow - mediated']
# ['HDL function', 'CHF', 'HDL', 'HDL - mediated']
# ['HF', 'HF - related']
# ['RV', 'RV dysfunction', 'cachexia', 'display cachexia', 'The', 'The extent', 'RV', 'RV dysfunction', 'lean', 'lean body', 'lean body mass', 'RV', 'RV dysfunction', 'cachexia', 'HR', 'fat', 'fat mass', 'free mass', 'free mass index', 'fat - free mass']
# ['Economic', 'Economic Analysis', 'Patient', 'Patient Management', 'Patient Management Interventions', 'Heart', 'Heart Failure', 'Heart Failure Cost', 'Cost', 'Failure Cost', 'Cost - Effectiveness']
# ['Economic', 'Economic Analysis', 'Patient', 'Patient Management', 'Patient Management Interventions', 'Heart', 'Heart Failure', 'Heart Failure Cost', 'Cost', 'Failure Cost', 'Cost - Effectiveness', 'cost', 'cost - effectiveness']
# ['Heart', 'medical', 'medical resource', 'costs', 'term costs', 'extrapolating', 'term', 'term outcomes', 'short - term']
# ['Economic', 'Economic Analysis', 'Patient', 'Patient Management', 'Patient Management Interventions', 'Cost', 'Failure Cost', 'Cost - Effectiveness']
# ['Economic', 'Economic Analysis', 'Patient', 'Patient Management', 'Patient Management Interventions', 'Cost', 'Failure Cost', 'Cost - Effectiveness', 'clinical', 'evidence', 'evidence - based']
# ['Economic', 'Economic Analysis', 'Patient', 'Patient Management', 'Patient Management Interventions', 'Cost', 'Failure Cost', 'Cost - Effectiveness', 'clinical', 'evidence', 'evidence - based', 'costs', 'Heart', 'Heart Failure', 'Heart Failure Model', 'Heart Failure', 'Heart Failure Model', 'Heart Failure Model scores', 'The', 'The model', 'single', 'single - cohort']
# ['Economic', 'Economic Analysis', 'Patient', 'Patient Management', 'Patient Management Interventions', 'Cost', 'Failure Cost', 'Cost - Effectiveness', 'clinical', 'evidence', 'evidence - based', 'costs', 'Heart', 'Heart Failure', 'Heart Failure Model', 'Heart Failure', 'Heart Failure Model', 'Heart Failure Model scores', 'The', 'The model', 'single', 'single - cohort', 'cohort', 'cohort study', 'cohort study designs', 'single - cohort']
# ['Economic', 'Economic Analysis', 'Patient', 'Patient Management', 'Patient Management Interventions', 'Cost', 'Failure Cost', 'Cost - Effectiveness', 'clinical', 'evidence', 'evidence - based', 'costs', 'Heart', 'Heart Failure', 'Heart Failure Model', 'Heart Failure', 'Heart Failure Model', 'Heart Failure Model scores', 'The', 'The model', 'single', 'single - cohort', 'cohort', 'cohort study', 'cohort study designs', 'single - cohort', 'cohorts', 'virtual cohorts', 'costs', 'cost', 'incremental cost', 'cost - effectiveness']
# ['internal', 'costs', 'clinical', 'clinical trials', 'cost', 'cost - effectiveness']
# ['internal', 'costs', 'clinical', 'clinical trials', 'cost', 'cost - effectiveness', 'heart', 'heart failure', 'heart failure disease', 'evidence', 'evidence - based']
# ['Economic', 'Economic Analysis', 'Patient', 'Patient Management', 'Patient Management Interventions', 'Heart', 'Heart Failure', 'Heart Failure Cost', 'Cost', 'Failure Cost', 'Cost - Effectiveness']
# ['Economic', 'Economic Analysis', 'Patient', 'Patient Management', 'Patient Management Interventions', 'Heart', 'Heart Failure', 'Heart Failure Cost', 'Cost', 'Failure Cost', 'Cost - Effectiveness', 'cost', 'term cost', 'cost - effectiveness']
# ['Carvedilol', 'nonselective', 'the', 'metoprolol', 'the', 'the risk', 'thromboembolic', 'thromboembolic events', 'heart', 'heart failure', 'The', 'The aim', 'cardiac', 'meta', '123 - meta']
# ['Carvedilol', 'nonselective', 'the', 'metoprolol', 'the', 'the risk', 'thromboembolic', 'thromboembolic events', 'heart', 'heart failure', 'The', 'The aim', 'cardiac', 'meta', '123 - meta', 'meta - iodobenzylguanidine']
# ['Carvedilol', 'nonselective', 'the', 'metoprolol', 'the', 'the risk', 'thromboembolic', 'thromboembolic events', 'heart', 'heart failure', 'The', 'The aim', 'cardiac', 'meta', '123 - meta', 'meta - iodobenzylguanidine', 'MIBG', '123 - MIBG']
# ['Carvedilol', 'nonselective', 'the', 'metoprolol', 'the', 'the risk', 'thromboembolic', 'thromboembolic events', 'heart', 'heart failure', 'The', 'The aim', 'cardiac', 'meta', '123 - meta', 'meta - iodobenzylguanidine', 'MIBG', '123 - MIBG', 'β', 'β - blocker']
# ['climate', 'economic climate', 'current economic climate', '- change', '- change interventions', 'acute', 'acute hospital', 'cost', 'cost - effective']
# ['mixed', 'mixed - methods']
# ['oxidase', 'ventricular', 'overload', 'volume overload', 'regurgitation', 'mitral regurgitation', 'fistula', 'XO', 'XO - mediated']
# ['oxidase', 'ventricular', 'overload', 'volume overload', 'regurgitation', 'mitral regurgitation', 'fistula', 'XO', 'XO - mediated', 'ROS', 'mitochondrial respiration', 'decrease mitochondrial respiration', 'contractile', 'contractile function', 'XO', 'XO inhibition', 'bioenergetics', 'cardiomyocyte bioenergetics', 'sham', 'Echocardiography', 'end', 'end - diastolic']
# ['oxidase', 'ventricular', 'overload', 'volume overload', 'regurgitation', 'mitral regurgitation', 'fistula', 'XO', 'XO - mediated', 'ROS', 'mitochondrial respiration', 'decrease mitochondrial respiration', 'contractile', 'contractile function', 'XO', 'XO inhibition', 'bioenergetics', 'cardiomyocyte bioenergetics', 'sham', 'Echocardiography', 'end', 'end - diastolic', 'diastolic dimension', 'end - diastolic dimension']
# ['oxidase', 'ventricular', 'overload', 'volume overload', 'regurgitation', 'mitral regurgitation', 'fistula', 'XO', 'XO - mediated', 'ROS', 'mitochondrial respiration', 'decrease mitochondrial respiration', 'contractile', 'contractile function', 'XO', 'XO inhibition', 'bioenergetics', 'cardiomyocyte bioenergetics', 'sham', 'Echocardiography', 'end', 'end - diastolic', 'diastolic dimension', 'end - diastolic dimension', 'end', 'end - diastolic']
# ['oxidase', 'ventricular', 'overload', 'volume overload', 'regurgitation', 'mitral regurgitation', 'fistula', 'XO', 'XO - mediated', 'ROS', 'mitochondrial respiration', 'decrease mitochondrial respiration', 'contractile', 'contractile function', 'XO', 'XO inhibition', 'bioenergetics', 'cardiomyocyte bioenergetics', 'sham', 'Echocardiography', 'end', 'end - diastolic', 'diastolic dimension', 'end - diastolic dimension', 'end', 'end - diastolic', 'diastolic', 'diastolic pressure', 'end - diastolic']
# ['oxidase', 'ventricular', 'overload', 'volume overload', 'regurgitation', 'mitral regurgitation', 'fistula', 'XO', 'XO - mediated', 'ROS', 'mitochondrial respiration', 'decrease mitochondrial respiration', 'contractile', 'contractile function', 'XO', 'XO inhibition', 'bioenergetics', 'cardiomyocyte bioenergetics', 'sham', 'Echocardiography', 'end', 'end - diastolic', 'diastolic dimension', 'end - diastolic dimension', 'end', 'end - diastolic', 'diastolic', 'diastolic pressure', 'end - diastolic', 'wall stress', 'lung', 'lung weight', 'sham', 'sham group', 'velocity', 'contractile', 'contractile efficiency', 'cardiomyocytes', 'flux', 'extracellular flux', 'flux analyzer', 'extracellular flux analyzer', 'contractile', 'contractile function', 'end', 'end - diastolic']
# ['oxidase', 'ventricular', 'overload', 'volume overload', 'regurgitation', 'mitral regurgitation', 'fistula', 'XO', 'XO - mediated', 'ROS', 'mitochondrial respiration', 'decrease mitochondrial respiration', 'contractile', 'contractile function', 'XO', 'XO inhibition', 'bioenergetics', 'cardiomyocyte bioenergetics', 'sham', 'Echocardiography', 'end', 'end - diastolic', 'diastolic dimension', 'end - diastolic dimension', 'end', 'end - diastolic', 'diastolic', 'diastolic pressure', 'end - diastolic', 'wall stress', 'lung', 'lung weight', 'sham', 'sham group', 'velocity', 'contractile', 'contractile efficiency', 'cardiomyocytes', 'flux', 'extracellular flux', 'flux analyzer', 'extracellular flux analyzer', 'contractile', 'contractile function', 'end', 'end - diastolic', 'diastolic', 'diastolic pressure', 'end - diastolic']
# ['oxidase', 'ventricular', 'overload', 'volume overload', 'regurgitation', 'mitral regurgitation', 'fistula', 'XO', 'XO - mediated', 'ROS', 'mitochondrial respiration', 'decrease mitochondrial respiration', 'contractile', 'contractile function', 'XO', 'XO inhibition', 'bioenergetics', 'cardiomyocyte bioenergetics', 'sham', 'Echocardiography', 'end', 'end - diastolic', 'diastolic dimension', 'end - diastolic dimension', 'end', 'end - diastolic', 'diastolic', 'diastolic pressure', 'end - diastolic', 'wall stress', 'lung', 'lung weight', 'sham', 'sham group', 'velocity', 'contractile', 'contractile efficiency', 'cardiomyocytes', 'flux', 'extracellular flux', 'flux analyzer', 'extracellular flux analyzer', 'contractile', 'contractile function', 'end', 'end - diastolic', 'diastolic', 'diastolic pressure', 'end - diastolic', 'wall stress', 'lung', 'lung weight', 'contractile', 'contractile function', 'XO', 'XO - mediated']
# ['Hospital', 'to', 'Hospital - to']
# ['Hospital', 'to', 'Hospital - to', 'to - Home']
# ['Hospital', 'to', 'Hospital - to', 'to - Home', 'Home', 'to - Home']
# ['two', 'two - center']
# ['transitions', 'intensive transitions', 'training', 'management training', 'out', 'out - patient']
# ['transitions', 'intensive transitions', 'training', 'management training', 'out', 'out - patient', 'follow', 'follow - up']
# ['The', 'neurological', 'cardiovascular', 'cardiovascular event', 'free rate', 'event - free rate']
# ['The', 'neurological', 'cardiovascular', 'cardiovascular event', 'free rate', 'event - free rate', 'BAT', 'walked', 'BAT', 'N', 'N - terminal']
# ['The', 'neurological', 'cardiovascular', 'cardiovascular event', 'free rate', 'event - free rate', 'BAT', 'walked', 'BAT', 'N', 'N - terminal', 'pro', 'pro - brain']
# ['BAT', 'N', 'N - terminal']
# ['BAT', 'N', 'N - terminal', 'pro', 'pro - brain']
# ['BAT', 'N', 'N - terminal', 'pro', 'pro - brain', 'natriuretic peptide', 'the', 'the burden', 'heart failure', 'heart failure hospitalizations', 'GDMT', 'GDMT - treated']
# ['Evidence', 'Reviews', 'Evidence', 'CPG', 'CPG recommendations', 'decision', 'decision - support']
# ['Evidence', 'Reviews', 'Evidence', 'CPG', 'CPG recommendations', 'decision', 'decision - support', 'financial', 'financial incentives', 'Taxonomy', 'Care Taxonomy', 'pharmacological treatment', 'device', 'device consideration', 'self', 'self - care']
# ['single', 'single - center']
# ['heart failure', 'heart', 'systolic heart', 'heart failure', 'readmissions', 'cause readmissions', 'follow', 'follow - up']
# ['computing', 'computing readmissions', 'pay', 'pay - for']
# ['Heart rate reduction', 'exercise performance', 'heart failure', 'onset heart failure', 'hypo', 'hypo - response']
# ['exercise', 'exercise protocol', 'gas', 'respiratory gas', 'gas analysis', 'respiratory gas analysis', 'blocker therapy', 'beta - blocker therapy']
# ['exercise', 'exercise protocol', 'gas', 'respiratory gas', 'gas analysis', 'respiratory gas analysis', 'blocker therapy', 'beta - blocker therapy', 'resting', 'resting HR', 'bpm', 'HR bpm', 'Beta', 'Beta - blocker']
# ['exercise', 'exercise protocol', 'gas', 'respiratory gas', 'gas analysis', 'respiratory gas analysis', 'blocker therapy', 'beta - blocker therapy', 'resting', 'resting HR', 'bpm', 'HR bpm', 'Beta', 'Beta - blocker', 'blocker dose', 'Beta - blocker dose']
# ['HFrEF', 'exercise performance', 'resting', 'resting HR', 'bpm', 'blocker therapy', 'beta - blocker therapy']
# ['HFrEF', 'exercise performance', 'resting', 'resting HR', 'bpm', 'blocker therapy', 'beta - blocker therapy', 'uptitration', 'dose uptitration', 'HR reduction', 'little HR reduction', 'beta', 'beta - blocker']
# ['HFrEF', 'exercise performance', 'resting', 'resting HR', 'bpm', 'blocker therapy', 'beta - blocker therapy', 'uptitration', 'dose uptitration', 'HR reduction', 'little HR reduction', 'beta', 'beta - blocker', 'blocker therapy', 'beta - blocker therapy']
# ['ventricular ejection fraction', 'long', 'long - term']
# ['ventricular ejection fraction', 'long', 'long - term', 'term mortality', 'long - term mortality']
# ['heart failure', 'Contemporary heart failure', 'age Contemporary heart failure', 'HF', 'therapies', 'ventricular ejection', 'ventricular ejection fraction', 'LVEF', 'the', 'the differential', 'LVEF', 'long', 'long - term']
# ['heart failure', 'Contemporary heart failure', 'age Contemporary heart failure', 'HF', 'therapies', 'ventricular ejection', 'ventricular ejection fraction', 'LVEF', 'the', 'the differential', 'LVEF', 'long', 'long - term', 'Heart', 'Heart Failure', 'Heart Failure Survey', 'long', 'long - term']
# ['heart failure', 'Contemporary heart failure', 'age Contemporary heart failure', 'HF', 'therapies', 'ventricular ejection', 'ventricular ejection fraction', 'LVEF', 'the', 'the differential', 'LVEF', 'long', 'long - term', 'Heart', 'Heart Failure', 'Heart Failure Survey', 'long', 'long - term', 'term', 'Interaction term', 'term analysis', 'long', 'long - term']
# ['heart failure', 'Contemporary heart failure', 'age Contemporary heart failure', 'HF', 'therapies', 'ventricular ejection', 'ventricular ejection fraction', 'LVEF', 'the', 'the differential', 'LVEF', 'long', 'long - term', 'Heart', 'Heart Failure', 'Heart Failure Survey', 'long', 'long - term', 'term', 'Interaction term', 'term analysis', 'long', 'long - term', 'long', 'long - term']
# ['heart failure', 'Contemporary heart failure', 'age Contemporary heart failure', 'HF', 'therapies', 'ventricular ejection', 'ventricular ejection fraction', 'LVEF', 'the', 'the differential', 'LVEF', 'long', 'long - term', 'Heart', 'Heart Failure', 'Heart Failure Survey', 'long', 'long - term', 'term', 'Interaction term', 'term analysis', 'long', 'long - term', 'long', 'long - term', 'moderate reductions', 'long', 'long - term']
# ['heart failure', 'Contemporary heart failure', 'age Contemporary heart failure', 'HF', 'therapies', 'ventricular ejection', 'ventricular ejection fraction', 'LVEF', 'the', 'the differential', 'LVEF', 'long', 'long - term', 'Heart', 'Heart Failure', 'Heart Failure Survey', 'long', 'long - term', 'term', 'Interaction term', 'term analysis', 'long', 'long - term', 'long', 'long - term', 'moderate reductions', 'long', 'long - term', 'The', 'The differential', 'long', 'long - term']
# ['heart failure', 'Contemporary heart failure', 'age Contemporary heart failure', 'HF', 'therapies', 'ventricular ejection', 'ventricular ejection fraction', 'LVEF', 'the', 'the differential', 'LVEF', 'long', 'long - term', 'Heart', 'Heart Failure', 'Heart Failure Survey', 'long', 'long - term', 'term', 'Interaction term', 'term analysis', 'long', 'long - term', 'long', 'long - term', 'moderate reductions', 'long', 'long - term', 'The', 'The differential', 'long', 'long - term', 'term mortality', 'long - term mortality']
# ['longitudinal strain', 'ventricle', 'echocardiographic', 'echocardiographic measurements', 'echocardiography', 'baseline echocardiography', 'CRT', 'an', 'reverse remodeling', 'the', 'end', 'end - systolic']
# ['insulin', 'Cardiac insulin', 'insulin - resistance']
# ['cardiac', 'cardiac hypertrophy', 'pressure', 'pressure - overload']
# ['cardiac', 'cardiac hypertrophy', 'pressure', 'pressure - overload', 'overload', 'pressure - overload']
# ['cardiac', 'cardiac hypertrophy', 'pressure', 'pressure - overload', 'overload', 'pressure - overload', 'abdominal', 'The rates', 'metabolism', 'substrate metabolism', 'hearts', 'cardiac', 'cardiac hypertrophy', 'vivo', 'vivo assessment', 'cardiac function', 'echocardiography', 'diastolic', 'diastolic dysfunction', 'ejection fraction', 'insulin', 'cardiac insulin', 'insulin - resistance']
# ['insulin', 'cardiac insulin', 'insulin - resistance']
# ['congestive', 'congestive symptoms', 'heart failure', 'HF', 'the', 'the potential', 'HF', 'HF - related']
# ['congestive', 'congestive symptoms', 'heart failure', 'HF', 'the', 'the potential', 'HF', 'HF - related', 'morbidity', 'related morbidity', 'neurohormonal activation', 'congestion', 'congestion - like']
# ['heart failure', 'HF', 'the', 'the use', 'cardioverter defibrillators', 'implantable cardioverter defibrillators', 'ICDs', 'ICD', 'ICD - HF']
# ['heart failure', 'HF', 'the', 'the use', 'cardioverter defibrillators', 'implantable cardioverter defibrillators', 'ICDs', 'ICD', 'ICD - HF', 'HF', 'HF patients', 'ICD - HF']
# ['EMBASE', 'ICD', 'ICD patients', 'the association', 'random', 'random - effects']
# ['ICD', 'ICD - HF']
# ['ICD', 'ICD - HF', 'HF', 'HF patients', 'ICD - HF']
# ['cardiotoxicity', 'doxorubicin', 'neoplastic agent', 'anti - neoplastic agent']
# ['cardiotoxicity', 'doxorubicin', 'neoplastic agent', 'anti - neoplastic agent', 'the', 'the treatment', 'cancers', 'several cancers', 'cardioprotective effect', 'hemodynamic', 'hemodynamic alterations', 'doxorubicin', 'Doxorubicin', 'doxorubicin', 'doxorubicin treatment', 'Heart', 'Heart rate', 'blood flow', 'aortic blood flow', 'doxorubicin', 'adenine', 'adenine nucleotides', 'adenine nucleotides contents', 'phosphorylation capacity', 'oxidative phosphorylation capacity', 'mitochondrial oxidative phosphorylation capacity', 'heart', 'heart rate', 'blood flow', 'aortic blood flow', 'cardiotoxicity', 'doxorubicin cardiotoxicity', 'phosphorylation capacity', 'oxidative phosphorylation capacity', 'mitochondrial oxidative phosphorylation capacity', 'cardioprotection', 'significant cardioprotection', 'apoptotic', 'apoptotic signaling', 'cytotoxic', 'cytotoxic effect', 'doxorubicin against', 'solid', 'doxorubicin', 'doxorubicin - induced']
# ['apoptosis', 'pacing', 'pacing - induced']
# ['apoptosis', 'pacing', 'pacing - induced', 'cardiomyopathy', 'dilated cardiomyopathy', 'ventricular', 'ventricular pacing', 'Bax', 'RTQ', 'RTQ - PCR']
# ['artery disease', 'Peripheral artery disease', 'heart failure', 'HF', 'the', 'the prevalence', 'HF', 'ankle', 'ankle - brachial']
# ['artery disease', 'Peripheral artery disease', 'heart failure', 'HF', 'the', 'the prevalence', 'HF', 'ankle', 'ankle - brachial', 'brachial index', 'ankle - brachial index']
# ['artery disease', 'Peripheral artery disease', 'heart failure', 'HF', 'the', 'the prevalence', 'HF', 'ankle', 'ankle - brachial', 'brachial index', 'ankle - brachial index', 'natriuretic peptide', 'pg', 'glomerular filtration rate', 'hypertension', 'E', 'E - wave']
# ['artery disease', 'Peripheral artery disease', 'heart failure', 'HF', 'the', 'the prevalence', 'HF', 'ankle', 'ankle - brachial', 'brachial index', 'ankle - brachial index', 'natriuretic peptide', 'pg', 'glomerular filtration rate', 'hypertension', 'E', 'E - wave', 'wave', 'E - wave']
# ['FFM', 'FM', 'fat distribution', 'absorptiometry', 'DXA', 'diabetic', 'diabetic patients', 'non - diabetic']
# ['FFM', 'FM', 'fat distribution', 'absorptiometry', 'DXA', 'diabetic', 'diabetic patients', 'non - diabetic', 'heart failure', 'chronic heart failure', 'CC', 'cachectic', 'non - cachectic']
# ['FFM', 'FM', 'fat distribution', 'absorptiometry', 'DXA', 'diabetic', 'diabetic patients', 'non - diabetic', 'heart failure', 'chronic heart failure', 'CC', 'cachectic', 'non - cachectic', 'infarction', 'myocardial infarction', 'prior myocardial infarction', 'infarction - both']
# ['N', 'terminal', 'N - terminal']
# ['N', 'terminal', 'N - terminal', 'elevated', 'CHF', 'BMI', 'adrenomedullin', 'pro - adrenomedullin']
# ['heart failure', 'ventricular ejection fraction', 'Morbidity', 'the', 'the importance', 'diastolic', 'diastolic dysfunction', 'the pathophysiology', 'diastolic', 'diastolic abnormalities', 'non - diastolic']
# ['heart failure', 'ventricular ejection fraction', 'Morbidity', 'the', 'the importance', 'diastolic', 'diastolic dysfunction', 'the pathophysiology', 'diastolic', 'diastolic abnormalities', 'non - diastolic', 'cardiovascular', 'cardiovascular function', 'echo', 'echo - Doppler']
# ['L', 'L - type']
# ['influx', 'voltage', 'type voltage', 'voltage - gated']
# ['influx', 'voltage', 'type voltage', 'voltage - gated', 'gated', 'voltage - gated']
# ['influx', 'voltage', 'type voltage', 'voltage - gated', 'gated', 'voltage - gated', 'plateau', 'plateau phase', 'ventricular action potentials', 'excitation', 'excitation - contraction']
# ['influx', 'voltage', 'type voltage', 'voltage - gated', 'gated', 'voltage - gated', 'plateau', 'plateau phase', 'ventricular action potentials', 'excitation', 'excitation - contraction', 'myocardium', 'Gem', 'monomeric', 'ventricular action', 'ventricular action potential', 'L', 'L - type']
# ['influx', 'voltage', 'type voltage', 'voltage - gated', 'gated', 'voltage - gated', 'plateau', 'plateau phase', 'ventricular action potentials', 'excitation', 'excitation - contraction', 'myocardium', 'Gem', 'monomeric', 'ventricular action', 'ventricular action potential', 'L', 'L - type', 'heart failure', 'congestive heart failure', 'heart', 'murine', 'wild', 'wild - type']
# ['influx', 'voltage', 'type voltage', 'voltage - gated', 'gated', 'voltage - gated', 'plateau', 'plateau phase', 'ventricular action potentials', 'excitation', 'excitation - contraction', 'myocardium', 'Gem', 'monomeric', 'ventricular action', 'ventricular action potential', 'L', 'L - type', 'heart failure', 'congestive heart failure', 'heart', 'murine', 'wild', 'wild - type', 'movement', 'gating movement', 'wild', 'wild - type']
# ['anthracycline', 'anthracycline - related']
# ['Haematopoietic', 'transplantation', 'cell transplantation', 'HCT', 'heart failure', 'congestive heart failure', 'developing congestive heart failure', 'anthracyclines', 'the association', 'the', 'the development', 'anthracycline metabolism', 'homeostasis', 'iron homeostasis', 'oxidant defence', 'anti - oxidant defence']
# ['Haematopoietic', 'transplantation', 'cell transplantation', 'HCT', 'heart failure', 'congestive heart failure', 'developing congestive heart failure', 'anthracyclines', 'the association', 'the', 'the development', 'anthracycline metabolism', 'homeostasis', 'iron homeostasis', 'oxidant defence', 'anti - oxidant defence', 'myocardial remodelling', 'post', 'post - HCT']
# ['Haematopoietic', 'transplantation', 'cell transplantation', 'HCT', 'heart failure', 'congestive heart failure', 'developing congestive heart failure', 'anthracyclines', 'the association', 'the', 'the development', 'anthracycline metabolism', 'homeostasis', 'iron homeostasis', 'oxidant defence', 'anti - oxidant defence', 'myocardial remodelling', 'post', 'post - HCT', 'the', 'the sampling', 'anthracycline', 'cumulative anthracycline', 'anthracycline exposure', 'cumulative anthracycline exposure', 'stem', 'stem cell', 'stem cell source', 'autologous', 'germline', 'the', 'the odds', 'chest radiation', 'hypertension', 'the', 'oxidase', 'NAD - oxidase']
# ['The', 'breathing pulse', 'breathing pulse sequence', 'free - breathing pulse']
# ['swine', 'pacemakers', 'ventricularly', 'heart failure', 'MRI scanner', 'heart failure', 'T1-mapping', 'T1-mapping sequence', 'tidal', 'tidal respiration', 'the', 'the administration', 'gadolinium', 'gadolinium - chelate']
# ['swine', 'pacemakers', 'ventricularly', 'heart failure', 'MRI scanner', 'heart failure', 'T1-mapping', 'T1-mapping sequence', 'tidal', 'tidal respiration', 'the', 'the administration', 'gadolinium', 'gadolinium - chelate', 'chelate', 'chelate contrast', 'chelate contrast agent', 'gadolinium - chelate']
# ['The', 'T1-mapping', 'T1-mapping technique', 'heart', 'heart failure', 'the', 'the use', 'holding', 'breath - holding']
# ['oxygenation', 'membrane oxygenation', 'infarction', 'infarction - related']
# ['heart failure', 'Acute heart failure', 'AHF', 'heart failure', 'HF', 'long', 'long - term']
# ['heart failure', 'Acute heart failure', 'AHF', 'heart failure', 'HF', 'long', 'long - term', 'term', 'term survival', 'term survival rates', 'long - term']
# ['rate', 'Heart rate', 'cardiac', 'cardiac patients', 'infarction', 'myocardial infarction', 'acute myocardial infarction', 'heart failure', 'congestive heart failure', 'CHF', 'ventricular', 'LV', 'abnormal', 'abnormal HR', 'dynamics', 'HR dynamics', 'spectral', 'power', 'prognostic power', 'R', 'R - R']
# ['heart failure', 'HF', 'HF', 'HF populations', 'non - HF']
# ['HF', 'HF hospitalization', 'food', 'food - frequency']
# ['evidence', 'adopting evidence', 'evidence - based']
# ['off', 'off - pump']
# ['ventricular', 'LVADs', 'heart failure', 'advanced heart failure', 'the', 'the incidence', 'driveline', 'driveline injury', 'pump', 'safe pump', 'pump - exchange']
# ['hand', 'hand - searching']
# ['randomised', 'randomised - controlled']
# ['randomised', 'randomised - controlled', 'trials', 'RCTs', 'cohort', 'observational cohort', 'cohort studies', 'observational cohort studies', 'RM', 'RM interventions', 'telemonitoring', 'home telemonitoring', 'medical', 'medical support', 'telephone', 'telephone support', 'STS', 'machine interface', 'to - machine interface']
# ['carvedilol', 'metoprolol', 'cardioverter - defibrillator therapy', 'implantable cardioverter - defibrillator therapy', 'inappropriate implantable cardioverter - defibrillator therapy', 'MADIT', 'MADIT - CRT']
# ['The', 'the effects', 'carvedilol', 'metoprolol', 'the', 'the endpoint', 'cardioverter - defibrillator therapy', 'implantable cardioverter - defibrillator therapy', 'inappropriate implantable cardioverter - defibrillator therapy', 'MADIT', 'MADIT - CRT']
# ['MADIT', 'MADIT - CRT']
# ['MADIT', 'MADIT - CRT', 'CRT', 'CRT study', 'MADIT - CRT']
# ['MADIT', 'MADIT - CRT', 'CRT', 'CRT study', 'MADIT - CRT', 'Cox regression', 'Cox regression analysis', 'beta', 'beta - blockers']
# ['heart failure', 'heart failure patients', 'cardiac resynchronization therapy', 'defibrillator', 'an', 'cardioverter', 'implantable cardioverter', 'cardioverter - defibrillator']
# ['heart failure', 'heart failure patients', 'cardiac resynchronization therapy', 'defibrillator', 'an', 'cardioverter', 'implantable cardioverter', 'cardioverter - defibrillator', 'defibrillator device', 'cardioverter - defibrillator device']
# ['heart failure', 'heart failure patients', 'cardiac resynchronization therapy', 'defibrillator', 'an', 'cardioverter', 'implantable cardioverter', 'cardioverter - defibrillator', 'defibrillator device', 'cardioverter - defibrillator device', 'carvedilol', 'ATP', 'shock therapy', 'metoprolol', 'fibrillation', 'atrial fibrillation', 'carvedilol', 'metoprolol', 'MADIT', 'MADIT - CRT']
# ['heart failure', 'heart failure patients', 'cardiac resynchronization therapy', 'defibrillator', 'an', 'cardioverter', 'implantable cardioverter', 'cardioverter - defibrillator', 'defibrillator device', 'cardioverter - defibrillator device', 'carvedilol', 'ATP', 'shock therapy', 'metoprolol', 'fibrillation', 'atrial fibrillation', 'carvedilol', 'metoprolol', 'MADIT', 'MADIT - CRT', 'CRT', 'MADIT - CRT']
# ['Peritoneal dialysis', 'long', 'long - term']
# ['The', 'PD', 'pre - PD']
# ['The', 'PD', 'pre - PD', 'the', 'the majority', 'ventricular', 'ventricular dysfunction', 'kidney', 'chronic kidney', 'kidney disease', 'chronic kidney disease', 'CKD', 'PD', 'PD initiation', 'diuretic', 'diuretic response', 'edema', 'peripheral edema', 're', 're - hospitalization']
# ['alendronate-', 'etidronate-', 'raloxifene', 'raloxifene - treated']
# ['Bisphosphonate', 'heart failure', 'alendronate', 'dose', 'dose - dependent']
# ['aortic', 'aortic insufficiency', 'mechanical circulatory', 'mechanical circulatory support', 'flow', 'continuous flow', 'CF', 'ventricular', 'LVADs', 'pulsatile devices', 'novo', 'post', 'post - LVAD']
# ['aortic', 'aortic insufficiency', 'mechanical circulatory', 'mechanical circulatory support', 'flow', 'continuous flow', 'CF', 'ventricular', 'LVADs', 'pulsatile devices', 'novo', 'post', 'post - LVAD', 'LVAD', 'post - LVAD']
# ['aortic', 'aortic insufficiency', 'mechanical circulatory', 'mechanical circulatory support', 'flow', 'continuous flow', 'CF', 'ventricular', 'LVADs', 'pulsatile devices', 'novo', 'post', 'post - LVAD', 'LVAD', 'post - LVAD', 'valve surgery', 'aortic valve surgery', 'post', 'onset post', 'post - LVAD']
# ['aortic', 'aortic insufficiency', 'mechanical circulatory', 'mechanical circulatory support', 'flow', 'continuous flow', 'CF', 'ventricular', 'LVADs', 'pulsatile devices', 'novo', 'post', 'post - LVAD', 'LVAD', 'post - LVAD', 'valve surgery', 'aortic valve surgery', 'post', 'onset post', 'post - LVAD', 'LVAD', 'post - LVAD']
# ['implantation', 'LVAD implantation', 'LVADs', 'HeartMate', 'HVAD', 'HVAD devices', 'HeartWare', 'onset', 'new - onset']
# ['post', 'post - LVAD']
# ['post', 'post - LVAD', 'LVAD', 'post - LVAD']
# ['HF', 'black ethnicity', 'idiopathic', 'idiopathic - dilated']
# ['Psoriasis', 'cardiovascular disease', 'CVD', 'the', 'the association', 'psoriasis', 'cardiovascular', 'cardiovascular outcomes', 'atherosclerosis', 'subclinical atherosclerosis', 'linear', 'linear models', 'Cox regression', 'the', 'the hazards', 'psoriasis', 'systemic', 'UV treatment', 'smoked', 'blood pressure', 'diastolic blood pressure', 'intima', 'carotid intima', 'intima - media']
# ['Psoriasis', 'cardiovascular disease', 'CVD', 'the', 'the association', 'psoriasis', 'cardiovascular', 'cardiovascular outcomes', 'atherosclerosis', 'subclinical atherosclerosis', 'linear', 'linear models', 'Cox regression', 'the', 'the hazards', 'psoriasis', 'systemic', 'UV treatment', 'smoked', 'blood pressure', 'diastolic blood pressure', 'intima', 'carotid intima', 'intima - media', 'crude', 'ankle', 'ankle - brachial']
# ['Psoriasis', 'cardiovascular disease', 'CVD', 'the', 'the association', 'psoriasis', 'cardiovascular', 'cardiovascular outcomes', 'atherosclerosis', 'subclinical atherosclerosis', 'linear', 'linear models', 'Cox regression', 'the', 'the hazards', 'psoriasis', 'systemic', 'UV treatment', 'smoked', 'blood pressure', 'diastolic blood pressure', 'intima', 'carotid intima', 'intima - media', 'crude', 'ankle', 'ankle - brachial', 'brachial', 'brachial index', 'ankle - brachial']
# ['Hemoglobin', 'training', 'exercise training', 'heart failure', 'chronic heart failure', 'HF', 'HF - ACTION']
# ['Hemoglobin', 'training', 'exercise training', 'heart failure', 'chronic heart failure', 'HF', 'HF - ACTION', 'ACTION', 'HF - ACTION']
# ['heart failure', 'chronic heart failure', 'HF', 'hemoglobin', 'training', 'training - induced']
# ['heart failure', 'chronic heart failure', 'HF', 'hemoglobin', 'training', 'training - induced', 'cohort', 'Heart', 'Heart Failure', 'Training', 'Exercise Training', 'HF', 'HF - ACTION']
# ['heart failure', 'chronic heart failure', 'HF', 'hemoglobin', 'training', 'training - induced', 'cohort', 'Heart', 'Heart Failure', 'Training', 'Exercise Training', 'HF', 'HF - ACTION', 'training', 'exercise training', 'ventricular ejection fractions', 'Cardiomyopathy', 'Cardiomyopathy Questionnaire', 'linear', 'training', 'exercise training', 'exercise', 'exercise training', 'HF', 'HF - ACTION']
# ['Psychosocial', 'Exercise', 'Exercise Adherence', 'Trial', 'Training', 'Exercise Training', 'HF', 'HF - ACTION']
# ['enrolled', 'Heart', 'Heart Failure', 'Trial', 'Training', 'Exercise Training', 'HF', 'HF - ACTION']
# ['The', 'arm', 'single - arm']
# ['The', 'Mechanically', 'ejection fraction', 'cardiac index', 'inotropes', 'inotrope', 'inotrope - dependent']
# ['The', 'the', 'flow', 'centrifugal - flow']
# ['fibrillation', 'Atrial fibrillation', 'Stroke', 'Stroke prevention', 'Stroke prevention Trial', 'onset', 'recent onset', 'mandated', 'guideline - mandated']
# ['heart failure', 'heart failure - related']
# ['Heart failure', 'ejection fraction', 'morbidity', 'cardiovascular morbidity', 'adverse', 'adverse outcomes', 'heart', 'heart failure', 'HF', 'self', 'self - management']
# ['Heart failure', 'ejection fraction', 'morbidity', 'cardiovascular morbidity', 'adverse', 'adverse outcomes', 'heart', 'heart failure', 'HF', 'self', 'self - management', 'ejection fraction', 'walk test', 'diuretics', 'co', 'co - morbidities']
# ['Heart failure', 'ejection fraction', 'morbidity', 'cardiovascular morbidity', 'adverse', 'adverse outcomes', 'heart', 'heart failure', 'HF', 'self', 'self - management', 'ejection fraction', 'walk test', 'diuretics', 'co', 'co - morbidities', 'morbidities', 'co - morbidities']
# ['the', 'the incidence', 'HF', 'AMI', 'long', 'long - term']
# ['The', 'Heart', 'Heart Failure', 'Heart Failure Index', 'psychometric', 'psychometric profile', 'heart failure', 'heart failure patients', 'the', 'the', 'the', 'the presence', 'RMSEA', 'internal', 'internal consistency', 'test', 'test - retest']
# ['cytoskeletal', 'dynamics', 'heart failure', 'HF', 'cardiac', 'deletion', 'cardiac', 'cardiac dysfunction', 'hypertrophy', 'elevated', 'HF', 'the', 'cardiac', 'cardiac pathophysiology', 'cardiac', 'cardiac myocyte', 'cardiac', 'cardiac pathology', 'hearts', 'wild', 'wild - type']
# ['ventricular', 'LVADs', 'heart failure', 'stage heart failure', 'bridge', 'transplantation', 'transplant', 'transplant - ineligible']
# ['ventricular', 'LVADs', 'heart failure', 'stage heart failure', 'bridge', 'transplantation', 'transplant', 'transplant - ineligible', 'the', 'the evidence', 'cost', 'cost - effectiveness']
# ['ventricular', 'LVADs', 'heart failure', 'stage heart failure', 'bridge', 'transplantation', 'transplant', 'transplant - ineligible', 'the', 'the evidence', 'cost', 'cost - effectiveness', 'LVADs', 'flow LVADs', 'the', 'HeartWare', 'HeartWare patients', 'economic', 'economic evaluations', 'policy', 'policy recommendations', 'the', 'the basis', 'implantation', 'LVAD', 'LVAD therapy', 'transplantation', 'transplantation eligibility', 'transplantation eligibility status', 'medical therapy', 'cost', 'traditional cost', 'cost - effectiveness']
# ['diabetes', 'sitagliptin', 'long', 'long - acting']
# ['follow', 'follow - up']
# ['Catheter ablation', 'HFPEF', 'ventricular', 'LV', 'AF', 'AF - free']
# ['Catheter ablation', 'HFPEF', 'ventricular', 'LV', 'AF', 'AF - free', 'free', 'free probability', 'AF - free']
# ['composite', 'pharmaceuticals', 'HFPEF', 'single', 'single - arm']
# ['HF', 'mitral', 'degenerative mitral', 'mitral valve', 'degenerative mitral valve', 'murmur', 'heart', 'the', 'blood pressure', 'chordal ruptures', 'triangular resection', 'anastomosis', 'edge anastomosis', 'annuloplasty', 'ring annuloplasty', 'the surgery', 'HF', 'echocardiography', 'postoperative echocardiography', 'an', 'an end', 'diastolic volume', 'diastolic volume index', 'end - diastolic volume']
# ['HF', 'mitral', 'degenerative mitral', 'mitral valve', 'degenerative mitral valve', 'murmur', 'heart', 'the', 'blood pressure', 'chordal ruptures', 'triangular resection', 'anastomosis', 'edge anastomosis', 'annuloplasty', 'ring annuloplasty', 'the surgery', 'HF', 'echocardiography', 'postoperative echocardiography', 'an', 'an end', 'diastolic volume', 'diastolic volume index', 'end - diastolic volume', 'diastolic volume', 'end - diastolic volume']
# ['HF', 'mitral', 'degenerative mitral', 'mitral valve', 'degenerative mitral valve', 'murmur', 'heart', 'the', 'blood pressure', 'chordal ruptures', 'triangular resection', 'anastomosis', 'edge anastomosis', 'annuloplasty', 'ring annuloplasty', 'the surgery', 'HF', 'echocardiography', 'postoperative echocardiography', 'an', 'an end', 'diastolic volume', 'diastolic volume index', 'end - diastolic volume', 'diastolic volume', 'end - diastolic volume', 'diastolic volume - LV']
# ['HF', 'diastolic', 'diastolic murmurs', 'the', 'Echocardiography', 'mitral', 'limited mitral', 'mitral valve', 'limited mitral valve', 'mitral valve opening', 'MVA', 'angiography', 'Coronary angiography', 'the', 'organic lesion', 'clear organic lesion', 'the', 'surgical', 'surgical indication', 'dynamic', 'vasodilators', 'diuretics', 'HF', 'HF symptom', 'cardiac', 'cardiac murmurs', 'blood pressure', 'echocardiography', 'diastolic volume', 'end - diastolic volume']
# ['echocardiography', 'rheumatic', 'MVA', 'annular', 'annular size', 'implantation', 'ring implantation', 'edge', 'edge - to']
# ['HFPEF', 'resonance imaging', 'magnetic resonance imaging', 'cardiac magnetic resonance imaging', 'hemodynamic', 'hemodynamic assessments', 'HFPEF', 'cardiac', 'cardiac event', 'resonance', 'magnetic resonance', 'Cardiac magnetic resonance', 'atrial area', 'vascular resistance', 'cardiac', 'cardiac events', 'the', 'cardiac', 'cardiac events', 'Extracellular', 'Extracellular matrix', 'ventricular biopsies', 'technology', 'ventricular', 'ventricular - pulmonary']
# ['natriuretic peptide', 'pro', 'pro - B']
# ['natriuretic peptide', 'N', 'N - terminal']
# ['natriuretic peptide', 'N', 'N - terminal', 'fragment', 'NT', 'NT - proBNP']
# ['natriuretic peptide', 'N', 'N - terminal', 'fragment', 'NT', 'NT - proBNP', 'cardiomyocytes', 'ventricular cardiomyocytes', 'wall', 'ventricular wall', 'wall stress', 'ventricular wall stress', 'ischemia', 'myocardial ischemia', 'NT', 'NT - proBNP']
# ['natriuretic peptide', 'N', 'N - terminal', 'fragment', 'NT', 'NT - proBNP', 'cardiomyocytes', 'ventricular cardiomyocytes', 'wall', 'ventricular wall', 'wall stress', 'ventricular wall stress', 'ischemia', 'myocardial ischemia', 'NT', 'NT - proBNP', 'biomarkers', 'prognostic biomarkers', 'heart', 'heart failure', 'the', 'NT', 'NT - proBNP']
# ['cardiac death', 'nervous system activity', 'heart failure', 'tachycardia', 'ventricular tachycardia', 'spontaneous ventricular tachycardia', 'spontaneous', 'hearts', 'normal hearts', 'beat', 'beat - to']
# ['cardiac death', 'nervous system activity', 'heart failure', 'tachycardia', 'ventricular tachycardia', 'spontaneous ventricular tachycardia', 'spontaneous', 'hearts', 'normal hearts', 'beat', 'beat - to', 'isoprenaline', 'RR', 'RR intervals', 'heart rate', 'heart rate variability', 'fixed', 'fixed - rate']
# ['cardiac death', 'nervous system activity', 'heart failure', 'tachycardia', 'ventricular tachycardia', 'spontaneous ventricular tachycardia', 'spontaneous', 'hearts', 'normal hearts', 'beat', 'beat - to', 'isoprenaline', 'RR', 'RR intervals', 'heart rate', 'heart rate variability', 'fixed', 'fixed - rate', 'isoprenaline infusion', 'elevated', 'β', 'β - adrenoceptor']
# ['cardiac death', 'nervous system activity', 'heart failure', 'tachycardia', 'ventricular tachycardia', 'spontaneous ventricular tachycardia', 'spontaneous', 'hearts', 'normal hearts', 'beat', 'beat - to', 'isoprenaline', 'RR', 'RR intervals', 'heart rate', 'heart rate variability', 'fixed', 'fixed - rate', 'isoprenaline infusion', 'elevated', 'β', 'β - adrenoceptor', 'adrenoceptor', 'adrenoceptor blockade', 'β - adrenoceptor']
# ['cardiac death', 'nervous system activity', 'heart failure', 'tachycardia', 'ventricular tachycardia', 'spontaneous ventricular tachycardia', 'spontaneous', 'hearts', 'normal hearts', 'beat', 'beat - to', 'isoprenaline', 'RR', 'RR intervals', 'heart rate', 'heart rate variability', 'fixed', 'fixed - rate', 'isoprenaline infusion', 'elevated', 'β', 'β - adrenoceptor', 'adrenoceptor', 'adrenoceptor blockade', 'β - adrenoceptor', 'spontaneous', 'beat', 'beat - to']
# ['heart failure', 'stage heart failure', 'implantation', 'long', 'long - term']
# ['natriuretic peptides', 'pro', 'pro - B']
# ['methotrexate', 'the', 'the study', 'cohort', 'study cohort', 'antagonist', 'biological disease', 'biological disease modifying', 'non - biological disease']
# ['antagonist', 'The', 'The HR', 'TNF', 'TNF antagonists', 'The', 'The HR', 'elevated', 'HF', 'elevated', 'glucocorticoids', 'Oral glucocorticoids', 'dose', 'dose - related']
# ['neurohormone', 'electrolytes', 'heart failure', 'an', 'an aldosterone', 'heart failure', 'heart failure', 'advanced heart failure', 'heart failure patients', 'advanced heart failure patients', 'chronic advanced heart failure', 'an', 'an aldosterone', 'antagonist', 'aldosterone antagonist', 'spironolactone', 'standard therapy', 'Post', 'post', 'post - myocardial']
# ['neurohormone', 'electrolytes', 'heart failure', 'an', 'an aldosterone', 'heart failure', 'heart failure', 'advanced heart failure', 'heart failure patients', 'advanced heart failure patients', 'chronic advanced heart failure', 'an', 'an aldosterone', 'antagonist', 'aldosterone antagonist', 'spironolactone', 'standard therapy', 'Post', 'post', 'post - myocardial', 'eplerenone', 'post', 'post - myocardial']
# ['heart failure', 'systolic heart failure', 'β', 'β - blocker']
# ['heart failure', 'systolic heart failure', 'β', 'β - blocker', 'angiotensin', 'enzyme', 'enzyme inhibitor', 'angiotensin', 'angiotensin - receptor']
# ['heart failure', 'systolic heart failure', 'β', 'β - blocker', 'angiotensin', 'enzyme', 'enzyme inhibitor', 'angiotensin', 'angiotensin - receptor', 'receptor blocker', 'angiotensin - receptor blocker']
# ['angiotensin', 'prescribing angiotensin', 'enzyme', 'enzyme inhibitor', 'angiotensin', 'angiotensin - receptor']
# ['angiotensin', 'prescribing angiotensin', 'enzyme', 'enzyme inhibitor', 'angiotensin', 'angiotensin - receptor', 'β', 'β - blockers']
# ['Atrial fibrillation', 'heart failure', 'congestive heart failure', 'cost', 'cost analysis', 'rhythm', 'rhythm - control']
# ['Atrial fibrillation', 'heart failure', 'congestive heart failure', 'cost', 'cost analysis', 'rhythm', 'rhythm - control', 'rate', 'rate - control']
# ['fibrillation', 'Atrial fibrillation', 'heart', 'heart failure', 'Rhythm-', 'rate', 'rate - control']
# ['Fibrillation', 'Atrial Fibrillation', 'Heart', 'Congestive Heart', 'Heart Failure', 'Heart Failure trial', 'expenditures', 'care expenditures', 'rhythm', 'rate', 'rate - control']
# ['Fibrillation', 'Atrial Fibrillation', 'Heart', 'Congestive Heart', 'Heart Failure', 'Heart Failure trial', 'expenditures', 'care expenditures', 'rhythm', 'rate', 'rate - control', 'payer', 'payer perspective', 'single - payer']
# ['Fibrillation', 'Atrial Fibrillation', 'Heart', 'Congestive Heart', 'Heart Failure', 'Heart Failure trial', 'expenditures', 'care expenditures', 'rhythm', 'rate', 'rate - control', 'payer', 'payer perspective', 'single - payer', 'cost', 'cost - minimization']
# ['Fibrillation', 'Atrial Fibrillation', 'Heart', 'Congestive Heart', 'Heart Failure', 'Heart Failure trial', 'expenditures', 'care expenditures', 'rhythm', 'rate', 'rate - control', 'payer', 'payer perspective', 'single - payer', 'cost', 'cost - minimization', 'costs', 'unit costs', 'disease', 'disease - specific']
# ['ejection', 'ejection fraction', 'rhythm', 'rhythm - control']
# ['ejection', 'ejection fraction', 'rhythm', 'rhythm - control', 'rate', 'rate - control']
# ['ejection', 'ejection fraction', 'rhythm', 'rhythm - control', 'rate', 'rate - control', 'Arrhythmia', 'Arrhythmia - related']
# ['ejection', 'ejection fraction', 'rhythm', 'rhythm - control', 'rate', 'rate - control', 'Arrhythmia', 'Arrhythmia - related', 'costs', 'related costs', 'Rate', 'Rate - control']
# ['ejection', 'ejection fraction', 'rhythm', 'rhythm - control', 'rate', 'rate - control', 'Arrhythmia', 'Arrhythmia - related', 'costs', 'related costs', 'Rate', 'Rate - control', 'cardiac', 'cardiac procedures', 'cardioversions', 'fewer cardioversions', 'costs', 'lower costs', 'antiarrhythmic drugs', 'expenditures', 'higher expenditures', 'arrhythmia devices', 'cardiac arrhythmia devices', 'implantable cardiac arrhythmia devices', 'rate', 'rate - control']
# ['ejection', 'ejection fraction', 'rhythm', 'rhythm - control', 'rate', 'rate - control', 'Arrhythmia', 'Arrhythmia - related', 'costs', 'related costs', 'Rate', 'Rate - control', 'cardiac', 'cardiac procedures', 'cardioversions', 'fewer cardioversions', 'costs', 'lower costs', 'antiarrhythmic drugs', 'expenditures', 'higher expenditures', 'arrhythmia devices', 'cardiac arrhythmia devices', 'implantable cardiac arrhythmia devices', 'rate', 'rate - control', 'cost', 'total cost', 'rhythm', 'rhythm - control']
# ['ejection', 'ejection fraction', 'rhythm', 'rhythm - control', 'rate', 'rate - control', 'Arrhythmia', 'Arrhythmia - related', 'costs', 'related costs', 'Rate', 'Rate - control', 'cardiac', 'cardiac procedures', 'cardioversions', 'fewer cardioversions', 'costs', 'lower costs', 'antiarrhythmic drugs', 'expenditures', 'higher expenditures', 'arrhythmia devices', 'cardiac arrhythmia devices', 'implantable cardiac arrhythmia devices', 'rate', 'rate - control', 'cost', 'total cost', 'rhythm', 'rhythm - control', 'rate', 'rate - control']
# ['HF', 'non', 'non - frail']
# ['HF', 'non', 'non - frail', 'frail', 'frail participants', 'non - frail']
# ['training', 'work rate', 'quadriceps force', 'peak quadriceps force', 'oxygen', 'Peak oxygen', 'oxygen consumption', 'pulse', 'oxygen pulse', 'NT', 'NT - ProBNP']
# ['training', 'work rate', 'quadriceps force', 'peak quadriceps force', 'oxygen', 'Peak oxygen', 'oxygen consumption', 'pulse', 'oxygen pulse', 'NT', 'NT - ProBNP', 'ProBNP', 'NT - ProBNP']
# ['gait therapy', 'Lokomat', 'heart', 'heart failure', 'heart failure patients', 'aerobic', 'training', 'resistance training', 'training intervention', 'feedback', 'exercise', 'exercise capacity', 'muscle', 'muscle strength', 'cardiac', 'NT', 'NT - ProBNP']
# ['heart failure', 'advanced heart failure', 'mechanical', 'mechanical support', 'Cardiology', 'Cardiology - Cardiovascular']
# ['heart failure', 'advanced heart failure', 'mechanical', 'mechanical support', 'Cardiology', 'Cardiology - Cardiovascular', 'Cardiovascular Surgery', 'Cardiovascular Surgery Consensus', 'Cardiology - Cardiovascular Surgery']
# ['N', 'N - terminal']
# ['N', 'N - terminal', 'pro', 'pro - B']
# ['The', 'N', 'N - terminal']
# ['The', 'N', 'N - terminal', 'terminal', 'N - terminal']
# ['The', 'N', 'N - terminal', 'terminal', 'N - terminal', 'natriuretic peptide', 'NT', 'NT - proBNP']
# ['The', 'N', 'N - terminal', 'terminal', 'N - terminal', 'natriuretic peptide', 'NT', 'NT - proBNP', 'misdiagnosis', 'heart failure', 'HF', 'the', 'the circulating', 'NT', 'NT - proBNP']
# ['The', 'N', 'N - terminal', 'terminal', 'N - terminal', 'natriuretic peptide', 'NT', 'NT - proBNP', 'misdiagnosis', 'heart failure', 'HF', 'the', 'the circulating', 'NT', 'NT - proBNP', 'the', 'NT', 'NT - proBNP']
# ['HF', 'HF patients', 'NT', 'NT - proBNP']
# ['HF', 'HF patients', 'NT', 'NT - proBNP', 'HF', 'immunoprecipitation', 'spectrometric', 'spectrometric analysis', 'sandwich', 'homogeneous sandwich', 'immunoassays', 'NT', 'NT - proBNP']
# ['the', 'the presence', 'NT', 'NT - proBNP']
# ['the', 'the presence', 'NT', 'NT - proBNP', 'proteolysis', 'physiological proteolysis', 'immunoassays', 'antibodies', 'the', 'NT', 'NT - proBNP']
# ['the', 'the presence', 'NT', 'NT - proBNP', 'proteolysis', 'physiological proteolysis', 'immunoassays', 'antibodies', 'the', 'NT', 'NT - proBNP', 'The', 'NT', 'NT - proBNP']
# ['HF', 'HF patients', 'NT', 'NT - proBNP']
# ['HF', 'HF patients', 'NT', 'NT - proBNP', 'the', 'NT', 'NT - proBNP']
# ['HF', 'HF patients', 'NT', 'NT - proBNP', 'the', 'NT', 'NT - proBNP', 'molecule', 'Immunodetection', 'the', 'the use', 'antibodies', 'the', 'the development', 'NT', 'NT - proBNP']
# ['QRS morphology', 'cardiac resynchronization therapy', 'Resynchronization', 'Resynchronization - Defibrillation']
# ['QRS morphology', 'cardiac resynchronization therapy', 'Resynchronization', 'Resynchronization - Defibrillation', 'Defibrillation', 'Resynchronization - Defibrillation']
# ['Resynchronization', 'Resynchronization - Defibrillation']
# ['Resynchronization', 'Resynchronization - Defibrillation', 'Defibrillation', 'Resynchronization - Defibrillation']
# ...
# ['Race', 'training', 'exercise training', 'heart', 'chronic heart', 'heart failure', 'chronic heart failure', 'Trial', 'TraiNing', 'Exercise TraiNing', 'HF', 'HF - ACTION']
# ['HF', 'HF - ACTION']
# ['embryonic', 'embryonic gene', 'heart', 'pathological heart', 'heart disease', 'pathological heart disease', 'transcription factors driving', 'miR-25', 'miR-25 expression', 'the', 'helix', 'helix - loop']
# ['embryonic', 'embryonic gene', 'heart', 'pathological heart', 'heart disease', 'pathological heart disease', 'transcription factors driving', 'miR-25', 'miR-25 expression', 'the', 'helix', 'helix - loop', 'loop', 'helix - loop']
# ['embryonic', 'embryonic gene', 'heart', 'pathological heart', 'heart disease', 'pathological heart disease', 'transcription factors driving', 'miR-25', 'miR-25 expression', 'the', 'helix', 'helix - loop', 'loop', 'helix - loop', 'loop - helix']
# ['embryonic', 'embryonic gene', 'heart', 'pathological heart', 'heart disease', 'pathological heart disease', 'transcription factors driving', 'miR-25', 'miR-25 expression', 'the', 'helix', 'helix - loop', 'loop', 'helix - loop', 'loop - helix', 'transcription factor', 'Hand2', 'mutant', 'mutant mice', 'Hand2', 'heart muscle cells', 'healthy heart muscle cells', 'gene', 'conditional gene', 'gene - targeted']
# ['embryonic', 'embryonic gene', 'heart', 'pathological heart', 'heart disease', 'pathological heart disease', 'transcription factors driving', 'miR-25', 'miR-25 expression', 'the', 'helix', 'helix - loop', 'loop', 'helix - loop', 'loop - helix', 'transcription factor', 'Hand2', 'mutant', 'mutant mice', 'Hand2', 'heart muscle cells', 'healthy heart muscle cells', 'gene', 'conditional gene', 'gene - targeted', 'Hand2', 'Hand2 mice', 'pressure', 'pressure - overload']
# ['embryonic', 'embryonic gene', 'heart', 'pathological heart', 'heart disease', 'pathological heart disease', 'transcription factors driving', 'miR-25', 'miR-25 expression', 'the', 'helix', 'helix - loop', 'loop', 'helix - loop', 'loop - helix', 'transcription factor', 'Hand2', 'mutant', 'mutant mice', 'Hand2', 'heart muscle cells', 'healthy heart muscle cells', 'gene', 'conditional gene', 'gene - targeted', 'Hand2', 'Hand2 mice', 'pressure', 'pressure - overload', 'overload', 'pressure - overload']
# ['embryonic', 'embryonic gene', 'heart', 'pathological heart', 'heart disease', 'pathological heart disease', 'transcription factors driving', 'miR-25', 'miR-25 expression', 'the', 'helix', 'helix - loop', 'loop', 'helix - loop', 'loop - helix', 'transcription factor', 'Hand2', 'mutant', 'mutant mice', 'Hand2', 'heart muscle cells', 'healthy heart muscle cells', 'gene', 'conditional gene', 'gene - targeted', 'Hand2', 'Hand2 mice', 'pressure', 'pressure - overload', 'overload', 'pressure - overload', 'overload - induced']
# ['heart failure', 'systolic heart failure', 'ejection fraction', 'ivabradine', 'SHIFT', 'the', 'Ivabradine', 'Ivabradine Trial', 'echocardiographic', 'echocardiographic substudy', 'arterial', 'arterial compliance', 'TAC', 'end', 'end - systolic']
# ['heart failure', 'systolic heart failure', 'ejection fraction', 'ivabradine', 'SHIFT', 'the', 'Ivabradine', 'Ivabradine Trial', 'echocardiographic', 'echocardiographic substudy', 'arterial', 'arterial compliance', 'TAC', 'end', 'end - systolic', 'Blood pressure', 'cuff', 'arm cuff', 'stroke volume', 'end', 'end - diastolic']
# ['heart failure', 'systolic heart failure', 'ejection fraction', 'ivabradine', 'SHIFT', 'the', 'Ivabradine', 'Ivabradine Trial', 'echocardiographic', 'echocardiographic substudy', 'arterial', 'arterial compliance', 'TAC', 'end', 'end - systolic', 'Blood pressure', 'cuff', 'arm cuff', 'stroke volume', 'end', 'end - diastolic', 'diastolic volume', 'end - diastolic volume']
# ['TAC', 'ivabradine-', 'ivabradine', 'ivabradine group', 'TAC', 'contractility', 'ventricular', 'ventricular - arterial']
# ['TAC', 'ivabradine-', 'ivabradine', 'ivabradine group', 'TAC', 'contractility', 'ventricular', 'ventricular - arterial', 'arterial coupling', 'ventricular - arterial coupling']
# ['TAC', 'ivabradine-', 'ivabradine', 'ivabradine group', 'TAC', 'contractility', 'ventricular', 'ventricular - arterial', 'arterial coupling', 'ventricular - arterial coupling', 'ivabradine', 'ivabradine - treated']
# ['HR reduction', 'TAC', 'Ees', 'unaltered', 'ventricular', 'ventricular - arterial']
# ['HR reduction', 'TAC', 'Ees', 'unaltered', 'ventricular', 'ventricular - arterial', 'arterial coupling', 'ventricular - arterial coupling']
# ['double', 'double - blind']
# ['dopamine', 'double', 'double - blind']
# ['the', 'the development', 'ischemic', 'ischemic events', 'cardiomyopathy', 'ischemic cardiomyopathy', 'cardiac', 'cardiac resynchronization', 'defibrillator', 'CRT', 'CRT - D']
# ['the', 'the development', 'ischemic', 'ischemic events', 'cardiomyopathy', 'ischemic cardiomyopathy', 'cardiac', 'cardiac resynchronization', 'defibrillator', 'CRT', 'CRT - D', 'the', 'the efficacy', 'the device', 'The', 'enrolled', 'the', 'the Multicenter', 'Trial', 'Implantation Trial', 'Trial - Cardiac']
# ['the', 'the development', 'ischemic', 'ischemic events', 'cardiomyopathy', 'ischemic cardiomyopathy', 'cardiac', 'cardiac resynchronization', 'defibrillator', 'CRT', 'CRT - D', 'the', 'the efficacy', 'the device', 'The', 'enrolled', 'the', 'the Multicenter', 'Trial', 'Implantation Trial', 'Trial - Cardiac', 'Cardiac', 'Cardiac Resynchronization', 'Trial - Cardiac']
# ['the', 'the development', 'ischemic', 'ischemic events', 'cardiomyopathy', 'ischemic cardiomyopathy', 'cardiac', 'cardiac resynchronization', 'defibrillator', 'CRT', 'CRT - D', 'the', 'the efficacy', 'the device', 'The', 'enrolled', 'the', 'the Multicenter', 'Trial', 'Implantation Trial', 'Trial - Cardiac', 'Cardiac', 'Cardiac Resynchronization', 'Trial - Cardiac', 'Cox', 'the', 'the development', 'coronary', 'acute coronary', 'coronary syndromes', 'acute coronary syndromes', 'coronary', 'coronary interventions', 'the', 'the trial', 'heart failure', 'subsequent heart failure', 'HF', 'CRT', 'CRT - D']
# ['the', 'the development', 'ischemic', 'ischemic events', 'cardiomyopathy', 'ischemic cardiomyopathy', 'cardiac', 'cardiac resynchronization', 'defibrillator', 'CRT', 'CRT - D', 'the', 'the efficacy', 'the device', 'The', 'enrolled', 'the', 'the Multicenter', 'Trial', 'Implantation Trial', 'Trial - Cardiac', 'Cardiac', 'Cardiac Resynchronization', 'Trial - Cardiac', 'Cox', 'the', 'the development', 'coronary', 'acute coronary', 'coronary syndromes', 'acute coronary syndromes', 'coronary', 'coronary interventions', 'the', 'the trial', 'heart failure', 'subsequent heart failure', 'HF', 'CRT', 'CRT - D', 'the', 'the development', 'revascularization', 'previous revascularization', 'artery', 'coronary artery', 'artery bypass', 'artery bypass surgery', 'coronary', 'percutaneous coronary', 'coronary intervention', 'percutaneous coronary intervention', 'blood pressure', 'systolic blood pressure', 'branch', 'bundle branch', 'branch block', 'branch block pattern', 'electrocardiogram', 'baseline electrocardiogram', 'defibrillator', 'defibrillator - only']
# ['the', 'the development', 'ischemic', 'ischemic events', 'cardiomyopathy', 'ischemic cardiomyopathy', 'cardiac', 'cardiac resynchronization', 'defibrillator', 'CRT', 'CRT - D', 'the', 'the efficacy', 'the device', 'The', 'enrolled', 'the', 'the Multicenter', 'Trial', 'Implantation Trial', 'Trial - Cardiac', 'Cardiac', 'Cardiac Resynchronization', 'Trial - Cardiac', 'Cox', 'the', 'the development', 'coronary', 'acute coronary', 'coronary syndromes', 'acute coronary syndromes', 'coronary', 'coronary interventions', 'the', 'the trial', 'heart failure', 'subsequent heart failure', 'HF', 'CRT', 'CRT - D', 'the', 'the development', 'revascularization', 'previous revascularization', 'artery', 'coronary artery', 'artery bypass', 'artery bypass surgery', 'coronary', 'percutaneous coronary', 'coronary intervention', 'percutaneous coronary intervention', 'blood pressure', 'systolic blood pressure', 'branch', 'bundle branch', 'branch block', 'branch block pattern', 'electrocardiogram', 'baseline electrocardiogram', 'defibrillator', 'defibrillator - only', 'the', 'the development', 'CRT', 'CRT - D']
# ['the', 'the development', 'ischemic', 'ischemic events', 'cardiomyopathy', 'ischemic cardiomyopathy', 'cardiac', 'cardiac resynchronization', 'defibrillator', 'CRT', 'CRT - D', 'the', 'the efficacy', 'the device', 'The', 'enrolled', 'the', 'the Multicenter', 'Trial', 'Implantation Trial', 'Trial - Cardiac', 'Cardiac', 'Cardiac Resynchronization', 'Trial - Cardiac', 'Cox', 'the', 'the development', 'coronary', 'acute coronary', 'coronary syndromes', 'acute coronary syndromes', 'coronary', 'coronary interventions', 'the', 'the trial', 'heart failure', 'subsequent heart failure', 'HF', 'CRT', 'CRT - D', 'the', 'the development', 'revascularization', 'previous revascularization', 'artery', 'coronary artery', 'artery bypass', 'artery bypass surgery', 'coronary', 'percutaneous coronary', 'coronary intervention', 'percutaneous coronary intervention', 'blood pressure', 'systolic blood pressure', 'branch', 'bundle branch', 'branch block', 'branch block pattern', 'electrocardiogram', 'baseline electrocardiogram', 'defibrillator', 'defibrillator - only', 'the', 'the development', 'CRT', 'CRT - D', 'heart failure', 'subsequent heart failure', 'CRT', 'CRT - D']
# ['ejection', 'ejection fraction', 'natriuretic peptide', 'natriuretic peptide levels', 'heart', 'heart failure', 'Heart', 'Heart Failure', 'Heart Failure Registry', 'Guideline - Heart']
# ['Heart', 'Heart Failure', 'Guidelines - Heart']
# ['soluble', 'heart failure', 'blocker', 'β - blocker']
# ['BB therapy', 'dose', 'dose - related']
# ['defibrillator deactivation', 'defibrillator deactivation discussions', 'cardioverter - defibrillator deactivation']
# ['cardioverter', 'implantable cardioverter', 'cardioverter - defibrillator']
# ['cardioverter', 'implantable cardioverter', 'cardioverter - defibrillator', 'defibrillator', 'defibrillator deactivation', 'defibrillator deactivation discussions', 'cardioverter - defibrillator']
# ['cardioverter', 'implantable cardioverter', 'cardioverter - defibrillator', 'defibrillator', 'defibrillator deactivation', 'defibrillator deactivation discussions', 'cardioverter - defibrillator', 'heart failure', 'heart failure patients', 'the', 'the', 'the timing', 'cardioverter', 'implantable cardioverter', 'cardioverter - defibrillator']
# ['cardioverter', 'implantable cardioverter', 'cardioverter - defibrillator', 'defibrillator', 'defibrillator deactivation', 'defibrillator deactivation discussions', 'cardioverter - defibrillator', 'heart failure', 'heart failure patients', 'the', 'the', 'the timing', 'cardioverter', 'implantable cardioverter', 'cardioverter - defibrillator', 'defibrillator', 'defibrillator deactivation', 'defibrillator deactivation discussions', 'cardioverter - defibrillator']
# ['defibrillator deactivation', 'defibrillator deactivation discussions', 'cardioverter - defibrillator deactivation']
# ['Grounded theory', 'heart failure', 'heart failure patients', 'defibrillator', 'cardioverter - defibrillator']
# ['defibrillator', 'cardioverter - defibrillator']
# ['The', 'cardioverter', 'implantable cardioverter', 'cardioverter - defibrillator']
# ['The', 'cardioverter', 'implantable cardioverter', 'cardioverter - defibrillator', 'defibrillator', 'defibrillator deactivation', 'cardioverter - defibrillator']
# ['The', 'cardioverter', 'implantable cardioverter', 'cardioverter - defibrillator', 'defibrillator', 'defibrillator deactivation', 'cardioverter - defibrillator', 'implantation', 'cardioverter', 'implantable cardioverter', 'cardioverter - defibrillator']
# ['The', 'cardioverter', 'implantable cardioverter', 'cardioverter - defibrillator', 'defibrillator', 'defibrillator deactivation', 'cardioverter - defibrillator', 'implantation', 'cardioverter', 'implantable cardioverter', 'cardioverter - defibrillator', 'defibrillator', 'defibrillator deactivation', 'cardioverter - defibrillator']
# ['The', 'the', 'cardioverter', 'implantable cardioverter', 'cardioverter - defibrillator']
# ['The', 'the', 'cardioverter', 'implantable cardioverter', 'cardioverter - defibrillator', 'defibrillator', 'defibrillator deactivation', 'cardioverter - defibrillator']
# ['The', 'the', 'cardioverter', 'implantable cardioverter', 'cardioverter - defibrillator', 'defibrillator', 'defibrillator deactivation', 'cardioverter - defibrillator', 'implant', 'cardioverter', 'implantable cardioverter', 'cardioverter - defibrillator']
# ['The', 'the', 'cardioverter', 'implantable cardioverter', 'cardioverter - defibrillator', 'defibrillator', 'defibrillator deactivation', 'cardioverter - defibrillator', 'implant', 'cardioverter', 'implantable cardioverter', 'cardioverter - defibrillator', 'defibrillator', 'defibrillator deactivation', 'defibrillator deactivation preferences', 'cardioverter - defibrillator']
# ['The', 'the', 'cardioverter', 'implantable cardioverter', 'cardioverter - defibrillator', 'defibrillator', 'defibrillator deactivation', 'cardioverter - defibrillator', 'implant', 'cardioverter', 'implantable cardioverter', 'cardioverter - defibrillator', 'defibrillator', 'defibrillator deactivation', 'defibrillator deactivation preferences', 'cardioverter - defibrillator', 'the', 'the number', 'cardioverter', 'implantable cardioverter', 'distressing implantable cardioverter', 'cardioverter - defibrillator']
# ['Medicare', 'Medicare data', 'cohort', 'acute care', 'acute care hospital', 'HF', 'AMI', 'PNA', '30-day', 'risk', 'risk - adjusted']
# ['sphingosine-1-phosphate receptor', 'G', 'G - protein']
# ['sphingosine-1-phosphate receptor', 'G', 'G - protein', 'heart', 'cyclase', 'G', 'G - protein']
# ['sphingosine-1-phosphate receptor', 'G', 'G - protein', 'heart', 'cyclase', 'G', 'G - protein', 'G', 'G - protein']
# ['sphingosine-1-phosphate receptor', 'G', 'G - protein', 'heart', 'cyclase', 'G', 'G - protein', 'G', 'G - protein', 'kinase-2', 'cAMP production', 'regulatory', 'regulatory involvement', 'G', 'G - protein']
# ['kidney', 'embryonic kidney', 'human embryonic kidney', 'sphingosine-1-phosphate', 'agonist', 'isoproterenol', 'agonist', 'G', 'G - protein']
# ['kidney', 'embryonic kidney', 'human embryonic kidney', 'sphingosine-1-phosphate', 'agonist', 'isoproterenol', 'agonist', 'G', 'G - protein', 'hearts', 'mouse hearts', 'adrenergic receptor stimulation', 'β - adrenergic receptor stimulation']
# ['heart failure', 'Human heart failure', 'translational state', 'post - translational state']
# ['Adrenergic receptor', 'Adrenergic receptor blockade', 'β - Adrenergic receptor']
# ['Adrenergic receptor', 'Adrenergic receptor blockade', 'β - Adrenergic receptor', 'heart failure', 'cAMP', 'cAMP - dependent']
# ['Adrenergic receptor', 'Adrenergic receptor blockade', 'β - Adrenergic receptor', 'heart failure', 'cAMP', 'cAMP - dependent', 'kinase', 'protein kinase', 'adrenergic', 'β - adrenergic']
# ['Adrenergic receptor', 'Adrenergic receptor blockade', 'β - Adrenergic receptor', 'heart failure', 'cAMP', 'cAMP - dependent', 'kinase', 'protein kinase', 'adrenergic', 'β - adrenergic', 'the', 'the state', 'protein', 'binding protein', 'protein - C']
# ['Adrenergic receptor', 'Adrenergic receptor blockade', 'β - Adrenergic receptor', 'heart failure', 'cAMP', 'cAMP - dependent', 'kinase', 'protein kinase', 'adrenergic', 'β - adrenergic', 'the', 'the state', 'protein', 'binding protein', 'protein - C', 'troponin', 'catalytic', 'Thr197', 'phosphorylation', 'the', 'the expression', 'vivo', 'vivo phosphorylation', 'Western', 'Western blots', 'monoclonal', 'monoclonal antibodies', 'cAMP', 'cAMP binding', '8-fluo - cAMP']

# %%
print(evaluation_metrics(preds, gt))
stop_words = set(stopwords.words('english'))
pred_terms =  set(preds) - set(stop_words)
pred_terms = [x for x in pred_terms if len(x)>1]
pred_terms = [x.strip() for x in pred_terms]
pred_terms = [re.sub(' -','-', x) for x in pred_terms]
pred_terms = [re.sub('- ','-', x) for x in pred_terms]
pred_terms = [re.sub(' \(','', x) for x in pred_terms]
evaluation_metrics(pred_terms, gt)
# Out:
# Prediction:  3708
# GT:  2361
# 1036 2672 1325
# (27.94, 43.88, 34.14)
# Prediction:  3690
# GT:  2361
# 1089 2601 1272
# (29.51, 46.12, 35.99)

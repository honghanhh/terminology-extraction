# %%
import pandas as pd
import pickle as pkl
import re
from collections import Counter
import nltk
nltk.download('stopwords')
from nltk.corpus import stopwords 

import stanza
# stanza.download('en')
nlp = stanza.Pipeline(lang='en', processors='tokenize,mwt,pos,lemma')
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     /Users/hanhtran/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# 2021-05-17 17:22:32 WARNING: Can not find mwt: default from official model list. Ignoring it.
# 2021-05-17 17:22:32 INFO: Loading these models for language: en (English):
# ========================
# | Processor | Package  |
# ------------------------
# | tokenize  | combined |
# | pos       | combined |
# | lemma     | combined |
# ========================
#
# 2021-05-17 17:22:32 INFO: Use device: cpu
# 2021-05-17 17:22:32 INFO: Loading: tokenize
# 2021-05-17 17:22:32 INFO: Loading: pos
# 2021-05-17 17:22:33 INFO: Loading: lemma
# 2021-05-17 17:22:33 INFO: Done loading processors!

# %%
def count_freq(preds, gts):
    preds_len = [len(x.split(' ')) for x in preds]
    gts_len = [len(x.split(' ')) for x in gts]
    print(Counter(preds_len))
    print(Counter(gts_len))

def evaluation_metrics(pred, gt):
    print("Prediction: ", len(set(pred)))
    print("GT: ",len(set(gt)))
    TP = len(set(pred) & set(gt)) 
    FP = len(set(pred)-set(gt))
    FN = len(set(gt)-set(pred))
    print(TP,FP,FN)
    precision = round((TP/(TP+FP))*100, 2)
    recall = round((TP/(TP+FN))*100,2)
    f1_score = round((2 * precision * recall) / (precision + recall),2)
    return precision, recall, f1_score 

def lemma(li):
    new_list = []
    for t in li:
        doc = nlp(str(t))
        doc1 = ' '.join([word.lemma for sent in doc.sentences for word in sent.words])
        doc1 = re.sub('-',' ',doc1)
        doc1 = re.sub(' +', ' ',doc1)
        new_list.append(doc1)
    new_list = [s for s in new_list if len(s) >= 2]
    return new_list

def get_term(predictions):
    all_term = []
    for sentence in predictions:
        tokens = []
        labels = []
        for d in sentence:
            tokens.extend(d.keys())
            labels.extend(d.values())

        for i, label in enumerate(labels):
            if labels[i] == 'I' and (i == 0 or labels[i - 1] == 'O'):
                labels[i] = 'O'

        terms = []
        term = []
        for i, (token, label) in enumerate(zip(tokens, labels)):
            if label == 'B': 
                #Lưu vị trí B
                b_pos = i
                term = [token]
            elif label == 'I':
                term.append(token)
            elif len(term) > 0:
                terms.append(' '.join(term))
                # Check b_pos = 0 không
                if b_pos != 0:
                    if (tokens[b_pos - 1] != '') and (tokens[b_pos - 1] != ' '):
                        if len(nlp(str(tokens[b_pos - 1])).sentences) > 0:
                            b_word = nlp(str(tokens[b_pos - 1])).sentences[0].words[0]
                            if len(nlp(str(tokens[b_pos])).sentences) > 0:
                                c_word = nlp(str(tokens[b_pos])).sentences[0].words[0]
                                if (c_word.upos == 'NOUN') and (c_word.text != 'None') and (b_word.text != 'None') and ((b_word.upos == 'NOUN') or (b_word.upos == 'ADJ')):
                                    terms.append(' '.join([b_word.text] + term))
                    if (tokens[i] != '') and (tokens[i] != ' '):
                        if len(nlp(str(tokens[i])).sentences) > 0:
                            a_word = nlp(str(tokens[i])).sentences[0].words[0]
                            if (a_word.text != 'None') and (a_word.upos == 'NOUN'):
                                terms.append(' '.join(term + [a_word.text]))
                    
                    #ADJ NOUN NOUN
                    if (tokens[i] != '') and (tokens[i] != ' ') and (tokens[b_pos - 1] != '') and (tokens[b_pos - 1] != ' '):
                        if len(nlp(str(tokens[b_pos - 1])).sentences) > 0 and len(nlp(str(tokens[i])).sentences) > 0:
                            a_word = nlp(str(tokens[i])).sentences[0].words[0]
                            b_word = nlp(str(tokens[b_pos - 1])).sentences[0].words[0]
                            if len(nlp(str(tokens[b_pos])).sentences) > 0:
                                c_word = nlp(str(tokens[b_pos])).sentences[0].words[0]
                                # Check vị trí b_pos - 1: terms.append()
                                if (c_word.text != 'None') and (c_word.upos == 'NOUN') and (b_word.text != 'None') and ((b_word.upos == 'ADJ') and (a_word.upos == 'NOUN')):
                                    terms.append(' '.join([b_word.text] + term + [a_word.text]))
#                                     print(terms)
                    #ADJ ADJ NOUN              
                    if (tokens[b_pos - 2] != '') and (tokens[b_pos - 2] != ' ') and (tokens[b_pos - 1] != '') and (tokens[b_pos - 1] != ' '):
                        if (len(nlp(str(tokens[b_pos - 2])).sentences) > 0 and len(nlp(str(tokens[b_pos - 1])).sentences) > 0 and len(nlp(str(tokens[b_pos])).sentences) > 0):
                            b1_word = nlp(str(tokens[b_pos - 2])).sentences[0].words[0] 
                            b_word = nlp(str(tokens[b_pos - 1])).sentences[0].words[0]
                            c_word = nlp(str(tokens[b_pos])).sentences[0].words[0]
                            # Check vị trí b_pos - 1: terms.append()
                            if (c_word.upos == 'NOUN') and (c_word.text != 'None') and (b_word.text != 'None') and (b1_word.text != 'None') and ((b_word.upos == 'ADJ') and (b1_word.upos == 'ADJ')):
                                terms.append(' '.join([b1_word.text] +[b_word.text] + term))
#                                 print(terms)
                    #NOUN ADJ NOUN
                    if (tokens[b_pos - 2] != '') and (tokens[b_pos - 2] != ' ') and (tokens[b_pos - 1] != '') and (tokens[b_pos - 1] != ' '):
                        if (len(nlp(str(tokens[b_pos - 2])).sentences) > 0 and len(nlp(str(tokens[b_pos - 1])).sentences) > 0 and len(nlp(str(tokens[b_pos])).sentences) > 0):
                            b1_word = nlp(str(tokens[b_pos - 2])).sentences[0].words[0] 
                            b_word = nlp(str(tokens[b_pos - 1])).sentences[0].words[0]
                            c_word = nlp(str(tokens[b_pos])).sentences[0].words[0]
                            # Check vị trí b_pos - 1: terms.append()
                            if (c_word.upos == 'NOUN') and (c_word.text != 'None') and (b_word.text != 'None') and (b1_word.text != 'None') and ((b_word.upos == 'ADJ') and (b1_word.upos == 'NOUN')):
                                terms.append(' '.join([b1_word.text] +[b_word.text] + term))
#                                 print(terms)
                                
                # NOUN NOUN NOUN
                if b_pos != 0 and i + 1 < len(tokens):
                    if (tokens[i] != '') and (tokens[i] != ' ') and (tokens[i+1] != '') and (tokens[i+1] != ' '):
                        if (len(nlp(str(tokens[i])).sentences) > 0 and len(nlp(str(tokens[i+1])).sentences) > 0 and len(nlp(str(tokens[b_pos])).sentences) > 0):
                            a1_word = nlp(str(tokens[i+1])).sentences[0].words[0] 
                            a_word = nlp(str(tokens[i])).sentences[0].words[0]
                            c_word = nlp(str(tokens[b_pos])).sentences[0].words[0]
                            if (c_word.text != 'None') and (c_word.upos == 'NOUN') and (a_word.text != 'None') and (a1_word.text != 'None') and ((a_word.upos == 'NOUN') and (a1_word.upos == 'NOUN')):
                                terms.append(' '.join( term + [a_word.text] +[a1_word.text]))
#                                 print(terms)
                if b_pos != 0:
                    # RULE 1
#                     if (tokens[i] != '') and (tokens[i] != ' ') and (tokens[b_pos - 1] != '') and (tokens[b_pos - 1] != ' '):
#                         if len(nlp(str(tokens[b_pos - 1])).sentences) > 0 and len(nlp(str(tokens[i])).sentences) > 0:
#                             b_word = nlp(str(tokens[b_pos - 1])).sentences[0].words[0]
#                             a_word = nlp(str(tokens[i])).sentences[0].words[0]
#                             if  (b_word.text != 'None') and (a_word.text != 'None') and tokens[b_pos] == '-':
#                                 terms.append(' '.join([b_word.text] + term + [a_word.text]))
#                                 print(terms)
                    # RULE 2
                    if (tokens[b_pos-2] != '') and (tokens[b_pos -2] != ' ') and (tokens[b_pos - 1] != '') and (tokens[b_pos - 1] != ' '):
                        if len(nlp(str(tokens[b_pos - 1])).sentences) > 0 and len(nlp(str(tokens[b_pos-2])).sentences) > 0:
                            b_word = nlp(str(tokens[b_pos - 1])).sentences[0].words[0]
                            b1_word = nlp(str(tokens[b_pos - 2])).sentences[0].words[0]
                            # Check vị trí b_pos - 1: terms.append()
                            if  (b_word.text == '-') and (b1_word.text != 'None'):
                                terms.append(' '.join([b1_word.text] + [b_word.text] + term))
                                print(terms)
#                 if b_pos != 0 and i + 1 < len(tokens):
#                 # RULE 3
#                     if (tokens[i] != '') and (tokens[i] != ' ') and (tokens[i+1] != '') and (tokens[i+1] != ' '):
#                         if len(nlp(str(tokens[i])).sentences) > 0 and len(nlp(str(tokens[i+1])).sentences) > 0:
#                             a_word = nlp(str(tokens[i])).sentences[0].words[0]
#                             a1_word = nlp(str(tokens[i+1])).sentences[0].words[0]
#                             if  (a_word.text == '-') and (a1_word.text != 'None'):
#                                 terms.append(' '.join(term + [a_word.text] + [a1_word.text]))
#                                 print(terms)
                    
                term = []
        if len(term) > 0:
            terms.append(' '.join(term))
            # check b_pos - 1
        all_term.append(terms)
    
    final_terms = []
    for i in all_term:
        final_terms.extend(i)

    final_terms = [x.lower() for x in final_terms]
    return final_terms    

def get_term_(predictions):
    all_term = []
    for sentence in predictions:
        tokens = []
        labels = []
        for d in sentence:
            tokens.extend(d.keys())
            labels.extend(d.values())

        for i, label in enumerate(labels):
            if labels[i] == 'I' and (i == 0 or labels[i - 1] == 'O'):
                labels[i] = 'O'

        terms = []
        term = []
        for token, label in zip(tokens, labels):
            if label == 'B':
                term = [token]
            elif label == 'I':
                term.append(token)
            elif len(term) > 0:
                terms.append(' '.join(term))
                term = []
        if len(term) > 0:
            terms.append(' '.join(term))
        all_term.append(terms)
    
    final_terms = []
    for i in all_term:
        final_terms.extend(i)

    final_terms = [x.lower() for x in final_terms]
    return final_terms

# %%
groundtruth = pd.read_csv('/Users/hanhtran/Documents/terminology-extraction/ACTER/en/htfl/annotations/htfl_en_terms.ann', sep='	', engine='python',header=None)
gt = list(groundtruth[0]) 

# pkl_file = open('final_preds_sklearn.pkl', 'rb')
pkl_file = open('../weighted_results/ann_weighted_roberta.pkl', 'rb')
predictions = pkl.load(pkl_file)

# %%
predictions
# Out:
# [[{'Exercise': 'B'},
#   {'training': 'B'},
#   {'in': 'O'},
#   {'patients': 'O'},
#   {'with': 'O'},
#   {'chronic': 'O'},
#   {'heart': 'B'},
#   {'failure': 'I'},
#   {'promotes': 'O'},
#   {'restoration': 'O'},
#   {'of': 'O'},
#   {' ': 'O'},
#   {'high': 'O'},
#   {'-': 'O'},
#   {'density': 'I'},
#   {'lipoprotein': 'B'},
#   {'functional': 'O'},
#   {'properties': 'O'},
#   {'.': 'O'}],
#  [{'RATIONALE': 'B'}, {':': 'O'}],
#  [{'High': 'O'},
#   {'-': 'O'},
#   {'density': 'I'},
#   {'lipoprotein': 'B'},
#   {'(': 'O'},
#   {'HDL': 'B'},
#   {')': 'O'},
#   {'exerts': 'O'},
#   {'endothelial': 'B'},
#   {'-': 'O'},
#   {'protective': 'O'},
#   {'effects': 'I'},
#   {'via': 'O'},
#   {'stimulation': 'I'},
#   {'of': 'O'},
#   {'endothelial': 'O'},
#   {'cell': 'I'},
#   {'(': 'O'},
#   {'EC': 'O'},
#   {')': 'O'},
#   {'nitric': 'B'},
#   {'oxide': 'B'},
#   {'(': 'O'},
#   {'NO': 'O'},
#   {')': 'O'},
#   {'production': 'I'},
#   {'.': 'O'},
#   {'This': 'O'},
#   {'function': 'O'},
#   {'is': 'O'},
#   {'impaired': 'O'},
#   {'in': 'O'},
#   {'patients': 'O'},
#   {'with': 'O'},
#   {'cardiovascular': 'B'},
#   {'disease': 'O'},
#   {'.': 'O'},
#   {'Protective': 'O'},
#   {'effects': 'O'},
#   {'of': 'O'},
#   {'exercise': 'B'},
#   {'training': 'B'},
#   {'(': 'O'},
#   {'ET': 'O'},
#   {')': 'O'},
#   {'on': 'O'},
#   {'endothelial': 'B'},
#   {'function': 'O'},
#   {'have': 'O'},
#   {'been': 'O'},
#   {'demonstrated': 'O'},
#   {'.': 'O'}],
#  [{'OBJECTIVE': 'B'}, {':': 'O'}],
#  [{'This': 'O'},
#   {'study': 'O'},
#   {'was': 'O'},
#   {'performed': 'O'},
#   {'to': 'O'},
#   {'evaluate': 'O'},
#   {'the': 'B'},
#   {'impact': 'O'},
#   {'of': 'O'},
#   {'ET': 'O'},
#   {'on': 'O'},
#   {'HDL': 'B'},
#   {'-': 'O'},
#   {'mediated': 'O'},
#   {'protective': 'O'},
#   {'effects': 'I'},
#   {'and': 'O'},
#   {'the': 'B'},
#   {'respective': 'O'},
#   {'molecular': 'B'},
#   {'pathways': 'I'},
#   {'in': 'O'},
#   {'patients': 'O'},
#   {'with': 'O'},
#   {'chronic': 'O'},
#   {'heart': 'B'},
#   {'failure': 'I'},
#   {'(': 'O'},
#   {'CHF': 'B'},
#   {')': 'O'},
#   {'.': 'O'}],
#  [{'METHODS': 'O'}, {'AND': 'O'}, {'RESULTS': 'O'}, {':': 'O'}],
#  [{'HDL': 'B'},
#   {'was': 'O'},
#   {'isolated': 'O'},
#   {'from': 'O'},
#   {'16': 'O'},
#   {'healthy': 'O'},
#   {'controls': 'I'},
#   {'(': 'O'},
#   {'HDL(healthy': 'O'},
#   {')': 'O'},
#   {')': 'O'},
#   {'and': 'O'},
#   {'16': 'O'},
#   {'patients': 'O'},
#   {'with': 'O'},
#   {'CHF': 'O'},
#   {'-': 'O'},
#   {'NYHA': 'O'},
#   {'-': 'O'},
#   {'III': 'O'},
#   {'(': 'O'},
#   {'HDL(NYHA': 'O'},
#   {'-': 'O'},
#   {'IIIb': 'O'},
#   {')': 'O'},
#   {')': 'O'},
#   {'before': 'O'},
#   {'and': 'O'},
#   {'after': 'O'},
#   {'ET': 'O'},
#   {',': 'O'},
#   {'as': 'O'},
#   {'well': 'O'},
#   {'as': 'O'},
#   {'from': 'O'},
#   {'8': 'O'},
#   {'patients': 'O'},
#   {'with': 'O'},
#   {'CHF': 'O'},
#   {'-': 'O'},
#   {'NYHA': 'O'},
#   {'-': 'O'},
#   {'II': 'O'},
#   {'(': 'O'},
#   {'HDL(NYHA': 'O'},
#   {'-': 'O'},
#   {'II': 'O'},
#   {')': 'O'},
#   {')': 'O'},
#   {'.': 'O'},
#   {'ECs': 'O'},
#   {'were': 'O'},
#   {'incubated': 'O'},
#   {'with': 'O'},
#   {'HDL': 'O'},
#   {',': 'O'},
#   {'and': 'O'},
#   {'phosphorylation': 'O'},
#   {'of': 'O'},
#   {'eNOS': 'O'},
#   {'-': 'O'},
#   {'Ser(1177': 'O'},
#   {')': 'O'},
#   {',': 'O'},
#   {'eNOS': 'O'},
#   {'-': 'O'},
#   {'Thr(495': 'B'},
#   {')': 'O'},
#   {',': 'O'},
#   {'PKC': 'O'},
#   {'-': 'O'},
#   {'βII': 'O'},
#   {'-': 'O'},
#   {'Ser(660': 'O'},
#   {')': 'O'},
#   {',': 'O'},
#   {'and': 'O'},
#   {'p70S6K': 'O'},
#   {'-': 'O'},
#   {'Ser(411': 'O'},
#   {')': 'O'},
#   {'was': 'O'},
#   {'evaluated': 'O'},
#   {'.': 'O'},
#   {'HDL': 'B'},
#   {'-': 'O'},
#   {'bound': 'B'},
#   {'malondialdehyde': 'B'},
#   {'and': 'O'},
#   {'HDL': 'O'},
#   {'-': 'O'},
#   {'induced': 'O'},
#   {'NO': 'O'},
#   {'production': 'I'},
#   {'by': 'O'},
#   {'EC': 'O'},
#   {'were': 'O'},
#   {'quantified': 'O'},
#   {'.': 'O'},
#   {'Endothelial': 'B'},
#   {'function': 'I'},
#   {'was': 'O'},
#   {'assessed': 'O'},
#   {'by': 'O'},
#   {'flow': 'B'},
#   {'-': 'O'},
#   {'mediated': 'O'},
#   {'dilatation': 'O'},
#   {'.': 'O'},
#   {'The': 'B'},
#   {'proteome': 'B'},
#   {'of': 'O'},
#   {'HDL': 'O'},
#   {'particles': 'O'},
#   {'was': 'O'},
#   {'profiled': 'O'},
#   {'by': 'O'},
#   {'shotgun': 'B'},
#   {'LC': 'B'},
#   {'-': 'O'},
#   {'MS': 'O'},
#   {'/': 'O'},
#   {'MS': 'O'},
#   {'.': 'O'},
#   {'Incubation': 'O'},
#   {'of': 'O'},
#   {'EC': 'O'},
#   {'with': 'O'},
#   {'HDL(NYHA': 'O'},
#   {'-': 'O'},
#   {'IIIb': 'O'},
#   {')': 'O'},
#   {'triggered': 'O'},
#   {'a': 'O'},
#   {'lower': 'O'},
#   {'stimulation': 'I'},
#   {'of': 'O'},
#   {'phosphorylation': 'O'},
#   {'at': 'O'},
#   {'eNOS': 'O'},
#   {'-': 'O'},
#   {'Ser(1177': 'O'},
#   {')': 'O'},
#   {'and': 'O'},
#   {'a': 'O'},
#   {'higher': 'O'},
#   {'phosphorylation': 'O'},
#   {'at': 'O'},
#   {'eNOS': 'O'},
#   {'-': 'O'},
#   {'Thr(495': 'B'},
#   {')': 'O'},
#   {'when': 'O'},
#   {'compared': 'O'},
#   {'with': 'O'},
#   {'HDL(healthy': 'O'},
#   {')': 'O'},
#   {'.': 'O'},
#   {'This': 'O'},
#   {'was': 'O'},
#   {'associated': 'O'},
#   {'with': 'O'},
#   {'lower': 'O'},
#   {'NO': 'O'},
#   {'production': 'I'},
#   {'of': 'O'},
#   {'EC': 'O'},
#   {'.': 'O'},
#   {'In': 'O'},
#   {'addition': 'O'},
#   {',': 'O'},
#   {'an': 'O'},
#   {'elevated': 'B'},
#   {'activation': 'I'},
#   {'of': 'O'},
#   {'p70S6': 'O'},
#   {'K': 'O'},
#   {',': 'O'},
#   {'PKC': 'O'},
#   {'-': 'O'},
#   {'βII': 'O'},
#   {'by': 'O'},
#   {'HDL(NYHA': 'O'},
#   {'-': 'O'},
#   {'IIIb': 'O'},
#   {')': 'O'},
#   {',': 'O'},
#   {'and': 'O'},
#   {'a': 'O'},
#   {'higher': 'O'},
#   {'amount': 'O'},
#   {'of': 'O'},
#   {'malondialdehyde': 'B'},
#   {'bound': 'O'},
#   {'to': 'O'},
#   {'HDL(NYHA': 'O'},
#   {'-': 'O'},
#   {'IIIb': 'O'},
#   {')': 'O'},
#   {'compared': 'O'},
#   {'with': 'O'},
#   {'HDL(healthy': 'O'},
#   {')': 'O'},
#   {'was': 'O'},
#   {'measured': 'O'},
#   {'.': 'O'},
#   {'In': 'O'},
#   {'healthy': 'O'},
#   {'individuals': 'O'},
#   {',': 'O'},
#   {'ET': 'O'},
#   {'had': 'O'},
#   {'no': 'O'},
#   {'effect': 'I'},
#   {'on': 'O'},
#   {'HDL': 'O'},
#   {'function': 'O'},
#   {',': 'O'},
#   {'whereas': 'O'},
#   {'ET': 'O'},
#   {'of': 'O'},
#   {'CHF': 'O'},
#   {'-': 'O'},
#   {'NYHA': 'O'},
#   {'-': 'O'},
#   {'IIIb': 'O'},
#   {'significantly': 'O'},
#   {'improved': 'O'},
#   {'HDL': 'O'},
#   {'function': 'O'},
#   {'.': 'O'},
#   {'A': 'O'},
#   {'correlation': 'O'},
#   {'between': 'O'},
#   {'changes': 'O'},
#   {'in': 'O'},
#   {'HDL': 'O'},
#   {'-': 'O'},
#   {'induced': 'O'},
#   {'NO': 'O'},
#   {'production': 'I'},
#   {'and': 'O'},
#   {'flow': 'B'},
#   {'-': 'O'},
#   {'mediated': 'O'},
#   {'dilatation': 'O'},
#   {'improvement': 'O'},
#   {'by': 'O'},
#   {'ET': 'O'},
#   {'was': 'O'},
#   {'evident': 'O'},
#   {'.': 'O'}],
#  [{'CONCLUSIONS': 'O'}, {':': 'O'}],
#  [{'These': 'O'},
#   {'results': 'O'},
#   {'demonstrate': 'O'},
#   {'that': 'O'},
#   {'HDL': 'B'},
#   {'function': 'I'},
#   {'is': 'O'},
#   {'impaired': 'O'},
#   {'in': 'O'},
#   {'CHF': 'B'},
#   {'and': 'O'},
#   {'that': 'O'},
#   {'ET': 'O'},
#   {'improved': 'O'},
#   {'the': 'B'},
#   {'HDL': 'B'},
#   {'-': 'O'},
#   {'mediated': 'O'},
#   {'vascular': 'B'},
#   {'effects': 'I'},
#   {'.': 'O'},
#   {'This': 'O'},
#   {'may': 'O'},
#   {'be': 'O'},
#   {'one': 'O'},
#   {'mechanism': 'I'},
#   {'how': 'O'},
#   {'ET': 'O'},
#   {'exerts': 'O'},
#   {'beneficial': 'O'},
#   {'effects': 'I'},
#   {'in': 'O'},
#   {'CHF': 'O'},
#   {'.': 'O'}],
#  [{'Relationships': 'O'},
#   {'between': 'O'},
#   {'right': 'B'},
#   {'ventricular': 'B'},
#   {'function': 'I'},
#   {',': 'O'},
#   {'body': 'O'},
#   {'composition': 'O'},
#   {',': 'O'},
#   {'and': 'O'},
#   {'prognosis': 'I'},
#   {'in': 'O'},
#   {'advanced': 'O'},
#   {'heart': 'B'},
#   {'failure': 'I'},
#   {'.': 'O'}],
#  [{'OBJECTIVES': 'B'}, {':': 'O'}],
#  [{'This': 'O'},
#   {'study': 'O'},
#   {'sought': 'O'},
#   {'to': 'O'},
#   {'examine': 'O'},
#   {'the': 'O'},
#   {'relationships': 'O'},
#   {'between': 'O'},
#   {'right': 'B'},
#   {'ventricular': 'B'},
#   {'(': 'O'},
#   {'RV': 'B'},
#   {')': 'O'},
#   {'function': 'I'},
#   {',': 'O'},
#   {'body': 'O'},
#   {'composition': 'O'},
#   {',': 'O'},
#   {'and': 'O'},
#   {'prognosis': 'O'},
#   {'in': 'O'},
#   {'patients': 'O'},
#   {'with': 'O'},
#   {'advanced': 'O'},
#   {'heart': 'B'},
#   {'failure': 'I'},
#   {'(': 'O'},
#   {'HF': 'B'},
#   {')': 'O'},
#   {'.': 'O'}],
#  [{'BACKGROUND': 'B'}, {':': 'O'}],
#  [{'Previous': 'O'},
#   {'studies': 'O'},
#   {'investigating': 'O'},
#   {'HF': 'B'},
#   {'-': 'O'},
#   {'related': 'O'},
#   {'cachexia': 'B'},
#   {'have': 'O'},
#   {'not': 'O'},
#   {'examined': 'O'},
#   {'the': 'B'},
#   {'impact': 'O'},
#   {'of': 'O'},
#   {'RV': 'B'},
#   {'function': 'O'},
#   {'on': 'O'},
#   {'body': 'O'},
#   {'composition': 'O'},
#   {'.': 'O'},
#   {'We': 'O'},
#   {'hypothesized': 'O'},
#   {'that': 'O'},
#   {'RV': 'B'},
#   {'dysfunction': 'B'},
#   {'is': 'O'},
#   {'linked': 'O'},
#   {'to': 'O'},
#   {'weight': 'O'},
#   {'loss': 'I'},
#   {',': 'O'},
#   {'abnormal': 'O'},
#   {'body': 'O'},
#   {'composition': 'O'},
#   {',': 'O'},
#   {'and': 'O'},
#   {'worsened': 'O'},
#   {'prognosis': 'O'},
#   {'in': 'O'},
#   {'advanced': 'O'},
#   {'HF': 'B'},
#   {'.': 'O'}],
#  [{'METHODS': 'O'}, {':': 'O'}],
#  [{'Subjects': 'O'},
#   {'with': 'O'},
#   {'advanced': 'O'},
#   {'HF': 'B'},
#   {'(': 'O'},
#   {'n': 'O'},
#   {'=': 'O'},
#   {'408': 'O'},
#   {')': 'O'},
#   {'underwent': 'O'},
#   {'prospective': 'O'},
#   {'assessment': 'O'},
#   {'of': 'O'},
#   {'body': 'O'},
#   {'composition': 'O'},
#   {'(': 'O'},
#   {'skinfold': 'O'},
#   {'thickness': 'O'},
#   {',': 'O'},
#   {'dual': 'B'},
#   {'-': 'I'},
#   {'energy': 'I'},
#   {'X': 'B'},
#   {'-': 'I'},
#   {'ray': 'I'},
#   {'absorptiometry': 'B'},
#   {')': 'O'},
#   {',': 'O'},
#   {'comprehensive': 'O'},
#   {'echocardiography': 'B'},
#   {',': 'O'},
#   {'and': 'O'},
#   {'blood': 'B'},
#   {'testing': 'I'},
#   {'.': 'O'},
#   {'Subjects': 'O'},
#   {'were': 'O'},
#   {'followed': 'O'},
#   {'up': 'O'},
#   {'for': 'O'},
#   {'adverse': 'B'},
#   {'events': 'O'},
#   {'(': 'O'},
#   {'defined': 'O'},
#   {'as': 'O'},
#   {'death': 'O'},
#   {',': 'O'},
#   {'transplantation': 'B'},
#   {',': 'O'},
#   {'or': 'O'},
#   {'circulatory': 'B'},
#   {'assist': 'I'},
#   {'device': 'I'},
#   {')': 'O'},
#   {'.': 'O'}],
#  [{'RESULTS': 'B'}, {':': 'O'}],
#  [{'Subjects': 'O'},
#   {'with': 'O'},
#   {'RV': 'B'},
#   {'dysfunction': 'O'},
#   {'(': 'O'},
#   {'51': 'O'},
#   {'%': 'O'},
#   {')': 'O'},
#   {'had': 'O'},
#   {'lower': 'O'},
#   {'body': 'O'},
#   {'mass': 'I'},
#   {'index': 'O'},
#   {',': 'O'},
#   {'lower': 'O'},
#   {'fat': 'O'},
#   {'mass': 'I'},
#   {'index': 'O'},
#   {',': 'O'},
#   {'and': 'O'},
#   {'were': 'O'},
#   {'more': 'O'},
#   {'likely': 'O'},
#   {'to': 'O'},
#   {'display': 'O'},
#   {'cachexia': 'B'},
#   {'(': 'O'},
#   {'19': 'O'},
#   {'%': 'O'},
#   {')': 'O'},
#   {'.': 'O'},
#   {'The': 'B'},
#   {'extent': 'O'},
#   {'of': 'O'},
#   {'RV': 'B'},
#   {'dysfunction': 'O'},
#   {'correlated': 'O'},
#   {'with': 'O'},
#   {'greater': 'O'},
#   {'antecedent': 'O'},
#   {'weight': 'O'},
#   {'loss': 'I'},
#   {'and': 'O'},
#   {'a': 'O'},
#   {'lower': 'O'},
#   {'fat': 'O'},
#   {'/': 'O'},
#   {'lean': 'B'},
#   {'body': 'O'},
#   {'mass': 'I'},
#   {'ratio': 'I'},
#   {'.': 'O'},
#   {'Over': 'O'},
#   {'a': 'O'},
#   {'median': 'O'},
#   {'follow': 'O'},
#   {'-': 'O'},
#   {'up': 'O'},
#   {'of': 'O'},
#   {'541': 'O'},
#   {'days': 'O'},
#   {',': 'O'},
#   {'there': 'O'},
#   {'were': 'O'},
#   {'150': 'O'},
#   {'events': 'O'},
#   {'(': 'O'},
#   {'37': 'O'},
#   {'%': 'O'},
#   {')': 'O'},
#   {'.': 'O'},
#   {'Risk': 'I'},
#   {'of': 'O'},
#   {'event': 'O'},
#   {'was': 'O'},
#   {'greater': 'O'},
#   {'in': 'O'},
#   {'subjects': 'O'},
#   {'with': 'O'},
#   {'RV': 'B'},
#   {'dysfunction': 'O'},
#   {'(': 'O'},
#   {'hazard': 'O'},
#   {'ratio': 'I'},
#   {':': 'O'},
#   {'3.09': 'O'},
#   {'[': 'O'},
#   {'95': 'O'},
#   {'%': 'O'},
#   {'confidence': 'O'},
#   {'interval': 'O'},
#   {'(': 'O'},
#   {'CI': 'O'},
#   {')': 'O'},
#   {':': 'O'},
#   {'2.18': 'O'},
#   {'to': 'O'},
#   {'4.45': 'O'},
#   {']': 'O'},
#   {')': 'O'},
#   {'and': 'O'},
#   {'cachexia': 'B'},
#   {'(': 'O'},
#   {'hazard': 'O'},
#   {'ratio': 'I'},
#   {':': 'O'},
#   {'2.90': 'O'},
#   {'[': 'O'},
#   {'95': 'O'},
#   {'%': 'O'},
#   {'CI': 'O'},
#   {':': 'O'},
#   {'2.00': 'O'},
#   {'to': 'O'},
#   {'4.12': 'O'},
#   {']': 'O'},
#   {')': 'O'},
#   {'in': 'O'},
#   {'univariate': 'O'},
#   {'and': 'O'},
#   {'multivariate': 'O'},
#   {'analyses': 'O'},
#   {'.': 'O'},
#   {'Increased': 'O'},
#   {'body': 'O'},
#   {'mass': 'I'},
#   {'index': 'O'},
#   {'was': 'O'},
#   {'associated': 'O'},
#   {'with': 'O'},
#   {'a': 'O'},
#   {'lower': 'O'},
#   {'event': 'O'},
#   {'rate': 'I'},
#   {'(': 'O'},
#   {'HR': 'B'},
#   {'per': 'O'},
#   {'kg': 'O'},
#   {'/': 'O'},
#   {'m(2': 'O'},
#   {')': 'O'},
#   {':': 'O'},
#   {'0.92': 'O'},
#   {'[': 'O'},
#   {'95': 'O'},
#   {'%': 'O'},
#   {'CI': 'O'},
#   {':': 'O'},
#   {'0.88': 'O'},
#   {'to': 'O'},
#   {'0.96': 'O'},
#   {']': 'O'},
#   {')': 'O'},
#   {',': 'O'},
#   {'and': 'O'},
#   {'this': 'O'},
#   {'protection': 'I'},
#   {'was': 'O'},
#   {'mediated': 'O'},
#   {'by': 'O'},
#   {'a': 'O'},
#   {'higher': 'O'},
#   {'fat': 'B'},
#   {'mass': 'O'},
#   {'(': 'O'},
#   {'0.91': 'O'},
#   {'[': 'O'},
#   {'95': 'O'},
#   {'%': 'O'},
#   {'CI': 'O'},
#   {':': 'O'},
#   {'0.87': 'O'},
#   {'to': 'O'},
#   {'0.96': 'O'},
#   {']': 'O'},
#   {')': 'O'},
#   {'but': 'O'},
#   {'not': 'O'},
#   {'a': 'O'},
#   {'fat': 'B'},
#   {'-': 'B'},
#   {'free': 'B'},
#   {'mass': 'I'},
#   {'index': 'O'},
#   {'(': 'O'},
#   {'0.97': 'O'},
#   {'[': 'O'},
#   {'95': 'O'},
#   {'%': 'O'},
#   {'CI': 'O'},
#   {':': 'O'},
#   {'0.92': 'O'},
#   {'to': 'O'},
#   {'1.03': 'O'},
#   {']': 'O'},
#   {')': 'O'},
#   {'.': 'O'}],
#  [{'CONCLUSIONS': 'O'}, {':': 'O'}],
#  [{'RV': 'B'},
#   {'dysfunction': 'B'},
#   {'and': 'O'},
#   {'cardiac': 'B'},
#   {'cachexia': 'B'},
#   {'often': 'O'},
#   {'coexist': 'O'},
#   {',': 'O'},
#   {'have': 'O'},
#   {'additive': 'O'},
#   {'adverse': 'O'},
#   {'impact': 'I'},
#   {',': 'O'},
#   {'and': 'O'},
#   {'might': 'O'},
#   {'be': 'O'},
#   {'mechanistically': 'O'},
#   {'interrelated': 'O'},
#   {'.': 'O'},
#   {'Wasting': 'O'},
#   {'of': 'O'},
#   {'fat': 'O'},
#   {'but': 'O'},
#   {'not': 'O'},
#   {'of': 'O'},
#   {'lean': 'O'},
#   {'mass': 'O'},
#   {'was': 'O'},
#   {'predictive': 'O'},
#   {'of': 'O'},
#   {'adverse': 'O'},
#   {'outcome': 'O'},
#   {',': 'O'},
#   {'suggesting': 'O'},
#   {'that': 'O'},
#   {'fat': 'O'},
#   {'loss': 'I'},
#   {'is': 'O'},
#   {'either': 'O'},
#   {'a': 'O'},
#   {'surrogate': 'O'},
#   {'of': 'O'},
#   {'enhanced': 'O'},
#   {'catabolism': 'B'},
#   {'or': 'O'},
#   {'adipose': 'O'},
#   {'tissue': 'I'},
#   {'is': 'O'},
#   {'cardioprotective': 'B'},
#   {'in': 'O'},
#   {'the': 'O'},
#   {'context': 'O'},
#   {'of': 'O'},
#   {'HF': 'B'},
#   {'.': 'O'}],
#  [{'Contemporary': 'O'},
#   {'use': 'O'},
#   {'of': 'O'},
#   {'devices': 'I'},
#   {'in': 'O'},
#   {'heart': 'B'},
#   {'failure': 'I'},
#   {'.': 'O'}],
#  [{'Devices': 'O'},
#   {'have': 'O'},
#   {'become': 'O'},
#   {'a': 'O'},
#   {'cornerstone': 'B'},
#   {'of': 'O'},
#   {'heart': 'B'},
#   {'failure': 'I'},
#   {'(': 'O'},
#   {'HF': 'B'},
#   {')': 'O'},
#   {'therapy': 'I'},
#   {'.': 'O'},
#   {'Implantable': 'B'},
#   {'cardioverter': 'B'},
#   {'-': 'I'},
#   {'defibrillators': 'I'},
#   {'(': 'O'},
#   {'ICDs': 'B'},
#   {')': 'O'},
#   {'decrease': 'O'},
#   {'mortality': 'O'},
#   {',': 'O'},
#   {'and': 'O'},
#   {'cardiac': 'B'},
#   {'resynchronization': 'I'},
#   {'therapy': 'I'},
#   {'(': 'O'},
#   {'CRT': 'B'},
#   {')': 'O'},
#   {'improves': 'O'},
#   {'symptoms': 'O'},
#   {'and': 'O'},
#   {'mortality': 'O'},
#   {'.': 'O'},
#   {'Most': 'O'},
#   {'data': 'O'},
#   {'have': 'O'},
#   {'been': 'O'},
#   {'collected': 'O'},
#   {'in': 'O'},
#   {'patients': 'O'},
#   {'with': 'O'},
#   {'systolic': 'O'},
#   {'dysfunction': 'O'},
#   {'.': 'O'},
#   {'Data': 'O'},
#   {'in': 'O'},
#   {'patients': 'O'},
#   {'with': 'O'},
#   {'preserved': 'O'},
#   {'systolic': 'O'},
#   {'function': 'O'},
#   {'are': 'O'},
#   {'scarce': 'O'},
#   {',': 'O'},
#   {'but': 'O'},
#   {'interesting': 'O'},
#   {'therapeutic': 'O'},
#   {'concepts': 'O'},
#   {'are': 'O'},
#   {'evolving': 'O'},
#   {'.': 'O'},
#   {'Besides': 'O'},
#   {'therapeutic': 'O'},
#   {'functions': 'O'},
#   {',': 'O'},
#   {'devices': 'I'},
#   {'can': 'O'},
#   {'have': 'O'},
#   {'add': 'O'},
#   {'-': 'O'},
#   {'on': 'O'},
#   {'diagnostic': 'O'},
#   {'features': 'O'},
#   {'such': 'O'},
#   {'as': 'O'},
#   {'early': 'O'},
#   {'detection': 'O'},
#   {'of': 'O'},
#   {'fluid': 'O'},
#   {'overload': 'B'},
#   {'.': 'O'},
#   {'In': 'O'},
#   {'addition': 'O'},
#   {',': 'O'},
#   {'stand': 'O'},
#   {'-': 'O'},
#   {'alone': 'O'},
#   {'diagnostic': 'O'},
#   {'devices': 'I'},
#   {'are': 'O'},
#   {'now': 'O'},
#   {'also': 'O'},
#   {'being': 'O'},
#   {'developed': 'O'},
#   {'for': 'O'},
#   {'HF': 'B'},
#   {'.': 'O'}],
#  [{'Tools': 'O'},
#   {'for': 'O'},
#   {'Economic': 'B'},
#   {'Analysis': 'O'},
#   {'of': 'O'},
#   {'Patient': 'B'},
#   {'Management': 'O'},
#   {'Interventions': 'O'},
#   {'in': 'O'},
#   {'Heart': 'B'},
#   {'Failure': 'O'},
#   {'Cost': 'B'},
#   {'-': 'O'},
#   {'Effectiveness': 'O'},
#   {'Model': 'I'},
#   {':': 'O'},
#   {'A': 'O'},
#   {'Web': 'O'},
#   {'-': 'O'},
#   {'based': 'O'},
#   {'program': 'O'},
#   {'designed': 'O'},
#   {'to': 'O'},
#   {'evaluate': 'O'},
#   {'the': 'O'},
#   {'cost': 'B'},
#   {'-': 'O'},
#   {'effectiveness': 'O'},
#   {'of': 'O'},
#   {'disease': 'B'},
#   {'management': 'O'},
#   {'programs': 'O'},
#   {'in': 'O'},
#   {'heart': 'B'},
#   {'failure': 'O'},
#   {'.': 'O'}],
#  [{'BACKGROUND': 'B'}, {':': 'O'}],
#  [{'Heart': 'B'},
#   {'failure': 'O'},
#   {'disease': 'O'},
#   {'management': 'O'},
#   {'programs': 'O'},
#   {'can': 'O'},
#   {'influence': 'O'},
#   {'medical': 'B'},
#   {'resource': 'O'},
#   {'use': 'O'},
#   {'and': 'O'},
#   {'quality': 'O'},
#   {'-': 'O'},
#   {'adjusted': 'O'},
#   {'survival': 'O'},
#   {'.': 'O'},
#   {'Because': 'O'},
#   {'projecting': 'O'},
#   {'long': 'O'},
#   {'-': 'O'},
#   {'term': 'B'},
#   {'costs': 'B'},
#   {'and': 'O'},
#   {'survival': 'O'},
#   {'is': 'O'},
#   {'challenging': 'O'},
#   {',': 'O'},
#   {'a': 'O'},
#   {'consistent': 'O'},
#   {'and': 'O'},
#   {'valid': 'O'},
#   {'approach': 'O'},
#   {'to': 'O'},
#   {'extrapolating': 'B'},
#   {'short': 'O'},
#   {'-': 'O'},
#   {'term': 'B'},
#   {'outcomes': 'O'},
#   {'would': 'O'},
#   {'be': 'O'},
#   {'valuable': 'O'},
#   {'.': 'O'}],
#  [{'METHODS': 'O'}, {':': 'O'}],
#  [{'We': 'O'},
#   {'developed': 'O'},
#   {'the': 'O'},
#   {'Tools': 'O'},
#   {'for': 'O'},
#   {'Economic': 'B'},
#   {'Analysis': 'O'},
#   {'of': 'O'},
#   {'Patient': 'B'},
#   {'Management': 'O'},
#   {'Interventions': 'O'},
#   {'in': 'O'},
#   {'Heart': 'B'},
#   {'Failure': 'I'},
#   {'Cost': 'B'},
#   {'-': 'O'},
#   {'Effectiveness': 'I'},
#   {'Model': 'O'},
#   {',': 'O'},
#   {'a': 'O'},
#   {'Web': 'O'},
#   {'-': 'O'},
#   {'based': 'O'},
#   {'simulation': 'O'},
#   {'tool': 'O'},
#   {'designed': 'O'},
#   {'to': 'O'},
#   {'integrate': 'O'},
#   {'data': 'O'},
#   {'on': 'O'},
#   {'demographic': 'O'},
#   {',': 'O'},
#   {'clinical': 'B'},
#   {',': 'O'},
#   {'and': 'O'},
#   {'laboratory': 'O'},
#   {'characteristics': 'O'},
#   {';': 'O'},
#   {'use': 'O'},
#   {'of': 'O'},
#   {'evidence': 'B'},
#   {'-': 'O'},
#   {'based': 'O'},
#   {'medications': 'O'},
#   {';': 'O'},
#   {'and': 'O'},
#   {'costs': 'B'},
#   {'to': 'O'},
#   {'generate': 'O'},
#   {'predicted': 'O'},
#   {'outcomes': 'O'},
#   {'.': 'O'},
#   {'Survival': 'O'},
#   {'projections': 'O'},
#   {'are': 'O'},
#   {'based': 'O'},
#   {'on': 'O'},
#   {'a': 'O'},
#   {'modified': 'O'},
#   {'Seattle': 'O'},
#   {'Heart': 'B'},
#   {'Failure': 'O'},
#   {'Model': 'O'},
#   {'.': 'O'},
#   {'Projections': 'O'},
#   {'of': 'O'},
#   {'resource': 'O'},
#   {'use': 'O'},
#   {'and': 'O'},
#   {'quality': 'O'},
#   {'of': 'O'},
#   {'life': 'I'},
#   {'are': 'O'},
#   {'modeled': 'O'},
#   {'using': 'O'},
#   {'relationships': 'I'},
#   {'with': 'O'},
#   {'time': 'O'},
#   {'-': 'O'},
#   {'varying': 'O'},
#   {'Seattle': 'O'},
#   {'Heart': 'B'},
#   {'Failure': 'I'},
#   {'Model': 'O'},
#   {'scores': 'I'},
#   {'.': 'O'},
#   {'The': 'B'},
#   {'model': 'O'},
#   {'can': 'O'},
#   {'be': 'O'},
#   {'used': 'O'},
#   {'to': 'O'},
#   {'evaluate': 'O'},
#   {'parallel': 'O'},
#   {'-': 'O'},
#   {'group': 'O'},
#   {'and': 'O'},
#   {'single': 'B'},
#   {'-': 'O'},
#   {'cohort': 'B'},
#   {'study': 'O'},
#   {'designs': 'O'},
#   {'and': 'O'},
#   {'hypothetical': 'O'},
#   {'programs': 'O'},
#   {'.': 'O'},
#   {'Simulations': 'O'},
#   {'consist': 'O'},
#   {'of': 'O'},
#   {'10,000': 'O'},
#   {'pairs': 'O'},
#   {'of': 'O'},
#   {'virtual': 'O'},
#   {'cohorts': 'B'},
#   {'used': 'O'},
#   {'to': 'O'},
#   {'generate': 'O'},
#   {'estimates': 'O'},
#   {'of': 'O'},
#   {'resource': 'O'},
#   {'use': 'O'},
#   {',': 'O'},
#   {'costs': 'B'},
#   {',': 'O'},
#   {'survival': 'O'},
#   {',': 'O'},
#   {'and': 'O'},
#   {'incremental': 'O'},
#   {'cost': 'B'},
#   {'-': 'O'},
#   {'effectiveness': 'O'},
#   {'ratios': 'I'},
#   {'from': 'O'},
#   {'user': 'O'},
#   {'inputs': 'O'},
#   {'.': 'O'}],
#  [{'RESULTS': 'B'}, {':': 'O'}],
#  [{'The': 'O'},
#   {'model': 'O'},
#   {'demonstrated': 'O'},
#   {'acceptable': 'O'},
#   {'internal': 'B'},
#   {'and': 'O'},
#   {'external': 'O'},
#   {'validity': 'O'},
#   {'in': 'O'},
#   {'replicating': 'O'},
#   {'resource': 'I'},
#   {'use': 'O'},
#   {',': 'O'},
#   {'costs': 'B'},
#   {',': 'O'},
#   {'and': 'O'},
#   {'survival': 'O'},
#   {'estimates': 'O'},
#   {'from': 'O'},
#   {'3': 'O'},
#   {'clinical': 'B'},
#   {'trials': 'O'},
#   {'.': 'O'},
#   {'Simulations': 'O'},
#   {'to': 'O'},
#   {'evaluate': 'O'},
#   {'the': 'B'},
#   {'cost': 'B'},
#   {'-': 'O'},
#   {'effectiveness': 'O'},
#   {'of': 'O'},
#   {'heart': 'B'},
#   {'failure': 'O'},
#   {'disease': 'O'},
#   {'management': 'O'},
#   {'programs': 'O'},
#   {'across': 'O'},
#   {'3': 'O'},
#   {'scenarios': 'O'},
#   {'demonstrate': 'O'},
#   {'how': 'O'},
#   {'the': 'O'},
#   {'model': 'O'},
#   {'can': 'O'},
#   {'be': 'O'},
#   {'used': 'O'},
#   {'to': 'O'},
#   {'design': 'O'},
#   {'a': 'O'},
#   {'program': 'O'},
#   {'in': 'O'},
#   {'which': 'O'},
#   {'short': 'O'},
#   {'-': 'O'},
#   {'term': 'O'},
#   {'improvements': 'O'},
#   {'in': 'O'},
#   {'functioning': 'O'},
#   {'and': 'O'},
#   {'use': 'O'},
#   {'of': 'O'},
#   {'evidence': 'B'},
#   {'-': 'O'},
#   {'based': 'O'},
#   {'treatments': 'O'},
#   {'are': 'O'},
#   {'sufficient': 'O'},
#   {'to': 'O'},
#   {'demonstrate': 'O'},
#   {'good': 'O'},
#   {'long': 'O'},
#   {'-': 'O'},
#   {'term': 'O'},
#   {'value': 'O'},
#   {'to': 'O'},
#   {'the': 'O'},
#   {'health': 'O'},
#   {'care': 'I'},
#   {'system': 'I'},
#   {'.': 'O'}],
#  [{'CONCLUSION': 'O'}, {':': 'O'}],
#  [{'The': 'O'},
#   {'Tools': 'O'},
#   {'for': 'O'},
#   {'Economic': 'B'},
#   {'Analysis': 'O'},
#   {'of': 'O'},
#   {'Patient': 'B'},
#   {'Management': 'O'},
#   {'Interventions': 'O'},
#   {'in': 'O'},
#   {'Heart': 'B'},
#   {'Failure': 'O'},
#   {'Cost': 'B'},
#   {'-': 'O'},
#   {'Effectiveness': 'O'},
#   {'Model': 'I'},
#   {'provides': 'O'},
#   {'researchers': 'O'},
#   {'and': 'O'},
#   {'providers': 'O'},
#   {'with': 'O'},
#   {'a': 'O'},
#   {'tool': 'O'},
#   {'for': 'O'},
#   {'conducting': 'O'},
#   {'long': 'O'},
#   {'-': 'B'},
#   {'term': 'B'},
#   {'cost': 'B'},
#   {'-': 'O'},
#   {'effectiveness': 'O'},
#   {'analyses': 'I'},
#   {'of': 'O'},
#   {'disease': 'B'},
#   {'management': 'O'},
#   {'programs': 'O'},
#   {'in': 'O'},
#   {'heart': 'B'},
#   {'failure': 'O'},
#   {'.': 'O'}],
#  [{'Differential': 'O'},
#   {'effects': 'O'},
#   {'of': 'O'},
#   {'nonselective': 'B'},
#   {'versus': 'O'},
#   {'selective': 'O'},
#   {'beta': 'B'},
#   {'-': 'I'},
#   {'blockers': 'I'},
#   {'on': 'O'},
#   {'cardiac': 'B'},
#   {'sympathetic': 'O'},
#   {'activity': 'B'},
#   {'and': 'O'},
#   {'hemostasis': 'O'},
#   {'in': 'O'},
#   {'patients': 'O'},
#   {'with': 'O'},
#   {'heart': 'B'},
#   {'failure': 'I'},
#   {'.': 'O'}],
#  [{'Carvedilol': 'B'},
#   {',': 'O'},
#   {'a': 'O'},
#   {'nonselective': 'B'},
#   {'β': 'O'},
#   {'-': 'O'},
#   {'blocker': 'I'},
#   {',': 'O'},
#   {'may': 'O'},
#   {'be': 'O'},
#   {'more': 'O'},
#   {'effective': 'O'},
#   {'than': 'O'},
#   {'the': 'B'},
#   {'selective': 'O'},
#   {'β': 'O'},
#   {'-': 'O'},
#   {'blocker': 'I'},
#   {'metoprolol': 'B'},
#   {'in': 'O'},
#   {'reducing': 'O'},
#   {'the': 'B'},
#   {'risk': 'O'},
#   {'of': 'O'},
#   {'thromboembolic': 'B'},
#   {'events': 'O'},
#   {'in': 'O'},
#   {'heart': 'B'},
#   {'failure': 'O'},
#   {'.': 'O'},
#   {'The': 'B'},
#   {'aim': 'O'},
#   {'of': 'O'},
#   {'this': 'O'},
#   {'study': 'O'},
#   {'was': 'O'},
#   {',': 'O'},
#   {'first': 'O'},
#   {',': 'O'},
#   {'to': 'O'},
#   {'assess': 'O'},
#   {'whether': 'O'},
#   {'there': 'O'},
#   {'is': 'O'},
#   {'a': 'O'},
#   {'differential': 'O'},
#   {'response': 'O'},
#   {'in': 'O'},
#   {'cardiac': 'B'},
#   {'sympathetic': 'O'},
#   {'activity': 'I'},
#   {'by': 'O'},
#   {'(': 'O'},
#   {'123)I': 'O'},
#   {'-': 'O'},
#   {'meta': 'B'},
#   {'-': 'O'},
#   {'iodobenzylguanidine': 'I'},
#   {'(': 'O'},
#   {'(': 'O'},
#   {'123)I': 'O'},
#   {'-': 'O'},
#   {'MIBG': 'B'},
#   {')': 'O'},
#   {'imaging': 'O'},
#   {'when': 'O'},
#   {'either': 'O'},
#   {'β': 'B'},
#   {'-': 'O'},
#   {'blocker': 'I'},
#   {'is': 'O'},
#   {'used': 'O'},
#   {'.': 'O'},
#   {'Second': 'O'},
#   {',': 'O'},
#   {'we': 'O'},
#   {'assessed': 'O'},
#   {'whether': 'O'},
#   {'that': 'O'},
#   {'response': 'O'},
#   {'correlates': 'O'},
#   {'with': 'O'},
#   {'levels': 'O'},
#   {'of': 'O'},
#   {'various': 'O'},
#   {'serum': 'B'},
#   {'factors': 'O'},
#   {'that': 'O'},
#   {'serve': 'O'},
#   {'as': 'O'},
#   {'markers': 'O'},
#   {'for': 'O'},
#   {'coagulability': 'B'},
#   {'.': 'O'}],
#  [{'METHODS': 'O'}, {':': 'O'}],
#  [{'In': 'O'},
#   {'this': 'O'},
#   {'prospective': 'O'},
#   {',': 'O'},
#   {'randomized': 'O'},
#   {',': 'O'},
#   {'open': 'O'},
#   {'-': 'O'},
#   {'label': 'O'},
#   {'crossover': 'O'},
#   {'study': 'O'},
#   {'with': 'O'},
#   {'masked': 'O'},
#   {'outcome': 'O'},
#   {'assessments': 'O'},
#   {',': 'O'},
#   {'stable': 'B'},
#   {'heart': 'B'},
#   {'failure': 'I'},
#   {'patients': 'O'},
#   {'(': 'O'},
#   {'left': 'B'},
#   {'ventricular': 'B'},
#   {'ejection': 'I'},
#   {'fraction': 'I'},
#   {'<': 'O'},
#   {'40': 'O'},
#   {'%': 'O'},
#   {')': 'O'},
#   {'homozygous': 'B'},
#   {'for': 'O'},
#   {'the': 'B'},
#   {'Arg16': 'O'},
#   {'/': 'O'},
#   {'Gln27': 'B'},
#   {'(': 'O'},
#   {'n': 'O'},
#   {'=': 'O'},
#   {'13': 'O'},
#   {')': 'O'},
#   {'or': 'O'},
#   {'Gly16': 'O'},
#   {'/': 'O'},
#   {'Glu27': 'B'},
#   {'haplotype': 'O'},
#   {'(': 'O'},
#   {'n': 'O'},
#   {'=': 'O'},
#   {'8)': 'O'},
#   {'of': 'O'},
#   {'the': 'B'},
#   {'β2-receptor': 'O'},
#   {'were': 'O'},
#   {'randomized': 'O'},
#   {'to': 'O'},
#   {'equipotent': 'B'},
#   {'dosages': 'B'},
#   {'of': 'O'},
#   {'carvedilol': 'B'},
#   {'or': 'O'},
#   {'metoprolol': 'B'},
#   {'for': 'O'},
#   {'two': 'O'},
#   {'6-wk': 'O'},
#   {'periods': 'O'},
#   {'.': 'O'},
#   {'Primary': 'O'},
#   {'outcome': 'O'},
#   {'was': 'O'},
#   {'sympathetic': 'O'},
#   {'activity': 'I'},
#   {'as': 'O'},
#   {'measured': 'O'},
#   {'by': 'O'},
#   {'(': 'O'},
#   {'123)I': 'O'},
#   {'-': 'O'},
#   {'MIBG': 'B'},
#   {'myocardial': 'B'},
#   {'washout': 'B'},
#   {'.': 'O'},
#   {'Secondary': 'O'},
#   {'outcomes': 'O'},
#   {'included': 'O'},
#   {'markers': 'O'},
#   {'of': 'O'},
#   {'hemostasis': 'O'},
#   {'.': 'O'}],
#  [{'RESULTS': 'B'}, {':': 'O'}],
#  [{'(': 'O'},
#   {'123)I': 'O'},
#   {'-': 'B'},
#   {'MIBG': 'B'},
#   {'cardiac': 'B'},
#   {'washout': 'B'},
#   {'was': 'O'},
#   {'lower': 'O'},
#   {'during': 'O'},
#   {'carvedilol': 'B'},
#   {'than': 'O'},
#   {'metoprolol': 'O'},
#   {'treatment': 'O'},
#   {'(': 'O'},
#   {'12.9': 'O'},
#   {'%': 'O'},
#   {'±': 'O'},
#   {'3.9': 'O'},
#   {'%': 'O'},
#   {'vs.': 'O'},
#   {'22.1': 'O'},
#   {'%': 'O'},
#   {'±': 'O'},
#   {'2.8': 'O'},
#   {'%': 'O'},
#   {',': 'O'},
#   {'respectively': 'O'},
#   {',': 'O'},
#   {'P': 'O'},
#   {'=': 'O'},
#   {'0.003': 'O'},
#   {')': 'O'},
#   {',': 'O'},
#   {'irrespective': 'O'},
#   {'of': 'O'},
#   {'β2-adrenergic': 'O'},
#   {'receptor': 'I'},
#   {'haplotype': 'O'},
#   {'.': 'O'},
#   {'In': 'O'},
#   {'addition': 'O'},
#   {',': 'O'},
#   {'treatment': 'O'},
#   {'with': 'O'},
#   {'carvedilol': 'O'},
#   {'resulted': 'O'},
#   {'in': 'O'},
#   {'a': 'O'},
#   {'lower': 'O'},
#   {'von': 'O'},
#   {'Willebrand': 'O'},
#   {'factor': 'I'},
#   {'than': 'O'},
#   {'did': 'O'},
#   {'metoprolol': 'O'},
#   {'(': 'O'},
#   {'149': 'O'},
#   {'%': 'O'},
#   {'±': 'O'},
#   {'13': 'O'},
#   {'%': 'O'},
#   {'vs.': 'O'},
#   {'157': 'O'},
#   {'%': 'O'},
#   {'±': 'O'},
#   {'13': 'O'},
#   {'%': 'O'},
#   {',': 'O'},
#   {'respectively': 'O'},
#   {',': 'O'},
#   {'P': 'O'},
#   {'=': 'O'},
#   {'0.01': 'O'},
#   {')': 'O'},
#   {',': 'O'},
#   {'irrespective': 'O'},
#   {'of': 'O'},
#   {'β2-adrenergic': 'O'},
#   {'receptor': 'I'},
#   {'haplotype': 'O'},
#   {'.': 'O'}],
#  [{'CONCLUSION': 'O'}, {':': 'O'}],
#  [{'Compared': 'O'},
#   {'with': 'O'},
#   {'metoprolol': 'B'},
#   {',': 'O'},
#   {'carvedilol': 'B'},
#   {'resulted': 'O'},
#   {'in': 'O'},
#   {'greater': 'O'},
#   {'reduction': 'I'},
#   {'of': 'O'},
#   {'sympathetic': 'O'},
#   {'activity': 'B'},
#   {'after': 'O'},
#   {'6': 'O'},
#   {'wk': 'O'},
#   {'of': 'O'},
#   {'treatment': 'O'},
#   {'and': 'O'},
#   {'lower': 'O'},
#   {'von': 'O'},
#   {'Willebrand': 'O'},
#   {'factor': 'I'},
#   {'concentrations': 'O'},
#   {'in': 'O'},
#   {'both': 'O'},
#   {'Arg16': 'O'},
#   {'/': 'O'},
#   {'Gln27': 'B'},
#   {'and': 'O'},
#   {'Gly16': 'O'},
#   {'/': 'O'},
#   {'Glu27': 'B'},
#   {'individuals': 'O'},
#   {'.': 'O'},
#   {'Therefore': 'O'},
#   {',': 'O'},
#   {'carvedilol': 'B'},
#   {'may': 'O'},
#   {'reduce': 'O'},
#   {'the': 'B'},
#   {'risk': 'O'},
#   {'of': 'O'},
#   {'thromboembolic': 'B'},
#   {'events': 'O'},
#   {'in': 'O'},
#   {'patients': 'O'},
#   {'with': 'O'},
#   {'heart': 'B'},
#   {'failure': 'I'},
#   {',': 'O'},
#   {'irrespective': 'O'},
#   {'of': 'O'},
#   {'β2-receptor': 'O'},
#   {'haplotype': 'O'},
#   {'status': 'O'},
#   {'.': 'O'}],
#  [{'Using': 'O'},
#   {'exercise': 'B'},
#   {'to': 'O'},
#   {'improve': 'O'},
#   {'quality': 'O'},
#   {'of': 'O'},
#   {'life': 'O'},
#   {'for': 'O'},
#   {'people': 'O'},
#   {'with': 'O'},
#   {'heart': 'B'},
#   {'failure': 'O'},
#   {'.': 'O'}],
#  [{'Abstract': 'O'}],
#  [{'In': 'O'},
#   {'the': 'O'},
#   {'current': 'O'},
#   {'economic': 'B'},
#   {'climate': 'B'},
#   {'within': 'O'},
#   {'the': 'O'},
#   {'NHS': 'O'},
#   {',': 'O'},
#   {'behavioural': 'O'},
#   {'-': 'B'},
#   {'change': 'I'},
#   {'interventions': 'O'},
#   {'in': 'O'},
#   {'chronic': 'O'},
#   {'disease': 'O'},
#   {'such': 'O'},
#   {'as': 'O'},
#   {'exercise': 'O'},
#   {'programmes': 'O'},
#   {'will': 'O'},
#   {'be': 'O'},
#   {'time': 'O'},
#   {'-': 'O'},
#   {'limited': 'O'},
#   {'within': 'O'},
#   {'acute': 'B'},
#   {'hospital': 'O'},
#   {'facilities': 'O'},
#   {'.': 'O'},
#   {'The': 'O'},
#   {'challenge': 'O'},
#   {'is': 'O'},
#   {'to': 'O'},
#   {'deliver': 'O'},
#   {'cost': 'B'},
#   {'-': 'O'},
#   {'effective': 'O'},
#   {',': 'O'},
#   {'participatory': 'O'},
#   {',': 'O'},
#   {'population': 'O'},
#   {'-': 'O'},
#   {'specific': 'O'},
#   {'health': 'B'},
#   {'interventions': 'O'},
#   {'that': 'O'},
#   {'result': 'O'},
#   {'in': 'O'},
#   {'measurable': 'O'},
#   {'benefits': 'I'},
#   {'.': 'O'}],
#  [{'METHODOLOGY': 'O'}, {':': 'O'}],
#  [{'A': 'O'},
#   {'mixed': 'B'},
#   {'-': 'O'},
#   {'methods': 'O'},
#   {'study': 'O'},
#   {'was': 'O'},
#   {'undertaken': 'O'},
#   {'to': 'O'},
#   {'assess': 'O'},
#   {'the': 'B'},
#   {'benefits': 'I'},
#   {'of': 'O'},
#   {'participation': 'O'},
#   {'in': 'O'},
#   {'a': 'O'},
#   {'structured': 'O'},
#   {'exercise': 'O'},
#   {'programme': 'O'},
#   {'for': 'O'},
#   {'patients': 'O'},
#   {'with': 'O'},
#   {'heart': 'B'},
#   {'failure': 'O'},
#   {'.': 'O'},
#   {'Primary': 'O'},
#   {'outcomes': 'O'},
#   {'were': 'O'},
#   {'improvements': 'O'},
#   {'in': 'O'},
#   {'functional': 'O'},
#   {'capacity': 'I'},
#   {'and': 'O'},
#   {'quality': 'O'},
#   {'of': 'O'},
#   {'life': 'I'},
#   {'.': 'O'},
#   {'Secondary': 'O'},
#   {'outcome': 'O'},
#   {'measures': 'O'},
#   {'related': 'O'},
#   {'to': 'O'},
#   {'patient': 'O'},
#   {'satisfaction': 'O'},
#   {'and': 'O'},
#   {'sustainability': 'O'},
#   {'of': 'O'},
#   {'the': 'B'},
#   {'intervention': 'O'},
#   {'post': 'O'},
#   {'study': 'O'},
#   {'.': 'O'}],
#  [{'RESULTS': 'B'}, {':': 'O'}],
#  [{'Overall': 'O'},
#   {'significant': 'O'},
#   {'improvements': 'O'},
#   {'were': 'O'},
#   {'not': 'O'},
#   {'found': 'O'},
#   {'in': 'O'},
#   {'quality': 'O'},
#   {'of': 'O'},
#   {'life': 'O'},
#   {'or': 'O'},
#   {'functional': 'O'},
#   {'capacity': 'I'},
#   {';': 'O'},
#   {'some': 'O'},
#   {'participants': 'O'},
#   {'demonstrated': 'O'},
#   {'significant': 'O'},
#   {'improvements': 'O'},
#   {'with': 'O'},
#   {'others': 'O'},
#   {'showing': 'O'},
#   {'minor': 'O'},
#   {'improvement': 'O'},
#   {'or': 'O'},
#   {'no': 'O'},
#   {'improvement': 'O'},
#   {'in': 'O'},
#   {'one': 'O'},
#   {'or': 'O'},
#   {'both': 'O'},
#   {'domains': 'O'},
#   {'.': 'O'}],
#  [{'CONCLUSIONS': 'O'}, {':': 'O'}],
#  [{'Anecdotal': 'O'},
#   {'evidence': 'O'},
#   {'of': 'O'},
#   {'perceived': 'O'},
#   {'benefit': 'I'},
#   {'was': 'O'},
#   {'expressed': 'O'},
#   {'in': 'O'},
#   {'participant': 'O'},
#   {'satisfaction': 'O'},
#   {'responses': 'I'},
#   {'.': 'O'},
#   {'Secondary': 'O'},
#   {'outcomes': 'O'},
#   {'were': 'O'},
#   {'met': 'O'},
#   {'in': 'O'},
#   {'relation': 'O'},
#   {'to': 'O'},
#   {'sustainability': 'O'},
#   {'with': 'O'},
#   {'commissioning': 'B'},
#   {'of': 'O'},
#   {'hospital-': 'B'},
#   {'and': 'O'},
#   {'community': 'O'},
#   {'-': 'O'},
#   {'based': 'O'},
#   {'programmes': 'O'},
#   {'on': 'O'},
#   {'completion': 'O'},
#   {'of': 'O'},
#   {'the': 'B'},
#   {'study': 'O'},
#   {'.': 'O'}],
#  [{'Xanthine': 'B'},
#   {'oxidase': 'B'},
#   {'inhibition': 'O'},
#   {'preserves': 'O'},
#   {'left': 'B'},
#   {'ventricular': 'B'},
#   {'systolic': 'B'},
#   {'but': 'O'},
#   {'not': 'O'},
#   {'diastolic': 'B'},
#   {'function': 'I'},
#   {'in': 'O'},
#   {'cardiac': 'B'},
#   {'volume': 'I'},
#   {'overload': 'B'},
#   {'.': 'O'}],
#  [{'Xanthine': 'O'},
#   {'oxidase': 'B'},
#   {'(': 'O'},
#   {'XO': 'O'},
#   {')': 'O'},
#   {'is': 'O'},
#   {'increased': 'O'},
#   {'in': 'O'},
#   {'human': 'O'},
#   {'and': 'O'},
#   {'rat': 'O'},
#   {'left': 'B'},
#   {'ventricular': 'B'},
#   {'(': 'O'},
#   {'LV': 'O'},
#   {')': 'O'},
#   {'myocytes': 'O'},
#   {'with': 'O'},
#   {'volume': 'I'},
#   {'overload': 'B'},
#   {'(': 'O'},
#   {'VO': 'O'},
#   {')': 'O'},
#   {'of': 'O'},
#   {'mitral': 'B'},
#   {'regurgitation': 'B'},
#   {'and': 'O'},
#   {'aortocaval': 'O'},
#   {'fistula': 'B'},
#   {'(': 'O'},
#   {'ACF': 'O'},
#   {')': 'O'},
#   {'.': 'O'},
#   {'In': 'O'},
#   {'the': 'O'},
#   {'setting': 'O'},
#   {'of': 'O'},
#   {'increased': 'O'},
#   {'ATP': 'O'},
#   {'demand': 'O'},
#   {',': 'O'},
#   {'XO': 'B'},
#   {'-': 'O'},
#   {'mediated': 'O'},
#   {'ROS': 'B'},
#   {'can': 'O'},
#   {'decrease': 'O'},
#   {'mitochondrial': 'B'},
#   {'respiration': 'I'},
#   {'and': 'O'},
#   {'contractile': 'B'},
#   {'function': 'O'},
#   {'.': 'O'},
#   {'Thus': 'O'},
#   {',': 'O'},
#   {'we': 'O'},
#   {'tested': 'O'},
#   {'the': 'O'},
#   {'hypothesis': 'O'},
#   {'that': 'O'},
#   {'XO': 'B'},
#   {'inhibition': 'O'},
#   {'improves': 'O'},
#   {'cardiomyocyte': 'B'},
#   {'bioenergetics': 'B'},
#   {'and': 'O'},
#   {'LV': 'O'},
#   {'function': 'O'},
#   {'in': 'O'},
#   {'chronic': 'O'},
#   {'ACF': 'O'},
#   {'in': 'O'},
#   {'the': 'O'},
#   {'rat': 'O'},
#   {'.': 'O'},
#   {'Sprague': 'O'},
#   {'-': 'O'},
#   {'Dawley': 'O'},
#   {'rats': 'O'},
#   {'were': 'O'},
#   {'randomized': 'O'},
#   {'to': 'O'},
#   {'either': 'O'},
#   {'sham': 'B'},
#   {'or': 'O'},
#   {'ACF': 'O'},
#   {'±': 'O'},
#   {'allopurinol': 'O'},
#   {'(': 'O'},
#   {'100': 'O'},
#   {'mg·kg(-1)·day(-1': 'O'},
#   {')': 'O'},
#   {',': 'O'},
#   {'n': 'O'},
#   {'≥7': 'O'},
#   {'rats': 'O'},
#   {'/': 'O'},
#   {'group': 'O'},
#   {')': 'O'},
#   {'.': 'O'},
#   {'Echocardiography': 'B'},
#   {'at': 'O'},
#   {'8': 'O'},
#   {'wk': 'O'},
#   {'demonstrated': 'O'},
#   {'a': 'O'},
#   {'similar': 'O'},
#   {'37': 'O'},
#   {'%': 'O'},
#   {'increase': 'O'},
#   {'in': 'O'},
#   {'LV': 'O'},
#   {'end': 'B'},
#   {'-': 'O'},
#   {'diastolic': 'B'},
#   {'dimension': 'I'},
#   {'(': 'O'},
#   {'P': 'O'},
#   {'<': 'O'},
#   {'0.001': 'O'},
#   {')': 'O'},
#   {',': 'O'},
#   {'a': 'O'},
#   {'twofold': 'O'},
#   {'increase': 'O'},
#   {'in': 'O'},
#   {'LV': 'O'},
#   {'end': 'B'},
#   {'-': 'O'},
#   {'diastolic': 'B'},
#   {'pressure': 'O'},
#   {'/': 'O'},
#   {'wall': 'B'},
#   {'stress': 'I'},
#   {'(': 'O'},
#   {'P': 'O'},
#   {'<': 'O'},
#   {'0.05': 'O'},
#   {')': 'O'},
#   {',': 'O'},
#   {'and': 'O'},
#   {'a': 'O'},
#   {'twofold': 'O'},
#   {'increase': 'O'},
#   {'in': 'O'},
#   {'lung': 'B'},
#   {'weight': 'O'},
#   {'(': 'O'},
#   {'P': 'O'},
#   {'<': 'O'},
#   {'0.05': 'O'},
#   {')': 'O'},
#   {'in': 'O'},
#   {'treated': 'O'},
#   {'and': 'O'},
#   {'untreated': 'O'},
#   {'ACF': 'O'},
#   {'groups': 'O'},
#   {'versus': 'O'},
#   {'the': 'O'},
#   {'sham': 'B'},
#   {'group': 'O'},
#   {'.': 'O'},
#   {'LV': 'O'},
#   {'ejection': 'O'},
#   {'fraction': 'I'},
#   {',': 'O'},
#   {'velocity': 'B'},
#   {'of': 'O'},
#   {'circumferential': 'O'},
#   {'shortening': 'O'},
#   {',': 'O'},
#   {'maximal': 'O'},
#   {'systolic': 'O'},
#   {'elastance': 'O'},
#   {',': 'O'},
#   {'and': 'O'},
#   {'contractile': 'B'},
#   {'efficiency': 'O'},
#   {'were': 'O'},
#   {'significantly': 'O'},
#   {'depressed': 'O'},
#   {'in': 'O'},
#   {'ACF': 'O'},
#   {'and': 'O'},
#   {'significantly': 'O'},
#   {'improved': 'O'},
#   {'in': 'O'},
#   {'ACF': 'O'},
#   {'+': 'O'},
#   {'allopurinol': 'O'},
#   {'rats': 'O'},
#   {',': 'O'},
#   {'all': 'O'},
#   {'of': 'O'},
#   {'which': 'O'},
#   {'occurred': 'O'},
#   {'in': 'O'},
#   {'the': 'O'},
#   {'absence': 'O'},
#   {'of': 'O'},
#   {'changes': 'O'},
#   {'in': 'O'},
#   {'the': 'O'},
#   {'maximum': 'O'},
#   {'O2': 'O'},
#   {'consumption': 'O'},
#   {'rate': 'O'},
#   {'measured': 'O'},
#   {'in': 'O'},
#   {'isolated': 'O'},
#   {'cardiomyocytes': 'B'},
#   {'using': 'O'},
#   {'the': 'O'},
#   {'extracellular': 'B'},
#   {'flux': 'B'},
#   {'analyzer': 'O'},
#   {'.': 'O'},
#   {'However': 'O'},
#   {',': 'O'},
#   {'the': 'O'},
#   {'improvement': 'O'},
#   {'in': 'O'},
#   {'contractile': 'B'},
#   {'function': 'O'},
#   {'is': 'O'},
#   {'not': 'O'},
#   {'paralleled': 'O'},
#   {'by': 'O'},
#   {'any': 'O'},
#   {'attenuation': 'O'},
#   {'in': 'O'},
#   {'LV': 'O'},
#   {'dilatation': 'O'},
#   {',': 'O'},
#   {'LV': 'O'},
#   {'end': 'B'},
#   {'-': 'O'},
#   {'diastolic': 'B'},
#   {'pressure': 'O'},
#   {'/': 'O'},
#   {'wall': 'B'},
#   {'stress': 'I'},
#   {',': 'O'},
#   {'and': 'O'},
#   {'lung': 'B'},
#   {'weight': 'O'},
#   {'.': 'O'},
#   {'In': 'O'},
#   {'conclusion': 'O'},
#   {',': 'O'},
#   {'allopurinol': 'O'},
#   {'improves': 'O'},
#   {'LV': 'O'},
#   {'contractile': 'B'},
#   {'function': 'O'},
#   {'and': 'O'},
#   {'efficiency': 'O'},
#   {'possibly': 'O'},
#   {'by': 'O'},
#   {'diminishing': 'O'},
#   {'the': 'O'},
#   {'known': 'O'},
#   {'XO': 'B'},
#   {'-': 'O'},
#   {'mediated': 'O'},
#   {'ROS': 'B'},
#   {'effects': 'I'},
#   {'on': 'O'},
#   {'myofilament': 'O'},
#   {'Ca(2': 'O'},
#   {'+': 'O'},
#   {')': 'O'},
#   {'sensitivity': 'I'},
#   {'.': 'O'},
#   {'However': 'O'},
#   {',': 'O'},
#   {'LV': 'O'},
#   {'remodeling': 'O'},
#   {'and': 'O'},
#   {'diastolic': 'B'},
#   {'properties': 'O'},
#   {'are': 'O'},
#   {'not': 'O'},
#   {'improved': 'O'},
#   {',': 'O'},
#   {'which': 'O'},
#   {'may': 'O'},
#   {'explain': 'O'},
#   {'the': 'O'},
#   {'failure': 'O'},
#   {'of': 'O'},
#   {'XO': 'B'},
#   {'inhibition': 'O'},
#   {'to': 'O'},
#   {'improve': 'O'},
#   {'symptoms': 'O'},
#   {'and': 'O'},
#   {'hospitalizations': 'B'},
#   {'in': 'O'},
#   {'patients': 'O'},
#   {'with': 'O'},
#   {'severe': 'O'},
#   {'heart': 'B'},
#   {'failure': 'O'},
#   {'.': 'O'}],
#  [{'Relation': 'O'},
#   {'of': 'O'},
#   {'preoperative': 'O'},
#   {'serum': 'I'},
#   {'albumin': 'B'},
#   {'levels': 'O'},
#   {'to': 'O'},
#   {'survival': 'O'},
#   {'in': 'O'},
#   {'patients': 'O'},
#   {'undergoing': 'O'},
#   {' ': 'O'},
#   {'left': 'B'},
#   {'ventricular': 'B'},
#   {'assist': 'I'},
#   {'device': 'I'},
#   {'implantation': 'O'},
#   {'.': 'O'}],
#  [{'Hypoalbuminemia': 'B'},
#   {'has': 'O'},
#   {'been': 'O'},
#   {'recognized': 'O'},
#   {'as': 'O'},
#   {'a': 'O'},
#   {'prognostic': 'O'},
#   {'indicator': 'O'},
#   {'in': 'O'},
#   {'patients': 'O'},
#   {'with': 'O'},
#   {'heart': 'B'},
#   {'failure': 'I'},
#   {'.': 'O'},
#   {'We': 'O'},
#   {'aimed': 'O'},
#   {'to': 'O'},
#   {'investigate': 'O'},
#   {'the': 'B'},
#   {'association': 'O'},
#   {'of': 'O'},
#   {'hypoalbuminemia': 'B'},
#   {'with': 'O'},
#   {'postoperative': 'B'},
#   {'mortality': 'O'},
#   {'in': 'O'},
#   {'patients': 'O'},
#   {'undergoing': 'O'},
#   {'left': 'B'},
#   {'ventricular': 'B'},
#   {'assist': 'I'},
#   {'device': 'I'},
#   {'(': 'O'},
#   {'LVAD': 'B'},
#   {')': 'O'},
#   {'implantation': 'B'},
#   {'.': 'O'},
#   {'We': 'O'},
#   {'studied': 'O'},
#   {'272': 'O'},
#   {'consecutive': 'O'},
#   {'patients': 'O'},
#   {'undergoing': 'O'},
#   {'LVAD': 'B'},
#   {'implantation': 'B'},
#   {'from': 'O'},
#   {'2000': 'O'},
#   {'to': 'O'},
#   {'2010': 'O'},
#   {'at': 'O'},
#   {'our': 'O'},
#   {'institution': 'O'},
#   {'.': 'O'},
#   {'Preoperative': 'O'},
#   {'clinical': 'O'},
#   {'characteristics': 'O'},
#   {'and': 'O'},
#   {'laboratory': 'O'},
#   {'variables': 'O'},
#   {'associated': 'O'},
#   {'with': 'O'},
#   {'mortality': 'O'},
#   {'were': 'O'},
#   {'analyzed': 'O'},
#   {'.': 'O'},
#   {'Postoperative': 'O'},
#   {'survival': 'O'},
#   {'of': 'O'},
#   {'patients': 'O'},
#   {'with': 'O'},
#   {'preoperative': 'O'},
#   {'hypoalbuminemia': 'B'},
#   {'(': 'O'},
#   {'<': 'O'},
#   {'3.5': 'O'},
#   {'g': 'O'},
#   {'/': 'O'},
#   {'dl': 'O'},
#   {',': 'O'},
#   {'n': 'O'},
#   {'=': 'O'},
#   {'125': 'O'},
#   {')': 'O'},
#   {'and': 'O'},
#   {'those': 'O'},
#   {'with': 'O'},
#   {'normal': 'O'},
#   {'albumin': 'O'},
#   {'concentration': 'O'},
#   {'(': 'O'},
#   {'≥3.5': 'O'},
#   {'g': 'O'},
#   {'/': 'O'},
#   {'dl': 'O'},
#   {',': 'O'},
#   {'n': 'O'},
#   {'=': 'O'},
#   {'147': 'O'},
#   {')': 'O'},
#   {'was': 'O'},
#   {'compared': 'O'},
#   {'.': 'O'},
#   {'Survival': 'O'},
#   {'after': 'O'},
#   {'LVAD': 'O'},
#   {'surgery': 'O'},
#   {'was': 'O'},
#   {'better': 'O'},
#   {'in': 'O'},
#   {'patients': 'O'},
#   {'with': 'O'},
#   {'normal': 'O'},
#   {'albumin': 'O'},
#   {'levels': 'O'},
#   {'compared': 'O'},
#   {'with': 'O'},
#   {'those': 'O'},
#   {'with': 'O'},
#   {'hypoalbuminemia': 'B'},
#   {'before': 'O'},
#   {'surgery': 'O'},
#   {'(': 'O'},
#   {'3': 'O'},
#   {'and': 'O'},
#   {'12': 'O'},
#   {'months': 'O'},
#   {':': 'O'},
#   {'93.2': 'O'},
#   {'%': 'O'},
#   {'vs': 'O'},
#   {'82.4': 'O'},
#   {'%': 'O'},
#   {'and': 'O'},
#   {'88.4': 'O'},
#   {'%': 'O'},
#   {'vs': 'O'},
#   {'75.2': 'O'},
#   {'%': 'O'},
#   {',': 'O'},
#   {'respectively': 'O'},
#   {',': 'O'},
#   {'p': 'O'},
#   {'<': 'O'},
#   {'0.001': 'O'},
#   {')': 'O'},
#   {'.': 'O'},
#   {'Multivariate': 'O'},
#   {'analysis': 'O'},
#   {'revealed': 'O'},
#   {'that': 'O'},
#   {'preoperative': 'O'},
#   {'albumin': 'O'},
#   {'was': 'O'},
#   {'independently': 'O'},
#   {'associated': 'O'},
#   {'with': 'O'},
#   {'mortality': 'O'},
#   {'after': 'O'},
#   {'LVAD': 'B'},
#   {'implantation': 'O'},
#   {'(': 'O'},
#   {'hazard': 'O'},
#   {'ratio': 'I'},
#   {'0.521': 'O'},
#   {',': 'O'},
#   {'95': 'O'},
#   {'%': 'O'},
#   {'confidence': 'O'},
#   {'interval': 'O'},
#   {'0.290': 'O'},
#   {'to': 'O'},
#   {'0.934': 'O'},
#   {';': 'O'},
#   {'p': 'O'},
#   {'=': 'O'},
#   {'0.029': 'O'},
#   {'.': 'O'},
#   {')': 'O'},
#   {'Furthermore': 'O'},
#   {',': 'O'},
#   {'the': 'O'},
#   {'impact': 'O'},
#   {'of': 'O'},
#   {'normalization': 'O'},
#   {'of': 'O'},
#   {'albumin': 'O'},
#   {'levels': 'O'},
#   {'during': 'O'},
#   {'LVAD': 'O'},
#   {'support': 'O'},
#   {'on': 'O'},
#   {'postoperative': 'O'},
#   {'survival': 'O'},
#   {'was': 'O'},
#   {'analyzed': 'O'},
#   {'in': 'O'},
#   {'both': 'O'},
#   {'groups': 'O'},
#   {'.': 'O'},
#   {'Subgroup': 'O'},
#   {'analysis': 'O'},
#   {'of': 'O'},
#   {'patients': 'O'},
#   {'with': 'O'},
#   {'preoperative': 'O'},
#   {'hypoalbuminemia': 'B'},
#   {'and': 'O'},
#   {'postoperative': 'O'},
#   {'normalization': 'O'},
#   {'of': 'O'},
#   {'albumin': 'O'},
#   {'levels': 'O'},
#   {'(': 'O'},
#   {'n': 'O'},
#   {'=': 'O'},
#   {'81': 'O'},
#   {')': 'O'},
#   {'showed': 'O'},
#   {'improved': 'O'},
#   {'survival': 'O'},
#   {'compared': 'O'},
#   {'with': 'O'},
#   {'those': 'O'},
#   {'who': 'O'},
#   {'remained': 'O'},
#   {'hypoalbuminemia': 'B'},
#   {'(': 'O'},
#   {'n': 'O'},
#   {'=': 'O'},
#   {'44': 'O'},
#   {')': 'O'},
#   {'or': 'O'},
#   {'those': 'O'},
#   {'who': 'O'},
#   {'had': 'O'},
#   {'decreasing': 'O'},
#   {'albumin': 'O'},
#   {'levels': 'O'},
#   {'during': 'O'},
#   {'LVAD': 'O'},
#   {'support': 'O'},
#   {'(': 'O'},
#   {'n': 'O'},
#   {'=': 'O'},
#   {'40': 'O'},
#   {';': 'O'},
#   {'3-month': 'O'},
#   {'survival': 'O'},
#   {':': 'O'},
#   {'92.6': 'O'},
#   {'%': 'O'},
#   {'vs': 'O'},
#   {'63.6': 'O'},
#   {'%': 'O'},
#   {'and': 'O'},
#   {'65.0': 'O'},
#   {'%': 'O'},
#   {';': 'O'},
#   {'p': 'O'},
#   {'<': 'O'},
#   {'0.01': 'O'},
#   {')': 'O'},
#   {'.': 'O'},
#   {'In': 'O'},
#   {'conclusion': 'O'},
#   {',': 'O'},
#   {'preoperative': 'O'},
#   {'hypoalbuminemia': 'B'},
#   {'is': 'O'},
#   {'associated': 'O'},
#   {'with': 'O'},
#   {'poor': 'O'},
#   {'prognosis': 'O'},
#   {'after': 'O'},
#   {'LVAD': 'B'},
#   {'surgery': 'O'},
#   {'.': 'O'},
#   {'Postoperative': 'B'},
#   {'normalization': 'O'},
#   {'of': 'O'},
#   {'albumin': 'O'},
#   {'level': 'O'},
#   {'is': 'O'},
#   {'associated': 'O'},
#   {'with': 'O'},
#   {'improved': 'O'},
#   {'survival': 'O'},
#   {'.': 'O'},
#   {'Attention': 'O'},
#   {'to': 'O'},
#   {'albumin': 'O'},
#   {'levels': 'O'},
#   {'by': 'O'},
#   {'correcting': 'O'},
#   {'nutrition': 'O'},
#   {',': 'O'},
#   {'inflammation': 'B'},
#   {',': 'O'},
#   {'and': 'O'},
#   {'hepatic': 'O'},
#   {'function': 'O'},
#   {'could': 'O'},
#   {'be': 'O'},
#   {'an': 'O'},
#   {'effective': 'O'},
#   {'way': 'O'},
#   {'to': 'O'},
#   {'improve': 'O'},
#   {'prognosis': 'O'},
#   {'in': 'O'},
#   {'patients': 'O'},
#   {'evaluated': 'O'},
#   {'for': 'O'},
#   {'LVAD': 'B'},
#   {'implantation': 'B'},
#   {'.': 'O'}],
#  [{'Hospital': 'B'},
#   {'-': 'O'},
#   {'to': 'B'},
#   {'-': 'O'},
#   {'Home': 'B'},
#   {':': 'O'},
#   {'a': 'O'},
#   {'hospital': 'O'},
#   {'readmission': 'O'},
#   {'reduction': 'I'},
#   {'program': 'O'},
#   {'for': 'O'},
#   {'congestive': 'B'},
#   {'heart': 'B'},
#   {'failure': 'I'},
#   {'.': 'O'}],
#  [{'OBJECTIVE': 'B'}, {':': 'O'}],
#  [{'To': 'O'},
#   {'decrease': 'O'},
#   {'the': 'O'},
#   {'30-day': 'O'},
#   {'readmission': 'B'},
#   {'rate': 'O'},
#   {'following': 'O'},
#   {'hospital': 'O'},
#   {'stay': 'O'},
#   {'for': 'O'},
#   {'congestive': 'B'},
#   {'heart': 'B'},
#   {'failure': 'O'},
#   {',': 'O'},
#   {'which': 'O'},
#   {'in': 'O'},
#   {'the': 'O'},
#   {'United': 'O'},
#   {'States': 'O'},
#   {'approaches': 'O'},
#   {'30': 'O'},
#   {'percent': 'O'},
#   {'nationally': 'O'},
#   {'.': 'O'},
#   {'In': 'O'},
#   {'addition': 'O'},
#   {'to': 'O'},
#   {'indicating': 'O'},
#   {'possible': 'O'},
#   {'suboptimal': 'O'},
#   {'care': 'O'},
#   {'of': 'O'},
#   {'patients': 'O'},
#   {'with': 'O'},
#   {'this': 'O'},
#   {'condition': 'O'},
#   {',': 'O'},
#   {'there': 'O'},
#   {'are': 'O'},
#   {'significant': 'O'},
#   {'economic': 'B'},
#   {'considerations': 'O'},
#   {'.': 'O'}],
#  [{'DESIGN': 'B'}, {':': 'O'}],
#  [{'Prospective': 'O'},
#   {',': 'O'},
#   {'non': 'O'},
#   {'-': 'O'},
#   {'randomized': 'O'},
#   {',': 'O'},
#   {'two': 'B'},
#   {'-': 'O'},
#   {'center': 'I'},
#   {'pilot': 'B'},
#   {'project': 'O'},
#   {'.': 'O'}],
#  [{'SETTING': 'B'}, {':': 'O'}],
#  [{'General': 'B'},
#   {'hospital': 'O'},
#   {'and': 'O'},
#   {'cardiac': 'B'},
#   {'specialty': 'O'},
#   {'hospital': 'O'},
#   {',': 'O'},
#   {'both': 'O'},
#   {'located': 'O'},
#   {'in': 'O'},
#   {'a': 'O'},
#   {'community': 'O'},
#   {'of': 'O'},
#   {'150,000': 'O'},
#   {'population': 'O'},
#   {'in': 'O'},
#   {'predominantly': 'O'},
#   {'rural': 'O'},
#   {'South': 'O'},
#   {'Dakota': 'O'},
#   {'.': 'O'}],
#  [{'PARTICIPANTS': 'O'}, {':': 'O'}],
#  [{'All': 'O'},
#   {'patients': 'O'},
#   {'admitted': 'O'},
#   {'between': 'O'},
#   {'June': 'O'},
#   {'7': 'O'},
#   {',': 'O'},
#   {'2010': 'O'},
#   {'and': 'O'},
#   {'June': 'O'},
#   {'6': 'O'},
#   {',': 'O'},
#   {'2011': 'O'},
#   {'with': 'O'},
#   {'a': 'O'},
#   {'diagnosis': 'O'},
#   {'of': 'O'},
#   {'congestive': 'B'},
#   {'heart': 'B'},
#   {'failure': 'O'},
#   {'.': 'O'}],
#  [{'INTERVENTION': 'B'}, {':': 'O'}],
#  [{'An': 'O'},
#   {'intensive': 'O'},
#   {'transitions': 'B'},
#   {'of': 'O'},
#   {'care': 'I'},
#   {'program': 'O'},
#   {'was': 'O'},
#   {'implemented': 'O'},
#   {'to': 'O'},
#   {'ensure': 'O'},
#   {'adequate': 'O'},
#   {'self': 'O'},
#   {'-': 'O'},
#   {'management': 'O'},
#   {'training': 'B'},
#   {'of': 'O'},
#   {'patients': 'O'},
#   {'and': 'O'},
#   {'appropriate': 'O'},
#   {'out': 'B'},
#   {'-': 'O'},
#   {'patient': 'O'},
#   {'follow': 'B'},
#   {'-': 'O'},
#   {'up': 'O'},
#   {'and': 'O'},
#   {'monitoring': 'B'},
#   {'of': 'O'},
#   {'the': 'O'},
#   {'patient': 'O'},
#   {'by': 'O'},
#   {'the': 'O'},
#   {'health': 'O'},
#   {'care': 'I'},
#   {'system': 'I'},
#   {'.': 'O'}],
#  [{'MAIN': 'B'}, {'OUTCOME': 'O'}, {'MEASURE': 'O'}, {':': 'O'}],
#  [{'30-day': 'O'},
#   {'all': 'O'},
#   {'-': 'O'},
#   {'cause': 'O'},
#   {'readmissions': 'B'},
#   {'.': 'O'}],
#  [{'RESULTS': 'B'}, {':': 'O'}],
#  [{'A': 'O'},
#   {'statistically': 'O'},
#   {'significant': 'O'},
#   {'42': 'O'},
#   {'percent': 'O'},
#   {'relative': 'B'},
#   {'reduction': 'I'},
#   {'in': 'O'},
#   {'30-day': 'O'},
#   {'readmission': 'B'},
#   {'rate': 'I'},
#   {'was': 'O'},
#   {'documented': 'O'},
#   {'for': 'O'},
#   {'those': 'O'},
#   {'patients': 'O'},
#   {'participating': 'O'},
#   {'in': 'O'},
#   {'the': 'B'},
#   {'pilot': 'O'},
#   {'program': 'O'},
#   {'.': 'O'},
#   {'This': 'O'},
#   {'represented': 'O'},
#   {'a': 'O'},
#   {'net': 'B'},
#   {'economic': 'B'},
#   {'savings': 'I'},
#   {',': 'O'},
#   {'even': 'O'},
#   {'accounting': 'O'},
#   {'for': 'O'},
#   {'the': 'O'},
#   {'added': 'O'},
#   {'cost': 'B'},
#   {'of': 'O'},
#   {'the': 'O'},
#   {'intervention': 'O'},
#   {'.': 'O'}],
#  [{'CONCLUSIONS': 'O'}, {':': 'O'}],
#  [{'An': 'O'},
#   {'intensive': 'O'},
#   {'transitions': 'B'},
#   {'of': 'O'},
#   {'care': 'O'},
#   {'program': 'O'},
#   {'decreases': 'O'},
#   {'the': 'O'},
#   {'30-day': 'O'},
#   {'readmission': 'B'},
#   {'rate': 'O'},
#   {'for': 'O'},
#   {'patients': 'O'},
#   {'with': 'O'},
#   {'congestive': 'O'},
#   {'heart': 'B'},
#   {'failure': 'O'},
#   {'in': 'O'},
#   {'a': 'O'},
#   {'non': 'O'},
#   {'-': 'O'},
#   {'urbanized': 'O'},
#   {'Midwestern': 'O'},
#   {'state': 'O'},
#   {'like': 'O'},
#   {'South': 'O'},
#   {'Dakota': 'O'},
#   {'.': 'O'}],
#  [{'Comment': 'O'},
#   {'on': 'O'},
# ...
#   {'were': 'O'},
#   {'adjusted': 'O'},
#   {'for': 'O'},
#   {'demographics': 'O'},
#   {',': 'O'},
#   {'insurance': 'O'},
#   {'status': 'O'},
#   {',': 'O'},
#   {'and': 'O'},
#   {'comorbidities': 'O'},
#   {'.': 'O'},
#   {'A': 'O'},
#   {'median': 'O'},
#   {'rate': 'I'},
#   {'ratio': 'I'},
#   {'was': 'O'},
#   {'calculated': 'O'},
#   {'for': 'O'},
#   {'each': 'O'},
#   {'therapy': 'I'},
#   {',': 'O'},
#   {'which': 'O'},
#   {'describes': 'O'},
#   {'the': 'O'},
#   {'likelihood': 'O'},
#   {'that': 'O'},
#   {'the': 'B'},
#   {'treatment': 'O'},
#   {'of': 'O'},
#   {'a': 'O'},
#   {'patient': 'O'},
#   {'with': 'O'},
#   {'given': 'O'},
#   {'comorbidities': 'O'},
#   {'would': 'O'},
#   {'differ': 'O'},
#   {'at': 'O'},
#   {'2': 'O'},
#   {'randomly': 'O'},
#   {'selected': 'O'},
#   {'practices': 'O'},
#   {'.': 'O'},
#   {'We': 'O'},
#   {'identified': 'O'},
#   {'12': 'O'},
#   {'556': 'O'},
#   {'patients': 'O'},
#   {'from': 'O'},
#   {'45': 'O'},
#   {'practices': 'O'},
#   {'.': 'O'},
#   {'The': 'O'},
#   {'unadjusted': 'O'},
#   {'practice': 'O'},
#   {'-': 'O'},
#   {'level': 'O'},
#   {'prescription': 'O'},
#   {'rates': 'I'},
#   {'ranged': 'O'},
#   {'from': 'O'},
#   {'44': 'O'},
#   {'%': 'O'},
#   {'to': 'O'},
#   {'100': 'O'},
#   {'%': 'O'},
#   {'for': 'O'},
#   {'angiotensin': 'O'},
#   {'-': 'O'},
#   {'converting': 'O'},
#   {'enzyme': 'O'},
#   {'inhibitors': 'O'},
#   {'/': 'O'},
#   {'angiotensin': 'O'},
#   {'receptor': 'B'},
#   {'blockers': 'I'},
#   {'(': 'O'},
#   {'median': 'O'},
#   {',': 'O'},
#   {'85': 'O'},
#   {'%': 'O'},
#   {';': 'O'},
#   {'interquartile': 'O'},
#   {'range': 'O'},
#   {',': 'O'},
#   {'75%-89': 'O'},
#   {'%': 'O'},
#   {')': 'O'},
#   {',': 'O'},
#   {'from': 'O'},
#   {'49': 'O'},
#   {'%': 'O'},
#   {'to': 'O'},
#   {'100': 'O'},
#   {'%': 'O'},
#   {'for': 'O'},
#   {'β': 'B'},
#   {'-': 'O'},
#   {'blockers': 'I'},
#   {'(': 'O'},
#   {'median': 'O'},
#   {',': 'O'},
#   {'92': 'O'},
#   {'%': 'O'},
#   {';': 'O'},
#   {'interquartile': 'O'},
#   {'range': 'O'},
#   {',': 'O'},
#   {'83%-95': 'O'},
#   {'%': 'O'},
#   {')': 'O'},
#   {',': 'O'},
#   {'and': 'O'},
#   {'from': 'O'},
#   {'37': 'O'},
#   {'%': 'O'},
#   {'to': 'O'},
#   {'100': 'O'},
#   {'%': 'O'},
#   {'for': 'O'},
#   {'optimal': 'O'},
#   {'combined': 'B'},
#   {'treatment': 'O'},
#   {'(': 'O'},
#   {'median': 'O'},
#   {',': 'O'},
#   {'79': 'O'},
#   {'%': 'O'},
#   {';': 'O'},
#   {'interquartile': 'O'},
#   {'range': 'O'},
#   {',': 'O'},
#   {'66%-85': 'O'},
#   {'%': 'O'},
#   {')': 'O'},
#   {'.': 'O'},
#   {'The': 'O'},
#   {'adjusted': 'O'},
#   {'median': 'O'},
#   {'rate': 'I'},
#   {'ratio': 'I'},
#   {'was': 'O'},
#   {'1.11': 'O'},
#   {'(': 'O'},
#   {'95': 'O'},
#   {'%': 'O'},
#   {'confidence': 'O'},
#   {'interval': 'O'},
#   {',': 'O'},
#   {'1.08': 'O'},
#   {'-': 'O'},
#   {'1.18': 'O'},
#   {')': 'O'},
#   {'for': 'O'},
#   {'angiotensin': 'O'},
#   {'-': 'O'},
#   {'converting': 'O'},
#   {'enzyme': 'O'},
#   {'inhibitors': 'O'},
#   {'/': 'O'},
#   {'angiotensin': 'O'},
#   {'receptor': 'O'},
#   {'blockers': 'I'},
#   {'therapy': 'O'},
#   {',': 'O'},
#   {'1.08': 'O'},
#   {'(': 'O'},
#   {'95': 'O'},
#   {'%': 'O'},
#   {'confidence': 'O'},
#   {'interval': 'O'},
#   {',': 'O'},
#   {'1.05': 'O'},
#   {'-': 'O'},
#   {'1.15': 'O'},
#   {')': 'O'},
#   {'for': 'O'},
#   {'β': 'B'},
#   {'-': 'O'},
#   {'blockers': 'I'},
#   {'therapy': 'O'},
#   {',': 'O'},
#   {'and': 'O'},
#   {'1.17': 'O'},
#   {'(': 'O'},
#   {'1.13': 'O'},
#   {'-': 'O'},
#   {'1.26': 'O'},
#   {')': 'O'},
#   {'for': 'O'},
#   {'optimal': 'O'},
#   {'combined': 'B'},
#   {'treatment': 'O'},
#   {'.': 'O'}],
#  [{'CONCLUSIONS': 'O'}, {':': 'O'}],
#  [{'Variation': 'O'},
#   {'in': 'O'},
#   {'the': 'B'},
#   {'use': 'O'},
#   {'of': 'O'},
#   {'guideline': 'O'},
#   {'-': 'O'},
#   {'recommended': 'O'},
#   {'medications': 'O'},
#   {'for': 'O'},
#   {'patients': 'O'},
#   {'with': 'O'},
#   {'heart': 'B'},
#   {'failure': 'I'},
#   {'and': 'O'},
#   {'reduced': 'O'},
#   {'ejection': 'B'},
#   {'fraction': 'O'},
#   {'exists': 'O'},
#   {'in': 'O'},
#   {'the': 'B'},
#   {'outpatient': 'O'},
#   {'setting': 'O'},
#   {'.': 'O'},
#   {'Addressing': 'O'},
#   {'practice': 'O'},
#   {'-': 'O'},
#   {'level': 'O'},
#   {'differences': 'O'},
#   {'may': 'O'},
#   {'be': 'O'},
#   {'an': 'O'},
#   {'important': 'O'},
#   {'component': 'O'},
#   {'of': 'O'},
#   {'improving': 'O'},
#   {'quality': 'O'},
#   {'of': 'O'},
#   {'care': 'O'},
#   {'for': 'O'},
#   {'patients': 'O'},
#   {'with': 'O'},
#   {'heart': 'B'},
#   {'failure': 'O'},
#   {'and': 'O'},
#   {'reduced': 'O'},
#   {'ejection': 'B'},
#   {'fraction': 'O'},
#   {'.': 'O'}],
#  [{'The': 'O'},
#   {'reality': 'O'},
#   {'of': 'O'},
#   {'heart': 'B'},
#   {'failure': 'I'},
#   {'in': 'O'},
#   {'Latin': 'O'},
#   {'America': 'O'},
#   {'.': 'O'}],
#  [{'Heart': 'B'},
#   {'failure': 'I'},
#   {'(': 'O'},
#   {'HF': 'O'},
#   {')': 'O'},
#   {'data': 'O'},
#   {'in': 'O'},
#   {'Latin': 'O'},
#   {'America': 'O'},
#   {'(': 'O'},
#   {'LA': 'O'},
#   {')': 'O'},
#   {'were': 'O'},
#   {'reviewed': 'O'},
#   {'to': 'O'},
#   {'guide': 'O'},
#   {'health': 'O'},
#   {'service': 'I'},
#   {'planning': 'O'},
#   {'in': 'O'},
#   {'the': 'O'},
#   {'prevention': 'O'},
#   {'and': 'O'},
#   {'treatment': 'O'},
#   {'of': 'O'},
#   {'HF': 'O'},
#   {'.': 'O'},
#   {'The': 'O'},
#   {'HF': 'O'},
#   {'epidemiology': 'B'},
#   {'and': 'O'},
#   {'the': 'O'},
#   {'adequacy': 'O'},
#   {'of': 'O'},
#   {'relevant': 'O'},
#   {'health': 'O'},
#   {'service': 'I'},
#   {'provision': 'O'},
#   {'related': 'O'},
#   {'to': 'O'},
#   {'HF': 'O'},
#   {'in': 'O'},
#   {'LA': 'O'},
#   {'are': 'O'},
#   {'not': 'O'},
#   {'well': 'O'},
#   {'delineated': 'O'},
#   {'.': 'O'},
#   {'A': 'O'},
#   {'systematic': 'O'},
#   {'search': 'O'},
#   {'of': 'O'},
#   {'the': 'O'},
#   {'electronic': 'O'},
#   {'databases': 'O'},
#   {'and': 'O'},
#   {'the': 'O'},
#   {'World': 'O'},
#   {'Health': 'O'},
#   {'Organization': 'O'},
#   {'website': 'O'},
#   {'was': 'O'},
#   {'undertaken': 'O'},
#   {'for': 'O'},
#   {'HF': 'O'},
#   {'in': 'O'},
#   {'LA': 'O'},
#   {'.': 'O'},
#   {'LA': 'O'},
#   {'countries': 'O'},
#   {'have': 'O'},
#   {'reduced': 'O'},
#   {'gross': 'O'},
#   {'income': 'O'},
#   {'and': 'O'},
#   {'lower': 'O'},
#   {'total': 'O'},
#   {'expenditure': 'B'},
#   {'on': 'O'},
#   {'health': 'O'},
#   {'per': 'O'},
#   {'capita': 'O'},
#   {'.': 'O'},
#   {'LA': 'O'},
#   {'is': 'O'},
#   {'a': 'O'},
#   {'heterogeneous': 'O'},
#   {'region': 'O'},
#   {'with': 'O'},
#   {'HF': 'O'},
#   {'risk': 'O'},
#   {'factors': 'O'},
#   {'of': 'O'},
#   {'developed': 'O'},
#   {'and': 'O'},
#   {'nondeveloped': 'B'},
#   {'countries': 'O'},
#   {',': 'O'},
#   {'including': 'O'},
#   {'lower': 'O'},
#   {'risk': 'O'},
#   {'of': 'O'},
#   {'raised': 'O'},
#   {'blood': 'B'},
#   {'glucose': 'B'},
#   {'levels': 'O'},
#   {',': 'O'},
#   {'obesity': 'B'},
#   {',': 'O'},
#   {'tobacco': 'B'},
#   {',': 'O'},
#   {'and': 'O'},
#   {'aging': 'O'},
#   {',': 'O'},
#   {'whereas': 'O'},
#   {'systemic': 'O'},
#   {'hypertension': 'B'},
#   {'(': 'O'},
#   {'SH': 'O'},
#   {')': 'O'},
#   {',': 'O'},
#   {'rheumatic': 'B'},
#   {'fever': 'B'},
#   {',': 'O'},
#   {'and': 'O'},
#   {'Chagas': 'O'},
#   {"'": 'O'},
#   {'disease': 'O'},
#   {'(': 'O'},
#   {"C'D": 'O'},
#   {')': 'O'},
#   {'are': 'O'},
#   {'higher': 'O'},
#   {'in': 'O'},
#   {'LA': 'O'},
#   {'.': 'O'},
#   {'Main': 'O'},
#   {'etiologies': 'O'},
#   {'of': 'O'},
#   {'HF': 'O'},
#   {'in': 'O'},
#   {'LA': 'O'},
#   {'are': 'O'},
#   {'idiopathic': 'B'},
#   {'dilated': 'O'},
#   {'cardiomyopathy': 'B'},
#   {'(': 'O'},
#   {'from': 'O'},
#   {'1.3': 'O'},
#   {'%': 'O'},
#   {'to': 'O'},
#   {'37': 'O'},
#   {'%': 'O'},
#   {')': 'O'},
#   {',': 'O'},
#   {"C'D": 'O'},
#   {'(': 'O'},
#   {'from': 'O'},
#   {'1.3': 'O'},
#   {'%': 'O'},
#   {'to': 'O'},
#   {'21': 'O'},
#   {'%': 'O'},
#   {')': 'O'},
#   {',': 'O'},
#   {'ischemic': 'B'},
#   {'(': 'O'},
#   {'from': 'O'},
#   {'68': 'O'},
#   {'%': 'O'},
#   {'to': 'O'},
#   {'17': 'O'},
#   {'%': 'O'},
#   {')': 'O'},
#   {',': 'O'},
#   {'SH': 'O'},
#   {'(': 'O'},
#   {'from': 'O'},
#   {'14': 'O'},
#   {'%': 'O'},
#   {'to': 'O'},
#   {'76': 'O'},
#   {'%': 'O'},
#   {')': 'O'},
#   {',': 'O'},
#   {'valvular': 'O'},
#   {'(': 'O'},
#   {'from': 'O'},
#   {'3': 'O'},
#   {'%': 'O'},
#   {'to': 'O'},
#   {'22': 'O'},
#   {'%': 'O'},
#   {')': 'O'},
#   {',': 'O'},
#   {'and': 'O'},
#   {'alcohol': 'B'},
#   {'related': 'O'},
#   {'(': 'O'},
#   {'from': 'O'},
#   {'1.1': 'O'},
#   {'%': 'O'},
#   {'to': 'O'},
#   {'8': 'O'},
#   {'%': 'O'},
#   {')': 'O'},
#   {'.': 'O'},
#   {'The': 'O'},
#   {'prognosis': 'O'},
#   {'of': 'O'},
#   {"C'D": 'O'},
#   {'HF': 'O'},
#   {'is': 'O'},
#   {'worse': 'O'},
#   {'than': 'O'},
#   {'for': 'O'},
#   {'other': 'O'},
#   {'etiologies': 'O'},
#   {'.': 'O'},
#   {'Chronic': 'O'},
#   {'HF': 'O'},
#   {'is': 'O'},
#   {'the': 'O'},
#   {'cause': 'O'},
#   {'of': 'O'},
#   {'death': 'O'},
#   {'in': 'O'},
#   {'6.3': 'O'},
#   {'%': 'O'},
#   {'of': 'O'},
#   {'cases': 'O'},
#   {'.': 'O'},
#   {'Decompensated': 'O'},
#   {'HF': 'O'},
#   {'is': 'O'},
#   {'the': 'O'},
#   {'main': 'O'},
#   {'cause': 'O'},
#   {'of': 'O'},
#   {'cardiovascular': 'B'},
#   {'hospitalization': 'O'},
#   {'.': 'O'},
#   {'The': 'O'},
#   {'prevalence': 'O'},
#   {'of': 'O'},
#   {'systolic': 'O'},
#   {'HF': 'O'},
#   {'varies': 'O'},
#   {'from': 'O'},
#   {'64': 'O'},
#   {'%': 'O'},
#   {'to': 'O'},
#   {'69': 'O'},
#   {'%': 'O'},
#   {'.': 'O'},
#   {'LA': 'O'},
#   {'is': 'O'},
#   {'under': 'O'},
#   {'the': 'O'},
#   {'awful': 'O'},
#   {'paradox': 'O'},
#   {'of': 'O'},
#   {'having': 'O'},
#   {'the': 'O'},
#   {'HF': 'O'},
#   {'risk': 'O'},
#   {'factors': 'O'},
#   {'and': 'O'},
#   {'HF': 'O'},
#   {'epidemiology': 'B'},
#   {'of': 'O'},
#   {'developed': 'O'},
#   {'countries': 'O'},
#   {'with': 'O'},
#   {'the': 'O'},
#   {'added': 'O'},
#   {'factors': 'O'},
#   {'of': 'O'},
#   {'SH': 'O'},
#   {',': 'O'},
#   {"C'D": 'O'},
#   {',': 'O'},
#   {'and': 'O'},
#   {'rheumatic': 'B'},
#   {'fever': 'O'},
#   {'.': 'O'},
#   {'Overall': 'O'},
#   {',': 'O'},
#   {'in': 'O'},
#   {'the': 'O'},
#   {'scenario': 'O'},
#   {'of': 'O'},
#   {'lower': 'O'},
#   {'total': 'O'},
#   {'expenditure': 'B'},
#   {'on': 'O'},
#   {'health': 'O'},
#   {'per': 'O'},
#   {'capita': 'O'},
#   {'and': 'O'},
#   {'lower': 'O'},
#   {'gross': 'O'},
#   {'national': 'O'},
#   {'income': 'O'},
#   {'per': 'O'},
#   {'capita': 'O'},
#   {',': 'O'},
#   {'new': 'O'},
#   {'strategies': 'O'},
#   {'are': 'O'},
#   {'essential': 'O'},
#   {'for': 'O'},
#   {'prevention': 'O'},
#   {'and': 'O'},
#   {'treatment': 'O'},
#   {'of': 'O'},
#   {'HF': 'O'},
#   {'in': 'O'},
#   {'LA': 'O'},
#   {'.': 'O'}],
#  [{'Testosterone': 'B'},
#   {'therapy': 'I'},
#   {'during': 'O'},
#   {'exercise': 'B'},
#   {'rehabilitation': 'O'},
#   {'in': 'O'},
#   {'male': 'O'},
#   {'patients': 'O'},
#   {'with': 'O'},
#   {'chronic': 'O'},
#   {'heart': 'B'},
#   {'failure': 'O'},
#   {'who': 'O'},
#   {'have': 'O'},
#   {'low': 'O'},
#   {'testosterone': 'B'},
#   {'status': 'O'},
#   {':': 'O'},
#   {'a': 'O'},
#   {'double': 'O'},
#   {'-': 'O'},
#   {'blind': 'O'},
#   {'randomized': 'O'},
#   {'controlled': 'O'},
#   {'feasibility': 'O'},
#   {'study': 'O'},
#   {'.': 'O'}],
#  [{'BACKGROUND': 'B'}, {':': 'O'}],
#  [{'This': 'O'},
#   {'study': 'O'},
#   {'assessed': 'O'},
#   {'the': 'B'},
#   {'feasibility': 'O'},
#   {'of': 'O'},
#   {'a': 'O'},
#   {'12-week': 'O'},
#   {'program': 'O'},
#   {'of': 'O'},
#   {'exercise': 'B'},
#   {',': 'O'},
#   {'with': 'O'},
#   {'and': 'O'},
#   {'without': 'O'},
#   {'intramuscular': 'B'},
#   {'testosterone': 'B'},
#   {'supplementation': 'O'},
#   {',': 'O'},
#   {'in': 'O'},
#   {'male': 'O'},
#   {'patients': 'O'},
#   {'with': 'O'},
#   {'chronic': 'O'},
#   {'heart': 'B'},
#   {'failure': 'I'},
#   {'(': 'O'},
#   {'CHF': 'B'},
#   {')': 'O'},
#   {'and': 'O'},
#   {'low': 'O'},
#   {'testosterone': 'B'},
#   {'status': 'O'},
#   {'and': 'O'},
#   {'collected': 'O'},
#   {'preliminary': 'O'},
#   {'data': 'O'},
#   {'for': 'O'},
#   {'key': 'O'},
#   {'health': 'O'},
#   {'outcomes': 'O'},
#   {'.': 'O'}],
#  [{'METHODS': 'O'}, {':': 'O'}],
#  [{'Male': 'O'},
#   {'patients': 'O'},
#   {'with': 'O'},
#   {'CHF': 'B'},
#   {'(': 'O'},
#   {'n': 'O'},
#   {'=': 'O'},
#   {'41': 'O'},
#   {',': 'O'},
#   {'age': 'O'},
#   {'67.2': 'O'},
#   {'years': 'O'},
#   {',': 'O'},
#   {'range': 'O'},
#   {'51': 'O'},
#   {'-': 'O'},
#   {'84': 'O'},
#   {'years': 'O'},
#   {')': 'O'},
#   {'with': 'O'},
#   {'mean': 'O'},
#   {'±': 'O'},
#   {'SD': 'O'},
#   {'testosterone': 'B'},
#   {'levels': 'O'},
#   {'of': 'O'},
#   {'10.7': 'O'},
#   {'±': 'O'},
#   {'2.6': 'O'},
#   {'nmol': 'B'},
#   {'/': 'O'},
#   {'L': 'O'},
#   {'(': 'O'},
#   {'309': 'O'},
#   {'±': 'O'},
#   {'76': 'O'},
#   {'ng': 'B'},
#   {'/': 'O'},
#   {'dL': 'O'},
#   {')': 'O'},
#   {'were': 'O'},
#   {'randomly': 'O'},
#   {'allocated': 'O'},
#   {'to': 'O'},
#   {'exercise': 'B'},
#   {'with': 'O'},
#   {'testosterone': 'B'},
#   {'or': 'O'},
#   {'placebo': 'O'},
#   {'groups': 'O'},
#   {'.': 'O'},
#   {'Feasibility': 'O'},
#   {'was': 'O'},
#   {'assessed': 'O'},
#   {'in': 'O'},
#   {'terms': 'O'},
#   {'of': 'O'},
#   {'recruitment': 'O'},
#   {',': 'O'},
#   {'intervention': 'O'},
#   {'compliance': 'B'},
#   {',': 'O'},
#   {'and': 'O'},
#   {'attrition': 'O'},
#   {'.': 'O'},
#   {'Outcomes': 'O'},
#   {'included': 'O'},
#   {'an': 'O'},
#   {'incremental': 'O'},
#   {'shuttle': 'B'},
#   {'walk': 'B'},
#   {'test': 'I'},
#   {',': 'O'},
#   {'peak': 'O'},
#   {'oxygen': 'B'},
#   {'uptake': 'I'},
#   {',': 'O'},
#   {'muscular': 'B'},
#   {'strength': 'O'},
#   {',': 'O'},
#   {'echocardiographic': 'B'},
#   {'measures': 'O'},
#   {',': 'O'},
#   {'N': 'B'},
#   {'-': 'O'},
#   {'terminal': 'B'},
#   {'pro': 'B'},
#   {'-': 'O'},
#   {'brain': 'B'},
#   {'natriuretic': 'B'},
#   {'peptide': 'I'},
#   {',': 'O'},
#   {'inflammatory': 'B'},
#   {'markers': 'O'},
#   {',': 'O'},
#   {'depression': 'B'},
#   {'(': 'O'},
#   {'Beck': 'O'},
#   {'Depression': 'O'},
#   {'Inventory': 'O'},
#   {')': 'O'},
#   {',': 'O'},
#   {'and': 'O'},
#   {'health': 'O'},
#   {'-': 'O'},
#   {'related': 'O'},
#   {'quality': 'O'},
#   {'of': 'O'},
#   {'life': 'O'},
#   {'(': 'O'},
#   {'Minnesota': 'O'},
#   {'Living': 'O'},
#   {'with': 'O'},
#   {'Heart': 'B'},
#   {'Failure': 'O'},
#   {'Questionnaire': 'O'},
#   {'and': 'O'},
#   {'Medical': 'B'},
#   {'Outcomes': 'O'},
#   {'Study': 'O'},
#   {'Short': 'O'},
#   {'-': 'O'},
#   {'Form': 'O'},
#   {')': 'O'},
#   {'.': 'O'}],
#  [{'RESULTS': 'B'}, {':': 'O'}],
#  [{'Attrition': 'I'},
#   {'was': 'O'},
#   {'30': 'O'},
#   {'%': 'O'},
#   {'but': 'O'},
#   {'with': 'O'},
#   {'100': 'O'},
#   {'%': 'O'},
#   {'compliance': 'B'},
#   {'to': 'O'},
#   {'exercise': 'B'},
#   {'and': 'O'},
#   {'injections': 'O'},
#   {'in': 'O'},
#   {'patients': 'O'},
#   {'who': 'O'},
#   {'completed': 'O'},
#   {'the': 'O'},
#   {'study': 'O'},
#   {'.': 'O'},
#   {'Similar': 'O'},
#   {'improvements': 'O'},
#   {'in': 'O'},
#   {'shuttle': 'B'},
#   {'walk': 'B'},
#   {'test': 'I'},
#   {'(': 'O'},
#   {'18': 'O'},
#   {'%': 'O'},
#   {'vs': 'O'},
#   {'19': 'O'},
#   {'%': 'O'},
#   {')': 'O'},
#   {',': 'O'},
#   {'body': 'O'},
#   {'mass': 'I'},
#   {'(': 'O'},
#   {'-1.3': 'O'},
#   {'kg': 'O'},
#   {'vs': 'O'},
#   {'-1.0': 'O'},
#   {'kg': 'O'},
#   {')': 'O'},
#   {',': 'O'},
#   {'and': 'O'},
#   {'hand': 'B'},
#   {'grip': 'B'},
#   {'strength': 'O'},
#   {'(': 'O'},
#   {'2.1': 'O'},
#   {'kg': 'O'},
#   {'vs': 'O'},
#   {'2.5': 'O'},
#   {'kg': 'O'},
#   {')': 'O'},
#   {'from': 'O'},
#   {'baseline': 'O'},
#   {'were': 'O'},
#   {'observed': 'O'},
#   {'in': 'O'},
#   {'both': 'O'},
#   {'groups': 'O'},
#   {'.': 'O'},
#   {'The': 'O'},
#   {'exercise': 'B'},
#   {'with': 'O'},
#   {'testosterone': 'B'},
#   {'group': 'O'},
#   {'showed': 'O'},
#   {'improvements': 'O'},
#   {'from': 'O'},
#   {'baseline': 'O'},
#   {'in': 'O'},
#   {'peak': 'B'},
#   {'oxygen': 'B'},
#   {'uptake': 'I'},
#   {'(': 'O'},
#   {'P': 'O'},
#   {'<': 'O'},
#   {'.01': 'O'},
#   {')': 'O'},
#   {',': 'O'},
#   {'Beck': 'O'},
#   {'Depression': 'B'},
#   {'Inventory': 'O'},
#   {'(': 'O'},
#   {'P': 'O'},
#   {'<': 'O'},
#   {'.05': 'O'},
#   {')': 'O'},
#   {',': 'O'},
#   {'leg': 'B'},
#   {'strength': 'O'},
#   {'(': 'O'},
#   {'P': 'O'},
#   {'<': 'O'},
#   {'.05': 'O'},
#   {')': 'O'},
#   {',': 'O'},
#   {'and': 'O'},
#   {'several': 'O'},
#   {'Medical': 'B'},
#   {'Outcomes': 'O'},
#   {'Study': 'O'},
#   {'Short': 'O'},
#   {'-': 'O'},
#   {'Form': 'O'},
#   {'quality': 'O'},
#   {'of': 'O'},
#   {'life': 'I'},
#   {'domains': 'O'},
#   {'(': 'O'},
#   {'P': 'O'},
#   {'<': 'O'},
#   {'.05': 'O'},
#   {')': 'O'},
#   {',': 'O'},
#   {'which': 'O'},
#   {'were': 'O'},
#   {'generally': 'O'},
#   {'not': 'O'},
#   {'apparent': 'O'},
#   {'in': 'O'},
#   {'the': 'O'},
#   {'exercise': 'B'},
#   {'with': 'O'},
#   {'placebo': 'O'},
#   {'group': 'O'},
#   {'.': 'O'},
#   {'Echocardiographic': 'B'},
#   {'measures': 'O'},
#   {',': 'O'},
#   {'N': 'B'},
#   {'-': 'O'},
#   {'terminal': 'B'},
#   {'pro': 'B'},
#   {'-': 'O'},
#   {'brain': 'B'},
#   {'natriuretic': 'B'},
#   {'peptide': 'I'},
#   {',': 'O'},
#   {'and': 'O'},
#   {'inflammatory': 'B'},
#   {'markers': 'O'},
#   {'were': 'O'},
#   {'mostly': 'O'},
#   {'unchanged': 'O'},
#   {'.': 'O'}],
#  ...]

# %%
preds =  get_term_(predictions)

# %%
print(evaluation_metrics(preds, gt))
stop_words = set(stopwords.words('english'))
pred_terms =  set(preds) - set(stop_words)
pred_terms = [x for x in pred_terms if len(x)>1]
pred_terms = [x.strip() for x in pred_terms]
pred_terms = [re.sub(' -','-', x) for x in pred_terms]
pred_terms = [re.sub('- ','-', x) for x in pred_terms]
pred_terms = [re.sub(' \(','', x) for x in pred_terms]
evaluation_metrics(pred_terms, gt)
# Out:
# Prediction:  1674
# GT:  2361
# 701 973 1660
# (41.88, 29.69, 34.75)
# Prediction:  1656
# GT:  2361
# 703 953 1658
# (42.45, 29.78, 35.0)

# %%
evaluation_metrics(pred_terms, gt)
# Out:
# Prediction:  1656
# GT:  2361
# 703 953 1658
# (42.45, 29.78, 35.0)

# %%
def lemma(li):
    new_list = []
    for t in li:
        doc = nlp(str(t))
        doc1 = ' '.join([word.lemma for sent in doc.sentences for word in sent.words])
#         doc1 = re.sub('-',' ',doc1)
#         doc1 = re.sub(' +', ' ',doc1)
        new_list.append(doc1)
    new_list = [s for s in new_list if len(s) >= 2]
    return new_list

preds_lem = lemma(pred_terms)
gts_lem = lemma(gt)

print('After lemmatization')
print(len(set(preds_lem)))
print(len(set((gts_lem))))
print(evaluation_metrics(list(set(preds_lem)), list(set(gts_lem))))
# Out:
# After lemmatization
# 1570
# 2180
# Prediction:  1570
# GT:  2180
# 656 914 1524
# (41.78, 30.09, 34.98)

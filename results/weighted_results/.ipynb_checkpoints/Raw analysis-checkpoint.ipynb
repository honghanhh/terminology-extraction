# %%
import pandas as pd
import pickle as pkl
import re
from collections import Counter
import nltk
nltk.download('stopwords')
from nltk.corpus import stopwords 

import stanza
# stanza.download('en')
nlp = stanza.Pipeline(lang='en', processors='tokenize,mwt,pos,lemma')

def count_freq(preds, gts):
    preds_len = [len(x.split(' ')) for x in preds]
    gts_len = [len(x.split(' ')) for x in gts]
    print(Counter(preds_len))
    print(Counter(gts_len))

def evaluation_metrics(pred, gt):
    print("Prediction: ", len(set(pred)))
    print("GT: ",len(set(gt)))
    TP = len(set(pred) & set(gt)) 
    FP = len(set(pred)-set(gt))
    FN = len(set(gt)-set(pred))
    print(TP,FP,FN)
    precision = round((TP/(TP+FP))*100, 2)
    recall = round((TP/(TP+FN))*100,2)
    f1_score = round((2 * precision * recall) / (precision + recall),2)
    return precision, recall, f1_score 

def lemma(li):
    new_list = []
    for t in li:
        doc = nlp(str(t))
        doc1 = ' '.join([word.lemma for sent in doc.sentences for word in sent.words])
        doc1 = re.sub('-',' ',doc1)
        doc1 = re.sub(' +', ' ',doc1)
        new_list.append(doc1)
    new_list = [s for s in new_list if len(s) >= 2]
    return new_list

def get_term_(predictions):
    all_term = []
    for sentence in predictions:
        tokens = []
        labels = []
        for d in sentence:
            tokens.extend(d.keys())
            labels.extend(d.values())

        for i, label in enumerate(labels):
            if labels[i] == 'I' and (i == 0 or labels[i - 1] == 'O'):
                labels[i] = 'O'

        terms = []
        term = []
        for token, label in zip(tokens, labels):
            if label == 'B':
                #Lưu vị trí B
                b_pos = i
                term = [token]
            elif label == 'I':
                term.append(token)
            elif len(term) > 0:
                terms.append(' '.join(term))
                term = []
        if len(term) > 0:
            terms.append(' '.join(term))
            # Check b_pos = 0 không
        all_term.append(terms)
    
    final_terms = []
    for i in all_term:
        final_terms.extend(i)

    final_terms = [x.lower().strip() for x in final_terms]
    return final_terms
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     /Users/hanhtran/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# 2021-06-08 13:51:04 WARNING: Can not find mwt: default from official model list. Ignoring it.
# 2021-06-08 13:51:04 INFO: Loading these models for language: en (English):
# ========================
# | Processor | Package  |
# ------------------------
# | tokenize  | combined |
# | pos       | combined |
# | lemma     | combined |
# ========================
#
# 2021-06-08 13:51:04 INFO: Use device: cpu
# 2021-06-08 13:51:04 INFO: Loading: tokenize
# 2021-06-08 13:51:04 INFO: Loading: pos
# 2021-06-08 13:51:04 INFO: Loading: lemma
# 2021-06-08 13:51:04 INFO: Done loading processors!

# %%
def get_term(predictions):
    all_term = []
    for sentence in predictions:
        tokens = []
        labels = []
        for d in sentence:
            tokens.extend(d.keys())
            labels.extend(d.values())

        for i, label in enumerate(labels):
            if labels[i] == 'I' and (i == 0 or labels[i - 1] == 'O'):
                labels[i] = 'O'

        terms = []
        term = []
        for i, (token, label) in enumerate(zip(tokens, labels)):
            if label == 'B': 
                #Lưu vị trí B
                b_pos = i
                term = [token]
            elif label == 'I':
                term.append(token)
            elif len(term) > 0:
                terms.append(' '.join(term))
                # Check b_pos = 0 không
                if b_pos != 0:
                    if (tokens[b_pos - 1] != '') and (tokens[b_pos - 1] != ' '):
                        if len(nlp(str(tokens[b_pos - 1])).sentences) > 0:
                            b_word = nlp(str(tokens[b_pos - 1])).sentences[0].words[0]
                            if len(nlp(str(tokens[b_pos])).sentences) > 0:
                                c_word = nlp(str(tokens[b_pos])).sentences[0].words[0]
                                if (c_word.upos == 'NOUN') and (c_word.text != 'None') and (b_word.text != 'None') and ((b_word.upos == 'NOUN') or (b_word.upos == 'ADJ')):
                                    terms.append(' '.join([b_word.text] + term))
                    if (tokens[i] != '') and (tokens[i] != ' '):
                        if len(nlp(str(tokens[i])).sentences) > 0:
                            a_word = nlp(str(tokens[i])).sentences[0].words[0]
                            if (a_word.text != 'None') and (a_word.upos == 'NOUN'):
                                terms.append(' '.join(term + [a_word.text]))
                    
                    #ADJ NOUN NOUN
                    if (tokens[i] != '') and (tokens[i] != ' ') and (tokens[b_pos - 1] != '') and (tokens[b_pos - 1] != ' '):
                        if len(nlp(str(tokens[b_pos - 1])).sentences) > 0 and len(nlp(str(tokens[i])).sentences) > 0:
                            a_word = nlp(str(tokens[i])).sentences[0].words[0]
                            b_word = nlp(str(tokens[b_pos - 1])).sentences[0].words[0]
                            if len(nlp(str(tokens[b_pos])).sentences) > 0:
                                c_word = nlp(str(tokens[b_pos])).sentences[0].words[0]
                                # Check vị trí b_pos - 1: terms.append()
                                if (c_word.text != 'None') and (c_word.upos == 'NOUN') and (b_word.text != 'None') and ((b_word.upos == 'ADJ') and (a_word.upos == 'NOUN')):
                                    terms.append(' '.join([b_word.text] + term + [a_word.text]))
#                                     print(terms)
                    #ADJ ADJ NOUN              
                    if (tokens[b_pos - 2] != '') and (tokens[b_pos - 2] != ' ') and (tokens[b_pos - 1] != '') and (tokens[b_pos - 1] != ' '):
                        if (len(nlp(str(tokens[b_pos - 2])).sentences) > 0 and len(nlp(str(tokens[b_pos - 1])).sentences) > 0 and len(nlp(str(tokens[b_pos])).sentences) > 0):
                            b1_word = nlp(str(tokens[b_pos - 2])).sentences[0].words[0] 
                            b_word = nlp(str(tokens[b_pos - 1])).sentences[0].words[0]
                            c_word = nlp(str(tokens[b_pos])).sentences[0].words[0]
                            # Check vị trí b_pos - 1: terms.append()
                            if (c_word.upos == 'NOUN') and (c_word.text != 'None') and (b_word.text != 'None') and (b1_word.text != 'None') and ((b_word.upos == 'ADJ') and (b1_word.upos == 'ADJ')):
                                terms.append(' '.join([b1_word.text] +[b_word.text] + term))
#                                 print(terms)
                    #NOUN ADJ NOUN
                    if (tokens[b_pos - 2] != '') and (tokens[b_pos - 2] != ' ') and (tokens[b_pos - 1] != '') and (tokens[b_pos - 1] != ' '):
                        if (len(nlp(str(tokens[b_pos - 2])).sentences) > 0 and len(nlp(str(tokens[b_pos - 1])).sentences) > 0 and len(nlp(str(tokens[b_pos])).sentences) > 0):
                            b1_word = nlp(str(tokens[b_pos - 2])).sentences[0].words[0] 
                            b_word = nlp(str(tokens[b_pos - 1])).sentences[0].words[0]
                            c_word = nlp(str(tokens[b_pos])).sentences[0].words[0]
                            # Check vị trí b_pos - 1: terms.append()
                            if (c_word.upos == 'NOUN') and (c_word.text != 'None') and (b_word.text != 'None') and (b1_word.text != 'None') and ((b_word.upos == 'ADJ') and (b1_word.upos == 'NOUN')):
                                terms.append(' '.join([b1_word.text] +[b_word.text] + term))
#                                 print(terms)
                                
                # NOUN NOUN NOUN
                if b_pos != 0 and i + 1 < len(tokens):
                    if (tokens[i] != '') and (tokens[i] != ' ') and (tokens[i+1] != '') and (tokens[i+1] != ' '):
                        if (len(nlp(str(tokens[i])).sentences) > 0 and len(nlp(str(tokens[i+1])).sentences) > 0 and len(nlp(str(tokens[b_pos])).sentences) > 0):
                            a1_word = nlp(str(tokens[i+1])).sentences[0].words[0] 
                            a_word = nlp(str(tokens[i])).sentences[0].words[0]
                            c_word = nlp(str(tokens[b_pos])).sentences[0].words[0]
                            if (c_word.text != 'None') and (c_word.upos == 'NOUN') and (a_word.text != 'None') and (a1_word.text != 'None') and ((a_word.upos == 'NOUN') and (a1_word.upos == 'NOUN')):
                                terms.append(' '.join( term + [a_word.text] +[a1_word.text]))
#                                 print(terms)
                if b_pos != 0:
                    # RULE 2
                    if (tokens[b_pos-2] != '') and (tokens[b_pos -2] != ' ') and (tokens[b_pos - 1] != '') and (tokens[b_pos - 1] != ' '):
                        if len(nlp(str(tokens[b_pos - 1])).sentences) > 0 and len(nlp(str(tokens[b_pos-2])).sentences) > 0:
                            b_word = nlp(str(tokens[b_pos - 1])).sentences[0].words[0]
                            b1_word = nlp(str(tokens[b_pos - 2])).sentences[0].words[0]
                            # Check vị trí b_pos - 1: terms.append()
                            if  (b_word.text == '-') and (b1_word.text != 'None'):
                                terms.append(' '.join([b1_word.text] + [b_word.text] + term))
                                print(terms)
                    
                term = []
        if len(term) > 0:
            terms.append(' '.join(term))
            # check b_pos - 1
        all_term.append(terms)
    
    final_terms = []
    for i in all_term:
        final_terms.extend(i)

    final_terms = [x.lower().strip() for x in final_terms]
    return final_terms

# %%
groundtruth = pd.read_csv('/Users/hanhtran/Documents/terminology-extraction/ACTER/fr/htfl/annotations/htfl_fr_terms_nes.ann', sep='	', engine='python',header=None)
gt = list(groundtruth[0]) 
def lemma(doc):
    lemma_word = nlp(str(doc))
    lemma_word = ' '.join([w.lemma for sent in lemma_word.sentences for w in sent.words])
    lemma_word = re.sub(' -','-',lemma_word)
    lemma_word = re.sub('- ','-',lemma_word)
    lemma_word = re.sub(' \)', ' ',lemma_word)
    lemma_word = re.sub('\( ', ' ',lemma_word)
    lemma_word = re.sub(' +', ' ',lemma_word)
    return lemma_word
        
pkl_file = open('./fr/nes_distilbert_cased.pkl', 'rb') 
predictions = pkl.load(pkl_file)

preds =  get_term_(predictions)
print(evaluation_metrics(preds, gt))
stop_words = set(stopwords.words('english'))
pred_terms =  set(preds) - set(stop_words)
pred_terms = [x for x in pred_terms if len(x)>1]
pred_terms = [x.lower().strip() for x in pred_terms]
pred_terms = [re.sub(' -','-', x) for x in pred_terms]
pred_terms = [re.sub('- ','-', x) for x in pred_terms]
pred_terms = [re.sub('\(','', x) for x in pred_terms]
pred_terms = [re.sub('\/','', x) for x in pred_terms]
print(evaluation_metrics(pred_terms, gt))

gt = list(set([lemma(x) for x in gt]))
print(evaluation_metrics(pred_terms, gt))

# %%
groundtruth = pd.read_csv('/Users/hanhtran/Documents/terminology-extraction/ACTER/en/htfl/annotations/htfl_en_terms.ann', sep='	', engine='python',header=None)
gt = list(groundtruth[0]) 

pkl_file = open('./en_domains/ann_xlnet_htfl.pkl', 'rb') 
# pkl_file = open('./en/ann_weighted_xlnet.pkl', 'rb') 
# pkl_file = open('ann_xlnet_full.pkl', 'rb') 
predictions = pkl.load(pkl_file)

preds =  get_term_(predictions)
print(evaluation_metrics(preds, gt))
stop_words = set(stopwords.words('english'))
pred_terms =  set(preds) - set(stop_words)
pred_terms = [x for x in pred_terms if len(x)>1]
pred_terms = [x.lower().strip() for x in pred_terms]
pred_terms = [re.sub(' -','-', x) for x in pred_terms]
pred_terms = [re.sub('- ','-', x) for x in pred_terms]
pred_terms = [re.sub('\(','', x) for x in pred_terms]
pred_terms = [re.sub('\/','', x) for x in pred_terms]
print(evaluation_metrics(pred_terms, gt))
# Out:
# Prediction:  1542
# GT:  1091
# 574 968 517
# (37.22, 52.61, 43.6)
# Prediction:  1520
# GT:  1091
# 574 946 517
# (37.76, 52.61, 43.96)

# %%
preds =  get_term(predictions)
print(evaluation_metrics(preds, gt))
stop_words = set(stopwords.words('english'))
pred_terms =  set(preds) - set(stop_words)
pred_terms = [x for x in pred_terms if len(x)>1]
pred_terms = [x.lower().strip() for x in pred_terms]
pred_terms = [re.sub(' -','-', x) for x in pred_terms]
pred_terms = [re.sub('- ','-', x) for x in pred_terms]
pred_terms = [re.sub('\(','', x) for x in pred_terms]
pred_terms = [re.sub('\/','', x) for x in pred_terms]
print(evaluation_metrics(pred_terms, gt))
# Out:
# ['Aldosterone', 'neurohormone', 'heart failure', 'systolic dysfunction', 'aldosterone antagonist', 'heart failure', 'Aldactone', 'Aldactone Evaluation', 'Aldactone Evaluation Study', 'chronic', 'heart failure', 'advanced heart failure', 'heart failure patients', 'advanced heart failure patients', 'chronic advanced heart failure', 'aldosterone antagonist', 'spironolactone', 'placebo', 'beta blockade', 'myocardial', 'myocardial infarction', 'Efficacy', 'failure Efficacy', 'SUrvival Study', 'EPHESUS', 'post', 'myocardial', 'myocardial infarction', 'post - myocardial']
# ['Aldosterone', 'neurohormone', 'heart failure', 'systolic dysfunction', 'aldosterone antagonist', 'heart failure', 'Aldactone', 'Aldactone Evaluation', 'Aldactone Evaluation Study', 'chronic', 'heart failure', 'advanced heart failure', 'heart failure patients', 'advanced heart failure patients', 'chronic advanced heart failure', 'aldosterone antagonist', 'spironolactone', 'placebo', 'beta blockade', 'myocardial', 'myocardial infarction', 'Efficacy', 'failure Efficacy', 'SUrvival Study', 'EPHESUS', 'post', 'myocardial', 'myocardial infarction', 'post - myocardial', 'heart failure', 'eplerenone', 'aldosterone antagonist therapy', 'chronic', 'heart failure', 'advanced heart failure', 'heart failure patients', 'advanced heart failure patients', 'chronic advanced heart failure', 'post', 'myocardial', 'myocardial infarction', 'post - myocardial']
# ['Heart failure', 'public health problem', 'the molecular mechanism', 'DEGs', 'ischemic', 'non - ischemic']
# ['DEGs', 'ischemic', 'non - ischemic']
# ['ischemic', 'non - ischemic']
# ['Cardiology', 'Cardiovascular Disease Registry', 'Cardiovascular Disease Registry Practice', 'angiotensin', 'converting enzyme inhibitors', 'angiotensin - converting enzyme inhibitors']
# ['Cardiology', 'Cardiovascular Disease Registry', 'Cardiovascular Disease Registry Practice', 'angiotensin', 'converting enzyme inhibitors', 'angiotensin - converting enzyme inhibitors', 'angiotensin', 'blockers', 'blockers', 'β - blockers']
# ['Cardiology', 'Cardiovascular Disease Registry', 'Cardiovascular Disease Registry Practice', 'angiotensin', 'converting enzyme inhibitors', 'angiotensin - converting enzyme inhibitors', 'angiotensin', 'blockers', 'blockers', 'β - blockers', 'heart failure', 'ejection', 'ejection fraction', 'the', 'the treatment', 'We', 'The', 'angiotensin', 'converting enzyme inhibitors', 'angiotensin - converting enzyme inhibitors']
# ['Cardiology', 'Cardiovascular Disease Registry', 'Cardiovascular Disease Registry Practice', 'angiotensin', 'converting enzyme inhibitors', 'angiotensin - converting enzyme inhibitors', 'angiotensin', 'blockers', 'blockers', 'β - blockers', 'heart failure', 'ejection', 'ejection fraction', 'the', 'the treatment', 'We', 'The', 'angiotensin', 'converting enzyme inhibitors', 'angiotensin - converting enzyme inhibitors', 'angiotensin', 'blockers', 'blockers', 'β - blockers']
# ['Cardiology', 'Cardiovascular Disease Registry', 'Cardiovascular Disease Registry Practice', 'angiotensin', 'converting enzyme inhibitors', 'angiotensin - converting enzyme inhibitors', 'angiotensin', 'blockers', 'blockers', 'β - blockers', 'heart failure', 'ejection', 'ejection fraction', 'the', 'the treatment', 'We', 'The', 'angiotensin', 'converting enzyme inhibitors', 'angiotensin - converting enzyme inhibitors', 'angiotensin', 'blockers', 'blockers', 'β - blockers', 'The', 'angiotensin', 'converting enzyme inhibitors', 'angiotensin - converting enzyme inhibitors']
# ['Cardiology', 'Cardiovascular Disease Registry', 'Cardiovascular Disease Registry Practice', 'angiotensin', 'converting enzyme inhibitors', 'angiotensin - converting enzyme inhibitors', 'angiotensin', 'blockers', 'blockers', 'β - blockers', 'heart failure', 'ejection', 'ejection fraction', 'the', 'the treatment', 'We', 'The', 'angiotensin', 'converting enzyme inhibitors', 'angiotensin - converting enzyme inhibitors', 'angiotensin', 'blockers', 'blockers', 'β - blockers', 'The', 'angiotensin', 'converting enzyme inhibitors', 'angiotensin - converting enzyme inhibitors', 'angiotensin', 'blockers', 'blockers therapy', 'blockers', 'blockers therapy', 'β - blockers']
# ['Peripheral artery disease', 'heart failure', 'HF', 'We', 'ankle', 'brachial index', 'ankle - brachial index']
# ['Peripheral artery disease', 'heart failure', 'HF', 'We', 'ankle', 'brachial index', 'ankle - brachial index', 'natriuretic peptide', 'filtration rate', 'glomerular filtration rate', 'hypertension', 'transmitral', 'wave', 'E - wave']
# ['Cardiology', 'Cardiology guidelines', 'HFPEF', 'heart failure', 'ejection fraction', 'left ventricle', 'diastolic dysfunction', 'relaxation', 'stiffness', 'diastolic stiffness', 'filling pressures', 'diastolic dysfunction', 'invasively', 'non - invasively']
# ['cachexia', 'display cachexia', 'lean', 'lean body', 'lean body mass', 'cachexia', 'HR', 'free mass index', 'fat - free mass index']
# ['heart failure', 'Human heart failure', 'post', 'translational state', 'post - translational state']
# ['Adrenergic receptor blockade', 'β - Adrenergic receptor blockade']
# ['Adrenergic receptor blockade', 'β - Adrenergic receptor blockade', 'heart failure', 'HF', 'cAMP', 'downstream', 'adrenergic', 'β - adrenergic']
# ['Adrenergic receptor blockade', 'β - Adrenergic receptor blockade', 'heart failure', 'HF', 'cAMP', 'downstream', 'adrenergic', 'β - adrenergic', 'post', 'unique post', 'translational states', 'post - translational states']
# ['Adrenergic receptor blockade', 'β - Adrenergic receptor blockade', 'heart failure', 'HF', 'cAMP', 'downstream', 'adrenergic', 'β - adrenergic', 'post', 'unique post', 'translational states', 'post - translational states', 'myocardial', 'myocardial tissue', 'myosin', 'total myosin', 'myosin binding', 'total myosin binding', 'myosin binding protein', 'phosphorylation', 'troponin', 'phosphorylation', 'regulatory', 'catalytic', 'Thr197', 'phosphorylation', 'regulatory subunit', 'Isoelectric', 'Isoelectric focusing', 'phosphorylation sites', 'Western blots', 'phosphorylation', 'cAMP', 'cAMP binding', '8-fluo - cAMP']
# ['Adrenergic receptor blockade', 'β - Adrenergic receptor blockade', 'heart failure', 'HF', 'cAMP', 'downstream', 'adrenergic', 'β - adrenergic', 'post', 'unique post', 'translational states', 'post - translational states', 'myocardial', 'myocardial tissue', 'myosin', 'total myosin', 'myosin binding', 'total myosin binding', 'myosin binding protein', 'phosphorylation', 'troponin', 'phosphorylation', 'regulatory', 'catalytic', 'Thr197', 'phosphorylation', 'regulatory subunit', 'Isoelectric', 'Isoelectric focusing', 'phosphorylation sites', 'Western blots', 'phosphorylation', 'cAMP', 'cAMP binding', '8-fluo - cAMP', 'wild', 'wild type', 'phosphomimic', 'double', 'WT', 'myocardium', 'myocardium displays', 'post', 'translational', 'translational modification', 'post - translational']
# ['Heart rate', 'cardiac', 'cardiac patients', 'infarction', 'myocardial infarction', 'acute myocardial infarction', 'AMI', 'heart failure', 'congestive heart failure', 'CHF', 'left ventricular', 'LV', 'AMI', 'CHF', 'LV dysfunction', 'linear', 'linear measures', 'non - linear']
# ['Heart rate', 'cardiac', 'cardiac patients', 'infarction', 'myocardial infarction', 'acute myocardial infarction', 'AMI', 'heart failure', 'congestive heart failure', 'CHF', 'left ventricular', 'LV', 'AMI', 'CHF', 'LV dysfunction', 'linear', 'linear measures', 'non - linear', 'oscillations', 'interval oscillations', 'linear', 'linear HR', 'non - linear']
# ['stenosis', 'artery stenosis', 'RAS', 'peripheral arterial disease', 'RAS', 'atherosclerosis', 'unilateral', 'pathophysiologic mechanism', 'pathophysiologic mechanism stems', 'underperfusion', 'angiotensin', 'renin angiotensin', 'aldosterone pathway', 'angiotensin - aldosterone pathway']
# ['heart failure', 'HF', 'HF populations', 'non - HF populations']
# ['renin', 'angiotensin system blocker', 'renin - angiotensin system blocker']
# ['ambulatory', 'ambulatory patients', 'heart failure', 'renin', 'angiotensin system', 'renin - angiotensin system']
# ['ambulatory', 'ambulatory patients', 'heart failure', 'renin', 'angiotensin system', 'renin - angiotensin system', 'blockers', 'β - blockers']
# ['ambulatory', 'ambulatory patients', 'heart failure', 'renin', 'angiotensin system', 'renin - angiotensin system', 'blockers', 'β - blockers', 'readmissions', 'blocker', 'blocker uptitrations', 'β - blocker']
# ['ambulatory', 'ambulatory patients', 'heart failure', 'renin', 'angiotensin system', 'renin - angiotensin system', 'blockers', 'β - blockers', 'readmissions', 'blocker', 'blocker uptitrations', 'β - blocker', 'ventricular', 'ventricular ejection', 'left ventricular', 'left ventricular ejection', 'blocker', 'blocker dose', 'blocker dose changes', 'β - blocker']
# ['ambulatory', 'ambulatory patients', 'heart failure', 'renin', 'angiotensin system', 'renin - angiotensin system', 'blockers', 'β - blockers', 'readmissions', 'blocker', 'blocker uptitrations', 'β - blocker', 'ventricular', 'ventricular ejection', 'left ventricular', 'left ventricular ejection', 'blocker', 'blocker dose', 'blocker dose changes', 'β - blocker', 'blocker', 'blocker dose', 'blocker dose increase', 'β - blocker']
# ['ambulatory', 'ambulatory patients', 'heart failure', 'renin', 'angiotensin system', 'renin - angiotensin system', 'blockers', 'β - blockers', 'readmissions', 'blocker', 'blocker uptitrations', 'β - blocker', 'ventricular', 'ventricular ejection', 'left ventricular', 'left ventricular ejection', 'blocker', 'blocker dose', 'blocker dose changes', 'β - blocker', 'blocker', 'blocker dose', 'blocker dose increase', 'β - blocker', 'heart rate', 'higher heart rate', 'renal function', 'spironolactone', 'blocker', 'blocker uptitrations', 'β - blocker']
# ['ambulatory', 'ambulatory patients', 'heart failure', 'renin', 'angiotensin system', 'renin - angiotensin system', 'blockers', 'β - blockers', 'readmissions', 'blocker', 'blocker uptitrations', 'β - blocker', 'ventricular', 'ventricular ejection', 'left ventricular', 'left ventricular ejection', 'blocker', 'blocker dose', 'blocker dose changes', 'β - blocker', 'blocker', 'blocker dose', 'blocker dose increase', 'β - blocker', 'heart rate', 'higher heart rate', 'renal function', 'spironolactone', 'blocker', 'blocker uptitrations', 'β - blocker', 'readmissions', 'heart rate', 'blood pressure', 'renal function', 'spironolactone', 'spironolactone use', 'blockers', 'blockers', 'β - blockers']
# ['perturbations', 'permeability', 'absorption function', 'CHF', 'sonographic', 'histological', 'gastrointestinal regions', 'inflammatory state', 'catabolic', 'anabolic imbalance', 'cachexia', 'cardiac cachexia', 'terminal stage', 'CHF', 'CHF', 'fat', 'feeding', 'anti', 'inflammatory effects', 'anti - inflammatory effects']
# ['Cardiac', 'resynchronization therapy', 'Cardiac - resynchronization therapy']
# ['Cardiac', 'resynchronization therapy', 'Cardiac - resynchronization therapy']
# ['Echo', 'systolic pressure', 'arterial systolic pressure', 'pulmonary arterial systolic pressure', 'right ventricular', 'systolic excursion', 'plane systolic excursion', 'diastole', 'systole', 'end - systole']
# ['Echo', 'systolic pressure', 'arterial systolic pressure', 'pulmonary arterial systolic pressure', 'right ventricular', 'systolic excursion', 'plane systolic excursion', 'diastole', 'systole', 'end - systole', 'heart failure', 'cardiac', 'cardiac risk', 'We', 'longitudinal', 'shortening', 'fiber shortening', 'the', 'ventricular', 'LV', 'ejection fraction', 'echo', 'Doppler', 'Doppler studies', 'echo - Doppler']
# ['Echo', 'systolic pressure', 'arterial systolic pressure', 'pulmonary arterial systolic pressure', 'right ventricular', 'systolic excursion', 'plane systolic excursion', 'diastole', 'systole', 'end - systole', 'heart failure', 'cardiac', 'cardiac risk', 'We', 'longitudinal', 'shortening', 'fiber shortening', 'the', 'ventricular', 'LV', 'ejection fraction', 'echo', 'Doppler', 'Doppler studies', 'echo - Doppler', 'pro', 'brain', 'pro - brain']
# ['Echo', 'systolic pressure', 'arterial systolic pressure', 'pulmonary arterial systolic pressure', 'right ventricular', 'systolic excursion', 'plane systolic excursion', 'diastole', 'systole', 'end - systole', 'heart failure', 'cardiac', 'cardiac risk', 'We', 'longitudinal', 'shortening', 'fiber shortening', 'the', 'ventricular', 'LV', 'ejection fraction', 'echo', 'Doppler', 'Doppler studies', 'echo - Doppler', 'pro', 'brain', 'pro - brain', 'natriuretic peptide', 'natriuretic peptide assessment', 'adverse events', 'downward', 'downward regression', 'nonsurvivors', 'the', 'collinearity', 'Cox', 'Cox regression', 'Kaplan', 'Meier', 'Meier analyses', 'Kaplan - Meier']
# ['Xanthine oxidase', 'XO', 'ventricular', 'myocytes', 'VO', 'regurgitation', 'mitral regurgitation', 'fistula', 'ATP', 'ATP demand', 'XO', 'ROS', 'respiration', 'mitochondrial respiration', 'contractile function', 'we', 'the hypothesis', 'XO inhibition', 'cardiomyocyte bioenergetics', 'LV function', 'chronic', 'rat', 'Dawley', 'Dawley rats', 'Sprague - Dawley']
# ['cardiotoxicity', 'anti', 'neoplastic agent', 'anti - neoplastic agent']
# ['adverse events', 'training', 'work rate', 'quadriceps force', 'peak quadriceps force', 'Peak', 'Peak oxygen', 'Peak oxygen consumption', 'pulse', 'oxygen pulse', 'ProBNP', 'NT - ProBNP']
# ['gait therapy', 'Lokomat', 'heart failure', 'heart failure patients', 'The', 'aerobic', 'training intervention', 'resistance training intervention', 'exercise capacity', 'muscle', 'muscle strength', 'cardiac', 'ProBNP', 'NT - ProBNP']
# ['walking', 'functional capacity', 'travelled', 'activity', 'physical activity', 'right', 'right grip', 'depressive', 'depressive symptoms', 'Anxiety', 'Hospital Anxiety', 'aerobic capacity', 'peak aerobic capacity', 'left', 'hand', 'hand grip', 'hand grip strength', 'left - hand']
# ['angiogenesis', 'Impaired angiogenesis', 'post', 'heart', 'infarction heart', 'heart failure', 'endothelial growth factor', 'vascular endothelial growth factor', 'VEGF', 'hypertrophy', 'compensatory hypertrophy', 'cardiac failure', 'adrenergic receptor blocker therapy', 'β - adrenergic receptor blocker therapy']
# ['infarction', 'myocardial infarction', 'bisoprolol', 'echocardiography', 'cardiac function', 'angiogenesis', 'cardiac angiogenesis', 'perfusion', 'coronary perfusion', 'fibrosis', 'cardiac fibrosis', 'VEGF expression', 'Akt', 'endothelial', 'hearts', 'proangiogenic effects', 'VEGF pathway', 'injected', 'adenoviral vector', 'adenoviral vector encoding', 'VEGF receptor', 'Flk', 'Ad - Flk']
# ['infarction', 'myocardial infarction', 'bisoprolol', 'echocardiography', 'cardiac function', 'angiogenesis', 'cardiac angiogenesis', 'perfusion', 'coronary perfusion', 'fibrosis', 'cardiac fibrosis', 'VEGF expression', 'Akt', 'endothelial', 'hearts', 'proangiogenic effects', 'VEGF pathway', 'injected', 'adenoviral vector', 'adenoviral vector encoding', 'VEGF receptor', 'Flk', 'Ad - Flk', 'adenovirus', 'control adenovirus', 'the', 'the treatment', 'histological', 'histological analysis', 'capillary', 'perfusion', 'coronary perfusion', 'Flk', 'Flk rats', 'Ad - Flk']
# ['Blockade', 'β - Blockade']
# ['HEK', 'kidney', 'embryonic kidney', 'human embryonic kidney', 'we', 'sphingosine-1-phosphate', 'isoproterenol', 'adrenergic receptor agonist', 'β - adrenergic receptor agonist']
# ['HEK', 'kidney', 'embryonic kidney', 'human embryonic kidney', 'we', 'sphingosine-1-phosphate', 'isoproterenol', 'adrenergic receptor agonist', 'β - adrenergic receptor agonist', 'cross', 'reciprocal regulation', 'hearts', 'mouse hearts', 'chronic', 'adrenergic receptor stimulation', 'β - adrenergic receptor stimulation']
# ['transfusion protocols', 'liberal transfusion protocols', 'aggressive', 'aggressive protocols', 'relative risk', 'coronary syndrome', 'acute coronary syndrome', 'iron', 'intravenous iron', 'exercise', 'term exercise', 'exercise tolerance', 'heart failure', 'erythropoiesis', 'stimulating agent therapy', 'erythropoiesis - stimulating agent therapy']
# ['heart failure', 'chronic heart failure', 'CHF', 'sympathetic tone', 'autonomic imbalance', 'Renal denervation', 'CHF', 'CHF patients', 'CHF', 'renal', 'balance', 'autonomic balance', 'cardiac autonomic balance', 'conscious', 'New', 'rabbits', 'renal', 'pacing', 'CHF', 'Innervated', 'Sham - Innervated']
# ['HFrEF', 'exercise protocol', 'gas', 'respiratory gas', 'gas analysis', 'respiratory gas analysis', 'beta', 'blocker therapy', 'beta - blocker therapy']
# ['HFrEF', 'exercise protocol', 'gas', 'respiratory gas', 'gas analysis', 'respiratory gas analysis', 'beta', 'blocker therapy', 'beta - blocker therapy', 'resting', 'resting HR', 'blocker dose', 'Beta - blocker dose']
# ['HFrEF', 'exercise performance', 'HR', 'beta', 'blocker therapy', 'beta - blocker therapy']
# ['HFrEF', 'exercise performance', 'HR', 'beta', 'blocker therapy', 'beta - blocker therapy', 'HR reduction', 'little HR reduction', 'beta', 'blocker therapy', 'beta - blocker therapy']
# ['AAs', 'HF', 'hyperkalemia', 'less hyperkalemia', 'hypokalemia', 'more hypokalemia', 'spironolactone', 'AAs', 'non - AAs']
# ['transplantation', 'cell transplantation', 'heart failure', 'congestive heart failure', 'developing congestive heart failure', 'CHF', 'anthracyclines', 'CHF', 'anthracycline metabolism', 'iron homeostasis', 'anti', 'oxidant defence', 'anti - oxidant defence']
# ['transplantation', 'cell transplantation', 'heart failure', 'congestive heart failure', 'developing congestive heart failure', 'CHF', 'anthracyclines', 'CHF', 'anthracycline metabolism', 'iron homeostasis', 'anti', 'oxidant defence', 'anti - oxidant defence', 'myocardial', 'myocardial remodelling', 'CHF', 'the', 'the sampling', 'CHF', 'anthracycline', 'cumulative anthracycline', 'anthracycline exposure', 'cumulative anthracycline exposure', 'stem cell', 'stem cell source', 'allogeneic', 'germline', 'the', 'the odds', 'CHF', 'radiation', 'chest radiation', 'hypertension', 'NAD(P)H', 'oxidase', 'NAD - oxidase']
# ['heart disease', 'pathological heart disease', 'transcription factors', 'transcription factors driving', 'we', 'we report', 'calcineurin', 'Nfat signalling', 'miR-25 expression', 'the', 'loop', 'helix - loop']
# ['ventricular', 'LVADs', 'chronic', 'chronic end', 'heart failure', 'stage heart failure', 'the', 'the evidence', 'cost', 'continuous', 'flow', 'flow LVADs', 'continuous - flow']
# ['PARADIGM', 'Study PARADIGM', 'HF', 'PARADIGM - HF']
# ['Chronic', 'cardiology', 'current cardiology', 'the therapy', 'angiotensin', 'neprilysin inhibitors', 'AT1 receptors', 'renin', 'blocks renin', 'angiotensin', 'renin - angiotensin']
# ['Chronic', 'cardiology', 'current cardiology', 'the therapy', 'angiotensin', 'neprilysin inhibitors', 'AT1 receptors', 'renin', 'blocks renin', 'angiotensin', 'renin - angiotensin', 'aldosteron', 'angiotensin - aldosteron']
# ['Chronic', 'cardiology', 'current cardiology', 'the therapy', 'angiotensin', 'neprilysin inhibitors', 'AT1 receptors', 'renin', 'blocks renin', 'angiotensin', 'renin - angiotensin', 'aldosteron', 'angiotensin - aldosteron', 'RAS', 'vasodilatory', 'diuretic effect', 'natriuretic peptides', 'PARADIGM', 'trial PARADIGM', 'HF', 'PARADIGM - HF']
# ['Chronic', 'cardiology', 'current cardiology', 'the therapy', 'angiotensin', 'neprilysin inhibitors', 'AT1 receptors', 'renin', 'blocks renin', 'angiotensin', 'renin - angiotensin', 'aldosteron', 'angiotensin - aldosteron', 'RAS', 'vasodilatory', 'diuretic effect', 'natriuretic peptides', 'PARADIGM', 'trial PARADIGM', 'HF', 'PARADIGM - HF', 'systolic dysfunction', 'EF', 'NYHA', 'class NYHA', 'BNP', 'cardiovascular death', 'heart failure', 'sacubiltril', 'valsartan', 'sacubiltril - valsartan']
# ['QRS morphology', 'resynchronization therapy', 'cardiac resynchronization therapy', 'Resynchronization', 'Defibrillation', 'Resynchronization - Defibrillation']
# ['Resynchronization', 'Defibrillation', 'Resynchronization - Defibrillation']
# ['LBBB', 'defibrillator', 'cardioverter defibrillator', 'our data', 'defibrillator', 'cardioverter defibrillator', 'LBBB', 'non - LBBB']
# ['NT', 'proBNP', 'proBNP testing', 'NT - proBNP']
# ['plasma', 'terminal', 'N - terminal']
# ['plasma', 'terminal', 'N - terminal', 'natriuretic peptide', 'proBNP', 'NT - proBNP']
# ['plasma', 'terminal', 'N - terminal', 'natriuretic peptide', 'proBNP', 'NT - proBNP', 'long', 'heart failure', 'acute heart failure', 'HF', 'emergency department', 'our', 'proBNP', 'NT - proBNP']
# ['NT', 'proBNP levels', 'NT - proBNP levels']
# ['the', 'the patients', 'the', 'The', 'proBNP', 'proBNP cutoff', 'NT - proBNP']
# ['proBNP levels', 'NT - proBNP levels']
# ['proBNP levels', 'NT - proBNP levels', 'HF', 'cutoff level', 'optimal cutoff level', 'proBNP', 'NT - proBNP']
# ['Carvedilol', 'the', 'metoprolol', 'the risk', 'thromboembolic events', 'heart failure', 'sympathetic activity', 'meta', '123 - meta']
# ['Carvedilol', 'the', 'metoprolol', 'the risk', 'thromboembolic events', 'heart failure', 'sympathetic activity', 'meta', '123 - meta', 'iodobenzylguanidine', 'meta - iodobenzylguanidine']
# ['Carvedilol', 'the', 'metoprolol', 'the risk', 'thromboembolic events', 'heart failure', 'sympathetic activity', 'meta', '123 - meta', 'iodobenzylguanidine', 'meta - iodobenzylguanidine', 'MIBG', '123 - MIBG']
# ['cardioverter', 'implantable cardioverter', 'defibrillator', 'defibrillator deactivation', 'defibrillator deactivation discussions', 'cardioverter - defibrillator']
# ['cardioverter', 'implantable cardioverter', 'deactivation', 'defibrillator deactivation', 'deactivation discussions', 'heart failure', 'heart failure patients', 'the', 'cardioverter', 'implantable cardioverter', 'defibrillator', 'defibrillator deactivation', 'defibrillator deactivation discussions', 'cardioverter - defibrillator']
# ['cardioverter', 'implantable cardioverter', 'defibrillator', 'defibrillator deactivation', 'defibrillator deactivation discussions', 'cardioverter - defibrillator']
# ['Grounded theory', 'heart failure', 'heart failure patients', 'cardioverter', 'implantable cardioverter', 'defibrillator', 'cardioverter - defibrillator']
# ['cardioverter', 'implantable cardioverter', 'defibrillator', 'cardioverter - defibrillator']
# ['The', 'the', 'cardioverter', 'implantable cardioverter', 'defibrillator', 'defibrillator deactivation', 'cardioverter - defibrillator']
# ['double', 'blind', 'double - blind']
# ['open', 'dopamine', 'nesiritide strategy', 'double', 'blind', 'double - blind']
# ['influx', 'voltage', 'type voltage', 'gated', 'voltage - gated']
# ['influx', 'voltage', 'type voltage', 'gated', 'voltage - gated', 'the', 'the plateau', 'ventricular action potentials', 'trigger', 'excitation', 'contraction', 'excitation - contraction']
# ['Phosphodiesterase-2', 'human', 'hearts', 'beta', 'adrenergic responses', 'beta - adrenergic responses']
# ['phosphodiesterase-2', 'PDE2', 'heart failure', 'HF', 'PDE2-mediated effects', 'beta', 'AR', 'β - AR']
# ['hearts', 'acute', 'AR stimulation', 'β - AR stimulation']
# ['hearts', 'acute', 'AR stimulation', 'β - AR stimulation', 'cardiac', 'cardiac stress', 'AR drive', 'β - AR drive']
# ['terminal', 'N - terminal']
# ['terminal', 'N - terminal', 'natriuretic peptide', 'proBNP', 'NT - proBNP']
# ['terminal', 'N - terminal', 'natriuretic peptide', 'proBNP', 'NT - proBNP', 'heart failure', 'HF', 'circulating forms', 'proBNP', 'NT - proBNP']
# ['terminal', 'N - terminal', 'natriuretic peptide', 'proBNP', 'NT - proBNP', 'heart failure', 'HF', 'circulating forms', 'proBNP', 'NT - proBNP', 'We', 'the', 'proBNP', 'NT - proBNP']
# ['Plasma', 'HF', 'HF patients', 'proBNP', 'NT - proBNP']
# ['Plasma', 'HF', 'HF patients', 'proBNP', 'NT - proBNP', 'HF', 'plasma', 'patient plasma', 'immunoprecipitation', 'AlphaLISA', 'proBNP', 'NT - proBNP']
# ['the', 'the presence', 'terminally', 'C - terminally']
# ['the', 'the presence', 'terminally', 'C - terminally', 'proBNP', 'NT - proBNP']
# ['the', 'the presence', 'terminally', 'C - terminally', 'proBNP', 'NT - proBNP', 'proteolysis', 'physiological proteolysis', 'AlphaLISA immunoassays', 'extreme', 'termini', 'proBNP', 'NT - proBNP']
# ['the', 'the presence', 'terminally', 'C - terminally', 'proBNP', 'NT - proBNP', 'proteolysis', 'physiological proteolysis', 'AlphaLISA immunoassays', 'extreme', 'termini', 'proBNP', 'NT - proBNP', 'The', 'proBNP concentration', 'NT - proBNP concentration']
# ['plasma', 'HF', 'HF patients', 'immunoreactive', 'proBNP', 'NT - proBNP']
# ['plasma', 'HF', 'HF patients', 'immunoreactive', 'proBNP', 'NT - proBNP', 'terminally', 'C - terminally']
# ['plasma', 'HF', 'HF patients', 'immunoreactive', 'proBNP', 'NT - proBNP', 'terminally', 'C - terminally', 'the', 'proBNP molecule', 'NT - proBNP molecule']
# ['plasma', 'HF', 'HF patients', 'immunoreactive', 'proBNP', 'NT - proBNP', 'terminally', 'C - terminally', 'the', 'proBNP molecule', 'NT - proBNP molecule', 'proBNP', 'NT - proBNP']
# ['plasma', 'HF', 'HF patients', 'immunoreactive', 'proBNP', 'NT - proBNP', 'terminally', 'C - terminally', 'the', 'proBNP molecule', 'NT - proBNP molecule', 'proBNP', 'NT - proBNP', 'terminal regions', 'proBNP assay', 'NT - proBNP assay']
# ['the', 'the changes', 'platelet', 'activating factor', 'platelet - activating factor']
# ['the', 'the changes', 'platelet', 'activating factor', 'platelet - activating factor', 'metabolic enzymes', 'heart failure', 'HF', 'The', 'biosynthetic enzymes', 'acetyltransferase', 'dithiothreitol', 'choline', 'CDP choline', 'cholinephosphotransferase', 'catabolic isoenzymes', 'acetylhydrolase', 'PAF - acetylhydrolase']
# ['longitudinal', 'longitudinal strain', 'ventricle', 'echocardiography', 'baseline echocardiography', 'CRT', 'echocardiograms', 'Regression', 'Regression analysis', 'reverse', 'reverse remodeling', 'the', 'systolic volume', 'end - systolic volume']
# ['longitudinal', 'longitudinal strain', 'ventricle', 'echocardiography', 'baseline echocardiography', 'CRT', 'echocardiograms', 'Regression', 'Regression analysis', 'reverse', 'reverse remodeling', 'the', 'systolic volume', 'end - systolic volume', 'reverse', 'reverse remodeling', 'CRT', 'pre - CRT']
# ['longitudinal', 'longitudinal strain', 'ventricle', 'echocardiography', 'baseline echocardiography', 'CRT', 'echocardiograms', 'Regression', 'Regression analysis', 'reverse', 'reverse remodeling', 'the', 'systolic volume', 'end - systolic volume', 'reverse', 'reverse remodeling', 'CRT', 'pre - CRT', 'diastolic dimension index', 'end - diastolic dimension index']
# ['longitudinal', 'longitudinal strain', 'ventricle', 'echocardiography', 'baseline echocardiography', 'CRT', 'echocardiograms', 'Regression', 'Regression analysis', 'reverse', 'reverse remodeling', 'the', 'systolic volume', 'end - systolic volume', 'reverse', 'reverse remodeling', 'CRT', 'pre - CRT', 'diastolic dimension index', 'end - diastolic dimension index', 'longitudinal', 'longitudinal strain', 'ventricle', 'atrial area', 'ventricular', 'ventricular end', 'diastolic area', 'diastolic area index', 'end - diastolic area']
# ['Cox modeling', 'we', 'Heart', 'Heart Failure', 'Heart Failure Patient', 'the University of', 'primary', 'primary outcome', 'externally', 'the', 'Ann', 'Veterans', 'the cohort', 'The', 'nitrogen', 'urea nitrogen', 'natriuretic peptide', 'New', 'diabetes', 'diabetes status', 'fibrillation', 'atrial fibrillation', 'flutter', 'concordance', 'the', 'Kaplan', 'Meier curves', 'Kaplan - Meier curves']
# ['rats', 'Wistar', 'Kyoto', 'Wistar - Kyoto']
# ['repolarization', 'repolarization lability', 'cardiac', 'cardiac death', 'autonomic', 'tachycardia', 'ventricular tachycardia', 'spontaneous ventricular tachycardia', 'beat', 'beat', 'to - beat']
# ['repolarization', 'repolarization lability', 'cardiac', 'cardiac death', 'autonomic', 'tachycardia', 'ventricular tachycardia', 'spontaneous ventricular tachycardia', 'beat', 'beat', 'to - beat', 'ECGs', 'surface ECGs', 'pacing', 'atrial pacing', 'esmolol', 'isoprenaline', 'atropine infusion', 'pacing', 'atrial pacing', 'isoprenaline infusion', 'adrenoceptor blockade', 'β - adrenoceptor blockade']
# ['repolarization', 'repolarization lability', 'cardiac', 'cardiac death', 'autonomic', 'tachycardia', 'ventricular tachycardia', 'spontaneous ventricular tachycardia', 'beat', 'beat', 'to - beat', 'ECGs', 'surface ECGs', 'pacing', 'atrial pacing', 'esmolol', 'isoprenaline', 'atropine infusion', 'pacing', 'atrial pacing', 'isoprenaline infusion', 'adrenoceptor blockade', 'β - adrenoceptor blockade', 'esmolol', 'HF', 'beat', 'beat', 'to - beat']
# ['resynchronization therapy', 'Cardiac resynchronization therapy', 'CRT', 'heart failure', 'HF', 'CRT', 'CRT', 'bundle branch morphology', 'mellitus', 'diabetes mellitus', 'cardiomyopathy', 'cardiomyopathy origin', 'blocker', 'β - blocker']
# ['resynchronization therapy', 'Cardiac resynchronization therapy', 'CRT', 'heart failure', 'HF', 'CRT', 'CRT', 'bundle branch morphology', 'mellitus', 'diabetes mellitus', 'cardiomyopathy', 'cardiomyopathy origin', 'blocker', 'β - blocker', 'angiotensin', 'converting enzyme inhibitor', 'angiotensin - converting enzyme inhibitor']
# ['We', 'US healthcare programmes', 'RA', 'methotrexate', 'the', 'the study', 'TNF antagonist', 'biological disease', 'biological disease modifying', 'non - biological disease']
# ['Retrospective', 'Retrospective cohort', 'heart', 'heart failure', 'and', 'cause', 'cause readmission', 'all - cause']
# ['heart failure', 'HF', 'ejection fraction', 'ventricular ejection fraction', 'HFpEF', 'Morbidity', 'HFpEF', 'HF', 'diastolic dysfunction', 'pathophysiology', 'HFpEF', 'diastolic abnormalities', 'non - diastolic abnormalities']
# ['ablation', 'Catheter ablation', 'HFPEF', 'ventricular', 'LV', 'ejection fraction', 'free', 'free probability', 'AF - free']
# ['follow', 'free', 'free success', 'drug - free']
# ['We', 'HF', 'HF patients', 'ejection fraction', 'ventricular ejection fraction', 'We', 'CPCs', 'VO2', 'peak VO2', 'CPCs', 'outgrowth colony', 'early - outgrowth colony']
# ['We', 'HF', 'HF patients', 'ejection fraction', 'ventricular ejection fraction', 'We', 'CPCs', 'VO2', 'peak VO2', 'CPCs', 'outgrowth colony', 'early - outgrowth colony', 'EO', 'CFUs', 'EO - CFUs']
# ['heart failure', 'infarction', 'myocardial infarction', 'adrenoceptor blockade', 'β - adrenoceptor blockade']
# ['heart failure', 'infarction', 'myocardial infarction', 'adrenoceptor blockade', 'β - adrenoceptor blockade', 'rats', 'metoprolol', 'The', 'ventricular', 'systolic pressure', 'ejection fraction', 'shortening', 'fractional shortening', 'cardiac output', 'diastolic pressure', 'end - diastolic pressure']
# ['heart failure', 'infarction', 'myocardial infarction', 'adrenoceptor blockade', 'β - adrenoceptor blockade', 'rats', 'metoprolol', 'The', 'ventricular', 'systolic pressure', 'ejection fraction', 'shortening', 'fractional shortening', 'cardiac output', 'diastolic pressure', 'end - diastolic pressure', 'septum', 'systolic', 'wall', 'posterior wall', 'wall thickness', 'posterior wall thickness', 'internal diameter', 'the', 'norepinephrine', 'plasma norepinephrine', 'dopamine', 'the', 'epinephrine', 'reticular', 'phospholamban', 'hearts', 'myofibrillar', 'ATPase activity', 'phospholamban', 'myosin', 'α - myosin']
# ['heart failure', 'infarction', 'myocardial infarction', 'adrenoceptor blockade', 'β - adrenoceptor blockade', 'rats', 'metoprolol', 'The', 'ventricular', 'systolic pressure', 'ejection fraction', 'shortening', 'fractional shortening', 'cardiac output', 'diastolic pressure', 'end - diastolic pressure', 'septum', 'systolic', 'wall', 'posterior wall', 'wall thickness', 'posterior wall thickness', 'internal diameter', 'the', 'norepinephrine', 'plasma norepinephrine', 'dopamine', 'the', 'epinephrine', 'reticular', 'phospholamban', 'hearts', 'myofibrillar', 'ATPase activity', 'phospholamban', 'myosin', 'α - myosin', 'myosin', 'β - myosin']
# ['heart failure', 'infarction', 'myocardial infarction', 'adrenoceptor blockade', 'β - adrenoceptor blockade', 'rats', 'metoprolol', 'The', 'ventricular', 'systolic pressure', 'ejection fraction', 'shortening', 'fractional shortening', 'cardiac output', 'diastolic pressure', 'end - diastolic pressure', 'septum', 'systolic', 'wall', 'posterior wall', 'wall thickness', 'posterior wall thickness', 'internal diameter', 'the', 'norepinephrine', 'plasma norepinephrine', 'dopamine', 'the', 'epinephrine', 'reticular', 'phospholamban', 'hearts', 'myofibrillar', 'ATPase activity', 'phospholamban', 'myosin', 'α - myosin', 'myosin', 'β - myosin', 'The', 'The results', 'cardiac performance', 'adrenoceptor blockade', 'β - adrenoceptor blockade']
# ['cardioprotective signaling', 'myocardium', 'heart failure', 'HF', 'We', 'long', 'ambulatory', 'ambulatory patients', 'HF', 'Heart Failure', 'Training', 'Exercise Training', 'HF', 'ACTION', 'HF - ACTION']
# ['the', 'the patients', 'systolic heart failure', 'ejection fraction', 'ivabradine', 'SHIFT', 'Systolic Heart Failure', 'Systolic Heart Failure Treatment', 'the', 'Ivabradine Trial', 'placebo', 'ivabradine', 'echocardiographic substudy', 'Ea', 'compliance', 'arterial compliance', 'total arterial compliance', 'TAC', 'elastance', 'Ees', 'Blood pressure', 'arm cuff', 'stroke volume', 'SV', 'ejection fraction', 'diastolic volume', 'end - diastolic volume']
# ['HF', 'heart failure', 'T2D', 'diabetes', 'SkM', 'muscle', 'skeletal muscle', 'We', 'epicatechin', 'cocoa', 'mitochondrial structure', 'Taub', 'Ramirez', 'Sanchez', 'Ramirez - Sanchez']
# ['ejection', 'ventricular ejection', 'ejection fraction', 'ventricular ejection fraction', 'idiopathic', 'cardiomyopathy', 'dilated cardiomyopathy', 'idiopathic dilated cardiomyopathy', 'angiography', 'coronary angiography', 'heart failure', 'heart failure treatment', 'heart failure treatment eras', 'angiotensin', 'blockers', 'receptors blockers', 'blockers', 'β - blockers']
# ['breathing control', 'study breathing control', 'cardiac arrest', 'humans', 'fibrillation', 'ventricular fibrillation', 'pulseless ventricular fibrillation', 'cardioverter', 'defibrillator device', 'cardioverter - defibrillator device']
# ['the', 'cardiovascular diseases', 'heart failure', 'HF', 'We', 'troponin', 'cardiac troponin', 'cTnT', 'terminal', 'N - terminal']
# ['the', 'cardiovascular diseases', 'heart failure', 'HF', 'We', 'troponin', 'cardiac troponin', 'cTnT', 'terminal', 'N - terminal', 'natriuretic peptide', 'proBNP', 'NT - proBNP']
# ['we', 'cTnT', 'proBNP', 'NT - proBNP']
# ['HF', 'cTnT', 'proBNP', 'NT - proBNP']
# ['man', 'man experience', 'in - man']
# ['actin dynamics', 'HF', 'We', 'cardiac dysfunction', 'conduction', 'conduction abnormalities', 'hypertrophy', 'HF', 'we', 'myocyte', 'cardiac myocyte', 'We', 'hearts', 'wild', 'littermates', 'type littermates', 'transgenic', 'transgenic mice', 'cardiac', 'cardiac injury', 'ejection fraction', 'shortening', 'fractional shortening', 'dilatation', 'heart dilatation', 'hypertrophy', 'constriction', 'aortic constriction', 'transverse aortic constriction', 'TAC', 'TAC', 'TAC surgery', 'we', 'hypertrophy', 'cardiac hypertrophy', 'post', 'TAC', 'post - TAC']
# ['HNO', 'myocytes', 'ventricular myocytes', 'mouse ventricular myocytes', 'shortening', 'peak', 'transient', 'cyclase', 'contractile response', 'isoproterenol', 'myocytes', 'dogs', 'microembolization', 'coronary microembolization', 'HF', 'ventricular end', 'diastolic pressure', 'end - diastolic pressure']
# ['the', 'HNO donor', 'myocardial function', 'man', 'man evidence', 'in - man']
# ['training', 'Exercise training', 'heart failure', 'chronic heart failure', 'density', 'density lipoprotein', 'high - density']
# ['Exercise', 'heart failure', 'chronic heart failure', 'exercise variables', 'cardiopulmonary exercise variables', 'heart failure', 'oxygen consumption', 'peak oxygen consumption', 'VO2', 'peak VO2', 'VEN', 'VCO2 slope', 'exercise variables', 'other exercise variables', 'oscillatory ventilation', 'EOV', 'partial pressure', 'tidal', 'tidal CO2', 'end - tidal']
# ['We', 'The', 'The Guidelines', 'Heart Failure', 'Guidelines - Heart Failure']
# ['DASH diet', 'diastolic function', 'ventricular', 'arterial coupling', 'ventricular - arterial coupling']
# ['hypertension', 'HFPEF', 'the', 'We', 'post', 'brachial', 'central blood pressure', 'radial arterial tonometry', 'cardiovascular function', 'echocardiographic', 'echocardiographic measures', 'Diastolic function', 'diastolic', 'diastolic filling', 'diastolic filling formalism', 'relaxation', 'yields relaxation', 'viscoelastic', 'passive', 'inflow velocity', 'mitral inflow velocity', 'ventricular', 'arterial coupling', 'ventricular - arterial coupling']
# ['hypertension', 'HFPEF', 'the', 'We', 'post', 'brachial', 'central blood pressure', 'radial arterial tonometry', 'cardiovascular function', 'echocardiographic', 'echocardiographic measures', 'Diastolic function', 'diastolic', 'diastolic filling', 'diastolic filling formalism', 'relaxation', 'yields relaxation', 'viscoelastic', 'passive', 'inflow velocity', 'mitral inflow velocity', 'ventricular', 'arterial coupling', 'ventricular - arterial coupling', 'The', 'clinic', 'brachial', 'brachial systolic', 'brachial systolic pressure', 'central end', 'diastolic function', 'ventricular', 'arterial coupling', 'ventricular - arterial coupling']
# ['neurological', 'cardiovascular', 'cardiovascular event', 'free rate', 'event - free rate']
# ['Myocardial infarction', 'occlusion', 'artery occlusion', 'Sham', 'CHF', 'infarcted', 'infarcted animals', 'left ventricle end', 'diastolic pressure', 'diastolic pressure ≥', 'end - diastolic pressure']
# ['insulin', 'Cardiac insulin', 'hypertrophy Cardiac insulin', 'mitochondrial energy production', 'systolic heart', 'systolic heart failure', 'overload', 'overload hypertrophy', 'pressure - overload']
# ['carvedilol', 'metoprolol', 'cardioverter', 'implantable cardioverter', 'inappropriate implantable cardioverter', 'defibrillator therapy', 'cardioverter - defibrillator therapy']
# ['carvedilol', 'metoprolol', 'cardioverter', 'implantable cardioverter', 'inappropriate implantable cardioverter', 'defibrillator therapy', 'cardioverter - defibrillator therapy', 'MADIT', 'CRT trial', 'MADIT - CRT trial']
# ['the effects', 'carvedilol', 'metoprolol', 'the endpoint', 'cardioverter', 'implantable cardioverter', 'inappropriate implantable cardioverter', 'defibrillator therapy', 'cardioverter - defibrillator therapy']
# ['MADIT', 'CRT study', 'MADIT - CRT study']
# ['heart failure', 'heart failure patients', 'resynchronization therapy', 'cardiac resynchronization therapy', 'defibrillator', 'cardioverter', 'implantable cardioverter', 'defibrillator device', 'cardioverter - defibrillator device']
# ['heart failure', 'chronic heart failure', 'heart failure', 'neuro', 'hormonal system', 'neuro - hormonal system']
# ['ECCT', 'heart failure therapy', 'advanced heart failure therapy', 'renal dysfunction', 'long', 'post', 'transplant morbidity', 'post - transplant morbidity']
# ['rehospitalization', 'day rehospitalization', 'post', 'acute care transfer policy', 'post - acute care transfer policy']
# ['Anemia', 'heart failure', 'chronic heart failure', 'HF', 'Anemia', 'HF', 'HF remains', 'HF', 'hemoglobin', 'training', 'Heart Failure', 'Exercise', 'Exercise Training', 'ACTION', 'HF - ACTION']
# ['Anemia', 'heart failure', 'chronic heart failure', 'HF', 'Anemia', 'HF', 'HF remains', 'HF', 'hemoglobin', 'training', 'Heart Failure', 'Exercise', 'Exercise Training', 'ACTION', 'HF - ACTION', 'HF', 'ACTION', 'HF - ACTION']
# ['Anemia', 'heart failure', 'chronic heart failure', 'HF', 'Anemia', 'HF', 'HF remains', 'HF', 'hemoglobin', 'training', 'Heart Failure', 'Exercise', 'Exercise Training', 'ACTION', 'HF - ACTION', 'HF', 'ACTION', 'HF - ACTION', 'randomized', 'training', 'exercise training', 'HF', 'ejection fractions', 'ventricular ejection fractions', 'Kansas', 'Cardiomyopathy Questionnaire', 'linear', 'exercise', 'exercise training', 'exercise', 'exercise training', 'HF', 'ACTION cohort', 'HF - ACTION cohort']
# ['natriuretic peptide', 'terminal fragment', 'N - terminal fragment']
# ['natriuretic peptide', 'terminal fragment', 'N - terminal fragment', 'proBNP', 'NT - proBNP']
# ['natriuretic peptide', 'terminal fragment', 'N - terminal fragment', 'proBNP', 'NT - proBNP', 'cardiomyocytes', 'ventricular cardiomyocytes', 'wall', 'ventricular wall', 'wall stress', 'ventricular wall stress', 'ischemia', 'myocardial ischemia', 'proBNP', 'NT - proBNP']
# ['natriuretic peptide', 'terminal fragment', 'N - terminal fragment', 'proBNP', 'NT - proBNP', 'cardiomyocytes', 'ventricular cardiomyocytes', 'wall', 'ventricular wall', 'wall stress', 'ventricular wall stress', 'ischemia', 'myocardial ischemia', 'proBNP', 'NT - proBNP', 'heart failure', 'proBNP', 'NT - proBNP']
# ['natriuretic peptide', 'terminal fragment', 'N - terminal fragment', 'proBNP', 'NT - proBNP', 'cardiomyocytes', 'ventricular cardiomyocytes', 'wall', 'ventricular wall', 'wall stress', 'ventricular wall stress', 'ischemia', 'myocardial ischemia', 'proBNP', 'NT - proBNP', 'heart failure', 'proBNP', 'NT - proBNP', 'coronary artery disease', 'CAD', 'coronary syndromes', 'acute coronary syndromes', 'CAD', 'proBNP levels', 'NT - proBNP levels']
# ['natriuretic', 'natriuretic peptides', 'terminal', 'N - terminal']
# ['Renin', 'angiotensin', 'Renin - angiotensin']
# ['Renin', 'angiotensin', 'Renin - angiotensin', 'aldosterone system inhibitors', 'angiotensin - aldosterone system inhibitors']
# ['Heart failure', 'HF', 'HF', 'ejection fraction', 'HF', 'ejection fraction', 'HFpEF', 'renin', 'angiotensin', 'renin - angiotensin']
# ['Heart failure', 'HF', 'HF', 'ejection fraction', 'HF', 'ejection fraction', 'HFpEF', 'renin', 'angiotensin', 'renin - angiotensin', 'aldosterone system', 'angiotensin - aldosterone system']
# ['Heart failure', 'HF', 'HF', 'ejection fraction', 'HF', 'ejection fraction', 'HFpEF', 'renin', 'angiotensin', 'renin - angiotensin', 'aldosterone system', 'angiotensin - aldosterone system', 'RAAS', 'HFrEF', 'angiotensin', 'converting enzyme inhibitors', 'angiotensin - converting enzyme inhibitors']
# ['retest', 'retest reliability', 'test - retest']
# ['retest', 'retest reliability', 'test - retest']
# ['Cross', 'sectional', 'Cross - sectional']
# ['concentric', 'concentric remodeling', 'concentric', 'concentric hypertrophy', 'ventricular', 'heart failure', 'ejection fraction', 'eccentric', 'eccentric hypertrophy', 'wall thickness', 'relative wall thickness', 'echocardiographic', 'hemodynamic', 'systolic', 'lower systolic', 'systolic blood', 'lower systolic blood', 'systolic blood pressure', 'renal impairment', 'hypertension', 'covariates', 'contractility', 'systolic', 'systolic blood', 'systolic blood pressure', 'compliance', 'diastolic pressure', 'end - diastolic pressure']
# ['heart failure', 'HF', 'defibrillators', 'cardioverter defibrillators', 'We', 'meta', 'HF', 'HF patients', 'ICD - HF']
# ['meta', 'HF', 'HF patients', 'ICD - HF']
# ['eplerenone', 'hyperkalemia', 'renal function', 'EMPHASIS', 'HF', 'HF study', 'EMPHASIS - HF']
# ['eplerenone', 'hyperkalemia', 'renal function', 'WRF', 'EMPHASIS', 'HF', 'EMPHASIS - HF']
# ['eplerenone', 'hyperkalemia', 'renal function', 'WRF', 'EMPHASIS', 'HF', 'EMPHASIS - HF', 'heart failure', 'ejection fraction', 'HF', 'REF', 'HF - REF']
# ['eplerenone', 'HF', 'REF', 'HF - REF']
# ['HF', 'REF', 'HF - REF']
# ['HF', 'REF', 'HF - REF', 'functional class', 'eGFR', 'potassium', 'mmol', 'eplerenone', 'hyperkalemia', 'developing hyperkalemia', 'WRF', 'Heart Association', 'NYHA', 'Heart Failure', 'Eplerenone', 'Placebo', 'Medicines', 'Failure Medicines', 'EMPHASIS', 'HF Study', 'EMPHASIS - HF Study']
# ['Heart failure', 'HF', 'society', 'modern society', 'pathological', 'pathological remodelling', 'heart', 'hypertrophy', 'cardiac hypertrophy', 'HF', 'fibrosis', 'inflammation', 'HF', 'hyperacetylation', 'chromatin hyperacetylation', 'Anand', 'bromodomain proteins', 'family bromodomain proteins', 'BETs', 'acetyl', 'lysine', 'lysine reader', 'acetyl - lysine']
# ['HFpEF', 'ivabradine', 'placebo', 'double', 'blind trial', 'double - blind trial']
# ['HF', 'HF tissue', 'stem cell', 'pluripotent stem cell', 'cardiomyocytes', 'hiPSC', 'CMs', 'hiPSC - CMs']
# ['pump', 'muscle pump', 'cardiac', 'cardiac filling', 'exercise', 'subpulmonary ventricle', 'Fontan circulation', 'muscle', 'wasting syndrome', 'muscle - wasting syndrome']
# ['Neurohormonal abnormalities', 'heart failure', 'congestive heart failure', 'CHF', 'CHF', 'neurohormonal systems', 'renin', 'angiotensin', 'renin - angiotensin']
# ['Neurohormonal abnormalities', 'heart failure', 'congestive heart failure', 'CHF', 'CHF', 'neurohormonal systems', 'renin', 'angiotensin', 'renin - angiotensin', 'aldosterone', 'angiotensin - aldosterone']
# ['HF registry', 'dichotomized', 'dichotomized patients', 'The associations', 'Spearman correlations', 'the', 'Kaplan', 'Meier curves', 'Kaplan - Meier curves']
# ['HF registry', 'dichotomized', 'dichotomized patients', 'The associations', 'Spearman correlations', 'the', 'Kaplan', 'Meier curves', 'Kaplan - Meier curves', 'Internal', 'Internal reliability', 'Cronbach', 'free rates', 'event - free rates']
# ['HF', 'prolapse', 'mitral valve', 'degenerative mitral valve', 'holosystolic murmur', 'heart', 'apex', 'blood pressure', 'plasty', 'prolapse', 'ruptures', 'chordal ruptures', 'triangular', 'triangular resection', 'anastomosis', 'edge anastomosis', 'annuloplasty', 'ring annuloplasty', 'Edwards Lifesciences', 'Irvine', 'HF', 'echocardiography', 'postoperative echocardiography', 'diastolic volume index', 'end - diastolic volume index']
# ['HF', 'prolapse', 'mitral valve', 'degenerative mitral valve', 'holosystolic murmur', 'heart', 'apex', 'blood pressure', 'plasty', 'prolapse', 'ruptures', 'chordal ruptures', 'triangular', 'triangular resection', 'anastomosis', 'edge anastomosis', 'annuloplasty', 'ring annuloplasty', 'Edwards Lifesciences', 'Irvine', 'HF', 'echocardiography', 'postoperative echocardiography', 'diastolic volume index', 'end - diastolic volume index', 'ejection fraction', 'mitral valve area', 'The', 'systolic volume', 'end - systolic volume']
# ['mellitus', 'diabetes mellitus', 'systolic', 'murmurs', 'diastolic murmurs', 'apex', 'Echocardiography', 'ejection fraction', 'valve', 'mitral valve', 'valve opening', 'angiography', 'Coronary angiography', 'hypertensive', 'systolic', 'motions', 'leaflet motions', 'dynamic', 'vasodilators', 'diuretics', 'murmurs', 'cardiac murmurs', 'echocardiography', 'diastolic volume', 'end - diastolic volume']
# ['ACP', 'erythropoiesis', 'stimulating agents', 'erythropoiesis - stimulating agents']
# ['randomised', 'RCTs', 'RM interventions', 'telemonitoring', 'home telemonitoring', 'implanted monitoring devices', 'office hours', 'machine interface', 'to - machine interface']
# ['heart failure', 'HF', 'cardioverter', 'Implantable cardioverter', 'defibrillators', 'cardioverter - defibrillators']
# ['aortic insufficiency', 'circulatory support', 'flow', 'continuous flow', 'CF', 'left ventricular', 'LVADs', 'pulsatile devices', 'post', 'the', 'we', 'valve surgery', 'aortic valve surgery', 'post', 'onset post', 'LVAD', 'post - LVAD']
# ['Surgical', 'post', 'LVAD', 'post - LVAD']
# ['FFM', 'FM', 'X', 'DXA', 'diabetic', 'diabetic patients', 'non - diabetic']
# ['proBNP', 'proBNP', 'NT - proBNP']
# ['proBNP', 'proBNP', 'NT - proBNP', 'proANP', 'adiponectin', 'total adiponectin', 'CHF', 'adrenomedullin', 'pro - adrenomedullin']
# ['proBNP', 'proBNP', 'NT - proBNP', 'proANP', 'adiponectin', 'total adiponectin', 'CHF', 'adrenomedullin', 'pro - adrenomedullin', 'proADM', 'MR - proADM']
# ['proBNP', 'proBNP', 'NT - proBNP', 'proANP', 'adiponectin', 'total adiponectin', 'CHF', 'adrenomedullin', 'pro - adrenomedullin', 'proADM', 'MR - proADM', 'FFM', 'follow', 'FFM', 'CC', 'CC patients', 'proBNP', 'NT - proBNP']
# ['proBNP', 'proBNP', 'NT - proBNP', 'proANP', 'adiponectin', 'total adiponectin', 'CHF', 'adrenomedullin', 'pro - adrenomedullin', 'proADM', 'MR - proADM', 'FFM', 'follow', 'FFM', 'CC', 'CC patients', 'proBNP', 'NT - proBNP', 'proADM', 'MR - proADM']
# ['Mini', 'Sentinel program', 'Mini - Sentinel program']
# ['Psychosocial Factors', 'Exercise', 'Exercise Adherence', 'Heart', 'Heart Failure', 'Heart Failure Patients', 'Heart Failure', 'Controlled Trial', 'Training', 'Exercise Training', 'HF', 'ACTION', 'HF - ACTION']
# Prediction:  3684
# GT:  2585
# 1195 2489 1390
# (32.44, 46.23, 38.13)
# Prediction:  3659
# GT:  2585
# 1241 2418 1344
# (33.92, 48.01, 39.75)

# %%
# groundtruth = pd.read_csv('/Users/hanhtran/Documents/terminology-extraction/ACTER/nl/htfl/annotations/htfl_nl_terms.ann', sep='	', engine='python',header=None)
# gt = list(groundtruth[0]) 

# pkl_file = open('./nl/nes_weighted_distilbert_multilingual_cased.pkl', 'rb') 
# predictions = pkl.load(pkl_file)

# preds =  get_term_(predictions)
# print(evaluation_metrics(preds, gt))
# stop_words = set(stopwords.words('english'))
# pred_terms =  set(preds) - set(stop_words)
# pred_terms = [x for x in pred_terms if len(x)>1]
# pred_terms = [x.lower().strip() for x in pred_terms]
# pred_terms = [re.sub(' -','-', x) for x in pred_terms]
# pred_terms = [re.sub('- ','-', x) for x in pred_terms]
# pred_terms = [re.sub('\(','', x) for x in pred_terms]
# pred_terms = [re.sub('\/','', x) for x in pred_terms]
# evaluation_metrics(pred_terms, gt)

# %%
pred_terms
# Out:
# ['ladderpatroon',
#  'gedragsmatige',
#  'sinusritme',
#  'boezemfibrilleren',
#  'cyp2c9',
#  'spier-',
#  'myocardfibrose',
#  'ascitesvocht',
#  'nierfunctie-verslechtering',
#  'nabelasting',
#  'vochtrestrictie',
#  'geleidingssnelheid',
#  'hartslag',
#  'bradycardie',
#  'voorwaarts',
#  'arts-assistenten',
#  'mmhg',
#  'post-hoc',
#  'palpabel',
#  'serumcholesterol-',
#  'remmen',
#  'ischemische',
#  'h2o.',
#  'verzamelden',
#  'dialysetherapie',
#  'ramus',
#  'farmacogenetica',
#  'angiotensine-receptor-blokkers',
#  'onregelmatig',
#  'winst',
#  'mitralis-aortaklepinsufficiëntie',
#  'vaatlijden',
#  'gemeenschappelijk',
#  'supraventriculaire',
#  'natriumsuppletie',
#  'dotterbehandeling',
#  'cumarinen',
#  'thuisinfusietherapie',
#  'calciumantagonisten',
#  'voorkómen',
#  'telefoon',
#  'basistherapie',
#  'hartfalenverpleegkundige',
#  'klasse-iv-patiënt',
#  'antracyclinederivaten',
#  'longcrepitaties',
#  'cardiomyopathie',
#  'alcoholinname',
#  'glitazones',
#  'linkerventrikeldruk',
#  'receptorstructuur',
#  'cross-overonderzoek',
#  'trager',
#  'ziekenhuisopnamen',
#  'glp-1-analogen',
#  'grootschalig',
#  'sensibiliteit',
#  'asynchronie',
#  'ziektegeschiedenis',
#  'buikklachten',
#  'klachtenreductie',
#  'negroïde',
#  'remt',
#  'collapsneiging',
#  'statine',
#  'ace-remmergebruikers',
#  'midclaviculairlijn',
#  'visusstoornissen',
#  'combinatietherapie',
#  'ziekenhuisverplaatsende',
#  'hba1c',
#  'clopidogrel',
#  'cardiomyocyt',
#  'atriumfibrillatie',
#  'gastroscopie',
#  'cardioloog',
#  'neurohormonale',
#  'absorptie',
#  'richtlijn',
#  'anti-inflammatory drugs',
#  'gynaecomastie',
#  'receptorblokkers',
#  'antiarrhythmica',
#  'perifeer',
#  'pas',
#  'lisinopriltoediening',
#  'elektrisch',
#  'einddoeltherapie',
#  'pulmonale',
#  'rosuvastatine',
#  'klepoperaties',
#  'druk-volumerelaties',
#  'arteriole',
#  'medicatiebeleid',
#  'echografie',
#  'galblaas',
#  'laagste',
#  'antitumoreffect',
#  'linkerventrikel',
#  'βètablokkers',
#  'peptide',
#  'macroalbuminurie',
#  'filtratiesnelheid',
#  'vasodilatatie',
#  'pacing',
#  'zwangerschap',
#  'hemodynamiek',
#  'staken',
#  'regulatie',
#  'hartinfact',
#  'maag',
#  'hazardatio',
#  'dosisoptitratie',
#  'comet',
#  'nutritionele',
#  'overleving',
#  'aan de',
#  'cardiomyopathieën',
#  'nesiritide',
#  'ontwaterd',
#  'slagvolume',
#  'duwt',
#  'serumcreatininespiegel',
#  'normale',
#  'serumconcentraties',
#  'benauwdheid',
#  'vermageren',
#  'circumflexus',
#  'retentie',
#  'plasmaspiegel',
#  'thromboxaan',
#  'casussen',
#  'natriumconcentratie',
#  'hartas',
#  'eindsystolische',
#  'angiotensine-ii-receptorblokkers',
#  'rustsituatie',
#  'vagotoon',
#  'zittend',
#  'natriumbeperking',
#  'vochtsuppletie',
#  'afstandsmeting',
#  'vitamine-e-suppletie',
#  'angineuze',
#  'bindingsduur',
#  'bijsluiter',
#  'palliatie',
#  'stroomdiagram',
#  'polsgolf',
#  'diureticum',
#  'tropische',
#  'farmacokinetiek',
#  'linkerventrikelhypertrofie',
#  'coronaire',
#  'etiologie',
#  'intensive-careafdeling',
#  'cardiaal',
#  'bloedplaatjes',
#  'thorax',
#  'digotoxine',
#  'angiotensine converting enzyme',
#  'glomerulusfiltratie',
#  'ambulant',
#  'myocardinfarcten',
#  'neurohormoonbepalingen',
#  'nycturie',
#  'meetpunt',
#  'spironolacton',
#  "pacing'-pacemaker",
#  'st-elevaties',
#  'vrouwen',
#  'cooperative',
#  'sympathicolytica',
#  'onafhankelijke',
#  'opiaten',
#  'bètablokkers',
#  'sterni',
#  'gewichtscontrole',
#  'defecatiepatroon',
#  'borstkanker',
#  'pathofysiologische',
#  'ntprobnp',
#  'vochthuishouding',
#  'remodeling',
#  'voedingstoestand',
#  'halsvenen',
#  'metformine',
#  'implantatieprocedure',
#  'echotechniek',
#  'klinische analyse',
#  'borst',
#  'seksuele activiteit',
#  'cavum',
#  'ecg',
#  'transmurale',
#  'nitraatgebruik',
#  'troglitazon',
#  'voeding',
#  'hartrevalidatie',
#  'intrathoracale pathologie',
#  'nierperfusie',
#  'cohort',
#  'sterfte',
#  'nierdoorstroming',
#  'triphosphate',
#  'defecatie',
#  'vaatanatomie',
#  'brady-',
#  'placebobehandelde',
#  'nt-pro-bnp',
#  'ß-',
#  'flecaïnide',
#  'turgor',
#  'coronair syndroom',
#  'hr',
#  'diagnostische',
#  'bindingsplaatsen',
#  'ouderen',
#  'cox)-2-remmers',
#  'adipositas',
#  'mayo',
#  'farmacologie',
#  'mitralisklepinsufficiëntie',
#  'coronairangiografie',
#  'blood',
#  'verkeerde',
#  'cardioverter-defibrillator',
#  'opioïden',
#  'remodeling-theorie',
#  'tricuspidalisklepvlak',
#  'polymorfisme',
#  'voorbelasting',
#  'rugligging',
#  'startdosering',
#  'wgbo',
#  'zuurstofsoorten',
#  'spironolactongroep',
#  'griepvaccinatie',
#  'bcl2',
#  'accelerometer-eenheden',
#  'diastolische druk',
#  'overlijdensgevallen',
#  'placebopil',
#  'fibrinolytica',
#  'dehydratie',
#  'preëxistent',
#  'bijwerkingenprofiel',
#  'tartraat',
#  'biologische',
#  'training',
#  'myocardischemie',
#  'bnp concentratie',
#  'infarct',
#  'medicijn',
#  'hoesten',
#  'elderly',
#  'casustekst',
#  'echocardiografisch',
#  'marginale',
#  'assist devices',
#  'defibrillatortherapie',
#  'angiotensinogeen',
#  'hartsouffle',
#  'dihydropyrimidinedehydrogenase',
#  'nucleotidepolymorfisme',
#  'tong',
#  'cva',
#  'transmurale afspraak',
#  'trombo-embolische',
#  'maligniteiten',
#  'condensatie',
#  'vasodilaterende',
#  'anemie',
#  'lipidenverlagende',
#  'wens',
#  'bnp-waarde',
#  'tempo',
#  'hospice',
#  'sinoatriaal',
#  'therapiekeuze',
#  'heart survey',
#  'terugkoppeling',
#  'draagvlak',
#  'defibrillator',
#  'apotheker',
#  'percutane',
#  'medicijngebruik',
#  'melkzuuracidose',
#  'compensatiemogelijkheden',
#  'fluorouracil',
#  'siliconenlijm',
#  'anxiolytica',
#  'huisartsenpraktijk',
#  'glucosurie',
#  'grauwe',
#  'strijklicht',
#  'team',
#  'dubbelblinde',
#  'zelfzorg',
#  'cvz',
#  'chronotroop',
#  'therapieën',
#  'linker',
#  'externa',
#  'corticosteroïden',
#  'blanke',
#  'bijgeluiden',
#  'ace-remmer',
#  'downregulatie',
#  'koorts',
#  'vochtinname',
#  "bloedingsrisico's",
#  'handrug',
#  'lvedd',
#  'met',
#  "diabeteszorgprogamma's",
#  'comorbiditeiten',
#  'pioglitazon',
#  'vasopeptidase-remmer',
#  'recompensatie-evenwichten',
#  'seh',
#  'cholesterolsyntheseremmer',
#  'tabletje',
#  'bsvs-chf',
#  'dilatatie',
#  'medisch centrum',
#  'richtdosissen',
#  'pathognomonische',
#  'vervolgtraject',
#  'farmacotherapie',
#  'paradigm-hf-onderzoek',
#  'hart',
#  'standaardnazorg',
#  'therapietrouw',
#  'centraalveneuze druk',
#  'gerehydreerd',
#  'thoraxdiameter',
#  'behandelingsevenwicht',
#  'tweesnijdend',
#  'ferritinewaarde',
#  'crp',
#  "hartfalenzorgprogramma's",
#  'verminderde',
#  'wondzorg',
#  'seksuele',
#  'neurohumorale systemen',
#  'dna-ladders',
#  'hartfalenonderzoeken',
#  'hyperglykemie',
#  'grade',
#  'zorgorganisatie',
#  'besluiten',
#  'sterfgeval',
#  'gedialyseerd',
#  'epidemiologische',
#  'matrixverval',
#  'neurohumorale reacties',
#  'linkerbundeltakblokconfiguratie',
#  'psychofarmaca',
#  'diarree-episoden',
#  'pectoris',
#  'accelerometer',
#  'systolische',
#  'braken',
#  'celdood',
#  'probnp',
#  'omzettingssnelheid',
#  'sd',
#  'carcinoom',
#  'aspirin',
#  'ziektegeschiedenissen',
#  'een',
#  'geleidingsstoornissen',
#  'ventrikelfibrillatie',
#  'nierfunctiestoornis',
#  'qrs-duur',
#  'in-vitrostudie',
#  'captoprilgebruik',
#  'inriep',
#  'angiotensine-ii',
#  'raas',
#  'ischemie',
#  'licht',
#  'siginficant',
#  'monotherapie',
#  'wachttijd',
#  'kern',
#  'bloeddruk',
#  'ooghoogte',
#  'vkorc1',
#  'bijwerkingen',
#  'klinische praktijk',
#  'weefselhypoperfusie',
#  'systolisch',
#  'plasma-bnp-concentratie',
#  'polsfrequentie',
#  'pointes',
#  'follow-up',
#  'sensitiviteit',
#  'luchtbel',
#  'calciuminflux',
#  'darmpakket',
#  'gedilateerd',
#  'gezondheidszorgsysteem',
#  'hypoperfusie',
#  'cross-over',
#  'gly389-variant',
#  'constructvaliditeit',
#  'interventiegroep',
#  'venepols',
#  'ambulante',
#  'cardiomegalie',
#  'longfunctieafwijkingen',
#  'hartfalenpolikliniek',
#  'bindingsaffiniteit',
#  'ventrikelfibrilleren',
#  'bloedvat',
#  'hartfalenpatiënt',
#  'interventiegroepen',
#  'pneumokokkenvaccinatie',
#  'diuretica',
#  'diclofenac',
#  'neprilysine',
#  'oog',
#  'patiënt',
#  'ademgeruis',
#  'hyperlipidemie',
#  'klepdisfunctie',
#  'metoprololonderzoek',
#  'bloeddrukverlagende',
#  'glucoseverlagende',
#  'klasse-effect',
#  'laboratoriumcontroles',
#  'biventriculaire',
#  'zoutrestrictie',
#  'perfunderen',
#  'plasma-bnp-waarde',
#  'criticalcare-afdelingen',
#  'at-ii-antagonist',
#  'arbeid',
#  'lvad',
#  'rekking',
#  'qs-complexen',
#  'ontstekingsremmende',
#  'spiercellen',
#  'omgezet',
#  'infusiesysteem',
#  'leefstijladvies',
#  'angiotensine-converterendenzym',
#  'heart failure',
#  'cholecystitis',
#  'bloedglucoseverlagend',
#  'bloedonderzoek',
#  'cardiomyocyten',
#  'intensieve',
#  'zuurstof',
#  'angiotensine-converterend-enzymremmers',
#  'nefronen',
#  'tachy-',
#  'hospitalisatiefrequentie',
#  'beluisterde',
#  'hartkleplijden',
#  'vochtbeperking',
#  'rechtszijdig',
#  'vetzuren',
#  'mitralisklep',
#  'parasympathische',
#  'hartritmestoornis',
#  'kernboodschappen',
#  'chloorhexidine',
#  'artery disease',
#  'pacemakers',
#  'digoxinegebruik',
#  'longvelden',
#  'sinus syndrome',
#  'ii-receptorblokkers',
#  'interviewtechnieken',
#  'reutelende',
#  'bilirubinewaarde',
#  'uitademingsstand',
#  'colonoscopie',
#  'ontregeling',
#  'contractiliteit',
#  'doodsoorzaak',
#  'beta-blokkers',
#  'niet-cardiale',
#  'nier-',
#  'drukbelasting',
#  'steekproeven',
#  'diffuse',
#  'verdraagbaarheid',
#  'ziekenhuismaterialen',
#  'neutrale',
#  'epifenomenen',
#  'stappen',
#  'eiwit',
#  'longziekte',
#  'thuiszorg',
#  'in-vitro-opstelling',
#  'aii-antagonisten',
#  'genetische',
#  'stapsgewijze',
#  'therapeutische',
#  'digoxine-spiegels',
#  'creatinineklaring',
#  'verbindingslijn',
#  'agonisten',
#  'shock',
#  'zuurbranden',
#  'ziekte',
#  'protectie',
#  'hartschade',
#  'hartafwijking',
#  'neprilysine-receptoren',
#  'ziekenhuistherapie',
#  'dobutamine',
#  'weefselperfusie',
#  'ß1-adrenerge',
#  'vervolg',
#  'commentaar',
#  'serumkaliumconcentratie',
#  'plasmaconcentraties',
#  'viscerale',
#  'buikpijnklachten',
#  'superior',
#  'cholesterolverlager',
#  'aids',
#  'getuige',
#  'ace-remmers',
#  'bètablokkeerders',
#  'pci',
#  'pro-bnp',
#  'maagkanker',
#  'spierkrachttraining',
#  'volumedepletie',
#  'bnp',
#  'cerebrovasculair',
#  'cumarines',
#  'hazardratio',
#  'darmischemie',
#  'aortastenose',
#  'kanker',
#  'kaderhuisarts',
#  'bradycardieën',
#  'voetzoolreflexen',
#  'sleutelwoorden',
#  'lv)-schade',
#  'polikliniek',
#  'buikafwijkingen',
#  'pco2',
#  'piekconcentratie',
#  'eerstelijnsgezondheidszorg',
#  'nierfunctieverslechtering',
#  'antibioticavoorschriften',
#  'angiotensin',
#  'perifere',
#  'isosorbidedinitraat',
#  "angiotensine-'converting'-enzym",
#  'diureticaresistentie',
#  'casuïstische',
#  'hartklachten',
#  'bnp-test',
#  'thiazidediuretica',
#  'donororganen',
#  'copd-ers',
#  'plaatjesaggregatieremmer',
#  'aortae',
#  'map-daling',
#  'ventrikel-',
#  'mengelmoesje',
#  'aldosteronreceptorblokker',
#  'digoxinespiegel',
#  'pompen',
#  'vullings-',
#  'serum',
#  'sternocleidomastoideus',
#  'lagere',
#  'hyponatriëmie',
#  'longstuwing',
#  'left',
#  'herseninfarcten',
#  'verapamil',
#  'ureumconcentratie',
#  'poliklinieken',
#  'hartfalen?1',
#  'natriumarm',
#  'leverziekten',
#  'tricuspidalisklepplastiek',
#  'palliatieve',
#  'verzameld',
#  'apoptose',
#  'zuurstofopnamevermogen',
#  'regulair',
#  'horizontale',
#  'ventrikelfunctie',
#  'harttransplantatie',
#  'ziektebeeld',
#  'hf-pef',
#  're-entry-mechanismen',
#  'heartfailure',
#  'alogliptinebehandelde',
#  'implanteerbare',
#  'constrictoire',
#  'ritmestoornissen',
#  'digoxine-overdosering',
#  'geneesmiddelvoorschriften',
#  'éénjaarsoverleving',
#  'waarnemer',
#  'microal-buminurie',
#  'correctiemechanisme',
#  'nettoresultaat',
#  'pneumonie',
#  'leverstuwing',
#  'soepel',
#  'brieven',
#  'alfa-',
#  'conditie',
#  'voorkamerfibrillatie',
#  'atherogenese',
#  'hand',
#  'ritmestoornis',
#  'waakzaamheid',
#  'cardiovasculaire',
#  'comorbiditeit',
#  'cerebrovasculaire aandoeningen',
#  'overheid',
#  'klinische',
#  'gepoogd',
#  'hartinfarct',
#  'halfwaardetijd',
#  'fibrinolytische therapie',
#  'draagbare',
#  'serumcreatinineconcentratie',
#  'monogenetische',
#  'chf-diagnoses',
#  'obesitas',
#  'off-labelgebruik',
#  'hartcyclus',
#  'diabetesbehandeling',
#  'ß1-receptor',
#  'fev1',
#  'hartfunctie',
#  'vochtretentie',
#  'angiotensine-2-receptorblokker',
#  'diarree',
#  'spironalactone',
#  'vervolgonderzoek',
#  'spieren',
#  'ziektekostenverzekeraar',
#  'onderzoeksvragen',
#  'fret-ratio',
#  'rule-out',
#  'familieanamnese',
#  'hartactie',
#  'nitraten',
#  'therapie',
#  'os',
#  'regressieanalyse',
#  'nyha-klasse',
#  'lethargische',
#  'waterretentie',
#  'omapatrilaat',
#  'stimulator',
#  'mace',
#  'longproblemen',
#  'zoutvervangers',
#  'proeflaparotomie',
#  'angiotensine-ii-antagonisten',
#  'placebo-groep',
#  'waterhuishouding',
#  'vaatverwijders',
#  'drijven',
#  'roche-therapeutics',
#  'cordis',
#  'msec',
#  'mesangium',
#  'n-terminaal',
#  'thuisinfusie',
#  'beleid',
#  'gly389',
#  'neurohumorale',
#  'ruwweg',
#  'farmaceutische',
#  'horizontaal',
#  'multifactoriële',
#  'gfr',
#  'gang',
#  'renine-angiotensine-aldosteron',
#  'oraal',
#  'significantieniveau',
#  'gecombineerde',
#  'dieettherapietrouw',
#  'n-terminal-probnp',
#  'dutp',
#  'pijler',
#  'hartklepafwijkingen',
#  'angina',
#  'dosisverlaging',
#  'ijzerstatus',
#  'lagere waarde',
#  'vat',
#  'systeemtherapie',
#  'hartpatiënten',
#  'gewichtsverlies',
#  'nierfunctievermindering',
#  'halve',
#  'intraveneuze',
#  'luchtwegen',
#  'natuurlijk',
#  'warfarine',
#  'nyha-classificatie',
#  'digoxinespiegels',
#  'nt-probnp-waarden',
#  'ascites',
#  'diurese',
#  'angiotensine-converterend-enzym',
#  'afkappunten',
#  'wattage',
#  'thalidomide',
#  'roken',
#  'comfort',
#  'enzymwerking',
#  'cholesterol',
#  'shuttle',
#  'mswt',
#  'hand-voetsyndroom',
#  'langetermijneffect',
#  'polsdruk',
#  'cerebrale',
#  'klinische symptomen',
#  'voedingsintake',
#  'luchthoudendheid',
#  'polsslag',
#  'conditietraining',
#  'diagnostische standaard',
#  'progressie',
#  'digoxine',
#  'kaliumsuppletie',
#  'reutelendetachypnoïsche',
#  'chf-prevalentie',
#  'geneeskundig',
#  'bumetanide',
#  'hyperkaliëmie',
#  'tumorweefsel',
#  'haldol',
#  'paroxysmale',
#  'ontslagdiagnose',
#  'aan de hand',
#  'pulmonale dyspneu',
#  'longlijden',
#  'hartfalen.1',
#  'hartvaataandoening',
#  'zorginstellingen',
#  'triggers',
#  'transplantatie',
#  'terminale aandoeningen',
#  'beta-gonisten',
#  'myocardfunctie',
#  'bloedvaten',
#  'niet-cardiaal',
#  'perindopril',
#  'hypoglykemie',
#  'cytokinen',
#  'ontspannen',
#  'digoxin',
#  'nt-probnp',
#  'diuretische',
#  'ventrikeldiastole',
#  'iliopsoas',
#  'ventriculaire dysfunctie',
#  'aldactone',
#  'hartspiervezel',
#  'vaatafwijkingen',
#  'elektrofysiologische',
#  'rechteratriumdruk',
#  'abnormaal',
#  'screeningsonderzoeken',
#  'perfusiedruk',
#  'stuwingsbeeld',
#  'palpitaties',
#  'natriumintake',
#  'anaesthetica',
#  'tachyaritmieën',
#  'rosiglitazon',
#  'academisch',
#  'lvesd',
#  'creatininewaarden',
#  'voordeel',
#  'chloor',
#  'backward',
#  'eerstehulpafdeling',
#  'vochtbeleid',
#  'vetweefsel',
#  'biomedische',
#  'voorwandafleidingen',
#  'st-segmentdepressie',
#  'thoraxdiameters',
#  'antibioticagebruik',
#  'stapsgewijs',
#  'rekatheterisatie',
#  'hormoon',
#  'einddiastolische',
#  'indicatie',
#  'conclusie',
#  'hematologische',
#  'hb',
#  'hartpomp',
#  'fluorouracil-prodrugs',
#  'angiotensine-i',
#  'crt-d',
#  'perfusiescintigrafie',
#  'klein',
#  'prognose',
#  'recidiefhartfalen',
#  'omega-3-vetzuren',
#  'calciuretisch',
#  'ethische',
#  'nierinsufficientie',
#  'ß-blokkers',
#  'ventrikeldisfunctie',
#  'overlijdensrisico',
#  'ziekteprogressie',
#  'rhonchi',
#  'natriuretische peptiden',
#  'adjuvant',
#  'biochemische',
#  'lisdiuretica',
#  'geneesmiddelen',
#  'proto-oncogenen',
#  'longfunctieonderzoek',
#  'overlevingskans',
#  'ms w',
#  'ehs-hf',
#  'kamerfunctie',
#  'trastuzumab',
#  'receptor',
#  'zout',
#  'röntgenfoto',
#  'multidisciplinaire',
#  'bronchoconstrictie',
#  'darm-',
#  'erytrodysesthesie',
#  'contact',
#  'elektrocardiografisch',
#  'linker-ventrikel-ejectiefractie',
#  'externa stroomt',
#  'at1-receptor',
#  'nierperfusiestoornis',
#  'serumelektrolyten',
#  'groeifactoren',
#  'rupturering',
#  'hartgeruis',
#  'ontrafeling',
#  'fysiologische',
#  'pars',
#  'nt-probnp-bepalingen',
#  'standaardlab',
#  'overlijdensakte',
#  'systole',
#  'doxazosine',
#  'farmacodynamische',
#  'autorijden',
#  'vergevorderd',
#  'onderhydratie',
#  'medioclaviculaire lijn',
#  'bnp-uitslag',
#  'axial flow pump',
#  'heropnamecijfers',
#  'streefwaarde',
#  'gezondheidszorginstanties',
#  'hartgeruisen',
#  'regressiemodel',
#  'myocardinfarct',
#  'hart-',
#  'factoranalyse',
#  'angiotensine-receptorantagonisten',
#  'gewichtsreductie',
#  'placebopillen',
#  'bloedbeeld',
#  'pufje',
#  'hypertensie',
#  'zoutretentie',
#  'manueel',
#  'als',
#  'longfoto',
#  'thiazolidinedionderivaten',
#  'bicarbonaat',
#  'myocardweefsel',
#  'subgroepanalyses',
#  'pretransplantatiekandidaten',
#  'lage',
#  'transplantatie-wachtlijst',
#  'cholesterolwaarde',
#  'bax',
#  'ventrikelfrequentie',
#  'kleplijden',
#  'combinatie',
#  'bètareceptorantagonisten',
#  'vasoconstrictie',
#  'tubulair',
#  'therapieprotocol',
#  'angiotensine-ii-receptorantagonist',
#  'lichaamsgewicht',
#  'nhg-standaard',
#  'aldosteronproductie.1',
#  'biochemisch',
#  'transferrinesaturatie',
#  'hypoxie',
#  'linkerventrikelfunctie',
#  'arteriële systeem',
#  'extern referentiepunt',
#  'psychosociale',
#  'psychologische',
#  'bnp-plasmaspiegels',
#  'ziekenhuis',
#  'diureticatoediening',
#  'heropname',
#  'ejectiefractie',
#  'diabeten',
#  'thiazide',
#  'terminale',
#  'plantkundige',
#  'nesiritide-groep',
#  'echocardiografische',
#  'venen',
#  'ureum',
#  'hypotension',
#  'uitsluitingscriteria',
#  'remissieduur',
#  'linkerkamerdisfunctie',
#  'diltiazem',
#  'metoprololsuccinaat',
#  'galopritme',
#  'coronaire syndromen',
#  'non-invasief',
#  'batterijen',
#  'advising',
#  'huisartsencontract',
#  'coronairvaten',
#  'cox',
#  'arg389-variantcellen',
#  'infarcering',
#  "dyspnée d'effort",
#  'orale',
#  'veneuze',
#  'trombi',
#  'ß-blokker',
#  'prikkelhoest',
#  'wikkelhart',
#  'domperidon',
#  'veneuze boog',
#  'maculopathie',
#  'hartdood',
#  'fluoropyrimidine',
#  'thoraxcentrum',
#  'cardiovasculair',
#  'mellitus',
#  'geneeskunde',
#  'ibuprofen',
#  'matrixstabiliserende',
#  'endotheline',
#  'hyperthyreoïdie',
#  'ht',
#  'equipotente',
#  'cvd-metingen',
#  'chirurgie',
#  'fret',
#  'verzamelen',
#  'e-learning',
#  'cardiale schade',
#  'thuiszorgprogramma',
#  'acetylsalicylzuur',
#  'linkerventrikelvolume',
#  'ventrikel',
#  'creatinineconcentratie',
#  'dyslipedemie',
#  'adrenaline',
#  'enalapril',
#  'ß2-receptoren',
#  'metoprolol',
#  'heart attack trial',
#  'aan',
#  'bloeddrukwaarde',
#  'donorhart',
#  'zelfmedicatie',
#  'cardiac events',
#  'vervolgduur',
#  'extremiteiten',
#  'aldosteronreceptoren',
#  'atherosclerotische',
#  'hartpompen',
#  'kalium-',
#  'proatherosclerotische mechanismen.1',
#  'gamma-gt',
#  'euvolemische',
#  'slaapapneu',
#  'idiopathische',
#  'ace-inhibitoren',
#  'filtratierate',
#  'cox-2-remmers',
#  ...]

# %%
# preds_lem = lemma(pred_terms)
# gts_lem = lemma(gt)

# print('After lemmatization')
# print(len(set(preds_lem)))
# print(len(set((gts_lem))))
# print(evaluation_metrics(list(set(preds_lem)), list(set(gts_lem))))

# %%
# groundtruth = pd.read_csv('/Users/hanhtran/Documents/terminology-extraction/ACTER/en/htfl/annotations/htfl_en_terms.ann', sep='	', engine='python',header=None)
# gt = list(groundtruth[0]) 

# pkl_file = open('../rules/final_preds_sklearn.pkl', 'rb') #
# predictions = pkl.load(pkl_file)
# preds =  get_term_(predictions)
# print(evaluation_metrics(preds, gt))
# stop_words = set(stopwords.words('english'))
# pred_terms =  set(preds) - set(stop_words)
# pred_terms = [x for x in pred_terms if len(x)>1]
# pred_terms = [x.lower().strip() for x in pred_terms]
# pred_terms = [re.sub(' -','-', x) for x in pred_terms]
# pred_terms = [re.sub('- ','-', x) for x in pred_terms]
# pred_terms = [re.sub('\(','', x) for x in pred_terms]
# pred_terms = [re.sub('\/','', x) for x in pred_terms]
# evaluation_metrics(pred_terms, gt)

# %%
col = ['a','b','c','d']
for num, alpha in enumerate('abcd'):
    print(num)
    print(alpha)

# %%
for num, alpha in enumerate(col):
    print(num)
    print(alpha)

# %%
# def sephist(col):
#     yes = df[df['group'] == 'yes'][col]
#     no = df[df['group'] == 'no'][col]
#     return yes, no

# for num, alpha in enumerate('abcd'):
#     plt.subplot(2, 2, num)
#     plt.hist(sephist(alpha)[0], bins=25, alpha=0.5, label='yes', color='b')
#     plt.hist(sephist(alpha)[1], bins=25, alpha=0.5, label='no', color='r')
#     plt.legend(loc='upper right')
#     plt.title(alpha)
# plt.tight_layout(pad=0.4, w_pad=0.5, h_pad=1.0)

# #https://stackoverflow.com/questions/45883598/pandas-histogram-df-hist-group-by

# %%
nlp = stanza.Pipeline('en', processors='tokenize', use_gpu=True, pos_batch_size=3000) # Build the pipeline, specify part-of-speech processor's batch size
doc = nlp("Barack Obama was born in Hawaii.") # Run the pipeline on the input text
print(doc) # Look at the result
# Out:
# 2021-06-04 10:08:36 INFO: Loading these models for language: en (English):
# ========================
# | Processor | Package  |
# ------------------------
# | tokenize  | combined |
# ========================
#
# 2021-06-04 10:08:36 INFO: Use device: cpu
# 2021-06-04 10:08:36 INFO: Loading: tokenize
# 2021-06-04 10:08:36 INFO: Done loading processors!
# [
#   [
#     {
#       "id": 1,
#       "text": "Barack",
#       "misc": "start_char=0|end_char=6"
#     },
#     {
#       "id": 2,
#       "text": "Obama",
#       "misc": "start_char=7|end_char=12"
#     },
#     {
#       "id": 3,
#       "text": "was",
#       "misc": "start_char=13|end_char=16"
#     },
#     {
#       "id": 4,
#       "text": "born",
#       "misc": "start_char=17|end_char=21"
#     },
#     {
#       "id": 5,
#       "text": "in",
#       "misc": "start_char=22|end_char=24"
#     },
#     {
#       "id": 6,
#       "text": "Hawaii",
#       "misc": "start_char=25|end_char=31"
#     },
#     {
#       "id": 7,
#       "text": ".",
#       "misc": "start_char=31|end_char=32"
#     }
#   ]
# ]

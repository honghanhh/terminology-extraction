# %%
import stanza
stanza.download("en")
# Out:
# Downloading https://raw.githubusercontent.com/stanfordnlp/stanza-resources/master/resources_1.2.0.json: 128kB [00:00, 8.89MB/s]
# 2021-04-07 23:48:01 INFO: Downloading default packages for language: en (English)...
# Downloading http://nlp.stanford.edu/software/stanza/1.2.0/en/default.zip: 100%|██████████| 411M/411M [13:34<00:00, 505kB/s]
# 2021-04-08 00:01:44 INFO: Finished downloading models and saved to /home/hanh/stanza_resources.

# %%
nlp = stanza.Pipeline(lang='en', processors='tokenize,mwt,pos,lemma')
# Out:
# 2021-04-08 00:01:44 WARNING: Can not find mwt: default from official model list. Ignoring it.
# 2021-04-08 00:01:44 INFO: Loading these models for language: en (English):
# ========================
# | Processor | Package  |
# ------------------------
# | tokenize  | combined |
# | pos       | combined |
# | lemma     | combined |
# ========================
#
# 2021-04-08 00:01:44 INFO: Use device: cpu
# 2021-04-08 00:01:44 INFO: Loading: tokenize
# 2021-04-08 00:01:49 INFO: Loading: pos
# 2021-04-08 00:01:53 INFO: Loading: lemma
# 2021-04-08 00:01:54 INFO: Done loading processors!

# %%
import pandas as pd

import re

# %%
gt = pd.read_csv('../ACTER/en/htfl/annotations/htfl_en_terms.ann', sep='	', engine='python',header=None)

# %%
def lemma(li):
    new_list = []
    for t in li:
        doc = nlp(str(t))
        doc1 = ' '.join([word.lemma for sent in doc.sentences for word in sent.words])
        doc1 = re.sub('-',' ',doc1)
        doc1 = re.sub(' \)', '\)',doc1)
        doc1 = re.sub('\( ', '\(',doc1)
        doc1 = re.sub(' +', ' ',doc1)
        new_list.append(doc1)
    new_list = [s for s in new_list if len(s) >= 2]
    return new_list

# %%
gts_lem = lemma(gt[0])

# %%
gt[0]
# Out:
# 0                         (123)i-meta-iodobenzylguanidine
# 1                                             (123)i-mibg
# 2       1-alkyl-2-acetyl-sn-glycerol cholinephosphotra...
# 3                                            2-vessel cad
# 4                                             2-way anova
#                               ...
# 2356                                                 β1ar
# 2357                                                β1ars
# 2358                     β2-adrenergic receptor haplotype
# 2359                                          β2-receptor
# 2360                                β2-receptor haplotype
# Name: 0, Length: 2361, dtype: object

# %%
set(gts_lem)
# Out:
# {'gly7',
#  'renin inhibitor',
#  'wall stiffness',
#  'dialysis',
#  'hf index',
#  'ivc',
#  'medical treatment',
#  'systolic function',
#  'dopamine',
#  'paf',
#  'clinic',
#  'endopeptidase inhibitor',
#  'sympathetic nervous system',
#  'hrv',
#  'inotropic effect',
#  'adenoviral',
#  'all cause mortality',
#  'tug test',
#  'time up & go test',
#  'ventilatory efficiency slope',
#  'bcl 2',
#  'mitochondrial complex v activity',
#  'tonometric',
#  'prodrug',
#  'acute care surgery',
#  'xo',
#  'xanthine oxidase inhibition',
#  'hemocompatibility',
#  'massive embolism',
#  'tm24/7',
#  'basic helix loop helix',
#  'terminal heart failure',
#  'atropine',
#  'biomedical',
#  'bmi',
#  'pressure overload induce heart failure',
#  'insulin receptor substrate 1',
#  'monoclonal antibody',
#  'correlate',
#  'refractory right heart failure',
#  'non invasively',
#  'functional class',
#  'surgeon',
#  'c statistic',
#  'hm',
#  'neprilysin inhibitor',
#  'chromatin hyperacetylation',
#  'rv decompensation',
#  'hscrp',
#  'pde2 inhibition',
#  'vasopressin',
#  'doxorubicin efflux transporter',
#  'leave ventricular diastolic function',
#  'cabg',
#  'hemodynamics',
#  'regression analysis',
#  'mva',
#  'severe heart failure',
#  'ventricular assist device',
#  'doppler',
#  'ef',
#  'pde',
#  'myocardial extracellular matrix',
#  'retn',
#  'heart transplantation',
#  'myofibre regeneration',
#  'oral',
#  'abdominal',
#  'arrhythmia',
#  'hyperkalemia',
#  'l type channel',
#  'diastolic fill formalism',
#  'ventricular fibrillation',
#  'insulin resistance',
#  'icd shock',
#  'lean body mass',
#  'zsf1',
#  'guanylate cyclase',
#  'dnx',
#  'clinical practice guideline',
#  'fat free mass',
#  'if channel inhibition',
#  'rest tension',
#  'discharge',
#  'composite primary outcome',
#  'right ventricular contractile reserve',
#  'contracting',
#  'dilated',
#  'nri',
#  'anesthetize',
#  'clcnka',
#  'antiplatelet medication',
#  'cxl 1020',
#  'atrial tachyarrhythmias',
#  'chronic hf',
#  'dilatation',
#  'prescription',
#  'leave ventricular dysfunction',
#  'sympathetic activity',
#  'gene induction',
#  'lv end diastolic dimension',
#  'ldl cholesterol',
#  'isoproterenol',
#  'right ventricular end diastolic area index',
#  'lad',
#  'adenosine',
#  'to + channel α subunit',
#  'noncardiovascular',
#  'prescribe',
#  'sympathetic tone',
#  'microrna',
#  'uninephrectomy',
#  'tgf β signal',
#  'leave atrial area',
#  'proteomic',
#  'pcwp',
#  'hypokalemia',
#  'auc',
#  'extubate',
#  'placebo',
#  'p38',
#  'medical',
#  'thromboembolism',
#  'inhospital',
#  'calreticulin',
#  'camp hydrolysis',
#  'transmitral',
#  'crt d',
#  'cardiac transplantation',
#  'cell',
#  'dilation',
#  'stress doppler echocardiography',
#  'polymerase ii',
#  'dna fragmentation',
#  'testosterone therapy',
#  'stenting',
#  'baroreflex sensitivity',
#  'rna',
#  'right ventricular pulmonary arterial coupling',
#  'hypertrophic',
#  'phospholamban',
#  'multivariable model',
#  'hh',
#  'adenine nucleotide',
#  'video edge detection',
#  'arm cuff',
#  'multivariable adjust hazard ratio',
#  'coronary perfusion',
#  'diastolic mitral leaflet motion',
#  'epicatechin rich cocoa',
#  'new york heart association class ii',
#  'multivariate cox proportional hazard regression modeling',
#  'thrombotic',
#  'precapillary ph',
#  'acs',
#  'hgb',
#  'diabete mellitus',
#  'chronic',
#  'cardiac volume',
#  'chromatin structure',
#  'rem2',
#  'neprilysin inhibition',
#  'intention to treat',
#  'adipose tissue',
#  'contractile response',
#  'erk1/2',
#  'antagonism',
#  'von willebrand factor',
#  'crt',
#  'angiotensin converting enzyme',
#  'apoptotic signal pathway',
#  'β2 receptor',
#  'diagnostic',
#  'intravenously',
#  'shock therapy',
#  'hf with reduce ejection fraction',
#  'acetyl lysine reader protein',
#  'cardiac sodium',
#  'contractile function',
#  'l dko',
#  'parasympathetic',
#  'pharmacologic',
#  'phenotype',
#  'hypoalbuminemia',
#  'cardiac mrna',
#  'dapc',
#  'vascular endothelial growth factor blockade',
#  't score',
#  'cardiac index',
#  'neurohumoral',
#  'compensate hfpef',
#  'mitochondrial structure',
#  'outcome',
#  'gene expression',
#  'p70s6k ser \\(411\\)',
#  'heart failure with a reduce ejection fraction',
#  'surgically',
#  'heart mass',
#  'electrocardiographic q wave',
#  'sarcopenic range muscle waste',
#  'neurological',
#  'bpm',
#  'bypass',
#  'messenger rna',
#  'ventricular function',
#  'systolic ventricular function',
#  'cd34+vegfr2 + cell',
#  'right coronary artery',
#  'biopsy',
#  'percutaneous',
#  'randomize',
#  'intensive care unit',
#  'spontaneous vt',
#  'death',
#  'riα',
#  'af',
#  'renal disease',
#  'medicine',
#  'angiotensin convert enzyme',
#  'catheter ablation',
#  'cav1.2',
#  'post myocardial infarction',
#  'functional status',
#  'interatrial',
#  'epidemic',
#  'end stage renal disease',
#  'randomise control trial',
#  'sympathetic',
#  'cardioprotective',
#  'ec',
#  'systolic heart failure',
#  'fontan',
#  'valsartan',
#  'mitral valve',
#  'reverse remodeling',
#  'sarcomere',
#  'proangiogenic',
#  'testosterone supplementation',
#  'heart dilatation',
#  'incidence',
#  'chamber patterning',
#  'tunel',
#  'tolvaptan',
#  'doppler ultrasonography',
#  'fat mass',
#  'mix linear model',
#  'ischemic cardiomyopathy',
#  'lipolysis',
#  'vt',
#  'chronic kidney disease',
#  'aortic valve insufficiency',
#  'poc',
#  'ri',
#  'upr',
#  'general anaesthesia',
#  'circumferential strain',
#  'stent',
#  'physical therapy',
#  'spironolactone',
#  "angeli 's salt",
#  'rs',
#  'atherosclerotic',
#  'endothelial dysfunction',
#  'amyloidotic',
#  'qrs prolongation',
#  'vegf signal pathway',
#  'nyha functional class',
#  'pathogenesis',
#  'tricuspid',
#  'coronary disease',
#  't1',
#  'endothelin',
#  'leave ventricular end diastolic pressure',
#  'primary composite endpoint',
#  'ulcer',
#  'electromechanical delay',
#  'intramuscular testosterone supplementation',
#  'cardiac output',
#  'chelation',
#  'lv fibrosis',
#  'cox model',
#  '6 minute walking distance',
#  'nyha class iii',
#  'metoprolol',
#  'tonometry',
#  'maximum oxygen consumption',
#  'end diastolic',
#  'preserve ejection fraction',
#  'mix method study',
#  'hypothermic circulatory arrest',
#  'palliative',
#  'expression',
#  'citrate cycle',
#  'decompensated heart failure',
#  'cardiac death',
#  'collagen',
#  'ejection fraction',
#  'rvpo',
#  'salt loading',
#  'cox hazard model',
#  'nanomolar',
#  'renin angiotensin aldosterone',
#  'snp',
#  'morpholino based',
#  'qrs morphology',
#  'exercise capacity',
#  'patient',
#  'transcatheter',
#  'leave atrial',
#  'systolic pressure',
#  'β adrenergic receptor blocker therapy',
#  'hhd',
#  'interquartile range',
#  'β blocker',
#  'mechanical cardiac support',
#  'renin angiotensin aldosterone pathway',
#  'dystrophin associated protein complex',
#  'circulatory',
#  'sa',
#  'repolarization',
#  'autonomic balance',
#  'perk',
#  'no',
#  'nt probnp',
#  'myocardial diastolic dysfunction',
#  'remodelling',
#  'atrial pacing',
#  'q66p',
#  'lcz696',
#  'quality of life',
#  'paf cpt',
#  'chronic obstructive pulmonary disease',
#  'tricuspid annular plane',
#  'platelet activating factor',
#  'sts',
#  'echo derived pulmonary arterial systolic pressure',
#  'xo inhibition',
#  'vagal tone',
#  'hno donor',
#  'catheterisation',
#  'arterial pressure',
#  'anaerobic threshold',
#  'electrocardiographic',
#  'transfusion',
#  'peripheral muscle',
#  'chronic pah',
#  'cardiomyocyte',
#  'mr',
#  'hfpef',
#  'new york heart association class',
#  'lp pla2',
#  'drug',
#  'pulmonary arterial vasculature',
#  'β blockade',
#  'skeletal muscle',
#  'pro brain type natriuretic peptide',
#  'aldosterone blockade',
#  'fractional flow reserve',
#  'functional mitral stenosis',
#  'wilcoxon match pair sign rank test',
#  'glomerular filtration rate',
#  'arterial elastance',
#  'cardiac dysfunction',
#  'serum cystatin c',
#  'excitation contraction',
#  'retrospective match cohort study',
#  'jugular',
#  'eds',
#  'ang ii infusion',
#  'baseline',
#  'chordal rupture',
#  'extend criterion cardiac transplant',
#  'mild hf',
#  'doppler echocardiography',
#  'cvd',
#  'refractory congestive heart failure',
#  'nurse practitioner',
#  'mena overexpression',
#  'leave ventricle end diastolic pressure',
#  'internist',
#  'organ',
#  'chest',
#  'bundle branch morphology',
#  'cardiac growth',
#  'l type voltage gated can \\(2 +\\) channel',
#  'composite end point',
#  'minimal detectable change',
#  'sphingosine 1 phosphate',
#  'high density lipoprotein',
#  'pulmonary congestion',
#  'c would',
#  'deg',
#  'il6',
#  'area under the receiver operate characteristic curve',
#  'pro b type np',
#  'pulseless ventricular fibrillation',
#  'echocardiographic',
#  'chromatin',
#  'shuttle walk test',
#  'lv end diastolic pressure',
#  'fluid overload',
#  'differential effect',
#  'end diastolic volume',
#  'dna',
#  'neurohormonal stimulation',
#  'leave ventricular diastolic end diameter',
#  'revascularization',
#  'meta analyse',
#  'fm',
#  'compensate lv hypertrophy',
#  'n2bus',
#  'abcc2',
#  'angii',
#  'angiotensin receptor blocker',
#  'β 1ar',
#  'rate control',
#  'inflammatory',
#  'cxl 1051',
#  'magnetic resonance spectroscopy',
#  'prospectively',
#  'circulate progenitor cell',
#  'adenovirus',
#  'blood pressure',
#  'ss',
#  'type 2 diabete',
#  'functional electrical stimulation',
#  'multivariable regression',
#  'systolic hf',
#  'cox regression',
#  'pna',
#  'evidence base',
#  'consultation',
#  'pef',
#  'acute coronary syndrome',
#  'fractional shortening',
#  'pluripotency marker',
#  'sitagliptin',
#  'antitumor',
#  'driveline',
#  'renal',
#  'vegf pathway',
#  'valve plasty',
#  'sympathetic outflow',
#  'uti',
#  'kinase 2',
#  'unfold protein response',
#  'cell death',
#  'adjust odd ratio',
#  'bax',
#  'negative binomial regression model',
#  'pro75',
#  'troponin t',
#  'creatine',
#  'proteome',
#  'blood cell',
#  'n terminal pro b type np',
#  'mena',
#  'epidemiology',
#  'ring annuloplasty',
#  'right atrium',
#  'dpp 4 inhibitor',
#  'electrolyte',
#  'hrqol',
#  'vascular',
#  'at',
#  'mena expression',
#  'nicorandil',
#  'alendronate',
#  'emd',
#  'idiopathic dilated cardiomyopathy',
#  't2*',
#  'c kit + progenitor',
#  'cardiac stress',
#  't1 mapping',
#  'aldosterone',
#  'kidney',
#  'adverse outcome',
#  'molecular pathway',
#  'pulmonary hypertension',
#  'lvas',
#  'cohort study',
#  'kcl ki',
#  'cardiovascular',
#  'r r interval',
#  'peripheral artery disease',
#  'heart sound',
#  'cardiac metabolic gene expression',
#  'lean mass quantification',
#  'palliative care',
#  'thromboembolic pulmonary hypertension',
#  'gly4',
#  'brachial systolic pressure',
#  'angiotensin ii infusion',
#  'respiratory gas analysis',
#  'sd of rr interval',
#  'myocardial fibrosis',
#  'non biological disease modify antirheumatic drug',
#  'tnf',
#  'cv',
#  'prevalence',
#  'glucose oxidation',
#  'invasive haemodynamic assessment',
#  'standard error of measurement',
#  'raf mek1/2 erk1/2 scaffold protein',
#  'mitochondrial proteome',
#  'leave atrial pressure',
#  'hyperinsulinemia',
#  'angiotensin receptor antagonist',
#  'transcription factor',
#  'antiadrenergic',
#  'compensatory hypertrophy',
#  'leave ventricular fill',
#  'β be',
#  'renin angiotensin aldosterone system inhibitor',
#  'diagnose',
#  'area under the curve',
#  'tachyarrhythmias',
#  '71ar',
#  'cardiovascular reserve',
#  'cs',
#  'enos ser \\(1177\\)',
#  'circulation',
#  'cellular metabolism',
#  'cd 133 + cell',
#  'hemodynamically',
#  'c terminally',
#  'mitogen activate protein kinase',
#  'shunting',
#  'ischemic mitral regurgitation',
#  'concentric leave ventricular hypertrophy',
#  'rad',
#  'titin hypophosphorylation',
#  'severe hf',
#  'cardiomyopathy',
#  'rac1',
#  'protein kinase',
#  'acute heart failure',
#  'unilateral renal denervation',
#  'embolize',
#  'systolic',
#  'tachypacing induce hf',
#  'cardiography',
#  'nonterminal epitope',
#  "'s 12884",
#  'np',
#  'pathology',
#  'differential analysis',
#  'erythropoiesis',
#  'kidney failure',
#  'p.arg83gly',
#  'dacron patch closure',
#  'rest hr',
#  'transthoracic echocardiography',
#  'pah',
#  'cav1.3',
#  'orthotopic heart transplantation',
#  'lbbb',
#  'nitric oxide',
#  'exercise induce pasp',
#  'remote ischemic conditioning',
#  'dt',
#  'body mass index',
#  'maximal ventricular power index',
#  'riiα',
#  'terminal',
#  'nris',
#  'cyclase',
#  'medical history',
#  'postoperative',
#  'anemia',
#  'congestive hf',
#  'attrition',
#  'nyha iii',
#  'sacubiltril',
#  'kidney disease',
#  'physical',
#  'peak of 2',
#  'methylatropine',
#  'loop diuretics',
#  'hf',
#  'risk stratification',
#  'postischemic heart failure',
#  'diastolic mitral annular velocity',
#  'lv fill pressure',
#  'chronic end stage heart failure',
#  'renal function',
#  'cr',
#  'pkc βii',
#  'free wall rs',
#  'injection',
#  'autonomic imbalance',
#  'icc',
#  'surgical',
#  're hospitalization',
#  'ffm',
#  'papillary muscle',
#  'echocardiograms',
#  'contemporaneous control group',
#  'fluorescence resonance energy transfer',
#  'myocarditis',
#  'pharmacological',
#  'btt',
#  'oedema',
#  'protein kinase r like er kinase',
#  'pro brain natriuretic peptide',
#  'nephrectomy',
#  'observational cohort study',
#  'tidal respiration',
#  'symptomatic adult fontan',
#  'adjuvant',
#  'subclinical',
#  'baroreflex',
#  'b type natriuretic peptide',
#  'implantable',
#  'lipoprotein',
#  'mena deletion',
#  'gene expression profile',
#  'anti oxidant defence',
#  'mitral fill flow',
#  'multivariate analysis',
#  'nondiabete',
#  'coronary intervention',
#  'ivabradine',
#  'exercise rehabilitation',
#  'peptide',
#  'chf nyha iiib',
#  'carvedilol',
#  'rheumatoid arthritis',
#  'atherosclerosis',
#  'serum creatinine',
#  'organic',
#  'sd',
#  'microarray',
#  'confidence interval',
#  'fibrosis',
#  'narrow qrs complex',
#  '6mwt',
#  'mitral',
#  'linear mixed model',
#  'doctor',
#  'ea',
#  'retrospective cohort',
#  'antitachycardia pacing',
#  'operative',
#  'microembolization',
#  'coronary microembolization induce hf',
#  'heart beat',
#  'angiography',
#  'pathological',
#  'diastole',
#  'tnf antagonist',
#  'symptomatic systolic heart failure',
#  'myocardial tissue',
#  'peripheral arterial disease',
#  'nosignificant',
#  'anterior leaflet',
#  'degenerative mitral valve',
#  'randomization',
#  'biomarker',
#  'mrna splice',
#  'acf',
#  'met',
#  'medical therapy',
#  'n terminal pro brain natriuretic peptide',
#  'condition',
#  'trastuzumab',
#  'pasp',
#  'lv end diastolic volume',
#  'ra',
#  'physiology',
#  'cystatin c',
#  'cardiac fill pressure',
#  'pharmaceutical',
#  'breathing',
#  'subproteome',
#  'ch',
#  'cardiopulmonary exercise test',
#  'liver',
#  'mesenchymal',
#  'dyssynchronous fail heart',
#  'sv',
#  'pacing induce dilated cardiomyopathy',
#  'euthanization',
#  'emergency department',
#  'mrna splicing',
#  'significance',
#  'health related quality of life',
#  'lv strain',
#  'multivariate adjust odd ratio',
#  'central venous pressure',
#  'cardiac overexpression',
#  'second generation sulfonylureas',
#  'transmitral blood flow velocity',
#  'paf acetylhydrolase',
#  'lv assist device',
#  'invasively',
#  'ami',
#  'blood',
#  'deficit index',
#  'drs',
#  'dilated lv',
#  'monocyte',
#  'camp signal',
#  'radiological',
#  'bisphophonate',
#  'cardiac apoptosis',
#  'sternotomy',
#  'histone acetyltransferase',
#  'decompensation',
#  'serum sodium',
#  'leave atrium',
#  'leave ventricular dd',
#  'hypertensive heart failure',
#  'hf with reduce ef',
#  'petco2',
#  'cardiopulmonary resuscitation',
#  'log rank',
#  'cardiovascular morbidity',
#  'nonmitochondrial',
#  'ankle brachial index',
#  'circumflex artery',
#  'saf',
#  'chronic pulmonary arterial hypertension',
#  'adenylyl cyclase',
#  'ras',
#  'cardiopulmonary',
#  'net reclassification improvement',
#  'cox proportional hazard analysis',
#  'gluconeogenesis',
#  'scaffold protein',
#  'clinician',
#  'vegf',
#  'postmenopausal',
#  'iron homeostasis',
#  'mitral valve area',
#  'icd',
#  'hf with preserve ef',
#  'fully magnetically levitate centrifugal flow chronic lvas',
#  'arterial',
#  'neurohormonal system',
#  'candesartan',
#  'nontrastuzumab user',
#  'complication',
#  'right heart circulatory failure',
#  'hct',
#  'plasma norepinephrine',
#  'midregional proanp',
#  'resistin',
#  'intubate',
#  'longitudinal rv fiber shortening',
#  'gastrointestinal bleed',
#  'cardiac plasma membrane',
#  'co primary outcome',
#  'leave ventricular systolic dysfunction',
#  'sickle cell disease',
#  'cgmp',
#  'pathophysiologically',
#  'anaerobic metabolism',
#  'gadolinium chelate contrast agent',
#  'dapc protein',
#  'erythropoiesis stimulating agent',
#  'magnetic resonance angiography',
#  'rehospitalization',
#  'edema',
#  'cachexia',
#  'right atrial pressure',
#  'structure telephone support',
#  'cardiogenic',
#  'total arterial compliance',
#  'cachectic heart failure',
#  'cyclic adenosine monophosphate',
#  'disease',
#  'fpassive',
#  'hereditary',
#  'chronic organ failure',
#  'cardiac energy metabolism gene expression',
#  'prescribing',
#  'pevk',
#  'chronic hfpef',
#  'prognostically',
#  'isoform',
#  'acute myocardial infarction',
#  'ecs',
#  'reduce leave ventricular ejection fraction',
#  'correlation coefficient',
#  'surgical palliation',
#  'ventricular myocyte',
#  'heart magnetic resonance imaging',
#  'apoptosis',
#  'coronary artery disease',
#  'dhand',
#  'nucleolin',
#  'coprimary outcome',
#  'biventricular',
#  'asymptomatic',
#  'tunel positive cell',
#  'heart transplant',
#  'polytetrafluoroethylene',
#  'cox proportional hazard model',
#  'interventricular',
#  'prospective study',
#  'aortic',
#  'beta1 adrenergic receptor',
#  'acute hf',
#  'eh',
#  'pressure overload hypertrophy',
#  'breast cancer',
#  'lvad therapy',
#  'cardiovascular death',
#  'emergency room',
#  'endothelial',
#  'dd',
#  'p38α',
#  'hospitalization',
#  'bromodomain protein',
#  'etidronate',
#  'hypertensive lv dysfunction',
#  'myocardial insulin resistance',
#  'immunoreactive',
#  'eplerenone',
#  'haematopoietic cell transplantation',
#  'troponin i',
#  'heart failure with preserve ejection fraction',
#  'congestive heart failure',
#  'mitochondrial function',
#  'continuity equation',
#  'akt→forkhead box class o 1 signal',
#  'atrioventricular delay',
#  'rehabilitation',
#  'spontaneous ventricular tachycardia',
#  'bottleneck stent',
#  'vasopressin receptor antagonist',
#  'neuro hormonal',
#  'catecholamine',
#  'ka renal chloride channel gene',
#  'life expectancy',
#  'pressure ulcer',
#  'lyso paf acetyltransferase',
#  'peak respiratory quotient',
#  'rrna transcription',
#  'lv contractility',
#  'parasympathetic activity',
#  'symptomatic chronic advanced heart failure',
#  'hemolysis',
#  'annular ms',
#  'cardiac amyloidosis',
#  'preserve lvef',
#  'degenerative mitral regurgitation',
#  'cα',
#  'plasma catecholamine',
#  'mitral valve plasty',
#  'ser77',
#  'interaction term analysis',
#  'coronary artery bypass grafting',
#  'hr',
#  'nyha classification',
#  'signal protein',
#  'ventricular action potential',
#  'rm',
#  'continuous wave doppler echocardiography',
#  'third heart sound',
#  'concentric remodeling',
#  'logistic regression',
#  'osteomedullary biopsy',
#  'hypertensive',
#  'sulfonylureas',
#  'pro2',
#  'lv end systolic volume',
#  'antibody',
#  'bnp',
#  'morbidity',
#  'psoriasis',
#  'tumor necrosis factor',
#  'obese',
#  'albumin',
#  'explant',
#  'tapse',
#  'z score',
#  'breathlessness',
#  'radial strain',
#  'cardioverter defibrillator device',
#  'mrnas',
#  'bioprosthetic aortic valve replacement',
#  'right ventricular fractional area',
#  'human to human contact',
#  'mi',
#  'neuronal stressor',
#  'lung',
#  'post lvad be',
#  'leave bundle branch block pattern',
#  'β2 adrenergic receptor haplotype',
#  'neurohormonally',
#  'trpm7',
#  'plasma n terminal pro b type natriuretic peptide',
#  'myocardial angiogenesis',
#  'brain',
#  'rmsea',
#  'radial arterial tonometry',
#  'myofiber shortening',
#  'extracellular matrix',
#  'protein',
#  'mrna',
#  'diastolic failure',
#  'adverse event',
#  'bb',
#  'diagnosis',
#  'cerebrovascular',
#  'mechanical circulatory support',
#  'undiagnosed',
#  'aortocaval fistula',
#  'estimate glomerular filtration rate',
#  'polymorphism',
#  'sh',
#  'diastolic mitral valve tethering',
#  'vasopressin type 2 receptor antagonist',
#  'leave anterior descend coronary artery occlusion',
#  'cardiac fill',
#  'dpp 4',
#  'pump thrombosis',
#  'health care',
#  'bcl2',
#  'inverse correlation',
#  'st2',
#  'univariable analysis',
#  'lv mass',
#  'gut',
#  'coronary artery bypass',
#  'transcriptional pause release',
#  'heart rate variability',
#  'lv reverse remodeling',
#  'doxorubicin',
#  'incremental shuttle walk test',
#  'multivariate logistic regression analysis',
#  'at1 receptor',
#  'cardiogenic shock',
#  'mr proadm',
#  'phosphorylation',
#  'lv fractional shortening',
#  'myocardial t1',
#  'new york heart association functional class',
#  'nodularity',
#  'reduce ef',
#  'specificity',
#  'chronic renal failure',
#  'rct',
#  'remodeling',
#  'adiponectin',
#  'longitudinal',
#  'preserve ef',
#  'intestinal dysfunction',
#  'lv dilatation',
#  'mdc',
#  'immunoassays',
#  'epicatechin',
#  'cfi',
#  'ms',
#  'tgf β',
#  'stenosis',
#  'plasma nps',
#  'myocardial washout',
#  'pf',
#  'peak oxygen consumption',
#  'beta receptor blocker',
#  'postoperatively',
#  'renal dysfunction',
#  'β be responsiveness',
#  '6 minute hall walk',
#  'lyso paf at',
#  'fes',
#  'qt variability',
#  'valvular',
#  'cha₂ds₂vasc score',
#  'dual x ray absorptiometry',
#  'diastolic stiffness',
#  'intravenous bolus',
#  'thr197',
#  'renin',
#  'concentric hypertrophy',
#  'coronary artery bypass surgery',
#  'titin',
#  'leave anterior descend artery',
#  'diastolic blood pressure',
#  'atrial explant',
#  'shunt',
#  'afterload',
#  'atrium',
#  'myocyte depolarization',
#  'collagen cross linking',
#  'heart disease',
#  'severe systolic heart failure',
#  'pulmonary arterial pressure',
#  'leukocyte',
#  'nephropathy',
#  'defibrillation',
#  'lv internal diameter',
#  'central glycosylated region',
#  'furosemide',
#  'x ray',
#  'renal dnx',
#  'diastolic mitral annulus velocity',
#  ...}

# %%
df = pd.DataFrame({'Term': list(set(gts_lem))})
df.to_csv('../Lemmatized_ACTER/en/htfl_en_terms_lem.csv', header = False, index= False)

# %%
df
# Out:
#                                       Term
# 0                                     gly7
# 1                          renin inhibitor
# 2                           wall stiffness
# 3                                 dialysis
# 4                                 hf index
# ...                                    ...
# 2144                         liver disease
# 2145                                   pvf
# 2146                                 donor
# 2147  new york heart association class iii
# 2148                        nonprescribing
#
# [2149 rows x 1 columns]

# %%
def lemma_doc(doc):
    doc = nlp(str(t))
    doc1 = ' '.join([word.lemma for sent in doc.sentences for word in sent.words])
    doc1 = re.sub('-',' ',doc1)
    doc1 = re.sub(' +', ' ',doc1)
    return doc1

# %%
# with open('/ACTER/en/hthe-zen-of-python.txt') as f:
#     contents = f.read()
# f.close()

# %%
import pandas as pd

# %%
lem = pd.read_csv('ann_train_lem.csv')
non_lem = pd.read_csv('ann_train.csv')

# %%
lem.labels.value_counts()
# Out:
# O    124561
# B     23209
# I      3803
# Name: labels, dtype: int64

# %%
non_lem.labels.value_counts()
# Out:
# O    125353
# B     19605
# I      3779
# Name: labels, dtype: int64

# %%
lem_w = lem[(lem.labels == 'B') | (lem.labels == 'I')].words.to_list()
non_lem_w = non_lem[(non_lem.labels == 'B') | (non_lem.labels == 'I')].words.to_list()

# %%
set(lem_w) - set(non_lem)
# Out:
# {'fix',
#  'fatigue',
#  'centrifugal',
#  'legitimate',
#  'verification',
#  'ii',
#  'oldenburg',
#  'utility',
#  'market',
#  'burden',
#  'anlehnung',
#  'monitoring',
#  'bone',
#  'social',
#  'scandal',
#  'er',
#  'balancing',
#  'lip',
#  'inviolability',
#  'rights',
#  'lope',
#  'overstep',
#  'mediation',
#  'swedish',
#  'twisted',
#  'assessment',
#  'non-criminal',
#  'persian',
#  'cross-country',
#  'bitting',
#  'tracking',
#  'bureaucratisation',
#  'high',
#  'single',
#  'canadian',
#  'gas',
#  'foal',
#  'piaff',
#  'holsteiner',
#  'scribing',
#  'lawful',
#  'prediction',
#  '/',
#  'full-span',
#  'sector',
#  'young',
#  'governance',
#  'coe',
#  'slip-ring',
#  'meter',
#  'cp',
#  'supervision',
#  'control',
#  'net',
#  'mwhe',
#  'accomplice',
#  'surface',
#  'instrumentality',
#  'vorticity',
#  'forward-sideways',
#  'gear',
#  'appropriation',
#  'equestrianism',
#  'band',
#  'motor',
#  'responsibility',
#  'fossil',
#  'furling',
#  'core',
# ...

# %%
term = pd.read_csv('/home/hanh/Desktop/terminology-extraction/ACTER/en/equi/annotations/equi_en_terms.ann', delimiter = '\t', header = None)

# %%
term[(term[0].str.len() == 5)]
# Out:
#           0              1
# 37    arena  Specific_Term
# 68    beats    Common_Term
# 76    bends  Specific_Term
# 85    boots    Common_Term
# 86    bound    Common_Term
# ...     ...            ...
# 1123  walks    Common_Term
# 1138  whips    Common_Term
# 1146  wraps  Specific_Term
# 1147  wrist    Common_Term
# 1151  yield  Specific_Term
#
# [73 rows x 2 columns]

# %%
term = pd.read_csv('/home/hanh/Desktop/terminology-extraction/ACTER/en/wind/annotations/wind_en_terms.ann', delimiter = '\t', header = None)
term[(term[0].str.len() <= 1)]
# Out:
#      0            1
# 969  v  Common_Term

# %%
import pandas as pd

# %%
lem = pd.read_csv('ann_train_lem.csv')
non_lem = pd.read_csv('ann_train.csv')

# %%
lem.labels.value_counts()
# Out:
# O    124561
# B     23209
# I      3803
# Name: labels, dtype: int64

# %%
non_lem.labels.value_counts()
# Out:
# O    125353
# B     19605
# I      3779
# Name: labels, dtype: int64

# %%
lem_w = lem[(lem.labels == 'B') | (lem.labels == 'I')].words.to_list()
non_lem_w = non_lem[(non_lem.labels == 'B') | (non_lem.labels == 'I')].words.to_list()

# %%
set(lem_w) - set(non_lem)
# Out:
# {'revenue',
#  'third',
#  'renewable',
#  'haunch-in',
#  'barge',
#  'stifle',
#  'misconduct',
#  'steeplechasing',
#  'national',
#  'spars',
#  'close',
#  'walker',
#  'volte',
#  'biomass',
#  'penning',
#  'through',
#  'steady',
#  'laundering',
#  'resolution',
#  'assembly',
#  'over',
#  'v',
#  'fraudulent',
#  'loose-ring',
#  'expertise',
#  'accountant',
#  'conversion',
#  'fetlock',
#  'the',
#  'tip-loss',
#  'base',
#  'competence',
#  'provide',
#  'area',
#  'kwpn',
#  'list',
#  'economy',
#  'dynamics',
#  'rib',
#  'turn-on-the-forehand',
#  'canter-trot',
#  'jurisdiction',
#  'gdp',
#  'issue',
#  'magistracy',
#  'chordline',
#  'long-lining',
#  'mean',
#  'canadian',
#  'intensive',
#  'full-span',
#  'arabian',
#  'monetary',
#  'underarm',
#  'monitor',
#  'relax',
#  'pattern',
#  'outboard',
#  'tail',
#  'damage',
#  'knee',
#  'edge',
#  'prediction',
#  'protection',
#  'kick',
#  'english-type',
#  'voltage',
#  'viscosity',
#  'normal',
#  'culture',
#  'waiver',
#  'institution',
#  'handler',
#  'perpetrator',
#  'neighbourhood',
#  'environmental',
#  'coe',
#  'sanctioning',
#  'straighten',
#  'hay',
#  'holsteiner',
#  'effective-radius',
#  'wps',
#  'young',
#  'follow-up',
#  'confidential',
#  'off-axis',
#  'code',
#  'three-beat',
#  'gag',
#  'tip-brake',
#  'behind',
#  'concession',
#  'disk',
#  'arena',
#  'good',
#  'cool',
#  'gait',
#  'bone',
#  'spending',
#  'criminalise',
#  'g',
#  'deduct',
#  'true',
#  'formula',
#  'exception',
#  'gearless',
#  'network',
#  'driving',
#  'jockey',
#  'basis',
#  'quarter',
#  'elbow',
#  'plane',
#  'actively',
#  'reduction',
#  'appeal',
#  'aspect-ratio',
#  'pitch-change',
#  'figure',
#  'deprivation',
#  'elevation',
#  'off-book',
#  'kilowatt',
#  'trot–halt–trot',
#  'mechanical',
#  'plastic',
#  'pressure',
#  'helmet',
#  'legitimacy',
#  'correct',
#  'blackmail',
#  'inward',
#  'four-bladed',
#  'cut-out',
#  'warrant',
#  'body',
#  'm',
#  'relaxed',
#  'administrative',
#  'field',
#  'gallop',
#  'removal',
#  'apparatus',
#  'audit',
#  'election',
#  'speed',
#  'enquiry',
#  'millstone',
#  'reinforce',
#  'two-bladed',
#  'cervical',
#  'pelvis',
#  'tactful',
#  'banking',
#  'turbine',
#  'pasture',
#  'tip-controlled',
#  'legally',
#  'riding',
#  'correction',
#  'box',
#  'reform',
#  'relation',
#  'non-contractual',
#  'straight',
#  'barrel',
#  'stall-control',
#  'downwind',
#  'combine',
#  'hydraulic',
#  'donation',
#  'master',
#  'scandal',
#  'aero-elastic',
#  'side',
#  'i',
#  'tower',
#  'hub',
#  'aerodynamics',
#  'ratio',
#  'pole',
#  'immovable',
#  'enercon',
#  'relative',
#  'export',
#  'friction',
#  'anti-bribery',
#  'social',
#  'adjudication',
#  'walking',
#  'outside',
#  'competitive',
#  'servant',
#  'half-halt',
#  'weight',
#  'endurance',
#  'bull',
#  'rope',
#  'tco2',
#  'flicker',
#  'paso',
#  'winding',
#  'single-blade',
#  'losgelassenheit',
#  'free',
#  'connect',
#  'technically',
#  'appaloosas',
#  'half-volte',
#  'loading',
#  'counter-change',
#  'machine',
#  'contract',
#  'force-air',
#  'warming',
#  'sme',
#  'nacelle',
#  'improper',
#  'confidentiality',
#  'haunch',
#  'cutter',
#  'pato',
#  'rotor',
#  'upper',
#  'aerodynamic',
#  'counter-canter',
#  'forelimb',
#  'abb',
#  'butt',
#  'cpi',
#  'racing',
#  'rollkur',
#  'independence',
#  'glass',
#  'ngos',
#  'surcingle',
#  'duty',
#  'classical',
#  'camberline',
#  'storm',
#  'reward',
#  'park',
#  'tempo',
#  'benefit',
#  'housing',
#  'contain',
#  'far',
#  'practice',
#  'undue',
#  'judgement',
#  'suffrage',
#  'case',
#  'far-wake',
#  'large',
#  'organized',
#  'axis',
#  'reynold',
#  'applicable',
#  'society',
#  'glide',
#  'deductibility',
#  'system',
#  'mount',
#  'legal',
#  'cantle',
#  'opex',
#  'theoretical',
#  'durchlässigkeit',
#  'hydrodynamically',
#  'governance',
#  'commerce',
#  'free-stream',
#  'tongue',
#  'deep',
#  'special',
#  'union',
#  'levade',
#  'witness',
#  'truss',
#  'co-financing',
#  'warmblood',
#  'consolidate',
#  'segment',
#  'cyclic',
#  'wither',
#  'variable',
#  'intelligence',
#  'regulatory',
#  'royal',
#  'limit',
#  'corruption',
#  'evidential',
#  'instructor',
#  'gas',
#  'generalize',
#  'ear',
#  'generalise',
#  ',',
#  'order',
#  'motion',
#  'enfield-andreau',
#  'diagonal',
#  'official',
#  'onshore',
#  'cavalletti',
#  'cable',
#  'and',
#  'deflection',
#  'sport',
#  'impact',
#  'mouth',
#  'prosecution',
#  'count',
#  'bow',
#  'heat',
#  'trainer',
#  'mach',
#  'saliva',
#  'slow-twist',
#  'on-site',
#  'induction',
#  'elementary',
#  'g-20',
#  'subsistence',
#  'assurance',
#  'hip',
#  'plain',
#  'movement',
#  'wrist',
#  'kv',
#  'ne',
#  'memorandum',
#  'grackle',
#  'blade',
#  'dynamic',
#  'rate',
#  'transition',
#  'rna',
#  'malpractice',
#  'inspection',
#  'flash',
#  'serpentine',
#  'shadbelly',
#  'test',
#  'variation',
#  'axe',
#  'axisymmetric',
#  'neck',
#  'left',
#  'angular',
#  'court',
#  'compensation',
#  'whip',
#  'flow',
#  'horizontalaxis',
#  'foal',
#  'first',
#  'cabinet',
#  'axis-tilt',
#  'penalization',
#  'flank',
#  'electrotechnical',
#  'govern',
#  'classic',
#  'eia',
#  'aggravating',
#  'white',
#  'schwung',
#  'weymouth',
#  'half-10-meter',
#  'fibre',
#  'blowing',
#  'supervisory',
#  'differential',
#  '18-meter',
#  'automatic',
#  'liability',
#  'footfall',
#  'custodial',
#  'drop',
#  'transparent',
#  'flap',
#  'gelding',
#  'impartially',
#  'fix-bottom',
#  'driver',
#  'ventilation',
#  'plan',
#  'four-beat',
#  'tent',
#  'compliance',
#  'cross-cutting',
#  'fund',
#  'pacing',
#  'baroque',
#  'cut-in',
#  'monopoly',
#  'against',
#  'polish',
#  'serious',
#  'axial',
#  'reporting',
#  'overtrack',
#  'chest',
#  'reimbursement',
#  'ii',
#  'versammlung',
#  'development',
#  'repeal',
#  'toe',
#  'header',
#  'windmill',
#  'onesey',
#  'poll',
#  'platform',
#  'provider',
#  'freedom',
#  'bent',
#  '/',
#  'definitive',
#  'good-governance',
#  'monitoring',
#  'prosecutor',
#  'relationship',
#  'nose',
#  'strip',
#  'evidence',
#  'accessory',
#  'lipizzaner',
#  'ground',
#  'interest',
#  'anthropogenic',
#  'saddle',
#  'power-train',
#  'spur',
#  'scale',
#  'power',
#  'tco2e',
#  'ethically',
#  'capital',
#  'transnational',
#  '4-beat',
#  'braking',
#  'greenhouse',
#  'herd',
#  'mains',
#  'transparency',
#  'half-pass',
#  'draft-cross',
#  'electricity',
#  'aspect',
#  'stride',
#  'rotate',
#  'appropriation',
#  'long',
#  'sustainable',
#  'illegal',
#  't',
#  'instrument',
#  'forearm',
#  'fraud',
#  'run',
#  'dress',
#  'trot–walk',
#  'gymkhana',
#  'collusive',
#  'float',
#  'private-to-private',
#  'jog',
#  'collusion',
#  'tube',
#  'slip-ring',
#  'confiscation',
#  'per',
#  'definition',
#  'romal',
#  'subsidy',
#  'vaulting',
#  'rpm',
#  'community',
#  'low-solidity',
#  'broncs',
#  'money-laundering',
#  'pelham',
#  'mwh',
#  'thoracic',
#  'passage',
#  'element',
#  'counter-rotation',
#  'isolate',
#  'wind-direction',
#  'force',
#  'corkscrew',
#  'abdomen',
#  'composite',
#  'predicate',
#  'canter',
#  'rejoneo',
#  'rotation',
#  'government',
#  'momentum',
#  'financing',
#  'pco2',
#  'weldment',
#  'technological',
#  'chord',
#  'convention',
#  'transaction',
#  'extreme',
#  'inviolability',
#  'climate',
#  'offender',
#  'rear',
#  'ghg',
#  'combate',
#  'net',
#  'constant',
#  'into',
#  'push',
#  'piaff',
#  'tenderer',
#  'anemometer',
#  'additional',
#  'school',
#  'supply',
#  'slush',
#  'coefficient',
#  'loss',
#  'frame',
#  'intergovernmental',
#  'elevate',
#  'give',
#  'price',
#  'company',
#  'halter',
#  'imprisonment',
#  'black-list',
#  'roping',
#  'moment',
#  'move',
#  'in-house',
#  'shank',
#  'passive',
#  'criminalisation',
#  'public-service',
#  'install',
#  'core',
#  'chase',
#  'tlp',
#  'primary',
#  'distribution',
#  'tax',
#  'camber',
#  'breeding',
#  'equity',
#  'forward-sideways-driving',
#  'behaviour',
#  'orientation',
#  'sternum',
#  'erus',
#  'voting',
#  'training',
#  'legitimately',
#  'tariff',
#  'rodeo',
#  'increment',
#  'foreign',
#  'cream',
#  'diversion',
#  'radii',
#  'dam',
#  'auditing',
#  'natural',
#  'cycle',
#  'concentrator',
#  'meter',
#  'bona',
#  'equine',
#  'budget',
#  'distance',
#  'illicitly',
#  'straw',
#  'industry',
#  'feed-in',
#  'swedish',
#  'buzkashi',
#  'bribee',
#  'subcontract',
#  'party',
#  'crookedness',
#  'start',
#  'across',
#  'penalize',
#  'start-stop',
#  'half-pirouette',
#  'evaluation',
#  'cross-country',
#  'wind-up',
#  'decision',
#  'kineton',
#  'soft',
#  'thyristor',
#  'vorticitiy',
#  'extortion',
#  'draft',
#  'directive',
#  'pyramid',
#  'kimberwick',
#  'affair',
#  'topline',
#  'international',
#  'servo',
#  'silence',
#  'proceed',
#  'gradient',
#  'western',
#  'counter-weight',
#  'in',
#  'high',
#  'reclaim',
#  'advantage',
#  'illegitimate',
#  'hydraulic-pressure',
#  'hind',
#  'wake',
#  'pesade',
#  'whistleblowing',
#  'mismanagement',
#  'association',
#  'silent',
#  'conspiracy',
#  'elemental',
#  'range',
#  'unremunerated',
#  'rule',
#  'pirouettes',
#  'lariat',
#  'consultant',
#  'path',
#  'kinematic',
#  'courbette',
#  'direct',
#  'data-protection',
#  'vawt',
#  'legislation',
#  'four-loop',
#  'prohibition',
#  'ethic',
#  'privatisation',
#  'recognition',
#  'transpose',
#  'centrifugal',
#  'context',
#  'co2',
#  'bareback',
#  'office',
#  'farm',
#  'root',
#  'rein',
#  'statutory',
#  'induce',
#  'rider',
#  'circle',
#  'sulky',
#  'stallion',
#  'intermediare',
#  'indirect',
#  'illicit',
#  'equid',
#  'untwisting',
#  'straightaway',
#  'lightning',
#  'aid',
#  'gaited',
#  'justice',
#  'short',
#  'soring',
#  'empirical',
#  'lobbying',
#  'freezing',
#  'gymnastically',
#  'foundation',
#  'four-point',
#  'cost',
#  '10-meter',
#  'stock',
#  'shoe',
#  'morgan',
#  'bribing',
#  'rise',
#  'commission',
#  'road',
#  'integrity',
#  'compromise',
#  'coning',
#  'cavaletti',
#  'influence',
#  'value',
#  'learning',
#  'obstruct',
#  'drive',
#  'trailer',
#  'hydrodynamics',
#  'heeler',
#  'monopile',
#  'output',
#  'secondary',
#  'accounting',
#  'isa',
#  'ecological',
#  'halt',
#  'campdrafting',
#  'budgeting',
#  'off',
#  'vaulter',
#  'upward',
#  'control',
#  'account',
#  'director',
#  'flat-shod',
#  'azimuth',
#  'effect',
#  'posting',
#  'head',
#  'horseback',
#  'cp',
#  'registration',
#  'blade-tip',
#  'hack',
#  'equipotential',
#  'integer',
#  'safety',
#  'rayleigh',
#  'bedplate',
#  'politician',
#  'remuneration',
#  'canter–trot–canter',
#  'embezzle',
#  'polocrosse',
#  'crooked',
#  'steel',
#  'unconed',
#  'radius',
#  'arm',
#  'level',
#  'a',
#  'open',
#  'bitting',
#  'abdominal',
#  'gale',
#  'anti-fraud',
#  'intermediaire',
#  'gymnasticize',
#  'team',
#  'recreational',
#  'anti-corruption',
#  'performance',
#  'buckle',
#  'square',
#  'equestrianism',
#  'sector',
#  'irregularity',
#  'hindleg',
#  'management',
#  'common',
#  'gogue',
#  'furling',
#  'record',
#  'fast',
#  'inner',
#  'fair',
#  'horizontal-axis',
#  'cvm',
#  'assistance',
#  'report',
#  'akhal-teke',
#  'judge',
#  'world',
#  'committee',
#  'whistle',
#  'stop',
#  'remain',
#  'criminal',
#  'private',
#  'forward',
#  'step',
#  'employer',
#  'rheinlander',
#  'trot–canter',
#  'for',
#  'corrcuption',
#  'at',
#  'corporate',
#  'letter',
#  'jousting',
#  'circulation',
#  'modus',
#  'andalusian',
#  'police',
#  'vulnerability',
#  'lawyer',
#  'partialspan',
#  'civil',
#  'irrotational',
#  'resource',
#  'synchronous',
#  'drag',
#  'praise',
#  'line',
#  'market',
#  'basic',
#  'factor',
#  'plant',
#  'fatigue',
#  'curb',
#  'outflow',
#  'profile',
#  'stand',
#  'principal',
#  'abuse',
#  'hindlimb',
#  'legislator',
#  'bid',
#  'barrette',
#  'crime',
#  'collection',
#  'capacity',
#  'seat',
#  'lateral',
#  'contact',
#  'fix',
#  'forward-sideways',
#  'grp',
#  'sentence',
#  'enrichment',
#  'upwards',
#  'fuel',
#  'transformer',
#  'method',
#  'hoof',
#  'muscular',
#  'lawfully',
#  'formal',
#  'credit',
#  'victim',
#  'brake',
#  'procedure',
#  'gratuity',
#  'horseball',
#  'show',
#  'advisory',
#  'purchase',
#  'upwind',
#  'twisted',
#  'fluid',
#  'two-beat',
#  'aerofoil',
#  'exploitation',
#  'loin',
#  'collarbone',
#  'stirrup',
#  'cohesion',
#  'earth',
#  'expense',
#  'mezair',
#  'conviction',
#  'self-cleaning',
#  'home',
#  'in-hand',
#  'billet',
#  'kür',
#  'tenth',
#  'longeing',
#  'paraequestrian',
#  'finance',
#  'balance',
#  'public',
#  'ktoe',
#  'extradition',
#  'h',
#  'repression',
#  'pact',
#  'one',
#  'match-fixing',
#  'hannoverian',
#  'cannon',
#  'exclusion',
#  'upstream',
#  'ias',
#  'instrumentality',
#  'converter',
#  'change',
#  'intermediary',
#  'economic',
#  'lipizzan',
#  'structural',
#  'velocity',
#  'risk',
#  'objectively',
#  'accountability',
#  'annulus',
#  'proprioceptor',
#  'carbon-intensive',
#  'trocha',
#  'proposal',
#  "d'",
#  'multi-bladed',
#  'fino',
#  'mandate',
#  'bradoon',
#  'leg',
#  'amateur',
#  'annual',
#  'income',
#  'epoxy',
#  'mass',
#  'collect',
#  'condition',
#  'yearling',
#  'abetting',
#  'disinterest',
#  'lip',
#  'retention',
#  '¾-pirouette',
#  'constitutional',
#  'geometry',
#  'repealing',
#  'vane',
#  'horseman',
#  'gwh',
#  'three-loop',
#  'least-square',
#  'technical',
#  'electronics',
#  'breach',
#  'bound',
#  'potential',
#  'professional',
#  'whistleblower',
#  'misappropriation',
#  'cross',
#  'windturbine',
#  'electrical',
#  'paint',
#  'embezzlement',
#  'walk',
#  'nonlinear',
#  'yield',
#  'supervision',
#  'paddock',
#  'submission',
#  'conduct',
#  'slipstream',
#  'set',
#  'isometric',
#  'half-passing',
#  'equivalent',
#  'external',
#  'hind-end',
#  'windfarm',
#  'magistrate',
#  'anlehnung',
#  'rotational',
#  'heel',
#  'tender',
#  'chap',
#  'stomach',
#  'restitution',
#  'hindquarters',
#  'amble',
#  'swing',
#  'watt',
#  'up',
#  'organisation',
#  'tucking',
#  'non-criminal',
#  'trainability',
#  'sound-proof',
#  'foreleg',
#  'cavalry',
#  'model',
#  'procurement',
#  'hawt',
#  'state',
#  'dressage',
#  'favouritism',
#  'pirouetting',
#  'teeter',
#  'review',
#  'hunt',
#  'capriole',
#  'laterally',
#  'half',
#  'disbursement',
#  'pace',
#  'grand',
#  'vortice',
#  'cool-down',
#  'understanding',
#  ...}

# %%
term = pd.read_csv('/Users/hanhtran/Documents/terminology-extraction/ACTER/en/equi/annotations/equi_en_terms.ann', delimiter = '\t', header = None)

# %%
term[term[0].str.split().str.len() == 5]
# term
# Out:
#                                    0              1
# 145  change rein across the diagonal  Specific_Term
# 419    grand prix freestyle to music  Specific_Term
# 443        half turn on the haunches  Specific_Term
# 799     quarter turn on the haunches  Specific_Term

# %%
term = pd.read_csv('/home/hanh/Desktop/terminology-extraction/ACTER/en/wind/annotations/wind_en_terms.ann', delimiter = '\t', header = None)
term[(term[0].str.len() <= 1)]
# Out:
#      0            1
# 969  v  Common_Term

# %%
final_df = pd.read_csv('ann_train_lem_1c.csv')
final_df.head(5)
# Out:
#    sentence_id       words labels
# 0            0      united      O
# 1            0      nation      O
# 2            0  convention      O
# 3            0     against      O
# 4            0  corruption      B

# %%
final_df[final_df['labels'] == 'I' & len(final_df[])]
# Out:
#         sentence_id       words labels
# 43                2     against      I
# 52                2      affair      I
# 193               7    assembly      I
# 223               9    assembly      I
# 241               9  instrument      I
# ...             ...         ...    ...
# 148438         5919     station      I
# 148553         5922     station      I
# 148625         5923     station      I
# 148677         5926     station      I
# 148735         5928      effect      I
#
# [4061 rows x 3 columns]

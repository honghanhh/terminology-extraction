# %%
import pandas as pd
import pickle as pkl
import re
from collections import Counter
import nltk
nltk.download('stopwords')
from nltk.corpus import stopwords 

import stanza
# stanza.download('en')
nlp = stanza.Pipeline(lang='en', processors='tokenize,mwt,pos,lemma')

def count_freq(preds, gts):
    preds_len = [len(x.split(' ')) for x in preds]
    gts_len = [len(x.split(' ')) for x in gts]
    print(Counter(preds_len))
    print(Counter(gts_len))

def evaluation_metrics(pred, gt):
    TP = len(set(pred) & set(gt)) 
    FP = len(set(pred)-set(gt))
    FN = len(set(gt)-set(pred))
    precision = round((TP/(TP+FP))*100, 2)
    recall = round((TP/(TP+FN))*100,2)
    f1_score = round((2 * precision * recall) / (precision + recall),2)
    return precision, recall, f1_score 

def lemma(li):
    new_list = []
    for t in li:
        doc = nlp(str(t))
        doc1 = ' '.join([word.lemma for sent in doc.sentences for word in sent.words])
        doc1 = re.sub('-',' ',doc1)
        doc1 = re.sub(' +', ' ',doc1)
        new_list.append(doc1)
    new_list = [s for s in new_list if len(s) >= 2]
    return new_list

def get_term_(predictions):
    all_term = []
    for sentence in predictions:
        tokens = []
        labels = []
        for d in sentence:
            tokens.extend(d.keys())
            labels.extend(d.values())

        for i, label in enumerate(labels):
            if labels[i] == 'I' and (i == 0 or labels[i - 1] == 'O'):
                labels[i] = 'O'

        terms = []
        term = []
        for token, label in zip(tokens, labels):
            if label == 'B':
                #Lưu vị trí B
                b_pos = i
                term = [token]
            elif label == 'I':
                term.append(token)
            elif len(term) > 0:
                terms.append(' '.join(term))
                term = []
        if len(term) > 0:
            terms.append(' '.join(term))
            # Check b_pos = 0 không
        all_term.append(terms)
    
    final_terms = []
    for i in all_term:
        final_terms.extend(i)

    final_terms = [x.lower().strip() for x in final_terms]
    return final_terms
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     /Users/hanhtran/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# 2021-06-09 16:14:55 WARNING: Can not find mwt: default from official model list. Ignoring it.
# 2021-06-09 16:14:55 INFO: Loading these models for language: en (English):
# ========================
# | Processor | Package  |
# ------------------------
# | tokenize  | combined |
# | pos       | combined |
# | lemma     | combined |
# ========================
#
# 2021-06-09 16:14:55 INFO: Use device: cpu
# 2021-06-09 16:14:55 INFO: Loading: tokenize
# 2021-06-09 16:14:55 INFO: Loading: pos
# 2021-06-09 16:14:56 INFO: Loading: lemma
# 2021-06-09 16:14:56 INFO: Done loading processors!

# %% [markdown]
# 1. ADJ NOUN - 1

# %%
def get_term_adj_noun(predictions):
    all_term = []
    for sentence in predictions:
        tokens = []
        labels = []
        for d in sentence:
            tokens.extend(d.keys())
            labels.extend(d.values())

        for i, label in enumerate(labels):
            if labels[i] == 'I' and (i == 0 or labels[i - 1] == 'O'):
                labels[i] = 'O'
        terms = []
        term = []
        for i, (token, label) in enumerate(zip(tokens, labels)):
            if label == 'B': 
                #Lưu vị trí B
                b_pos = i
                term = [token]
            elif label == 'I':
                term.append(token)
            elif len(term) > 0:
                terms.append(' '.join(term))
                if (b_pos != 0) and (tokens[b_pos - 1] != '') and (tokens[b_pos - 1] != ' ') and (len(nlp(str(tokens[b_pos - 1])).sentences) > 0) and (len(nlp(str(tokens[b_pos])).sentences) > 0):
                    b_word = nlp(str(tokens[b_pos - 1])).sentences[0].words[0]
                    c_word = nlp(str(tokens[b_pos])).sentences[0].words[0]
                    if (c_word.upos == 'NOUN') and (c_word.text != 'None') and (b_word.text != 'None') and (b_word.upos == 'ADJ'):
                        terms.append(' '.join([b_word.text] + term))
                term = []
        if len(term) > 0:
            terms.append(' '.join(term))
        all_term.append(terms)
    
    final_terms = []
    for i in all_term:
        final_terms.extend(i)

    final_terms = [x.lower().strip() for x in final_terms]
    return final_terms

# %% [markdown]
# 2. NOUN NOUN - 0

# %%
def get_term_noun_noun(predictions):
    all_term = []
    for sentence in predictions:
        tokens = []
        labels = []
        for d in sentence:
            tokens.extend(d.keys())
            labels.extend(d.values())

        for i, label in enumerate(labels):
            if labels[i] == 'I' and (i == 0 or labels[i - 1] == 'O'):
                labels[i] = 'O'

        terms = []
        term = []
        for i, (token, label) in enumerate(zip(tokens, labels)):
            if label == 'B': 
                #Lưu vị trí B
                b_pos = i
                term = [token]
            elif label == 'I':
                term.append(token)
            elif len(term) > 0:
                terms.append(' '.join(term))
                if b_pos != 0:
                    if (tokens[b_pos - 1] != '') and (tokens[b_pos - 1] != ' ') and (len(nlp(str(tokens[b_pos - 1])).sentences) > 0) and (len(nlp(str(tokens[b_pos])).sentences) > 0):
                        b_word = nlp(str(tokens[b_pos - 1])).sentences[0].words[0]
                        c_word = nlp(str(tokens[b_pos])).sentences[0].words[0]
                        if (c_word.upos == 'NOUN') and (c_word.text != 'None') and (b_word.text != 'None') and (b_word.upos == 'NOUN'):
                            terms.append(' '.join([b_word.text] + term))
                    if (tokens[i] != '') and (tokens[i] != ' ') and (len(nlp(str(tokens[i])).sentences) > 0):
                        a_word = nlp(str(tokens[i])).sentences[0].words[0]
                        if (a_word.text != 'None') and (a_word.upos == 'NOUN'):
                            terms.append(' '.join(term + [a_word.text]))
                term = []
        if len(term) > 0:
            terms.append(' '.join(term))
        all_term.append(terms)
    
    final_terms = []
    for i in all_term:
        final_terms.extend(i)

    final_terms = [x.lower().strip() for x in final_terms]
    return final_terms

# %% [markdown]
# 3. ADJ NOUN NOUN - 1

# %%
def get_term_adj_noun_noun(predictions):
    all_term = []
    for sentence in predictions:
        tokens = []
        labels = []
        for d in sentence:
            tokens.extend(d.keys())
            labels.extend(d.values())

        for i, label in enumerate(labels):
            if labels[i] == 'I' and (i == 0 or labels[i - 1] == 'O'):
                labels[i] = 'O'

        terms = []
        term = []
        for i, (token, label) in enumerate(zip(tokens, labels)):
            if label == 'B': 
                #Lưu vị trí B
                b_pos = i
                term = [token]
            elif label == 'I':
                term.append(token)
            elif len(term) > 0:
                terms.append(' '.join(term))
                # Check b_pos = 0 không
                if b_pos != 0:
                    #ADJ NOUN NOUN
                    if (tokens[i] != '') and (tokens[i] != ' ') and (tokens[b_pos - 1] != '') and (tokens[b_pos - 1] != ' ') and (len(nlp(str(tokens[b_pos - 1])).sentences) > 0) and (len(nlp(str(tokens[i])).sentences) > 0) and (len(nlp(str(tokens[b_pos])).sentences) > 0):
                        a_word = nlp(str(tokens[i])).sentences[0].words[0]
                        b_word = nlp(str(tokens[b_pos - 1])).sentences[0].words[0]
                        c_word = nlp(str(tokens[b_pos])).sentences[0].words[0]
                        # Check vị trí b_pos - 1: terms.append()
                        if (c_word.text != 'None') and (c_word.upos == 'NOUN') and (b_word.text != 'None') and ((b_word.upos == 'ADJ') and (a_word.upos == 'NOUN')):
                            terms.append(' '.join([b_word.text] + term + [a_word.text]))
                term = []
        if len(term) > 0:
            terms.append(' '.join(term))
            # check b_pos - 1
        all_term.append(terms)
    
    final_terms = []
    for i in all_term:
        final_terms.extend(i)

    final_terms = [x.lower().strip() for x in final_terms]
    return final_terms

# %% [markdown]
# 4. ADJ ADJ NOUN - 2

# %%
def get_term_adj_adj_noun(predictions):
    all_term = []
    for sentence in predictions:
        tokens = []
        labels = []
        for d in sentence:
            tokens.extend(d.keys())
            labels.extend(d.values())

        for i, label in enumerate(labels):
            if labels[i] == 'I' and (i == 0 or labels[i - 1] == 'O'):
                labels[i] = 'O'

        terms = []
        term = []
        for i, (token, label) in enumerate(zip(tokens, labels)):
            if label == 'B': 
                b_pos = i
                term = [token]
            elif label == 'I':
                term.append(token)
            elif len(term) > 0:
                terms.append(' '.join(term))
                if b_pos != 0:
                    #ADJ ADJ NOUN              
                    if (tokens[b_pos - 2] != '') and (tokens[b_pos - 2] != ' ') and (tokens[b_pos - 1] != '') and (tokens[b_pos - 1] != ' ') and (len(nlp(str(tokens[b_pos - 2])).sentences) > 0 and len(nlp(str(tokens[b_pos - 1])).sentences) > 0 and len(nlp(str(tokens[b_pos])).sentences) > 0):
                        b1_word = nlp(str(tokens[b_pos - 2])).sentences[0].words[0] 
                        b_word = nlp(str(tokens[b_pos - 1])).sentences[0].words[0]
                        c_word = nlp(str(tokens[b_pos])).sentences[0].words[0]
                        if (c_word.upos == 'NOUN') and (c_word.text != 'None') and (b_word.text != 'None') and (b1_word.text != 'None') and ((b_word.upos == 'ADJ') and (b1_word.upos == 'ADJ')):
                            terms.append(' '.join([b1_word.text] +[b_word.text] + term))
                term = []
        if len(term) > 0:
            terms.append(' '.join(term))
        all_term.append(terms)
    
    final_terms = []
    for i in all_term:
        final_terms.extend(i)

    final_terms = [x.lower().strip() for x in final_terms]
    return final_terms

# %% [markdown]
# 5. NOUN ADJ NOUN - 2

# %%
def get_term_noun_adj_noun(predictions):
    all_term = []
    for sentence in predictions:
        tokens = []
        labels = []
        for d in sentence:
            tokens.extend(d.keys())
            labels.extend(d.values())

        for i, label in enumerate(labels):
            if labels[i] == 'I' and (i == 0 or labels[i - 1] == 'O'):
                labels[i] = 'O'

        terms = []
        term = []
        for i, (token, label) in enumerate(zip(tokens, labels)):
            if label == 'B': 
                b_pos = i
                term = [token]
            elif label == 'I':
                term.append(token)
            elif len(term) > 0:
                terms.append(' '.join(term))
                if b_pos != 0:
                    #NOUN ADJ NOUN
                    if (tokens[b_pos - 2] != '') and (tokens[b_pos - 2] != ' ') and (tokens[b_pos - 1] != '') and (tokens[b_pos - 1] != ' ') and (len(nlp(str(tokens[b_pos - 2])).sentences) > 0 and len(nlp(str(tokens[b_pos - 1])).sentences) > 0 and len(nlp(str(tokens[b_pos])).sentences) > 0):
                        b1_word = nlp(str(tokens[b_pos - 2])).sentences[0].words[0] 
                        b_word = nlp(str(tokens[b_pos - 1])).sentences[0].words[0]
                        c_word = nlp(str(tokens[b_pos])).sentences[0].words[0]
                        if (c_word.upos == 'NOUN') and (c_word.text != 'None') and (b_word.text != 'None') and (b1_word.text != 'None') and ((b_word.upos == 'ADJ') and (b1_word.upos == 'NOUN')):
                            terms.append(' '.join([b1_word.text] +[b_word.text] + term))
                term = []
        if len(term) > 0:
            terms.append(' '.join(term))
        all_term.append(terms)
    
    final_terms = []
    for i in all_term:
        final_terms.extend(i)

    final_terms = [x.lower().strip() for x in final_terms]
    return final_terms

# %% [markdown]
# 6. NOUN NOUN NOUN - 0

# %%
def get_term_noun_noun_noun(predictions):
    all_term = []
    for sentence in predictions:
        tokens = []
        labels = []
        for d in sentence:
            tokens.extend(d.keys())
            labels.extend(d.values())

        for i, label in enumerate(labels):
            if labels[i] == 'I' and (i == 0 or labels[i - 1] == 'O'):
                labels[i] = 'O'

        terms = []
        term = []
        for i, (token, label) in enumerate(zip(tokens, labels)):
            if label == 'B': 
                b_pos = i
                term = [token]
            elif label == 'I':
                term.append(token)
            elif len(term) > 0:
                terms.append(' '.join(term))
                # NOUN NOUN NOUN
                if b_pos != 0 and i + 1 < len(tokens):
                    if (tokens[i] != '') and (tokens[i] != ' ') and (tokens[i+1] != '') and (tokens[i+1] != ' ') and (len(nlp(str(tokens[i])).sentences) > 0 and len(nlp(str(tokens[i+1])).sentences) > 0 and len(nlp(str(tokens[b_pos])).sentences) > 0):
                        a1_word = nlp(str(tokens[i+1])).sentences[0].words[0] 
                        a_word = nlp(str(tokens[i])).sentences[0].words[0]
                        c_word = nlp(str(tokens[b_pos])).sentences[0].words[0]
                        if (c_word.text != 'None') and (c_word.upos == 'NOUN') and (a_word.text != 'None') and (a1_word.text != 'None') and ((a_word.upos == 'NOUN') and (a1_word.upos == 'NOUN')):
                            terms.append(' '.join( term + [a_word.text] +[a1_word.text]))
                term = []
        if len(term) > 0:
            terms.append(' '.join(term))
        all_term.append(terms)
    
    final_terms = []
    for i in all_term:
        final_terms.extend(i)

    final_terms = [x.lower().strip() for x in final_terms]
    return final_terms

# %% [markdown]
# 7. NOUN ADP NOUN - 0

# %%
def get_term_noun_adp_noun(predictions):
    all_term = []
    for sentence in predictions:
        tokens = []
        labels = []
        for d in sentence:
            tokens.extend(d.keys())
            labels.extend(d.values())

        for i, label in enumerate(labels):
            if labels[i] == 'I' and (i == 0 or labels[i - 1] == 'O'):
                labels[i] = 'O'

        terms = []
        term = []
        for i, (token, label) in enumerate(zip(tokens, labels)):
            if label == 'B': 
                b_pos = i
                term = [token]
            elif label == 'I':
                term.append(token)
            elif len(term) > 0:
                terms.append(' '.join(term))
                if b_pos != 0 and i+1 < len(tokens):
                    if (tokens[i] != '') and (tokens[i] != ' ') and (tokens[i+1] != '') and (tokens[i+1] != ' ') and (len(nlp(str(tokens[i])).sentences) > 0 and len(nlp(str(tokens[i+1])).sentences) > 0 and len(nlp(str(tokens[b_pos])).sentences) > 0):
                        a1_word = nlp(str(tokens[i+1])).sentences[0].words[0] 
                        a_word = nlp(str(tokens[i])).sentences[0].words[0]
                        c_word = nlp(str(tokens[b_pos])).sentences[0].words[0]
                        if (c_word.upos == 'NOUN')and (c_word.text != 'None') and (a_word.text != 'None') and (a1_word.text != 'None') and ((a_word.upos == 'ADP') and (a1_word.upos == 'NOUN')):
                            terms.append(' '.join(term + [a_word.text] + [a1_word.text]))                               
                term = []
        if len(term) > 0:
            terms.append(' '.join(term))
        
        all_term.append(terms)
    
    final_terms = []
    for i in all_term:
        final_terms.extend(i)

    final_terms = [x.lower() for x in final_terms]
    return final_terms

# %% [markdown]
# 8. NOUN ADP ADJ NOUN - 0

# %%
def get_term_noun_adp_adj_noun(predictions):
    all_term = []
    for sentence in predictions:
        tokens = []
        labels = []
        for d in sentence:
            tokens.extend(d.keys())
            labels.extend(d.values())
        for i, label in enumerate(labels):
            if labels[i] == 'I' and (i == 0 or labels[i - 1] == 'O'):
                labels[i] = 'O'
        terms = []
        term = []
        for i, (token, label) in enumerate(zip(tokens, labels)):
            if label == 'B': 
                #Lưu vị trí B
                b_pos = i
                term = [token]
            elif label == 'I':
                term.append(token)
            elif len(term) > 0:
                terms.append(' '.join(term))
                if b_pos != 0 and i + 2 < len(tokens):
                    if (tokens[i] != '') and (tokens[i] != ' ') and (tokens[i+1] != '') and (tokens[i+1] != ' ') and (tokens[i+2] != '') and (tokens[i+2] != ' ') and (tokens[b_pos] != '') and (tokens[b_pos] != ' ') and (len(nlp(str(tokens[i])).sentences) > 0 and len(nlp(str(tokens[i+1])).sentences) > 0 and len(nlp(str(tokens[i+2])).sentences) > 0 and len(nlp(str(tokens[b_pos])).sentences) > 0):
                        a2_word = nlp(str(tokens[i+2])).sentences[0].words[0] 
                        a1_word = nlp(str(tokens[i+1])).sentences[0].words[0] 
                        a_word = nlp(str(tokens[i])).sentences[0].words[0]
                        c_word = nlp(str(tokens[b_pos])).sentences[0].words[0]
                        if (c_word.upos == 'NOUN') and (c_word.text != 'None') and (a_word.text != 'None') and (a1_word.text != 'None') and (a2_word.text != 'None') and (a_word.upos == 'ADP') and (a1_word.upos == 'ADJ') and (a2_word.upos == 'NOUN'):
                            terms.append(' '.join(term + [a_word.text] + [a1_word.text] +[a2_word.text]))   
                term = []
        if len(term) > 0:
            terms.append(' '.join(term))
        all_term.append(terms)
    
    final_terms = []
    for i in all_term:
        final_terms.extend(i)

    final_terms = [x.lower() for x in final_terms]
    return final_terms

# %% [markdown]
# 9. ADJ NOUN ADP NOUN - 0

# %%
def get_term_adj_noun_adp_noun(predictions):
    all_term = []
    for sentence in predictions:
        tokens = []
        labels = []
        for d in sentence:
            tokens.extend(d.keys())
            labels.extend(d.values())

        for i, label in enumerate(labels):
            if labels[i] == 'I' and (i == 0 or labels[i - 1] == 'O'):
                labels[i] = 'O'

        terms = []
        term = []
        for i, (token, label) in enumerate(zip(tokens, labels)):
            if label == 'B': 
                b_pos = i
                term = [token]
            elif label == 'I':
                term.append(token)
            elif len(term) > 0:
                terms.append(' '.join(term))
                if b_pos != 0 and i + 1 < len(tokens):
                    if (tokens[i+1] != '') and (tokens[i+1] != ' ') and (tokens[i] != '') and (tokens[i] != ' ') and (tokens[b_pos - 1] != '') and (tokens[b_pos - 1] != ' ') and len(nlp(str(tokens[b_pos - 1])).sentences) > 0 and (len(nlp(str(tokens[i])).sentences) > 0) and (len(nlp(str(tokens[i+1])).sentences) > 0) and (len(nlp(str(tokens[b_pos])).sentences) > 0):
                        a1_word = nlp(str(tokens[i+1])).sentences[0].words[0]
                        a_word = nlp(str(tokens[i])).sentences[0].words[0]
                        b_word = nlp(str(tokens[b_pos - 1])).sentences[0].words[0]
                        c_word = nlp(str(tokens[b_pos])).sentences[0].words[0]
                        if (c_word.text != 'None') and (c_word.upos == 'NOUN') and (b_word.text != 'None') and (a_word.text != 'None') and (a1_word.text != 'None') and (b_word.upos == 'ADJ') and (a_word.upos == 'ADP') and (a1_word.upos == 'NOUN'):
                            terms.append(' '.join([b_word.text] + term + [a_word.text] + [a1_word.text]))        
                term = []
        if len(term) > 0:
            terms.append(' '.join(term))
        all_term.append(terms)
    
    final_terms = []
    for i in all_term:
        final_terms.extend(i)

    final_terms = [x.lower() for x in final_terms]
    return final_terms

# %% [markdown]
# 10. NOUN ADP NOUN NOUN - 0

# %%
def get_term_noun_adp_noun_noun(predictions):
    all_term = []
    for sentence in predictions:
        tokens = []
        labels = []
        for d in sentence:
            tokens.extend(d.keys())
            labels.extend(d.values())

        for i, label in enumerate(labels):
            if labels[i] == 'I' and (i == 0 or labels[i - 1] == 'O'):
                labels[i] = 'O'

        terms = []
        term = []
        for i, (token, label) in enumerate(zip(tokens, labels)):
            if label == 'B': 
                b_pos = i
                term = [token]
            elif label == 'I':
                term.append(token)
            elif len(term) > 0:
                terms.append(' '.join(term))
                if b_pos != 0 and i + 2 < len(tokens):
                    if (tokens[i+2] != '') and (tokens[i+2] != ' ') and (tokens[i+1] != '') and (tokens[i+1] != ' ') and (tokens[i] != '') and (tokens[i] != ' ') and (len(nlp(str(tokens[i])).sentences) > 0) and (len(nlp(str(tokens[i+1])).sentences) > 0) and (len(nlp(str(tokens[i+2])).sentences) > 0) and (len(nlp(str(tokens[b_pos])).sentences) > 0):
                            a2_word = nlp(str(tokens[i+2])).sentences[0].words[0]
                            a1_word = nlp(str(tokens[i+1])).sentences[0].words[0]
                            a_word = nlp(str(tokens[i])).sentences[0].words[0]
                            c_word = nlp(str(tokens[b_pos])).sentences[0].words[0]
                            if (c_word.text != 'None') and (c_word.upos == 'NOUN') and (a_word.text != 'None')and (a1_word.text != 'None') and (a2_word.text != 'None') and (a_word.upos == 'ADP') and (a1_word.upos == 'NOUN') and (a2_word.upos == 'NOUN'):
                                terms.append(' '.join(term + [a_word.text] + [a1_word.text] + [a2_word.text]))
                term = []
        if len(term) > 0:
            terms.append(' '.join(term))
            # check b_pos - 1
        all_term.append(terms)
    
    final_terms = []
    for i in all_term:
        final_terms.extend(i)

    final_terms = [x.lower() for x in final_terms]
    return final_terms

# %% [markdown]
# 11. ADJ NOUN ADP ADJ NOUN - 1

# %%
def get_term_adj_noun_adp_adj_noun(predictions):
    all_term = []
    for sentence in predictions:
        tokens = []
        labels = []
        for d in sentence:
            tokens.extend(d.keys())
            labels.extend(d.values())

        for i, label in enumerate(labels):
            if labels[i] == 'I' and (i == 0 or labels[i - 1] == 'O'):
                labels[i] = 'O'

        terms = []
        term = []
        for i, (token, label) in enumerate(zip(tokens, labels)):
            if label == 'B': 
                #Lưu vị trí B
                b_pos = i
                term = [token]
            elif label == 'I':
                term.append(token)
            elif len(term) > 0:
                terms.append(' '.join(term))
                if (b_pos != 0) and (i + 2 < len(tokens)) and (tokens[i+2] != '') and (tokens[i+2] != ' ') and (tokens[i+1] != '') and (tokens[i+1] != ' ') and (tokens[i] != '') and (tokens[i] != ' ')and (tokens[b_pos] != '') and (tokens[b_pos] != ' ') and (tokens[b_pos - 1] != '') and (tokens[b_pos - 1] != ' ') and (len(nlp(str(tokens[b_pos - 1])).sentences) > 0) and (len(nlp(str(tokens[i])).sentences) > 0) and (len(nlp(str(tokens[i+1])).sentences) > 0) and (len(nlp(str(tokens[i+2])).sentences) > 0) and (len(nlp(str(tokens[b_pos])).sentences) > 0):
                    a2_word = nlp(str(tokens[i+2])).sentences[0].words[0]
                    a1_word = nlp(str(tokens[i+1])).sentences[0].words[0]
                    a_word = nlp(str(tokens[i])).sentences[0].words[0]
                    b_word = nlp(str(tokens[b_pos - 1])).sentences[0].words[0]
                    c_word = nlp(str(tokens[b_pos])).sentences[0].words[0]
                    if (c_word.text != 'None') and (c_word.upos == 'NOUN') and (b_word.text != 'None') and (a_word.text != 'None') and (a1_word.text != 'None') and (a2_word.text != 'None') and (b_word.upos == 'ADJ') and (a_word.upos == 'ADP') and (a1_word.upos == 'ADJ')and (a2_word.upos == 'NOUN'):
                        terms.append(' '.join([b_word.text] + term + [a_word.text] + [a1_word.text]  + [a2_word.text]))
                term = []
        if len(term) > 0:
            terms.append(' '.join(term))
        all_term.append(terms)
    
    final_terms = []
    for i in all_term:
        final_terms.extend(i)

    final_terms = [x.lower() for x in final_terms]
    return final_terms

# %% [markdown]
# 12. NOUN PRON - 0

# %%
def get_term_noun_pron(predictions):
    all_term = []
    for sentence in predictions:
        tokens = []
        labels = []
        for d in sentence:
            tokens.extend(d.keys())
            labels.extend(d.values())

        for i, label in enumerate(labels):
            if labels[i] == 'I' and (i == 0 or labels[i - 1] == 'O'):
                labels[i] = 'O'

        terms = []
        term = []
        for i, (token, label) in enumerate(zip(tokens, labels)):
            if label == 'B': 
                #Lưu vị trí B
                b_pos = i
                term = [token]
            elif label == 'I':
                term.append(token)
            elif len(term) > 0:
                terms.append(' '.join(term))
                if (b_pos != 0) and (tokens[i] != '') and (tokens[i] != ' ') and (tokens[b_pos] != '') and (tokens[b_pos] != ' ') and (len(nlp(str(tokens[i])).sentences) > 0) and (len(nlp(str(tokens[b_pos])).sentences) > 0):
                        a_word = nlp(str(tokens[i])).sentences[0].words[0]
                        c_word = nlp(str(tokens[b_pos])).sentences[0].words[0]
                        # Check vị trí b_pos - 1: terms.append()
                        if (c_word.text != 'None') and (c_word.upos == 'NOUN')  and (a_word.text != 'None') and (a_word.upos == 'PROPN'):
                            terms.append(' '.join(term + [a_word.text]))
                term = []
        if len(term) > 0:
            terms.append(' '.join(term))
            # check b_pos - 1
        all_term.append(terms)
    
    final_terms = []
    for i in all_term:
        final_terms.extend(i)

    final_terms = [x.lower() for x in final_terms]
    return final_terms

# %% [markdown]
# 13. ADV ADJ NOUN - 2

# %%
def get_term_adv_adj_noun(predictions):
    all_term = []
    for sentence in predictions:
        tokens = []
        labels = []
        for d in sentence:
            tokens.extend(d.keys())
            labels.extend(d.values())

        for i, label in enumerate(labels):
            if labels[i] == 'I' and (i == 0 or labels[i - 1] == 'O'):
                labels[i] = 'O'
        terms = []
        term = []
        for i, (token, label) in enumerate(zip(tokens, labels)):
            if label == 'B': 
                #Lưu vị trí B
                b_pos = i
                term = [token]
            elif label == 'I':
                term.append(token)
            elif len(term) > 0:
                terms.append(' '.join(term))
                if (b_pos != 0) and (tokens[b_pos - 2] != '') and (tokens[b_pos - 2] != ' ') and (tokens[b_pos - 1] != '') and (tokens[b_pos - 1] != ' ') and (len(nlp(str(tokens[b_pos - 2])).sentences) > 0 and len(nlp(str(tokens[b_pos - 1])).sentences) > 0 and len(nlp(str(tokens[b_pos])).sentences) > 0):
                        b1_word = nlp(str(tokens[b_pos - 2])).sentences[0].words[0] 
                        b_word = nlp(str(tokens[b_pos - 1])).sentences[0].words[0]
                        c_word = nlp(str(tokens[b_pos])).sentences[0].words[0]
                        if (c_word.text != 'None') and (c_word.upos == 'NOUN') and (b_word.text != 'None') and (b1_word.text != 'None') and ((b_word.upos == 'ADJ') and (b1_word.upos == 'ADV')):
                            terms.append(' '.join([b1_word.text] +[b_word.text] + term))                   
                term = []
        if len(term) > 0:
            terms.append(' '.join(term))
        
        all_term.append(terms)
    
    final_terms = []
    for i in all_term:
        final_terms.extend(i)

    final_terms = [x.lower() for x in final_terms]
    return final_terms

# %% [markdown]
# 14. ADJ NOUN ADJ NOUN - 1

# %%
def get_term_adj_noun_adj_noun(predictions):
    all_term = []
    for sentence in predictions:
        tokens = []
        labels = []
        for d in sentence:
            tokens.extend(d.keys())
            labels.extend(d.values())

        for i, label in enumerate(labels):
            if labels[i] == 'I' and (i == 0 or labels[i - 1] == 'O'):
                labels[i] = 'O'

        terms = []
        term = []
        for i, (token, label) in enumerate(zip(tokens, labels)):
            if label == 'B': 
                b_pos = i
                term = [token]
            elif label == 'I':
                term.append(token)
            elif len(term) > 0:
                terms.append(' '.join(term))
                if (b_pos != 0) and (i + 1 < len(tokens)) and (tokens[b_pos - 1] != '') and (tokens[b_pos - 1] != ' ') and (tokens[b_pos] != '') and (tokens[b_pos] != ' ') and (tokens[i] != '') and (tokens[i] != ' ') and (tokens[i+1] != '') and (tokens[i+1] != ' ') and (len(nlp(str(tokens[b_pos - 1])).sentences) > 0) and (len(nlp(str(tokens[b_pos])).sentences) > 0) and (len(nlp(str(tokens[i])).sentences) > 0) and  (len(nlp(str(tokens[i+1])).sentences) > 0): 
                    a1_word = nlp(str(tokens[i+1])).sentences[0].words[0]
                    a_word = nlp(str(tokens[i])).sentences[0].words[0]
                    b_word = nlp(str(tokens[b_pos - 1])).sentences[0].words[0]
                    c_word = nlp(str(tokens[b_pos])).sentences[0].words[0]
                    # Check vị trí b_pos - 1: terms.append()
                    if (c_word.text != 'None') and (b_word.text != 'None') and (a_word.text != 'None') and (a1_word.text != 'None') and (c_word.upos == 'NOUN') and ((b_word.upos == 'ADJ') and (a_word.upos == 'ADJ') and (a1_word.upos == 'NOUN')):
                        terms.append(' '.join([b_word.text] + term + [a_word.text] + [a1_word.text]))
                                
                term = []
        if len(term) > 0:
            terms.append(' '.join(term))
            # check b_pos - 1
        
        all_term.append(terms)
    
    final_terms = []
    for i in all_term:
        final_terms.extend(i)

    final_terms = [x.lower() for x in final_terms]
    return final_terms

# %%
def term_evaluation(domain_path, preds_path, rule=None):
    groundtruth = pd.read_csv(domain_path, sep='	', engine='python',header=None)
    gt = list(groundtruth[0])
    predictions = pkl.load(open(preds_path, 'rb'))
    if rule == 'adj_noun':
        preds =  get_term_adj_noun(predictions)
    elif rule == 'noun_noun':
        preds =  get_term_noun_noun(predictions)
    elif rule == 'adj_adj_noun':
        preds = get_term_adj_adj_noun(predictions)
    elif rule == 'adj_noun_noun':
        preds = get_term_adj_noun_noun(predictions)
    elif rule == 'noun_adj_noun':
        preds = get_term_noun_adj_noun(predictions)
    elif rule == 'noun_noun_noun':
        preds = get_term_noun_noun_noun(predictions)
    elif rule == 'noun_adp_noun':
        preds = get_term_noun_adp_noun(predictions)
    elif rule == 'noun_adp_adj_noun':
        preds = get_term_noun_adp_adj_noun(predictions)
    elif rule == 'adj_noun_adp_noun':
        preds = get_term_adj_noun_adp_noun(predictions)
    elif rule == 'noun_adp_noun_noun':
        preds = get_term_noun_adp_noun_noun(predictions)
    elif rule == 'adj_noun_adp_adj_noun':
        preds = get_term_adj_noun_adp_adj_noun(predictions)
    elif rule == 'adv_adj_noun':
        preds = get_term_adv_adj_noun(predictions)
    elif rule == 'noun_pron':
        preds = get_term_noun_pron(predictions)
    elif rule == 'adj_noun_adj_noun':
        preds = get_term_adj_noun_adj_noun(predictions)
    else:
        preds =  get_term_(predictions)
    stop_words = set(stopwords.words('english'))
    pred_terms =  set(preds) - set(stop_words)
    pred_terms = [x for x in pred_terms if len(x)>1]
    pred_terms = [x.lower().strip() for x in pred_terms]
    pred_terms = [re.sub(' -','-', x) for x in pred_terms]
    pred_terms = [re.sub('- ','-', x) for x in pred_terms]
    pred_terms = [re.sub('\(','', x) for x in pred_terms]
    pred_terms = [re.sub('\/','', x) for x in pred_terms]
    precision, recall, f1 = evaluation_metrics(pred_terms, gt)
    return precision, recall, f1

# %%
path = '/Users/hanhtran/Documents/terminology-extraction/ACTER/'
domain_paths = [path+'en/htfl/annotations/htfl_en_terms.ann', path+'en/wind/annotations/wind_en_terms.ann',
                path+'en/equi/annotations/equi_en_terms.ann',path+'en/corp/annotations/corp_en_terms.ann',
                path+'en/htfl/annotations/htfl_en_terms_nes.ann', path+'en/wind/annotations/wind_en_terms_nes.ann',
                path+'en/equi/annotations/equi_en_terms_nes.ann',path+'en/corp/annotations/corp_en_terms_nes.ann',
               ]
preds_paths = ['ann_xlnet_htfl.pkl','ann_xlnet_wind.pkl','ann_xlnet_equi.pkl', 'ann_xlnet_corp.pkl',
              'nes_xlnet_htfl.pkl','nes_xlnet_wind.pkl','nes_xlnet_equi.pkl', 'nes_xlnet_corp.pkl']
results = []
for d, p in zip(domain_paths, preds_paths):
    pre, rec, f1 = term_evaluation(d,p)
    results.append([p,pre, rec, f1])
raw_res = pd.DataFrame(results,columns=['DOMAIN','NON_PATTERN_P','NON_PATTERN_R','NON_PATTERN_F1'])
raw_res
# Out:
#                DOMAIN  NON_PATTERN_P  NON_PATTERN_R  NON_PATTERN_F1
# 0  ann_xlnet_htfl.pkl          42.94          30.03           35.34
# 1  ann_xlnet_wind.pkl          37.76          52.61           43.96
# 2  ann_xlnet_equi.pkl          42.22          61.99           50.23
# 3  ann_xlnet_corp.pkl          42.54          59.33           49.55
# 4  nes_xlnet_htfl.pkl          43.63          36.83           39.94
# 5  nes_xlnet_wind.pkl          42.47          49.61           45.76
# 6  nes_xlnet_equi.pkl          46.77          55.17           50.62
# 7  nes_xlnet_corp.pkl          45.05          55.41           49.70

# %%
results = []
for d, p in zip(domain_paths, preds_paths):
    pre, rec, f1 = term_evaluation(d,p, 'adj_noun')
    results.append([p,pre, rec, f1])
adj_noun = pd.DataFrame(results,columns=['DOMAIN','ADJ_NOUN_P','ADJ_NOUN_R','ADJ_NOUN_F1'])
adj_noun
# Out:
#                DOMAIN  ADJ_NOUN_P  ADJ_NOUN_R  ADJ_NOUN_F1
# 0  ann_xlnet_htfl.pkl       40.83       34.22        37.23
# 1  ann_xlnet_wind.pkl       34.48       57.75        43.18
# 2  ann_xlnet_equi.pkl       34.81       64.59        45.24
# 3  ann_xlnet_corp.pkl       38.52       64.62        48.27
# 4  nes_xlnet_htfl.pkl       41.47       40.54        41.00
# 5  nes_xlnet_wind.pkl       39.42       52.22        44.93
# 6  nes_xlnet_equi.pkl       39.33       56.89        46.51
# 7  nes_xlnet_corp.pkl       41.79       59.42        49.07

# %%
results = []
for d, p in zip(domain_paths, preds_paths):
    pre, rec, f1  = term_evaluation(d,p, 'noun_noun')
    results.append([p,pre, rec, f1])
noun_noun = pd.DataFrame(results,columns=['DOMAIN','NOUN_NOUN_P','NOUN_NOUN_R','NOUN_NOUN_F1'])
noun_noun
# Out:
#                DOMAIN  NOUN_NOUN_P  NOUN_NOUN_R  NOUN_NOUN_F1
# 0  ann_xlnet_htfl.pkl        32.89        36.47         34.59
# 1  ann_xlnet_wind.pkl        25.93        60.86         36.37
# 2  ann_xlnet_equi.pkl        33.53        67.45         44.79
# 3  ann_xlnet_corp.pkl        32.93        64.40         43.58
# 4  nes_xlnet_htfl.pkl        35.28        41.43         38.11
# 5  nes_xlnet_wind.pkl        31.19        55.02         39.81
# 6  nes_xlnet_equi.pkl        38.06        59.68         46.48
# 7  nes_xlnet_corp.pkl        35.85        59.59         44.77

# %%
results = []
for d, p in zip(domain_paths, preds_paths):
    pre, rec, f1 = term_evaluation(d,p, 'adj_noun_noun')
    results.append([p,pre, rec, f1])
adj_noun_noun = pd.DataFrame(results,columns=['DOMAIN','ADJ_NOUN_NOUN_P','ADJ_NOUN_NOUN_R','ADJ_NOUN_NOUN_F1'])
adj_noun_noun
# Out:
#                DOMAIN  ADJ_NOUN_NOUN_P  ADJ_NOUN_NOUN_R  ADJ_NOUN_NOUN_F1
# 0  ann_xlnet_htfl.pkl            41.79            30.41             35.20
# 1  ann_xlnet_wind.pkl            36.67            52.70             43.25
# 2  ann_xlnet_equi.pkl            41.49            62.08             49.74
# 3  ann_xlnet_corp.pkl            42.01            59.55             49.27
# 4  nes_xlnet_htfl.pkl            42.79            37.10             39.74
# 5  nes_xlnet_wind.pkl            41.79            49.74             45.42
# 6  nes_xlnet_equi.pkl            46.18            55.24             50.31
# 7  nes_xlnet_corp.pkl            44.65            55.50             49.49

# %%
results = []
for d, p in zip(domain_paths, preds_paths):
    pre, rec, f1 = term_evaluation(d,p, 'adj_adj_noun')
    results.append([p,pre, rec, f1])
adj_adj_noun = pd.DataFrame(results,columns=['DOMAIN','ADJ_ADJ_NOUN_P','ADJ_ADJ_NOUN_R','ADJ_ADJ_NOUN_F1'])
adj_adj_noun
# Out:
#                DOMAIN  ADJ_ADJ_NOUN_P  ADJ_ADJ_NOUN_R  ADJ_ADJ_NOUN_F1
# 0  ann_xlnet_htfl.pkl           42.77           30.83            35.83
# 1  ann_xlnet_wind.pkl           37.21           52.80            43.65
# 2  ann_xlnet_equi.pkl           41.37           62.08            49.65
# 3  ann_xlnet_corp.pkl           41.52           59.44            48.89
# 4  nes_xlnet_htfl.pkl           43.45           37.45            40.23
# 5  nes_xlnet_wind.pkl           42.10           49.67            45.57
# 6  nes_xlnet_equi.pkl           45.98           55.24            50.19
# 7  nes_xlnet_corp.pkl           44.47           55.50            49.38

# %%
results = []
for d, p in zip(domain_paths, preds_paths):
    pre, rec, f1 = term_evaluation(d,p, 'noun_adj_noun')
    results.append([p,pre, rec, f1])
noun_adj_noun = pd.DataFrame(results,columns=['DOMAIN','NOUN_ADJ_NOUN_P','NOUN_ADJ_NOUN_R','NOUN_ADJ_NOUN_F1'])
noun_adj_noun
# Out:
#                DOMAIN  NOUN_ADJ_NOUN_P  NOUN_ADJ_NOUN_R  NOUN_ADJ_NOUN_F1
# 0  ann_xlnet_htfl.pkl            42.67            30.20             35.37
# 1  ann_xlnet_wind.pkl            37.19            52.80             43.64
# 2  ann_xlnet_equi.pkl            41.77            61.99             49.91
# 3  ann_xlnet_corp.pkl            41.98            59.33             49.17
# 4  nes_xlnet_htfl.pkl            43.33            36.94             39.88
# 5  nes_xlnet_wind.pkl            42.02            49.61             45.50
# 6  nes_xlnet_equi.pkl            46.32            55.17             50.36
# 7  nes_xlnet_corp.pkl            44.64            55.41             49.45

# %%
results = []
for d, p in zip(domain_paths, preds_paths):
    pre, rec, f1 = term_evaluation(d,p, 'noun_noun_noun')
    results.append([p,pre, rec, f1])
noun_noun_noun = pd.DataFrame(results,columns=['DOMAIN','NOUN_NOUN_NOUN_P','NOUN_NOUN_NOUN_R','NOUN_NOUN_NOUN_F1'])
noun_noun_noun
# Out:
#                DOMAIN  NOUN_NOUN_NOUN_P  NOUN_NOUN_NOUN_R  NOUN_NOUN_NOUN_F1
# 0  ann_xlnet_htfl.pkl             42.29             30.45              35.41
# 1  ann_xlnet_wind.pkl             36.66             52.89              43.30
# 2  ann_xlnet_equi.pkl             41.72             61.99              49.87
# 3  ann_xlnet_corp.pkl             42.08             59.33              49.24
# 4  nes_xlnet_htfl.pkl             43.19             37.06              39.89
# 5  nes_xlnet_wind.pkl             41.62             49.67              45.29
# 6  nes_xlnet_equi.pkl             46.40             55.17              50.41
# 7  nes_xlnet_corp.pkl             44.70             55.41              49.48

# %%
results = []
for d, p in zip(domain_paths, preds_paths):
    pre, rec, f1 = term_evaluation(d,p, 'noun_adp_noun')
    results.append([p,pre, rec, f1])
noun_adp_noun = pd.DataFrame(results,columns=['DOMAIN','NOUN_ADP_NOUN_P','NOUN_ADP_NOUN_R','NOUN_ADP_NOUN_F1'])
noun_adp_noun
# Out:
#                DOMAIN  NOUN_ADP_NOUN_P  NOUN_ADP_NOUN_R  NOUN_ADP_NOUN_F1
# 0  ann_xlnet_htfl.pkl            39.78            30.07             34.25
# 1  ann_xlnet_wind.pkl            34.89            52.80             42.02
# 2  ann_xlnet_equi.pkl            38.93            62.08             47.85
# 3  ann_xlnet_corp.pkl            38.09            60.19             46.66
# 4  nes_xlnet_htfl.pkl            41.00            36.91             38.85
# 5  nes_xlnet_wind.pkl            40.41            49.87             44.64
# 6  nes_xlnet_equi.pkl            43.08            55.30             48.43
# 7  nes_xlnet_corp.pkl            41.11            56.18             47.48

# %%
results = []
for d, p in zip(domain_paths, preds_paths):
    pre, rec, f1 = term_evaluation(d,p, 'noun_adp_adj_noun')
    results.append([p,pre, rec, f1])
noun_adp_adj_noun = pd.DataFrame(results,columns=['DOMAIN','NOUN_ADP_ADJ_NOUN_P','NOUN_ADP_ADJ_NOUN_R','NOUN_ADP_ADJ_NOUN_F1'])
noun_adp_adj_noun
# Out:
#                DOMAIN  NOUN_ADP_ADJ_NOUN_P  NOUN_ADP_ADJ_NOUN_R  \
# 0  ann_xlnet_htfl.pkl                41.85                30.03
# 1  ann_xlnet_wind.pkl                36.63                52.61
# 2  ann_xlnet_equi.pkl                41.29                61.99
# 3  ann_xlnet_corp.pkl                41.18                59.44
# 4  nes_xlnet_htfl.pkl                42.81                36.87
# 5  nes_xlnet_wind.pkl                41.65                49.61
# 6  nes_xlnet_equi.pkl                45.88                55.17
# 7  nes_xlnet_corp.pkl                43.75                55.75
#
#    NOUN_ADP_ADJ_NOUN_F1
# 0                 34.97
# 1                 43.19
# 2                 49.57
# 3                 48.65
# 4                 39.62
# 5                 45.28
# 6                 50.10
# 7                 49.03

# %%
results = []
for d, p in zip(domain_paths, preds_paths):
    pre, rec, f1 = term_evaluation(d,p, 'noun_adp_noun_noun')
    results.append([p,pre, rec, f1])
noun_adp_noun_noun = pd.DataFrame(results,columns=['DOMAIN','NOUN_ADP_NOUN_NOUN_P','NOUN_ADP_NOUN_NOUN_R','NOUN_ADP_NOUN_NOUN_F1'])
noun_adp_noun_noun
# Out:
#                DOMAIN  NOUN_ADP_NOUN_NOUN_P  NOUN_ADP_NOUN_NOUN_R  \
# 0  ann_xlnet_htfl.pkl                 41.83                 30.03
# 1  ann_xlnet_wind.pkl                 36.84                 52.61
# 2  ann_xlnet_equi.pkl                 41.82                 61.99
# 3  ann_xlnet_corp.pkl                 41.57                 59.33
# 4  nes_xlnet_htfl.pkl                 42.79                 36.87
# 5  nes_xlnet_wind.pkl                 41.79                 49.61
# 6  nes_xlnet_equi.pkl                 46.32                 55.17
# 7  nes_xlnet_corp.pkl                 44.41                 55.58
#
#    NOUN_ADP_NOUN_NOUN_F1
# 0                  34.96
# 1                  43.33
# 2                  49.95
# 3                  48.89
# 4                  39.61
# 5                  45.37
# 6                  50.36
# 7                  49.37

# %%
results = []
for d, p in zip(domain_paths, preds_paths):
    pre, rec, f1 = term_evaluation(d,p, 'adj_noun_adp_adj_noun')
    results.append([p,pre, rec, f1])
adj_noun_adp_adj_noun = pd.DataFrame(results,columns=['DOMAIN','ADJ_NOUN_ADP_ADJ_NOUN_P','ADJ_NOUN_ADP_ADJ_NOUN_R','ADJ_NOUN_ADP_ADJ_NOUN_F1'])
adj_noun_adp_adj_noun
# Out:
#                DOMAIN  ADJ_NOUN_ADP_ADJ_NOUN_P  ADJ_NOUN_ADP_ADJ_NOUN_R  \
# 0  ann_xlnet_htfl.pkl                    42.58                    30.03
# 1  ann_xlnet_wind.pkl                    37.52                    52.61
# 2  ann_xlnet_equi.pkl                    42.07                    61.99
# 3  ann_xlnet_corp.pkl                    42.37                    59.33
# 4  nes_xlnet_htfl.pkl                    43.44                    36.87
# 5  nes_xlnet_wind.pkl                    42.37                    49.61
# 6  nes_xlnet_equi.pkl                    46.70                    55.17
# 7  nes_xlnet_corp.pkl                    44.77                    55.41
#
#    ADJ_NOUN_ADP_ADJ_NOUN_F1
# 0                     35.22
# 1                     43.80
# 2                     50.12
# 3                     49.44
# 4                     39.89
# 5                     45.71
# 6                     50.58
# 7                     49.52

# %%
results = []
for d, p in zip(domain_paths, preds_paths):
    pre, rec, f1 = term_evaluation(d,p, 'adv_adj_noun')
    results.append([p,pre, rec, f1])
adv_adj_noun = pd.DataFrame(results,columns=['DOMAIN','ADV_ADJ_NOUN_P','ADV_ADJ_NOUN_R','ADV_ADJ_NOUN_F1'])
adv_adj_noun
# Out:
#                DOMAIN  ADV_ADJ_NOUN_P  ADV_ADJ_NOUN_R  ADV_ADJ_NOUN_F1
# 0  ann_xlnet_htfl.pkl           42.66           30.03            35.25
# 1  ann_xlnet_wind.pkl           37.32           52.61            43.67
# 2  ann_xlnet_equi.pkl           41.44           61.99            49.67
# 3  ann_xlnet_corp.pkl           42.21           59.33            49.33
# 4  nes_xlnet_htfl.pkl           43.46           36.87            39.89
# 5  nes_xlnet_wind.pkl           42.07           49.61            45.53
# 6  nes_xlnet_equi.pkl           46.03           55.17            50.19
# 7  nes_xlnet_corp.pkl           44.74           55.41            49.51

# %%
results = []
for d, p in zip(domain_paths, preds_paths):
    pre, rec, f1 = term_evaluation(d,p, 'noun_pron')
    results.append([p,pre, rec, f1])
noun_pron = pd.DataFrame(results,columns=['DOMAIN','NOUN_PRON_P','NOUN_PRON_R','NOUN_PRON_F1'])
noun_pron
# Out:
#                DOMAIN  NOUN_PRON_P  NOUN_PRON_R  NOUN_PRON_F1
# 0  ann_xlnet_htfl.pkl        42.43        30.37         35.40
# 1  ann_xlnet_wind.pkl        36.68        52.61         43.22
# 2  ann_xlnet_equi.pkl        41.60        61.99         49.79
# 3  ann_xlnet_corp.pkl        42.32        59.44         49.44
# 4  nes_xlnet_htfl.pkl        43.33        37.21         40.04
# 5  nes_xlnet_wind.pkl        41.56        49.61         45.23
# 6  nes_xlnet_equi.pkl        46.52        55.17         50.48
# 7  nes_xlnet_corp.pkl        44.95        55.41         49.63

# %%
results = []
for d, p in zip(domain_paths, preds_paths):
    pre, rec, f1 = term_evaluation(d,p, 'adj_noun_adj_noun')
    results.append([p,pre, rec, f1])
adj_noun_adj_noun = pd.DataFrame(results,columns=['DOMAIN','ADJ_NOUN_ADJ_NOUN_P','ADJ_NOUN_ADJ_NOUN_R','ADJ_NOUN_ADJ_NOUN_F1'])
adj_noun_adj_noun
# Out:
#                DOMAIN  ADJ_NOUN_ADJ_NOUN_P  ADJ_NOUN_ADJ_NOUN_R  \
# 0  ann_xlnet_htfl.pkl                42.92                30.03
# 1  ann_xlnet_wind.pkl                37.71                52.61
# 2  ann_xlnet_equi.pkl                42.19                61.99
# 3  ann_xlnet_corp.pkl                42.47                59.33
# 4  nes_xlnet_htfl.pkl                43.66                36.87
# 5  nes_xlnet_wind.pkl                42.47                49.61
# 6  nes_xlnet_equi.pkl                46.75                55.17
# 7  nes_xlnet_corp.pkl                45.05                55.41
#
#    ADJ_NOUN_ADJ_NOUN_F1
# 0                 35.34
# 1                 43.93
# 2                 50.21
# 3                 49.50
# 4                 39.98
# 5                 45.76
# 6                 50.61
# 7                 49.70

# %%
results = []
for d, p in zip(domain_paths, preds_paths):
    pre, rec, f1 = term_evaluation(d,p, 'adj_noun_adp_noun')
    results.append([p,pre, rec, f1])
adj_noun_adp_noun = pd.DataFrame(results,columns=['DOMAIN','ADJ_NOUN_ADP_NOUN_P','ADJ_NOUN_ADP_NOUN_R','ADJ_NOUN_ADP_NOUN_F1'])
adj_noun_adp_noun
# Out:
#                DOMAIN  ADJ_NOUN_ADP_NOUN_P  ADJ_NOUN_ADP_NOUN_R  \
# 0  ann_xlnet_htfl.pkl                42.18                30.03
# 1  ann_xlnet_wind.pkl                37.20                52.61
# 2  ann_xlnet_equi.pkl                41.82                61.99
# 3  ann_xlnet_corp.pkl                41.67                59.33
# 4  nes_xlnet_htfl.pkl                43.10                36.87
# 5  nes_xlnet_wind.pkl                42.10                49.67
# 6  nes_xlnet_equi.pkl                46.20                55.17
# 7  nes_xlnet_corp.pkl                44.52                55.41
#
#    ADJ_NOUN_ADP_NOUN_F1
# 0                 35.08
# 1                 43.58
# 2                 49.95
# 3                 48.96
# 4                 39.74
# 5                 45.57
# 6                 50.29
# 7                 49.37

# %%
df_ls = [adj_noun, noun_noun, adj_adj_noun, adj_noun_noun, noun_adj_noun, 
        noun_noun_noun , noun_adp_noun, noun_adp_adj_noun, adj_noun_adp_noun, noun_adp_noun_noun,
        adj_noun_adp_adj_noun, adv_adj_noun, noun_pron, adj_noun_adj_noun]

# %%
for d in df_ls:
    raw_res = raw_res.merge(d, on='DOMAIN', how='left')
raw_res
# Out:
#                DOMAIN  NON_PATTERN_P  NON_PATTERN_R  NON_PATTERN_F1  \
# 0  ann_xlnet_htfl.pkl          42.94          30.03           35.34
# 1  ann_xlnet_wind.pkl          37.76          52.61           43.96
# 2  ann_xlnet_equi.pkl          42.22          61.99           50.23
# 3  ann_xlnet_corp.pkl          42.54          59.33           49.55
# 4  nes_xlnet_htfl.pkl          43.63          36.83           39.94
# 5  nes_xlnet_wind.pkl          42.47          49.61           45.76
# 6  nes_xlnet_equi.pkl          46.77          55.17           50.62
# 7  nes_xlnet_corp.pkl          45.05          55.41           49.70
#
#    ADJ_NOUN_P  ADJ_NOUN_R  ADJ_NOUN_F1  NOUN_NOUN_P  NOUN_NOUN_R  \
# 0       40.83       34.22        37.23        32.89        36.47
# 1       34.48       57.75        43.18        25.93        60.86
# 2       34.81       64.59        45.24        33.53        67.45
# 3       38.52       64.62        48.27        32.93        64.40
# 4       41.47       40.54        41.00        35.28        41.43
# 5       39.42       52.22        44.93        31.19        55.02
# 6       39.33       56.89        46.51        38.06        59.68
# 7       41.79       59.42        49.07        35.85        59.59
#
#    NOUN_NOUN_F1  ...  ADJ_NOUN_ADP_ADJ_NOUN_F1  ADV_ADJ_NOUN_P  \
# 0         34.59  ...                     35.22           42.66
# 1         36.37  ...                     43.80           37.32
# 2         44.79  ...                     50.12           41.44
# 3         43.58  ...                     49.44           42.21
# 4         38.11  ...                     39.89           43.46
# 5         39.81  ...                     45.71           42.07
# 6         46.48  ...                     50.58           46.03
# 7         44.77  ...                     49.52           44.74
#
#    ADV_ADJ_NOUN_R  ADV_ADJ_NOUN_F1  NOUN_PRON_P  NOUN_PRON_R  NOUN_PRON_F1  \
# 0           30.03            35.25        42.43        30.37         35.40
# 1           52.61            43.67        36.68        52.61         43.22
# 2           61.99            49.67        41.60        61.99         49.79
# 3           59.33            49.33        42.32        59.44         49.44
# 4           36.87            39.89        43.33        37.21         40.04
# 5           49.61            45.53        41.56        49.61         45.23
# 6           55.17            50.19        46.52        55.17         50.48
# 7           55.41            49.51        44.95        55.41         49.63
#
#    ADJ_NOUN_ADJ_NOUN_P  ADJ_NOUN_ADJ_NOUN_R  ADJ_NOUN_ADJ_NOUN_F1
# 0                42.92                30.03                 35.34
# 1                37.71                52.61                 43.93
# 2                42.19                61.99                 50.21
# 3                42.47                59.33                 49.50
# 4                43.66                36.87                 39.98
# 5                42.47                49.61                 45.76
# 6                46.75                55.17                 50.61
# 7                45.05                55.41                 49.70
#
# [8 rows x 46 columns]

# %%
raw_res.to_csv('en_iate_comparison.csv')

# %%
cols = [col for col in raw_res.columns if 'DOMAIN' in col or '_F1' in col]
raw_res[cols]
# Out:
#                DOMAIN  NON_PATTERN_F1  ADJ_NOUN_F1  NOUN_NOUN_F1  \
# 0  ann_xlnet_htfl.pkl           35.34        37.23         34.59
# 1  ann_xlnet_wind.pkl           43.96        43.18         36.37
# 2  ann_xlnet_equi.pkl           50.23        45.24         44.79
# 3  ann_xlnet_corp.pkl           49.55        48.27         43.58
# 4  nes_xlnet_htfl.pkl           39.94        41.00         38.11
# 5  nes_xlnet_wind.pkl           45.76        44.93         39.81
# 6  nes_xlnet_equi.pkl           50.62        46.51         46.48
# 7  nes_xlnet_corp.pkl           49.70        49.07         44.77
#
#    ADJ_ADJ_NOUN_F1  ADJ_NOUN_NOUN_F1  NOUN_ADJ_NOUN_F1  NOUN_NOUN_NOUN_F1  \
# 0            35.83             35.20             35.37              35.41
# 1            43.65             43.25             43.64              43.30
# 2            49.65             49.74             49.91              49.87
# 3            48.89             49.27             49.17              49.24
# 4            40.23             39.74             39.88              39.89
# 5            45.57             45.42             45.50              45.29
# 6            50.19             50.31             50.36              50.41
# 7            49.38             49.49             49.45              49.48
#
#    NOUN_ADP_NOUN_F1  NOUN_ADP_ADJ_NOUN_F1  ADJ_NOUN_ADP_NOUN_F1  \
# 0             34.25                 34.97                 35.08
# 1             42.02                 43.19                 43.58
# 2             47.85                 49.57                 49.95
# 3             46.66                 48.65                 48.96
# 4             38.85                 39.62                 39.74
# 5             44.64                 45.28                 45.57
# 6             48.43                 50.10                 50.29
# 7             47.48                 49.03                 49.37
#
#    NOUN_ADP_NOUN_NOUN_F1  ADJ_NOUN_ADP_ADJ_NOUN_F1  ADV_ADJ_NOUN_F1  \
# 0                  34.96                     35.22            35.25
# 1                  43.33                     43.80            43.67
# 2                  49.95                     50.12            49.67
# 3                  48.89                     49.44            49.33
# 4                  39.61                     39.89            39.89
# 5                  45.37                     45.71            45.53
# 6                  50.36                     50.58            50.19
# 7                  49.37                     49.52            49.51
#
#    NOUN_PRON_F1  ADJ_NOUN_ADJ_NOUN_F1
# 0         35.40                 35.34
# 1         43.22                 43.93
# 2         49.79                 50.21
# 3         49.44                 49.50
# 4         40.04                 39.98
# 5         45.23                 45.76
# 6         50.48                 50.61
# 7         49.63                 49.70

# %%
f1_df = raw_res[cols].set_index('DOMAIN').T
f1_df.to_csv('en_iate_f1.csv')

# %%
def term_evaluation_preds(domain_path, preds_path, rule=None):
    groundtruth = pd.read_csv(domain_path, sep='	', engine='python',header=None)
    gt = list(groundtruth[0])
    predictions = pkl.load(open(preds_path, 'rb'))
    if rule == 'adj_noun':
        preds =  get_term_adj_noun(predictions)
    elif rule == 'noun_noun':
        preds =  get_term_noun_noun(predictions)
    elif rule == 'adj_adj_noun':
        preds = get_term_adj_adj_noun(predictions)
    elif rule == 'adj_noun_noun':
        preds = get_term_adj_noun_noun(predictions)
    elif rule == 'noun_adj_noun':
        preds = get_term_noun_adj_noun(predictions)
    elif rule == 'noun_noun_noun':
        preds = get_term_noun_noun_noun(predictions)
    elif rule == 'noun_adp_noun':
        preds = get_term_noun_adp_noun(predictions)
    elif rule == 'noun_adp_adj_noun':
        preds = get_term_noun_adp_adj_noun(predictions)
    elif rule == 'adj_noun_adp_noun':
        preds = get_term_adj_noun_adp_noun(predictions)
    elif rule == 'noun_adp_noun_noun':
        preds = get_term_noun_adp_noun_noun(predictions)
    elif rule == 'adj_noun_adp_adj_noun':
        preds = get_term_adj_noun_adp_adj_noun(predictions)
    elif rule == 'adv_adj_noun':
        preds = get_term_adv_adj_noun(predictions)
    elif rule == 'noun_pron':
        preds = get_term_noun_pron(predictions)
    elif rule == 'adj_noun_adj_noun':
        preds = get_term_adj_noun_adj_noun(predictions)
    else:
        preds =  get_term_(predictions)
    stop_words = set(stopwords.words('english'))
    pred_terms =  set(preds) - set(stop_words)
    pred_terms = [x for x in pred_terms if len(x)>1]
    pred_terms = [x.lower().strip() for x in pred_terms]
    pred_terms = [re.sub(' -','-', x) for x in pred_terms]
    pred_terms = [re.sub('- ','-', x) for x in pred_terms]
    pred_terms = [re.sub('\(','', x) for x in pred_terms]
    pred_terms = [re.sub('\/','', x) for x in pred_terms]
    print(pred_terms)
    precision, recall, f1 = evaluation_metrics(pred_terms, gt)
    return precision, recall, f1

# %%
with open('ann_xlnet_corp.pkl', 'rb') as f:
    h = pkl.load(f)
h
# Out:
# [[{'Code': 'B'},
#   {'of': 'I'},
#   {'Conduct': 'I'},
#   {'for': 'O'},
#   {'Members': 'O'},
#   {'of': 'I'},
#   {'the': 'O'},
#   {'European': 'O'},
#   {'Parliament': 'I'},
#   {'with': 'O'},
#   {'respect': 'O'},
#   {'to': 'O'},
#   {'financial': 'B'},
#   {'interests': 'I'},
#   {'and': 'I'},
#   {'conflicts': 'B'},
#   {'of': 'I'},
#   {'interest': 'I'}],
#  [],
#  [{'Article': 'O'}, {'1': 'O'}],
#  [],
#  [],
#  [{'Guiding': 'B'}, {'principles': 'B'}],
#  [],
#  [],
#  [{'In': 'O'},
#   {'exercising': 'O'},
#   {'their': 'O'},
#   {'duties': 'I'},
#   {',': 'O'},
#   {'Members': 'O'},
#   {'of': 'I'},
#   {'the': 'O'},
#   {'European': 'O'},
#   {'Parliament': 'O'},
#   {':': 'O'},
#   {'are': 'O'},
#   {'guided': 'O'},
#   {'by': 'O'},
#   {'and': 'O'},
#   {'observe': 'O'},
#   {'the': 'O'},
#   {'following': 'O'},
#   {'general': 'B'},
#   {'principles': 'I'},
#   {'of': 'I'},
#   {'conduct': 'I'},
#   {':': 'O'},
#   {'disinterest': 'B'},
#   {',': 'O'},
#   {'integrity': 'B'},
#   {',': 'O'},
#   {'openness': 'B'},
#   {',': 'O'},
#   {'diligence': 'O'},
#   {',': 'O'},
#   {'honesty': 'B'},
#   {',': 'O'},
#   {'accountability': 'B'},
#   {'and': 'O'},
#   {'respect': 'O'},
#   {'for': 'O'},
#   {'Parliament': 'O'},
#   {"'s": 'O'},
#   {'reputation': 'I'},
#   {',': 'O'},
#   {'act': 'O'},
#   {'solely': 'O'},
#   {'in': 'O'},
#   {'the': 'O'},
#   {'public': 'B'},
#   {'interest': 'I'},
#   {'and': 'O'},
#   {'refrain': 'O'},
#   {'from': 'O'},
#   {'obtaining': 'I'},
#   {'or': 'O'},
#   {'seeking': 'O'},
#   {'to': 'I'},
#   {'obtain': 'I'},
#   {'any': 'O'},
#   {'direct': 'B'},
#   {'or': 'O'},
#   {'indirect': 'B'},
#   {'financial': 'B'},
#   {'benefit': 'I'},
#   {'or': 'O'},
#   {'other': 'O'},
#   {'reward': 'B'},
#   {'.': 'O'}],
#  [],
#  [{'Article': 'O'}, {'2': 'O'}],
#  [],
#  [],
#  [{'Main': 'O'}, {'duties': 'B'}, {'of': 'O'}, {'Members': 'O'}],
#  [],
#  [],
#  [{'In': 'O'},
#   {'exercising': 'O'},
#   {'their': 'O'},
#   {'duties': 'B'},
#   {',': 'O'},
#   {'Members': 'O'},
#   {'of': 'O'},
#   {'the': 'O'},
#   {'European': 'O'},
#   {'Parliament': 'O'},
#   {'shall': 'O'},
#   {':': 'O'},
#   {'not': 'O'},
#   {'enter': 'O'},
#   {'into': 'O'},
#   {'any': 'O'},
#   {'agreement': 'I'},
#   {'to': 'O'},
#   {'act': 'I'},
#   {'or': 'O'},
#   {'vote': 'B'},
#   {'in': 'O'},
#   {'the': 'I'},
#   {'interest': 'I'},
#   {'of': 'I'},
#   {'any': 'O'},
#   {'other': 'O'},
#   {'legal': 'B'},
#   {'or': 'O'},
#   {'natural': 'B'},
#   {'person': 'I'},
#   {'that': 'O'},
#   {'would': 'O'},
#   {'compromise': 'O'},
#   {'their': 'O'},
#   {'voting': 'B'},
#   {'freedom': 'I'},
#   {',': 'O'},
#   {'as': 'O'},
#   {'enshrined': 'O'},
#   {'in': 'O'},
#   {'Article': 'O'},
#   {'6': 'O'},
#   {'of': 'O'},
#   {'the': 'O'},
#   {'Act': 'B'},
#   {'of': 'O'},
#   {'20': 'O'},
#   {'September': 'O'},
#   {'1976': 'O'},
#   {'concerning': 'O'},
#   {'the': 'O'},
#   {'election': 'B'},
#   {'of': 'I'},
#   {'the': 'O'},
#   {'members': 'O'},
#   {'of': 'O'},
#   {'the': 'O'},
#   {'European': 'O'},
#   {'Parliament': 'I'},
#   {'by': 'O'},
#   {'direct': 'B'},
#   {'universal': 'O'},
#   {'suffrage': 'I'},
#   {'and': 'O'},
#   {'Article': 'O'},
#   {'2': 'O'},
#   {'of': 'O'},
#   {'the': 'O'},
#   {'Statute': 'B'},
#   {'for': 'O'},
#   {'Members': 'O'},
#   {'of': 'O'},
#   {'the': 'O'},
#   {'European': 'O'},
#   {'Parliament': 'I'},
#   {',': 'O'},
#   {'not': 'O'},
#   {'solicit': 'O'},
#   {',': 'O'},
#   {'accept': 'O'},
#   {'or': 'O'},
#   {'receive': 'O'},
#   {'any': 'O'},
#   {'direct': 'B'},
#   {'or': 'O'},
#   {'indirect': 'B'},
#   {'financial': 'B'},
#   {'benefit': 'I'},
#   {'or': 'O'},
#   {'other': 'O'},
#   {'reward': 'B'},
#   {'in': 'O'},
#   {'exchange': 'O'},
#   {'for': 'O'},
#   {'influencing': 'O'},
#   {',': 'O'},
#   {'or': 'O'},
#   {'voting': 'B'},
#   {'on': 'I'},
#   {',': 'O'},
#   {'legislation': 'B'},
#   {',': 'O'},
#   {'motions': 'B'},
#   {'for': 'O'},
#   {'a': 'O'},
#   {'resolution': 'B'},
#   {',': 'O'},
#   {'written': 'O'},
#   {'declarations': 'B'},
#   {'or': 'O'},
#   {'questions': 'O'},
#   {'tabled': 'O'},
#   {'in': 'O'},
#   {'Parliament': 'O'},
#   {'or': 'O'},
#   {'any': 'O'},
#   {'of': 'O'},
#   {'its': 'O'},
#   {'committees': 'I'},
#   {',': 'O'},
#   {'and': 'O'},
#   {'shall': 'O'},
#   {'consciously': 'O'},
#   {'seek': 'O'},
#   {'to': 'O'},
#   {'avoid': 'O'},
#   {'any': 'O'},
#   {'situation': 'O'},
#   {'which': 'O'},
#   {'might': 'O'},
#   {'imply': 'O'},
#   {'bribery': 'B'},
#   {'or': 'O'},
#   {'corruption': 'B'},
#   {'.': 'O'}],
#  [],
#  [{'Article': 'B'}, {'3': 'O'}],
#  [],
#  [{'Conflicts': 'B'}, {'of': 'I'}, {'interest': 'I'}],
#  [],
#  [{'A': 'O'},
#   {'conflict': 'B'},
#   {'of': 'I'},
#   {'interest': 'I'},
#   {'exists': 'O'},
#   {'where': 'O'},
#   {'a': 'O'},
#   {'Member': 'O'},
#   {'of': 'I'},
#   {'the': 'O'},
#   {'European': 'O'},
#   {'Parliament': 'I'},
#   {'has': 'O'},
#   {'a': 'O'},
#   {'personal': 'B'},
#   {'interest': 'I'},
#   {'that': 'O'},
#   {'could': 'O'},
#   {'improperly': 'O'},
#   {'influence': 'O'},
#   {'the': 'O'},
#   {'performance': 'O'},
#   {'of': 'O'},
#   {'his': 'O'},
#   {'or': 'O'},
#   {'her': 'O'},
#   {'duties': 'B'},
#   {'as': 'O'},
#   {'a': 'O'},
#   {'Member': 'O'},
#   {'.': 'O'},
#   {'A': 'O'},
#   {'conflict': 'B'},
#   {'of': 'I'},
#   {'interest': 'I'},
#   {'does': 'O'},
#   {'not': 'O'},
#   {'exist': 'O'},
#   {'where': 'O'},
#   {'a': 'O'},
#   {'Member': 'O'},
#   {'benefits': 'I'},
#   {'only': 'O'},
#   {'as': 'O'},
#   {'a': 'O'},
#   {'member': 'O'},
#   {'of': 'I'},
#   {'the': 'O'},
#   {'general': 'B'},
#   {'public': 'B'},
#   {'or': 'O'},
#   {'of': 'I'},
#   {'a': 'O'},
#   {'broad': 'O'},
#   {'class': 'I'},
#   {'of': 'I'},
#   {'persons': 'I'},
#   {'.': 'O'}],
#  [],
#  [{'Any': 'O'},
#   {'Member': 'O'},
#   {'who': 'O'},
#   {'finds': 'O'},
#   {'that': 'O'},
#   {'he': 'O'},
#   {'or': 'O'},
#   {'she': 'O'},
#   {'has': 'O'},
#   {'a': 'O'},
#   {'conflict': 'B'},
#   {'of': 'I'},
#   {'interest': 'I'},
#   {'shall': 'O'},
#   {'immediately': 'O'},
#   {'take': 'O'},
#   {'the': 'O'},
#   {'necessary': 'O'},
#   {'steps': 'O'},
#   {'to': 'O'},
#   {'address': 'O'},
#   {'it': 'O'},
#   {',': 'O'},
#   {'in': 'O'},
#   {'accordance': 'O'},
#   {'with': 'O'},
#   {'the': 'O'},
#   {'principles': 'B'},
#   {'and': 'O'},
#   {'provisions': 'O'},
#   {'of': 'O'},
#   {'this': 'O'},
#   {'Code': 'B'},
#   {'of': 'I'},
#   {'Conduct': 'I'},
#   {'.': 'O'},
#   {'If': 'O'},
#   {'the': 'O'},
#   {'Member': 'O'},
#   {'is': 'O'},
#   {'unable': 'O'},
#   {'to': 'O'},
#   {'resolve': 'O'},
#   {'the': 'O'},
#   {'conflict': 'B'},
#   {'of': 'I'},
#   {'interest': 'I'},
#   {',': 'O'},
#   {'he': 'O'},
#   {'or': 'O'},
#   {'she': 'O'},
#   {'shall': 'O'},
#   {'report': 'B'},
#   {'this': 'O'},
#   {'to': 'O'},
#   {'the': 'O'},
#   {'President': 'O'},
#   {'in': 'O'},
#   {'writing': 'O'},
#   {'.': 'O'},
#   {'In': 'O'},
#   {'cases': 'I'},
#   {'of': 'I'},
#   {'ambiguity': 'O'},
#   {',': 'O'},
#   {'the': 'O'},
#   {'Member': 'O'},
#   {'may': 'O'},
#   {'seek': 'O'},
#   {'advice': 'I'},
#   {'in': 'O'},
#   {'confidence': 'O'},
#   {'from': 'O'},
#   {'the': 'O'},
#   {'Advisory': 'I'},
#   {'Committee': 'I'},
#   {'on': 'I'},
#   {'the': 'I'},
#   {'Conduct': 'I'},
#   {'of': 'I'},
#   {'Members': 'O'},
#   {',': 'O'},
#   {'established': 'O'},
#   {'under': 'O'},
#   {'Article': 'O'},
#   {'7': 'O'},
#   {'.': 'O'}],
#  [],
#  [{'Without': 'O'},
#   {'prejudice': 'O'},
#   {'to': 'O'},
#   {'paragraph': 'O'},
#   {'2': 'O'},
#   {',': 'O'},
#   {'Members': 'O'},
#   {'shall': 'O'},
#   {'disclose': 'B'},
#   {',': 'O'},
#   {'before': 'O'},
#   {'speaking': 'O'},
#   {'or': 'O'},
#   {'voting': 'B'},
#   {'in': 'O'},
#   {'plenary': 'O'},
#   {'or': 'O'},
#   {'in': 'O'},
#   {'one': 'O'},
#   {'of': 'O'},
#   {'Parliament': 'O'},
#   {"'s": 'O'},
#   {'bodies': 'I'},
#   {',': 'O'},
#   {'or': 'O'},
#   {'if': 'O'},
#   {'proposed': 'O'},
#   {'as': 'O'},
#   {'a': 'O'},
#   {'rapporteur': 'B'},
#   {',': 'O'},
#   {'any': 'O'},
#   {'actual': 'O'},
#   {'or': 'O'},
#   {'potential': 'O'},
#   {'conflict': 'B'},
#   {'of': 'I'},
#   {'interest': 'I'},
#   {'in': 'O'},
#   {'relation': 'O'},
#   {'to': 'O'},
#   {'the': 'O'},
#   {'matter': 'O'},
#   {'under': 'O'},
#   {'consideration': 'O'},
#   {',': 'O'},
#   {'where': 'O'},
#   {'such': 'O'},
#   {'conflict': 'B'},
#   {'is': 'O'},
#   {'not': 'O'},
#   {'evident': 'O'},
#   {'from': 'O'},
#   {'the': 'O'},
#   {'information': 'O'},
#   {'declared': 'O'},
#   {'pursuant': 'O'},
#   {'to': 'O'},
#   {'Article': 'O'},
#   {'4': 'O'},
#   {'.': 'O'},
#   {'Such': 'O'},
#   {'disclosure': 'O'},
#   {'shall': 'O'},
#   {'be': 'O'},
#   {'made': 'O'},
#   {'in': 'O'},
#   {'writing': 'O'},
#   {'or': 'O'},
#   {'orally': 'O'},
#   {'to': 'O'},
#   {'the': 'O'},
#   {'chair': 'O'},
#   {'during': 'O'},
#   {'the': 'O'},
#   {'parliamentary': 'O'},
#   {'proceedings': 'I'},
#   {'in': 'O'},
#   {'question': 'O'},
#   {'.': 'O'}],
#  [],
#  [{'Article': 'B'}, {'4': 'O'}],
#  [],
#  [],
#  [{'Declaration': 'B'}, {'by': 'O'}, {'Members': 'O'}],
#  [],
#  [],
#  [{'For': 'O'},
#   {'reasons': 'O'},
#   {'of': 'O'},
#   {'transparency': 'B'},
#   {',': 'O'},
#   {'Members': 'O'},
#   {'of': 'O'},
#   {'the': 'O'},
#   {'European': 'O'},
#   {'Parliament': 'O'},
#   {'shall': 'O'},
#   {'be': 'O'},
#   {'personally': 'O'},
#   {'responsible': 'O'},
#   {'for': 'O'},
#   {'submitting': 'O'},
#   {'a': 'O'},
#   {'declaration': 'B'},
#   {'of': 'I'},
#   {'financial': 'B'},
#   {'interests': 'I'},
#   {'to': 'O'},
#   {'the': 'O'},
#   {'President': 'O'},
#   {'by': 'O'},
#   {'the': 'O'},
#   {'end': 'O'},
#   {'of': 'O'},
#   {'the': 'O'},
#   {'first': 'O'},
#   {'part': 'O'},
#   {'-': 'O'},
#   {'session': 'O'},
#   {'after': 'O'},
#   {'elections': 'B'},
#   {'to': 'O'},
#   {'the': 'O'},
#   {'European': 'O'},
#   {'Parliament': 'O'},
#   {'(': 'O'},
#   {'or': 'O'},
#   {'within': 'O'},
#   {'30': 'O'},
#   {'days': 'O'},
#   {'of': 'O'},
#   {'taking': 'O'},
#   {'up': 'O'},
#   {'office': 'O'},
#   {'with': 'O'},
#   {'the': 'O'},
#   {'Parliament': 'O'},
#   {'in': 'O'},
#   {'the': 'O'},
#   {'course': 'O'},
#   {'of': 'O'},
#   {'a': 'O'},
#   {'parliamentary': 'O'},
#   {'term': 'B'},
#   {')': 'O'},
#   {',': 'O'},
#   {'in': 'O'},
#   {'accordance': 'O'},
#   {'with': 'O'},
#   {'a': 'O'},
#   {'form': 'O'},
#   {'to': 'O'},
#   {'be': 'O'},
#   {'adopted': 'O'},
#   {'by': 'O'},
#   {'the': 'O'},
#   {'Bureau': 'I'},
#   {'pursuant': 'O'},
#   {'to': 'O'},
#   {'Article': 'O'},
#   {'9': 'O'},
#   {'.': 'O'},
#   {'They': 'O'},
#   {'shall': 'O'},
#   {'notify': 'O'},
#   {'the': 'O'},
#   {'President': 'O'},
#   {'of': 'O'},
#   {'any': 'O'},
#   {'changes': 'O'},
#   {'that': 'O'},
#   {'have': 'O'},
#   {'an': 'O'},
#   {'influence': 'O'},
#   {'on': 'O'},
#   {'their': 'O'},
#   {'declaration': 'O'},
#   {'within': 'O'},
#   {'30': 'O'},
#   {'days': 'O'},
#   {'of': 'O'},
#   {'each': 'O'},
#   {'change': 'O'},
#   {'occurring': 'O'},
#   {'.': 'O'}],
#  [],
#  [{'The': 'O'},
#   {'declaration': 'B'},
#   {'of': 'O'},
#   {'financial': 'B'},
#   {'interests': 'I'},
#   {'shall': 'O'},
#   {'contain': 'O'},
#   {'the': 'O'},
#   {'following': 'O'},
#   {'information': 'O'},
#   {',': 'O'},
#   {'which': 'O'},
#   {'shall': 'O'},
#   {'be': 'O'},
#   {'provided': 'O'},
#   {'in': 'O'},
#   {'a': 'O'},
#   {'precise': 'O'},
#   {'manner': 'O'},
#   {':': 'O'},
#   {'the': 'O'},
#   {'Member': 'O'},
#   {"'s": 'O'},
#   {'occupation(s': 'O'},
#   {')': 'O'},
#   {'during': 'O'},
#   {'the': 'O'},
#   {'three': 'O'},
#   {'-': 'O'},
#   {'year': 'O'},
#   {'period': 'O'},
#   {'before': 'O'},
#   {'he': 'O'},
#   {'or': 'O'},
#   {'she': 'O'},
#   {'took': 'O'},
#   {'up': 'O'},
#   {'office': 'O'},
#   {'with': 'O'},
#   {'the': 'O'},
#   {'Parliament': 'O'},
#   {',': 'O'},
#   {'and': 'O'},
#   {'his': 'O'},
#   {'or': 'O'},
#   {'her': 'O'},
#   {'membership': 'O'},
#   {'during': 'O'},
#   {'that': 'O'},
#   {'period': 'O'},
#   {'of': 'O'},
#   {'any': 'O'},
#   {'boards': 'I'},
#   {'or': 'O'},
#   {'committees': 'I'},
#   {'of': 'O'},
#   {'companies': 'B'},
#   {',': 'O'},
#   {'non-': 'O'},
#   {'governmental': 'B'},
#   {'organisations': 'I'},
#   {',': 'O'},
#   {'associations': 'O'},
#   {'or': 'O'},
#   {'other': 'O'},
#   {'bodies': 'I'},
#   {'established': 'O'},
#   {'in': 'O'},
#   {'law': 'B'},
#   {',': 'O'},
#   {'any': 'O'},
#   {'salary': 'B'},
#   {'which': 'O'},
#   {'the': 'O'},
#   {'Member': 'O'},
#   {'receives': 'O'},
#   {'for': 'O'},
#   {'the': 'O'},
#   {'exercise': 'O'},
#   {'of': 'O'},
#   {'a': 'O'},
#   {'mandate': 'B'},
#   {'in': 'O'},
#   {'another': 'O'},
#   {'parliament': 'O'},
#   {',': 'O'},
#   {'any': 'O'},
#   {'regular': 'O'},
#   {'remunerated': 'O'},
#   {'activity': 'I'},
#   {'which': 'O'},
#   {'the': 'O'},
#   {'Member': 'O'},
#   {'undertakes': 'O'},
#   {'alongside': 'O'},
#   {'the': 'O'},
#   {'exercise': 'O'},
#   {'of': 'O'},
#   {'his': 'O'},
#   {'or': 'O'},
#   {'her': 'O'},
#   {'office': 'O'},
#   {',': 'O'},
#   {'whether': 'O'},
#   {'as': 'O'},
#   {'an': 'O'},
#   {'employee': 'B'},
#   {'or': 'O'},
#   {'as': 'O'},
#   {'a': 'O'},
#   {'self': 'B'},
#   {'-': 'O'},
#   {'employed': 'O'},
#   {'person': 'I'},
#   {',': 'O'},
#   {'membership': 'O'},
#   {'of': 'O'},
#   {'any': 'O'},
#   {'boards': 'I'},
#   {'or': 'O'},
#   {'committees': 'I'},
#   {'of': 'O'},
#   {'any': 'O'},
#   {'companies': 'B'},
#   {',': 'O'},
#   {'non-': 'O'},
#   {'governmental': 'B'},
#   {'organisations': 'I'},
#   {',': 'O'},
#   {'associations': 'O'},
#   {'or': 'O'},
#   {'other': 'O'},
#   {'bodies': 'I'},
#   {'established': 'O'},
#   {'in': 'O'},
#   {'law': 'B'},
#   {',': 'O'},
#   {'or': 'O'},
#   {'any': 'O'},
#   {'other': 'O'},
#   {'relevant': 'O'},
#   {'outside': 'O'},
#   {'activity': 'I'},
#   {'that': 'O'},
#   {'the': 'O'},
#   {'Member': 'O'},
#   {'undertakes': 'O'},
#   {',': 'O'},
#   {'whether': 'O'},
#   {'the': 'O'},
#   {'membership': 'O'},
#   {'or': 'O'},
#   {'activity': 'I'},
#   {'in': 'O'},
#   {'question': 'O'},
#   {'is': 'O'},
#   {'remunerated': 'B'},
#   {'or': 'O'},
#   {'unremunerated': 'B'},
#   {',': 'O'},
#   {'any': 'O'},
#   {'occasional': 'O'},
#   {'remunerated': 'O'},
#   {'outside': 'O'},
#   {'activity': 'I'},
#   {'(': 'O'},
#   {'including': 'O'},
#   {'writing': 'O'},
#   {',': 'O'},
#   {'lecturing': 'B'},
#   {'or': 'O'},
#   {'the': 'O'},
#   {'provision': 'O'},
#   {'of': 'O'},
#   {'expert': 'O'},
#   {'advice': 'I'},
#   {')': 'O'},
#   {',': 'O'},
#   {'if': 'O'},
#   {'the': 'O'},
#   {'total': 'O'},
#   {'remuneration': 'B'},
#   {'exceeds': 'O'},
#   {'EUR': 'O'},
#   {'5': 'O'},
#   {'000': 'O'},
#   {'in': 'O'},
#   {'a': 'O'},
#   {'calendar': 'O'},
#   {'year': 'O'},
#   {',': 'O'},
#   {'any': 'O'},
#   {'holding': 'O'},
#   {'in': 'O'},
#   {'any': 'O'},
#   {'company': 'B'},
#   {'or': 'O'},
#   {'partnership': 'B'},
#   {',': 'O'},
#   {'where': 'O'},
#   {'there': 'O'},
#   {'are': 'O'},
#   {'potential': 'O'},
#   {'public': 'B'},
#   {'policy': 'I'},
#   {'implications': 'O'},
#   {'or': 'O'},
#   {'where': 'O'},
#   {'that': 'O'},
#   {'holding': 'O'},
#   {'gives': 'O'},
#   {'the': 'O'},
#   {'Member': 'O'},
#   {'significant': 'O'},
#   {'influence': 'O'},
#   {'over': 'O'},
#   {'the': 'O'},
#   {'affairs': 'I'},
#   {'of': 'O'},
#   {'the': 'O'},
#   {'body': 'I'},
#   {'in': 'O'},
#   {'question': 'O'},
#   {',': 'O'},
#   {'any': 'O'},
#   {'support': 'O'},
#   {',': 'O'},
#   {'whether': 'O'},
#   {'financial': 'B'},
#   {'or': 'O'},
#   {'in': 'O'},
#   {'terms': 'O'},
#   {'of': 'O'},
#   {'staff': 'B'},
#   {'or': 'O'},
#   {'material': 'O'},
#   {',': 'O'},
#   {'additional': 'O'},
#   {'to': 'O'},
#   {'that': 'O'},
#   {'provided': 'O'},
#   {'by': 'O'},
#   {'Parliament': 'O'},
#   {'and': 'O'},
#   {'granted': 'O'},
#   {'to': 'O'},
#   {'the': 'O'},
#   {'Member': 'O'},
#   {'in': 'O'},
#   {'connection': 'O'},
#   {'with': 'O'},
#   {'his': 'O'},
#   {'or': 'O'},
#   {'her': 'O'},
#   {'political': 'B'},
#   {'activities': 'I'},
#   {'by': 'O'},
#   {'third': 'B'},
#   {'parties': 'I'},
#   {',': 'O'},
#   {'whose': 'O'},
#   {'identity': 'O'},
#   {'shall': 'O'},
#   {'be': 'O'},
#   {'disclosed': 'O'},
#   {',': 'O'},
#   {'any': 'O'},
#   {'other': 'O'},
#   {'financial': 'B'},
#   {'interests': 'I'},
#   {'which': 'O'},
#   {'might': 'O'},
#   {'influence': 'O'},
#   {'the': 'O'},
#   {'performance': 'O'},
#   {'of': 'O'},
#   {'the': 'O'},
#   {'Member': 'O'},
#   {"'s": 'O'},
#   {'duties': 'B'},
#   {'.': 'O'}],
#  [],
#  [{'Any': 'O'},
#   {'regular': 'B'},
#   {'income': 'B'},
#   {'Members': 'O'},
#   {'receive': 'O'},
#   {'in': 'O'},
#   {'respect': 'O'},
#   {'of': 'I'},
#   {'each': 'O'},
#   {'item': 'O'},
#   {'declared': 'O'},
#   {'in': 'O'},
#   {'accordance': 'O'},
#   {'with': 'O'},
#   {'the': 'B'},
#   {'first': 'O'},
#   {'subparagraph': 'O'},
#   {'shall': 'O'},
#   {'be': 'O'},
#   {'placed': 'O'},
#   {'in': 'O'},
#   {'one': 'O'},
#   {'of': 'O'},
#   {'the': 'O'},
#   {'following': 'O'},
#   {'categories': 'O'},
#   {':': 'O'},
#   {'EUR': 'O'},
#   {'500': 'O'},
#   {'to': 'O'},
#   {'EUR': 'O'},
#   {'1': 'O'},
#   {'000': 'O'},
#   {'a': 'O'},
#   {'month': 'O'},
#   {';': 'O'},
#   {'EUR': 'O'},
#   {'1': 'O'},
#   {'001': 'O'},
#   {'to': 'O'},
#   {'EUR': 'O'},
#   {'5': 'O'},
#   {'000': 'O'},
#   {'a': 'O'},
#   {'month': 'O'},
#   {';': 'O'},
#   {'EUR': 'O'},
#   {'5': 'O'},
#   {'001': 'O'},
#   {'to': 'O'},
#   {'EUR': 'O'},
#   {'10': 'O'},
#   {'000': 'O'},
#   {'a': 'O'},
#   {'month': 'O'},
#   {';': 'O'},
#   {'more': 'O'},
#   {'than': 'O'},
#   {'EUR': 'O'},
#   {'10': 'O'},
#   {'000': 'O'},
#   {'a': 'O'},
#   {'month': 'O'},
#   {'.': 'O'}],
#  [],
#  [{'Any': 'O'},
#   {'other': 'O'},
#   {'income': 'B'},
#   {'Members': 'O'},
#   {'receive': 'O'},
#   {'in': 'O'},
#   {'respect': 'O'},
#   {'of': 'I'},
#   {'each': 'O'},
#   {'item': 'O'},
#   {'declared': 'O'},
#   {'in': 'O'},
#   {'accordance': 'O'},
#   {'with': 'O'},
#   {'the': 'O'},
#   {'first': 'O'},
#   {'subparagraph': 'O'},
#   {'shall': 'O'},
#   {'be': 'O'},
#   {'calculated': 'O'},
#   {'on': 'O'},
#   {'an': 'O'},
#   {'annual': 'O'},
#   {'basis': 'O'},
#   {',': 'O'},
#   {'divided': 'O'},
#   {'by': 'O'},
#   {'twelve': 'O'},
#   {'and': 'O'},
#   {'placed': 'O'},
#   {'in': 'O'},
#   {'one': 'O'},
#   {'of': 'O'},
#   {'the': 'O'},
#   {'categories': 'O'},
#   {'set': 'O'},
#   {'out': 'O'},
#   {'in': 'O'},
#   {'the': 'O'},
#   {'second': 'O'},
#   {'subparagraph': 'O'},
#   {'.': 'O'}],
#  [],
#  [{'The': 'O'},
#   {'information': 'O'},
#   {'provided': 'O'},
#   {'to': 'O'},
#   {'the': 'O'},
#   {'President': 'O'},
#   {'in': 'O'},
#   {'line': 'O'},
#   {'with': 'O'},
#   {'this': 'O'},
#   {'Article': 'O'},
#   {'shall': 'O'},
#   {'be': 'O'},
#   {'published': 'O'},
#   {'on': 'O'},
#   {'Parliament': 'O'},
#   {"'s": 'O'},
#   {'website': 'O'},
#   {'in': 'O'},
#   {'an': 'O'},
#   {'easily': 'O'},
#   {'accessible': 'O'},
#   {'manner': 'O'},
#   {'.': 'O'}],
#  [],
#  [{'Members': 'O'},
#   {'may': 'O'},
#   {'not': 'O'},
#   {'be': 'O'},
#   {'elected': 'B'},
#   {'as': 'O'},
#   {'office': 'O'},
#   {'-': 'O'},
#   {'holders': 'O'},
#   {'of': 'O'},
#   {'Parliament': 'O'},
#   {'or': 'O'},
#   {'of': 'I'},
#   {'one': 'O'},
#   {'of': 'O'},
#   {'its': 'O'},
#   {'bodies': 'I'},
#   {',': 'O'},
#   {'be': 'O'},
#   {'appointed': 'O'},
#   {'as': 'O'},
#   {'a': 'O'},
#   {'rapporteur': 'B'},
#   {'or': 'O'},
#   {'participate': 'O'},
#   {'in': 'O'},
#   {'an': 'O'},
#   {'official': 'B'},
#   {'delegation': 'O'},
#   {',': 'O'},
#   {'if': 'O'},
#   {'they': 'O'},
#   {'have': 'O'},
#   {'not': 'O'},
#   {'submitted': 'O'},
#   {'their': 'O'},
#   {'declaration': 'B'},
#   {'of': 'I'},
#   {'financial': 'B'},
#   {'interests': 'I'},
#   {'.': 'O'}],
#  [],
#  [{'Article': 'B'}, {'5': 'O'}],
#  [],
#  [],
#  [{'Gifts': 'B'}, {'or': 'O'}, {'similar': 'O'}, {'benefits': 'I'}],
#  [],
#  [],
#  [{'Members': 'O'},
#   {'of': 'O'},
#   {'the': 'O'},
#   {'European': 'O'},
#   {'Parliament': 'O'},
#   {'shall': 'O'},
#   {'refrain': 'O'},
#   {'from': 'O'},
#   {'accepting': 'O'},
#   {',': 'O'},
#   {'in': 'O'},
#   {'the': 'O'},
#   {'performance': 'O'},
#   {'of': 'I'},
#   {'their': 'O'},
#   {'duties': 'B'},
#   {',': 'O'},
#   {'any': 'O'},
#   {'gifts': 'B'},
#   {'or': 'O'},
#   {'similar': 'O'},
#   {'benefits': 'I'},
#   {',': 'O'},
#   {'other': 'O'},
#   {'than': 'O'},
#   {'those': 'O'},
#   {'with': 'O'},
#   {'an': 'O'},
#   {'approximate': 'O'},
#   {'value': 'I'},
#   {'of': 'O'},
#   {'less': 'O'},
#   {'than': 'O'},
#   {'EUR': 'O'},
#   {'150': 'O'},
#   {'given': 'O'},
#   {'in': 'O'},
#   {'accordance': 'O'},
#   {'with': 'O'},
#   {'courtesy': 'O'},
#   {'usage': 'O'},
#   {'or': 'O'},
#   {'those': 'O'},
#   {'given': 'O'},
#   {'to': 'O'},
#   {'them': 'O'},
#   {'in': 'O'},
#   {'accordance': 'O'},
#   {'with': 'O'},
#   {'courtesy': 'O'},
#   {'usage': 'O'},
#   {'when': 'O'},
#   {'they': 'O'},
#   {'are': 'O'},
#   {'representing': 'O'},
#   {'Parliament': 'O'},
#   {'in': 'O'},
#   {'an': 'O'},
#   {'official': 'B'},
#   {'capacity': 'I'},
#   {'.': 'O'}],
#  [],
#  [{'Any': 'O'},
#   {'gifts': 'B'},
#   {'presented': 'O'},
#   {'to': 'O'},
#   {'Members': 'O'},
#   {',': 'O'},
#   {'in': 'O'},
#   {'accordance': 'O'},
#   {'with': 'O'},
#   {'paragraph': 'O'},
#   {'1': 'O'},
#   {',': 'O'},
#   {'when': 'O'},
#   {'they': 'O'},
#   {'are': 'O'},
#   {'representing': 'O'},
#   {'Parliament': 'O'},
#   {'in': 'O'},
#   {'an': 'O'},
#   {'official': 'B'},
#   {'capacity': 'I'},
#   {'shall': 'O'},
#   {'be': 'O'},
#   {'handed': 'B'},
#   {'over': 'O'},
#   {'to': 'O'},
#   {'the': 'O'},
#   {'President': 'O'},
#   {'and': 'O'},
#   {'dealt': 'O'},
#   {'with': 'O'},
#   {'in': 'O'},
#   {'accordance': 'O'},
#   {'with': 'O'},
#   {'implementing': 'O'},
#   {'measures': 'O'},
#   {'to': 'O'},
#   {'be': 'O'},
#   {'laid': 'O'},
#   {'down': 'O'},
#   {'by': 'O'},
#   {'the': 'O'},
#   {'Bureau': 'I'},
#   {'pursuant': 'O'},
#   {'to': 'O'},
#   {'Article': 'O'},
#   {'9': 'O'},
#   {'.': 'O'}],
#  [],
#  [{'The': 'O'},
#   {'provisions': 'O'},
#   {'of': 'O'},
#   {'paragraphs': 'O'},
#   {'1': 'O'},
#   {'and': 'O'},
#   {'2': 'O'},
#   {'shall': 'O'},
#   {'not': 'O'},
#   {'apply': 'O'},
#   {'to': 'O'},
#   {'the': 'O'},
#   {'reimbursement': 'B'},
#   {'of': 'I'},
#   {'travel': 'O'},
#   {',': 'O'},
#   {'accommodation': 'O'},
#   {'and': 'O'},
#   {'subsistence': 'B'},
#   {'expenses': 'I'},
#   {'of': 'O'},
#   {'Members': 'O'},
#   {',': 'O'},
#   {'or': 'O'},
#   {'to': 'O'},
#   {'the': 'O'},
#   {'direct': 'B'},
#   {'payment': 'B'},
#   {'of': 'I'},
#   {'such': 'O'},
#   {'expenses': 'B'},
#   {'by': 'O'},
#   {'third': 'B'},
#   {'parties': 'I'},
#   {',': 'O'},
#   {'when': 'O'},
#   {'Members': 'O'},
#   {'attend': 'O'},
#   {',': 'O'},
#   {'pursuant': 'O'},
#   {'to': 'O'},
#   {'an': 'O'},
#   {'invitation': 'O'},
#   {'and': 'O'},
#   {'in': 'O'},
#   {'the': 'O'},
#   {'performance': 'O'},
#   {'of': 'O'},
#   {'their': 'O'},
#   {'duties': 'B'},
#   {',': 'O'},
#   {'at': 'O'},
#   {'any': 'O'},
#   {'events': 'O'},
#   {'organised': 'O'},
#   {'by': 'O'},
#   {'third': 'B'},
#   {'parties': 'O'},
#   {'.': 'O'}],
#  [],
#  [{'The': 'O'},
#   {'scope': 'O'},
#   {'of': 'O'},
#   {'this': 'O'},
#   {'paragraph': 'O'},
#   {',': 'O'},
#   {'in': 'O'},
#   {'particular': 'O'},
#   {'the': 'O'},
#   {'rules': 'B'},
#   {'designed': 'O'},
#   {'to': 'O'},
#   {'ensure': 'O'},
#   {'transparency': 'B'},
#   {',': 'O'},
#   {'shall': 'O'},
#   {'be': 'O'},
#   {'specified': 'O'},
#   {'in': 'O'},
#   {'the': 'O'},
#   {'implementing': 'O'},
#   {'measures': 'I'},
#   {'to': 'O'},
#   {'be': 'O'},
#   {'laid': 'O'},
#   {'down': 'O'},
#   {'by': 'O'},
#   {'the': 'O'},
#   {'Bureau': 'B'},
#   {'pursuant': 'O'},
#   {'to': 'O'},
#   {'Article': 'O'},
#   {'9': 'O'},
#   {'.': 'O'}],
#  [],
#  [{'Article': 'B'}, {'6': 'O'}],
#  [],
#  [],
#  [{'Activities': 'I'}, {'of': 'O'}, {'former': 'O'}, {'Members': 'O'}],
#  [],
#  [],
#  [{'Former': 'O'},
#   {'Members': 'O'},
#   {'of': 'O'},
#   {'the': 'O'},
#   {'European': 'O'},
#   {'Parliament': 'O'},
#   {'who': 'O'},
#   {'engage': 'O'},
#   {'in': 'O'},
#   {'professional': 'O'},
#   {'lobbying': 'B'},
#   {'or': 'O'},
#   {'representational': 'B'},
#   {'activities': 'I'},
#   {'directly': 'O'},
#   {'linked': 'O'},
#   {'to': 'O'},
#   {'the': 'O'},
#   {'European': 'O'},
#   {'Union': 'O'},
#   {'decision': 'B'},
#   {'-': 'O'},
#   {'making': 'O'},
#   {'process': 'I'},
#   {'may': 'O'},
#   {'not': 'O'},
#   {',': 'O'},
#   {'throughout': 'O'},
#   {'the': 'O'},
#   {'period': 'O'},
#   {'in': 'O'},
#   {'which': 'O'},
#   {'they': 'O'},
#   {'engage': 'O'},
#   {'in': 'O'},
#   {'those': 'O'},
#   {'activities': 'I'},
#   {',': 'O'},
#   {'benefit': 'O'},
#   {'from': 'O'},
#   {'the': 'O'},
#   {'facilities': 'I'},
#   {'granted': 'O'},
#   {'to': 'O'},
#   {'former': 'O'},
#   {'Members': 'O'},
#   {'under': 'O'},
#   {'the': 'O'},
#   {'rules': 'B'},
#   {'laid': 'O'},
#   {'down': 'O'},
#   {'by': 'O'},
#   {'the': 'O'},
#   {'Bureau': 'O'},
#   {'to': 'O'},
#   {'that': 'O'},
#   {'effect': 'O'},
#   {'1': 'O'},
#   {'.': 'O'}],
#  [],
#  [{'Article': 'B'}, {'7': 'O'}],
#  [],
#  [],
#  [{'Advisory': 'B'},
#   {'Committee': 'I'},
#   {'on': 'I'},
#   {'the': 'I'},
#   {'Conduct': 'I'},
#   {'of': 'I'},
#   {'Members': 'O'}],
#  [],
#  [],
#  [{'An': 'O'},
#   {'Advisory': 'B'},
#   {'Committee': 'I'},
#   {'on': 'I'},
#   {'the': 'O'},
#   {'Conduct': 'I'},
#   {'of': 'I'},
#   {'Members': 'O'},
#   {'(': 'O'},
#   {"'": 'O'},
#   {'the': 'O'},
#   {'Advisory': 'B'},
#   {'Committee': 'I'},
#   {"'": 'O'},
#   {')': 'O'},
#   {'is': 'O'},
#   {'hereby': 'O'},
#   {'established': 'O'},
#   {'.': 'O'}],
#  [],
#  [{'The': 'O'},
#   {'Advisory': 'B'},
#   {'Committee': 'I'},
#   {'shall': 'O'},
#   {'be': 'O'},
#   {'composed': 'O'},
#   {'of': 'O'},
#   {'five': 'O'},
#   {'members': 'O'},
#   {',': 'O'},
#   {'appointed': 'O'},
#   {'by': 'O'},
#   {'the': 'O'},
#   {'President': 'O'},
#   {'at': 'O'},
#   {'the': 'O'},
#   {'beginning': 'O'},
#   {'of': 'O'},
#   {'his': 'O'},
#   {'or': 'O'},
#   {'her': 'O'},
#   {'term': 'B'},
#   {'of': 'O'},
#   {'office': 'O'},
#   {'from': 'O'},
#   {'amongst': 'O'},
#   {'the': 'O'},
#   {'members': 'O'},
#   {'of': 'O'},
#   {'the': 'O'},
#   {'bureaux': 'O'},
#   {'and': 'O'},
#   {'the': 'O'},
#   {'coordinators': 'O'},
#   {'of': 'O'},
#   {'the': 'O'},
#   {'Committee': 'I'},
#   {'on': 'O'},
#   {'Constitutional': 'B'},
#   {'Affairs': 'I'},
#   {'and': 'O'},
#   {'the': 'O'},
#   {'Committee': 'I'},
#   {'on': 'O'},
#   {'Legal': 'B'},
#   {'Affairs': 'I'},
#   {',': 'O'},
#   {'taking': 'O'},
#   {'due': 'O'},
#   {'account': 'B'},
#   {'of': 'O'},
#   {'the': 'O'},
#   {'Members': 'O'},
#   {"'": 'O'},
#   {'experience': 'O'},
#   {'and': 'O'},
#   {'of': 'O'},
#   {'political': 'B'},
#   {'balance': 'B'},
#   {'.': 'O'}],
#  [],
#  [{'Each': 'O'},
#   {'member': 'O'},
#   {'of': 'I'},
#   {'the': 'O'},
#   {'Advisory': 'B'},
#   {'Committee': 'I'},
#   {'shall': 'O'},
#   {'serve': 'O'},
#   {'as': 'O'},
#   {'chair': 'B'},
#   {'for': 'O'},
#   {'six': 'O'},
#   {'months': 'O'},
#   {'on': 'O'},
#   {'a': 'O'},
#   {'rotating': 'B'},
#   {'basis': 'O'},
#   {'.': 'O'}],
#  [],
#  [{'The': 'O'},
#   {'President': 'B'},
#   {'shall': 'O'},
#   {'also': 'O'},
#   {',': 'O'},
#   {'at': 'O'},
#   {'the': 'O'},
#   {'beginning': 'O'},
#   {'of': 'O'},
#   {'his': 'O'},
#   {'or': 'O'},
#   {'her': 'O'},
#   {'term': 'B'},
#   {'of': 'I'},
#   {'office': 'I'},
#   {',': 'O'},
#   {'nominate': 'O'},
#   {'reserve': 'O'},
#   {'members': 'O'},
#   {'for': 'O'},
#   {'the': 'O'},
#   {'Advisory': 'B'},
#   {'Committee': 'I'},
#   {',': 'O'},
#   {'one': 'O'},
#   {'for': 'O'},
#   {'each': 'O'},
#   {'political': 'B'},
#   {'group': 'I'},
#   {'not': 'O'},
#   {'represented': 'O'},
#   {'in': 'O'},
#   {'the': 'O'},
#   {'Advisory': 'B'},
#   {'Committee': 'I'},
#   {'.': 'O'}],
#  [],
#  [{'In': 'O'},
#   {'the': 'O'},
#   {'event': 'O'},
#   {'of': 'O'},
#   {'an': 'O'},
#   {'alleged': 'O'},
#   {'breach': 'B'},
#   {'of': 'I'},
#   {'this': 'O'},
#   {'Code': 'B'},
#   {'of': 'I'},
#   {'Conduct': 'I'},
#   {'by': 'O'},
#   {'a': 'O'},
#   {'member': 'O'},
#   {'of': 'I'},
#   {'a': 'O'},
#   {'political': 'B'},
#   {'group': 'I'},
#   {'not': 'O'},
#   {'represented': 'O'},
#   {'in': 'O'},
#   {'the': 'O'},
#   {'Advisory': 'B'},
#   {'Committee': 'I'},
#   {',': 'O'},
#   {'the': 'O'},
#   {'relevant': 'O'},
#   {'reserve': 'O'},
#   {'member': 'O'},
#   {'shall': 'O'},
#   {'serve': 'O'},
#   {'as': 'O'},
#   {'a': 'O'},
#   {'sixth': 'O'},
#   {'full': 'O'},
#   {'member': 'O'},
#   {'of': 'O'},
#   {'the': 'O'},
#   {'Advisory': 'B'},
#   {'Committee': 'I'},
#   {'for': 'O'},
#   {'the': 'O'},
#   {'purposes': 'O'},
#   {'of': 'O'},
#   {'investigation': 'I'},
#   {'of': 'I'},
#   {'that': 'O'},
#   {'alleged': 'O'},
#   {'breach': 'B'},
#   {'.': 'O'}],
#  [],
#  [{'Upon': 'O'},
#   {'request': 'O'},
#   {'by': 'O'},
#   {'a': 'O'},
#   {'Member': 'O'},
#   {',': 'O'},
#   {'the': 'O'},
#   {'Advisory': 'B'},
#   {'Committee': 'I'},
#   {'shall': 'O'},
#   {'give': 'O'},
#   {'him': 'O'},
#   {'or': 'O'},
#   {'her': 'O'},
#   {',': 'O'},
#   {'in': 'O'},
#   {'confidence': 'O'},
#   {'and': 'O'},
#   {'within': 'O'},
#   {'30': 'O'},
#   {'calendar': 'O'},
#   {'days': 'O'},
#   {',': 'O'},
#   {'guidance': 'O'},
#   {'on': 'O'},
#   {'the': 'O'},
#   {'interpretation': 'O'},
#   {'and': 'O'},
#   {'implementation': 'O'},
#   {'of': 'I'},
#   {'the': 'O'},
#   {'provisions': 'O'},
#   {'of': 'O'},
#   {'this': 'O'},
#   {'Code': 'B'},
#   {'of': 'I'},
#   {'Conduct': 'I'},
#   {'.': 'O'},
#   {'The': 'O'},
#   {'Member': 'O'},
#   {'in': 'O'},
#   {'question': 'O'},
#   {'shall': 'O'},
#   {'be': 'O'},
#   {'entitled': 'O'},
#   {'to': 'O'},
#   {'rely': 'O'},
#   {'on': 'O'},
#   {'such': 'O'},
#   {'guidance': 'O'},
#   {'.': 'O'}],
#  [],
#  [{'At': 'O'},
#   {'the': 'O'},
#   {'request': 'O'},
#   {'of': 'O'},
#   {'the': 'O'},
#   {'President': 'O'},
#   {',': 'O'},
#   {'the': 'O'},
#   {'Advisory': 'I'},
#   {'Committee': 'I'},
#   {'shall': 'O'},
#   {'also': 'O'},
#   {'assess': 'O'},
#   {'alleged': 'B'},
#   {'breaches': 'B'},
#   {'of': 'I'},
#   {'this': 'O'},
#   {'Code': 'B'},
#   {'of': 'I'},
#   {'Conduct': 'I'},
#   {'and': 'O'},
#   {'advise': 'O'},
#   {'the': 'O'},
#   {'President': 'O'},
#   {'on': 'O'},
#   {'possible': 'O'},
#   {'action': 'I'},
#   {'to': 'O'},
#   {'be': 'O'},
#   {'taken': 'O'},
#   {'.': 'O'}],
#  [],
#  [{'The': 'O'},
#   {'Advisory': 'I'},
#   {'Committee': 'I'},
#   {'may': 'O'},
#   {',': 'O'},
#   {'after': 'O'},
#   {'consulting': 'O'},
#   {'the': 'B'},
#   {'President': 'O'},
#   {',': 'O'},
#   {'seek': 'O'},
#   {'advice': 'O'},
#   {'from': 'O'},
#   {'outside': 'B'},
#   {'experts': 'O'},
#   {'.': 'O'}],
#  [],
#  [{'The': 'O'},
#   {'Advisory': 'B'},
#   {'Committee': 'I'},
#   {'shall': 'O'},
#   {'publish': 'O'},
#   {'an': 'O'},
#   {'annual': 'O'},
#   {'report': 'B'},
#   {'of': 'O'},
#   {'its': 'O'},
#   {'work': 'O'},
#   {'.': 'O'}],
#  [],
#  [{'Article': 'B'}, {'8': 'O'}],
#  [],
#  [],
#  [{'Procedure': 'I'},
#   {'in': 'O'},
#   {'the': 'O'},
#   {'event': 'O'},
#   {'of': 'I'},
#   {'possible': 'O'},
#   {'breaches': 'B'},
#   {'of': 'I'},
#   {'the': 'O'},
#   {'Code': 'B'},
#   {'of': 'I'},
#   {'Conduct': 'I'}],
#  [],
#  [],
#  [{'Where': 'O'},
#   {'there': 'O'},
#   {'is': 'O'},
#   {'reason': 'O'},
#   {'to': 'O'},
#   {'think': 'O'},
#   {'that': 'O'},
#   {'a': 'O'},
#   {'Member': 'O'},
#   {'of': 'I'},
#   {'the': 'O'},
#   {'European': 'O'},
#   {'Parliament': 'I'},
#   {'may': 'O'},
#   {'have': 'O'},
#   {'breached': 'B'},
#   {'this': 'O'},
#   {'Code': 'B'},
#   {'of': 'I'},
#   {'Conduct': 'I'},
#   {',': 'O'},
#   {'the': 'O'},
#   {'President': 'B'},
#   {'may': 'O'},
#   {'refer': 'O'},
#   {'the': 'O'},
#   {'matter': 'O'},
#   {'to': 'O'},
#   {'the': 'O'},
#   {'Advisory': 'B'},
#   {'Committee': 'I'},
#   {'.': 'O'}],
#  [],
#  [{'The': 'O'},
#   {'Advisory': 'B'},
#   {'Committee': 'I'},
#   {'shall': 'O'},
#   {'examine': 'O'},
#   {'the': 'O'},
#   {'circumstances': 'I'},
#   {'of': 'I'},
#   {'the': 'O'},
#   {'alleged': 'O'},
#   {'breach': 'B'},
#   {',': 'O'},
#   {'and': 'O'},
#   {'may': 'O'},
#   {'hear': 'O'},
#   {'the': 'O'},
#   {'Member': 'O'},
#   {'concerned': 'O'},
#   {'.': 'O'},
#   {'On': 'O'},
#   {'the': 'O'},
#   {'basis': 'O'},
#   {'of': 'O'},
#   {'the': 'O'},
#   {'conclusions': 'O'},
#   {'of': 'O'},
#   {'its': 'O'},
#   {'findings': 'O'},
#   {',': 'O'},
#   {'it': 'O'},
#   {'shall': 'O'},
#   {'make': 'O'},
#   {'a': 'O'},
#   {'recommendation': 'O'},
#   {'to': 'O'},
#   {'the': 'O'},
#   {'President': 'O'},
#   {'on': 'O'},
#   {'a': 'O'},
#   {'possible': 'O'},
#   {'decision': 'B'},
#   {'.': 'O'}],
#  [],
#  [{'If': 'O'},
#   {',': 'O'},
#   {'taking': 'O'},
#   {'into': 'O'},
#   {'account': 'O'},
#   {'that': 'O'},
#   {'recommendation': 'O'},
#   {',': 'O'},
#   {'the': 'O'},
#   {'President': 'O'},
#   {'concludes': 'O'},
#   {'that': 'O'},
#   {'the': 'O'},
#   {'Member': 'O'},
#   {'concerned': 'O'},
#   {'has': 'O'},
#   {'breached': 'B'},
#   {'the': 'B'},
#   {'Code': 'B'},
#   {'of': 'I'},
#   {'Conduct': 'I'},
#   {',': 'O'},
#   {'he': 'O'},
#   {'shall': 'O'},
#   {',': 'O'},
#   {'after': 'O'},
#   {'hearing': 'I'},
#   {'the': 'O'},
#   {'Member': 'O'},
#   {',': 'O'},
#   {'adopt': 'O'},
#   {'a': 'O'},
#   {'reasoned': 'O'},
#   {'decision': 'B'},
#   {'laying': 'O'},
#   {'down': 'O'},
#   {'a': 'B'},
#   {'penalty': 'B'},
#   {',': 'O'},
#   {'which': 'O'},
#   {'he': 'O'},
#   {'shall': 'O'},
#   {'notify': 'O'},
#   {'to': 'O'},
#   {'the': 'O'},
#   {'Member': 'O'},
#   {'.': 'O'}],
#  [],
#  [{'The': 'O'},
#   {'penalty': 'B'},
#   {'may': 'O'},
#   {'consist': 'O'},
#   {'of': 'O'},
#   {'one': 'O'},
#   {'or': 'O'},
#   {'more': 'O'},
#   {'of': 'O'},
#   {'the': 'O'},
#   {'measures': 'I'},
#   {'listed': 'O'},
#   {'in': 'O'},
#   {'Rule': 'B'},
#   {'153(3': 'O'},
#   {')': 'O'},
#   {'of': 'O'},
#   {'the': 'O'},
#   {'Rules': 'B'},
#   {'of': 'I'},
#   {'Procedure': 'I'},
#   {'.': 'O'}],
#  [],
#  [{'The': 'O'},
#   {'internal': 'B'},
#   {'appeal': 'B'},
#   {'procedures': 'I'},
#   {'defined': 'O'},
#   {'in': 'O'},
#   {'Rule': 'B'},
#   {'154': 'O'},
#   {'of': 'O'},
#   {'the': 'O'},
#   {'Rules': 'B'},
#   {'of': 'I'},
#   {'Procedure': 'I'},
#   {'shall': 'O'},
#   {'be': 'O'},
#   {'open': 'O'},
#   {'to': 'O'},
#   {'the': 'O'},
#   {'Member': 'O'},
#   {'concerned': 'O'},
#   {'.': 'O'}],
#  [],
#  [{'After': 'O'},
#   {'the': 'O'},
#   {'expiry': 'O'},
#   {'of': 'O'},
#   {'the': 'O'},
#   {'time': 'O'},
#   {'-': 'O'},
#   {'limits': 'O'},
#   {'laid': 'O'},
#   {'down': 'O'},
#   {'in': 'O'},
#   {'Rule': 'B'},
#   {'154': 'O'},
#   {'of': 'O'},
#   {'the': 'O'},
#   {'Rules': 'B'},
#   {'of': 'I'},
#   {'the': 'O'},
#   {'Procedure': 'I'},
#   {',': 'O'},
#   {'any': 'O'},
#   {'penalty': 'B'},
#   {'imposed': 'O'},
#   {'on': 'I'},
#   {'a': 'O'},
#   {'Member': 'O'},
#   {'shall': 'O'},
#   {'be': 'O'},
#   {'announced': 'O'},
#   {'by': 'O'},
#   {'the': 'O'},
#   {'President': 'O'},
#   {'in': 'O'},
#   {'plenary': 'O'},
#   {'and': 'O'},
#   {'prominently': 'O'},
#   {'published': 'O'},
#   {'on': 'O'},
#   {'Parliament': 'O'},
#   {"'s": 'O'},
#   {'website': 'O'},
#   {'for': 'O'},
#   {'the': 'O'},
#   {'remainder': 'O'},
#   {'of': 'O'},
#   {'the': 'O'},
#   {'parliamentary': 'B'},
#   {'term': 'B'},
#   {'.': 'O'}],
#  [],
#  [{'Article': 'B'}, {'9': 'O'}],
#  [],
#  [],
#  [{'Implementation': 'B'}],
#  [],
#  [],
#  [{'The': 'O'},
#   {'Bureau': 'B'},
#   {'shall': 'O'},
#   {'lay': 'O'},
#   {'down': 'O'},
#   {'implementing': 'O'},
#   {'measures': 'I'},
#   {'for': 'O'},
#   {'this': 'O'},
#   {'Code': 'B'},
#   {'of': 'I'},
#   {'Conduct': 'I'},
#   {',': 'O'},
#   {'including': 'O'},
#   {'a': 'O'},
#   {'monitoring': 'B'},
#   {'procedure': 'I'},
#   {',': 'O'},
#   {'and': 'O'},
#   {'shall': 'O'},
#   {'update': 'O'},
#   {'the': 'O'},
#   {'amounts': 'O'},
#   {'referred': 'O'},
#   {'to': 'O'},
#   {'in': 'O'},
#   {'Articles': 'O'},
#   {'4': 'O'},
#   {'and': 'O'},
#   {'5': 'O'},
#   {',': 'O'},
#   {'when': 'O'},
#   {'necessary': 'O'},
#   {'.': 'O'}],
#  [],
#  [{'It': 'O'},
#   {'may': 'O'},
#   {'bring': 'O'},
#   {'forward': 'O'},
#   {'proposals': 'O'},
#   {'for': 'O'},
#   {'revision': 'O'},
#   {'of': 'O'},
#   {'this': 'O'},
#   {'Code': 'B'},
#   {'of': 'I'},
#   {'Conduct': 'I'},
#   {'.': 'O'}],
#  [{'Corruption': 'B'}, {'?': 'O'}],
#  [],
#  [{'Not': 'O'}, {'in': 'O'}, {'our': 'O'}, {'company': 'B'}, {'…': 'O'}],
#  [],
#  [],
#  [],
#  [{'Preventing': 'O'},
#   {'corruption': 'B'},
#   {'in': 'O'},
#   {'corporate': 'B'},
#   {'life': 'I'}],
#  [],
#  [],
#  [],
#  [{'Preface': 'B'}],
#  [],
#  [],
#  [],
#  [{'Conscious': 'O'},
#   {'of': 'O'},
#   {'its': 'O'},
#   {'central': 'O'},
#   {'position': 'O'},
#   {'within': 'O'},
#   {'the': 'O'},
#   {'European': 'O'},
#   {'Union': 'O'},
#   {',': 'O'},
#   {'Belgium': 'O'},
#   {'has': 'O'},
#   {',': 'O'},
#   {'for': 'O'},
#   {'many': 'O'},
#   {'years': 'O'},
#   {',': 'O'},
#   {'taken': 'O'},
#   {'a': 'O'},
#   {'firm': 'O'},
#   {'line': 'I'},
#   {'against': 'I'},
#   {'corruption': 'B'},
#   {'in': 'O'},
#   {'national': 'O'},
#   {'and': 'O'},
#   {'international': 'O'},
#   {'transactions': 'B'},
#   {'.': 'O'}],
#  [],
#  [],
#  [],
#  [{'For': 'O'},
#   {'this': 'O'},
#   {'purpose': 'O'},
#   {',': 'O'},
#   {'a': 'O'},
#   {'major': 'O'},
#   {'reform': 'I'},
#   {'was': 'O'},
#   {'carried': 'O'},
#   {'out': 'O'},
#   {'at': 'O'},
#   {'the': 'O'},
#   {'end': 'O'},
#   {'of': 'O'},
#   {'the': 'O'},
#   {'1990s': 'O'},
#   {'.': 'O'},
#   {'This': 'O'},
#   {'affected': 'O'},
#   {'aspects': 'O'},
#   {'of': 'O'},
#   {'both': 'O'},
#   {'the': 'O'},
#   {'criminal': 'B'},
#   {'liability': 'I'},
#   {'of': 'I'},
#   {'legal': 'B'},
#   {'persons': 'I'},
#   {'and': 'O'},
#   {'the': 'O'},
#   {'implications': 'O'},
#   {'in': 'O'},
#   {'fiscal': 'B'},
#   {'and': 'O'},
#   {'criminal': 'B'},
#   {'law': 'B'},
#   {'.': 'O'},
#   {'Since': 'O'},
#   {'then': 'O'},
#   {',': 'O'},
#   {'action': 'I'},
#   {'against': 'I'},
#   {'corruption': 'B'},
#   {'has': 'O'},
#   {'been': 'O'},
#   {'a': 'O'},
#   {'priority': 'O'},
#   {'of': 'O'},
#   {'the': 'O'},
#   {'Belgian': 'O'},
#   {'government': 'B'},
#   {'in': 'O'},
#   {'its': 'O'},
#   {'National': 'O'},
#   {'Security': 'I'},
#   {'Plan': 'I'},
#   {'2008': 'O'},
#   {'-': 'O'},
#   {'2011': 'O'},
#   {'.': 'O'}],
#  [],
#  [],
#  [],
#  [{'Corruption': 'B'},
#   {'occurs': 'O'},
#   {'in': 'O'},
#   {'various': 'O'},
#   {'forms': 'O'},
#   {'and': 'O'},
#   {'attracts': 'O'},
#   {'severe': 'O'},
#   {'penalties': 'B'},
#   {'.': 'O'},
#   {'By': 'O'},
#   {'means': 'O'},
#   {'of': 'O'},
#   {'this': 'O'},
#   {'brochure': 'O'},
#   {',': 'O'},
#   {'Belgium': 'O'},
#   {'wants': 'O'},
#   {'to': 'O'},
#   {'raise': 'O'},
#   {'the': 'O'},
#   {'awareness': 'O'},
#   {'of': 'O'},
#   {'companies': 'B'},
#   {'engaged': 'O'},
#   {'in': 'O'},
#   {'the': 'O'},
#   {'international': 'O'},
#   {'markets': 'I'},
#   {'for': 'O'},
#   {'goods': 'B'},
#   {'and': 'O'},
#   {'services': 'I'},
#   {'about': 'O'},
#   {'the': 'O'},
#   {'consequences': 'B'},
#   {'of': 'O'},
#   {'corruption': 'B'},
#   {'.': 'O'}],
#  [],
#  [],
#  [],
#  [{'Responsible': 'O'},
#   {'management': 'I'},
#   {'requires': 'O'},
#   {'a': 'O'},
#   {'clear': 'O'},
#   {'definition': 'O'},
#   {'of': 'O'},
#   {'what': 'O'},
#   {'is': 'O'},
#   {'acceptable': 'O'},
#   {'or': 'O'},
#   {'unacceptable': 'O'},
#   {'.': 'O'},
#   {'Belgium': 'O'},
#   {'hopes': 'O'},
#   {'that': 'O'},
#   {'this': 'O'},
#   {'brochure': 'O'},
#   {'will': 'O'},
#   {'raise': 'O'},
#   {'the': 'O'},
#   {'awareness': 'O'},
#   {'of': 'O'},
#   {'commercial': 'B'},
#   {'players': 'O'},
#   {'and': 'O'},
#   {'warn': 'O'},
#   {'them': 'O'},
#   {'of': 'O'},
#   {'the': 'O'},
#   {'risks': 'O'},
#   {'associated': 'O'},
#   {'with': 'O'},
#   {'their': 'O'},
#   {'business': 'B'},
#   {'contacts': 'O'},
#   {'.': 'O'}],
#  [],
#  [],
#  [{'What': 'O'}, {'is': 'O'}, {'corruption': 'B'}, {'?': 'O'}],
#  [],
#  [{'Corruption': 'B'},
#   {'is': 'O'},
#   {'a': 'O'},
#   {'manifestation': 'O'},
#   {'of': 'I'},
#   {'criminality': 'B'},
#   {'.': 'O'},
#   {'It': 'O'},
#   {'can': 'O'},
#   {'be': 'O'},
#   {'very': 'O'},
#   {'damaging': 'O'},
#   {'to': 'O'},
#   {'companies': 'B'},
#   {'and': 'O'},
#   {'to': 'O'},
#   {'society': 'I'},
#   {'.': 'O'},
#   {'It': 'O'},
#   {'leads': 'O'},
#   {'to': 'O'},
#   {'distortion': 'O'},
#   {'of': 'O'},
#   {'competition': 'B'},
#   {',': 'O'},
#   {'frightens': 'O'},
#   {'off': 'O'},
#   {'investors': 'B'},
#   {'and': 'O'},
#   {'jeopardizes': 'O'},
#   {'the': 'O'},
#   {'further': 'O'},
#   {'development': 'O'},
#   {'of': 'O'},
#   {'sound': 'O'},
#   {'companies': 'B'},
#   {'.': 'O'},
#   {'Corruption': 'B'},
#   {'is': 'O'},
#   {'morally': 'B'},
#   {'reprehensible': 'O'},
#   {'and': 'O'},
#   {'undermines': 'O'},
#   {'trust': 'O'},
#   {'in': 'O'},
#   {'society': 'I'},
#   {'and': 'O'},
#   {'in': 'O'},
#   {'democracy': 'B'},
#   {'.': 'O'},
#   {'The': 'O'},
#   {'business': 'B'},
#   {'community': 'O'},
#   {'sees': 'O'},
#   {'it': 'O'},
#   {'as': 'O'},
#   {'the': 'O'},
#   {'main': 'O'},
#   {'obstacle': 'O'},
#   {'to': 'O'},
#   {'investment': 'B'},
#   {'in': 'O'},
#   {'certain': 'O'},
#   {'countries': 'O'},
#   {'.': 'O'},
#   {'In': 'O'},
#   {'the': 'O'},
#   {'longer': 'B'},
#   {'term': 'B'},
#   {',': 'O'},
#   {'corruption': 'B'},
#   {'adds': 'O'},
#   {'to': 'O'},
#   {'costs': 'B'},
#   {',': 'O'},
#   {'both': 'O'},
#   {'to': 'O'},
#   {'the': 'O'},
#   {'community': 'O'},
#   {'and': 'O'},
#   {'for': 'O'},
#   {'companies': 'B'},
#   {'.': 'O'},
#   {'Often': 'O'},
#   {'it': 'O'},
#   {'is': 'O'},
#   {'accompanied': 'O'},
#   {'by': 'O'},
#   {'a': 'O'},
#   {'deterioration': 'O'},
#   {'of': 'O'},
#   {'quality': 'O'},
#   {'and': 'O'},
#   {'safety': 'O'},
#   {'.': 'O'}],
#  [],
#  [{'For': 'O'},
#   {'a': 'O'},
#   {'natural': 'B'},
#   {'or': 'O'},
#   {'a': 'O'},
#   {'legal': 'B'},
#   {'person': 'I'},
#   {',': 'O'},
#   {'corruption': 'B'},
#   {'means': 'O'},
#   {'the': 'O'},
#   {'soliciting': 'B'},
#   {',': 'O'},
#   {'acceptance': 'O'},
#   {'or': 'O'},
#   {'receipt': 'O'},
#   {'of': 'O'},
#   {'any': 'O'},
#   {'form': 'O'},
#   {'of': 'I'},
#   {'advantage': 'B'},
#   {',': 'O'},
#   {'in': 'O'},
#   {'an': 'O'},
#   {'official': 'B'},
#   {'context': 'O'},
#   {',': 'O'},
#   {'to': 'O'},
#   {'gain': 'B'},
#   {'acceptance': 'O'},
#   {'for': 'O'},
#   {'a': 'O'},
#   {'given': 'O'},
#   {'practice': 'I'},
#   {'or': 'O'},
#   {'behaviour': 'I'},
#   {'.': 'O'},
#   {'It': 'O'},
#   {'is': 'O'},
#   {'also': 'O'},
#   {'the': 'O'},
#   {'offering': 'O'},
#   {'or': 'O'},
#   {'granting': 'B'},
#   {'of': 'O'},
#   {'such': 'O'},
#   {'advantage': 'B'},
#   {'to': 'O'},
#   {'induce': 'B'},
#   {'a': 'O'},
#   {'person': 'I'},
#   {'to': 'O'},
#   {'accept': 'O'},
#   {'such': 'O'},
#   {'behaviour': 'I'},
#   {'.': 'O'},
#   {'The': 'O'},
#   {'law': 'B'},
#   {'applies': 'O'},
#   {'to': 'O'},
#   {'Belgian': 'O'},
#   {'individuals': 'I'},
#   {'and': 'O'},
#   {'companies': 'B'},
#   {'active': 'O'},
#   {'both': 'O'},
#   {'in': 'O'},
#   {'Belgium': 'O'},
#   {'and': 'O'},
#   {'abroad': 'O'},
#   {'.': 'O'},
#   {'Belgium': 'O'},
#   {'also': 'O'},
#   {'makes': 'O'},
#   {'no': 'O'},
#   {'distinction': 'O'},
#   {'between': 'O'},
#   {'national': 'O'},
#   {',': 'O'},
#   {'international': 'O'},
#   {'and': 'O'},
#   {'foreign': 'O'},
#   {'office': 'I'},
#   {'-': 'O'},
#   {'holders': 'O'},
#   {'.': 'O'}],
#  [],
#  [],
#  [{'It': 'O'},
#   {'makes': 'O'},
#   {'no': 'O'},
#   {'difference': 'O'},
#   {'whether': 'O'},
#   {'the': 'O'},
#   {'bribery': 'I'},
#   {'takes': 'O'},
#   {'place': 'O'},
#   {'directly': 'B'},
#   {'or': 'O'},
#   {'through': 'O'},
#   {'intermediaries': 'B'},
#   {';': 'O'},
#   {'nor': 'O'},
#   {'whether': 'O'},
#   {'the': 'O'},
#   {'advantage': 'B'},
#   {'is': 'O'},
#   {'intended': 'O'},
#   {'for': 'O'},
#   {'oneself': 'O'},
#   {'or': 'O'},
#   {'for': 'O'},
#   {'a': 'O'},
#   {'third': 'B'},
#   {'party': 'I'},
#   {'.': 'O'},
#   {'It': 'O'},
#   {'is': 'O'},
#   {'also': 'O'},
#   {'irrelevant': 'O'},
#   {'whether': 'O'},
#   {'it': 'O'},
#   {'happens': 'O'},
#   {'in': 'O'},
#   {'the': 'O'},
#   {'public': 'B'},
#   {'or': 'O'},
#   {'the': 'O'},
#   {'private': 'B'},
#   {'sector': 'I'},
#   {'.': 'O'},
#   {'Both': 'O'},
#   {'the': 'O'},
#   {'person': 'I'},
#   {'offering': 'O'},
#   {'such': 'O'},
#   {'advantages': 'B'},
#   {'and': 'O'},
#   {'the': 'O'},
#   {'recipient': 'O'},
#   {'can': 'O'},
#   {'be': 'O'},
#   {'convicted': 'B'},
#   {'of': 'I'},
#   {'corruption': 'B'},
#   {'.': 'O'},
#   {'Therefore': 'O'},
#   {'Belgian': 'O'},
#   {'law': 'B'},
#   {'covers': 'O'},
#   {'both': 'O'},
#   {'private': 'B'},
#   {'and': 'O'},
#   {'public': 'B'},
#   {'bribery': 'I'},
#   {'and': 'O'},
#   {'both': 'O'},
#   {'active': 'O'},
#   {'and': 'O'},
#   {'passive': 'B'},
#   {'bribery': 'I'},
#   {'.': 'O'}],
#  [],
#  [],
#  [{'In': 'O'},
#   {'other': 'O'},
#   {'words': 'O'},
#   {',': 'O'},
#   {'corruption': 'B'},
#   {'may': 'O'},
#   {'occur': 'O'},
#   {'at': 'O'},
#   {'various': 'O'},
#   {'levels': 'I'},
#   {'and': 'O'},
#   {'in': 'O'},
#   {'various': 'O'},
#   {'forms': 'O'},
#   {'.': 'O'},
#   {'All': 'O'},
#   {'these': 'O'},
#   {'forms': 'O'},
#   {'of': 'I'},
#   {'corruption': 'B'},
#   {'are': 'O'},
#   {'criminal': 'B'},
#   {'offences': 'B'},
#   {'in': 'O'},
#   {'Belgium': 'O'},
#   {'.': 'O'}],
#  [],
#  [{'In': 'O'},
#   {'fact': 'O'},
#   {'an': 'O'},
#   {'incidental': 'O'},
#   {'condition': 'O'},
#   {'applies': 'O'},
#   {'to': 'O'},
#   {'private': 'B'},
#   {'corruption': 'B'},
#   {':': 'O'},
#   {'it': 'O'},
#   {'must': 'O'},
#   {'have': 'O'},
#   {'taken': 'O'},
#   {'place': 'O'},
#   {'without': 'O'},
#   {'prior': 'O'},
#   {'knowledge': 'O'},
#   {'and': 'O'},
#   {'without': 'O'},
#   {'the': 'O'},
#   {'authorisation': 'O'},
#   {'of': 'O'},
#   {',': 'O'},
#   {'depending': 'O'},
#   {'on': 'O'},
#   {'the': 'O'},
#   {'case': 'I'},
#   {',': 'O'},
#   {'the': 'O'},
#   {'board': 'I'},
#   {'of': 'I'},
#   {'directors': 'I'},
#   {'or': 'O'},
#   {'the': 'O'},
#   {'general': 'B'},
#   {'assembly': 'I'},
#   {',': 'O'},
#   {'the': 'O'},
#   {'principal': 'B'},
#   {'or': 'O'},
#   {'the': 'O'},
#   {'employer': 'B'},
#   {'.': 'O'}],
#  [],
#  [{'The': 'O'},
#   {'Belgian': 'O'},
#   {'Criminal': 'B'},
#   {'Code': 'B'},
#   {'contains': 'O'},
#   {'two': 'O'},
#   {'chapters': 'O'},
#   {'of': 'O'},
#   {'importance': 'O'},
#   {'in': 'O'},
#   {'combating': 'B'},
#   {'corruption': 'B'},
#   {'.': 'O'},
#   {'They': 'O'},
#   {'are': 'O'},
#   {'Criminal': 'B'},
#   {'Code': 'B'},
#   {'Articles': 'O'},
#   {'246': 'O'},
#   {'ff': 'O'},
#   {'.': 'O'},
#   {',': 'O'},
#   {'which': 'O'},
#   {'concern': 'O'},
#   {'public': 'B'},
#   {'bribery': 'I'},
#   {',': 'O'},
#   {'and': 'O'},
#   {'504bis': 'O'},
#   {'and': 'O'},
#   {'ter': 'O'},
#   {'on': 'O'},
#   {'private': 'B'},
#   {'bribery': 'I'},
#   {'.': 'O'},
#   {'Penalties': 'B'},
#   {'range': 'O'},
#   {'from': 'O'},
#   {'six': 'O'},
#   {'months': 'O'},
#   {'to': 'O'},
#   {'three': 'O'},
#   {'years': 'O'},
#   {'imprisonment': 'B'},
#   {'.': 'O'},
#   {'If': 'O'},
#   {'there': 'O'},
#   {'are': 'O'},
#   {'aggravating': 'B'},
#   {'circumstances': 'I'},
#   {',': 'O'},
#   {'the': 'O'},
#   {'custodial': 'B'},
#   {'sentence': 'B'},
#   {'may': 'O'},
#   {'be': 'O'},
#   {'up': 'O'},
#   {'to': 'O'},
#   {'10': 'O'},
#   {'years': 'O'},
#   {'.': 'O'},
#   {'Fines': 'B'},
#   {'imposed': 'O'},
#   {'may': 'O'},
#   {'amount': 'O'},
#   {'to': 'O'},
#   {'up': 'O'},
#   {'to': 'O'},
#   {'100': 'O'},
#   {'000': 'O'},
#   {'euros': 'O'},
#   {'.': 'O'}],
#  [],
#  [],
#  [{'Criminal': 'B'},
#   {'proceedings': 'I'},
#   {'not': 'O'},
#   {'only': 'O'},
#   {'attract': 'O'},
#   {'negative': 'O'},
#   {'publicity': 'O'},
#   {'.': 'O'},
#   {'A': 'O'},
#   {'legal': 'B'},
#   {'person': 'I'},
#   {'may': 'O'},
#   {'also': 'O'},
#   {'be': 'O'},
#   {'struck': 'O'},
#   {'off': 'O'},
#   {'the': 'O'},
#   {'list': 'O'},
#   {'of': 'O'},
#   {'contractors': 'I'},
#   {'eligible': 'O'},
#   {'for': 'O'},
#   {'government': 'B'},
#   {'contracts': 'I'},
#   {'.': 'O'},
#   {'In': 'O'},
#   {'Belgium': 'O'},
#   {',': 'O'},
#   {'anyway': 'O'},
#   {',': 'O'},
#   {'companies': 'B'},
#   {'are': 'O'},
#   {'debarred': 'O'},
#   {'from': 'O'},
#   {'awards': 'I'},
#   {'of': 'I'},
#   {'public': 'B'},
#   {'contracts': 'B'},
#   {'if': 'O'},
#   {'they': 'O'},
#   {'have': 'O'},
#   {'been': 'O'},
#   {'convicted': 'B'},
#   {'of': 'I'},
#   {'criminal': 'B'},
#   {'conspiracy': 'I'},
#   {',': 'O'},
#   {'bribery': 'B'},
#   {',': 'O'},
#   {'fraud': 'B'},
#   {',': 'O'},
#   {'money': 'B'},
#   {'laundering': 'I'},
#   {'or': 'O'},
#   {'any': 'O'},
#   {'other': 'O'},
#   {'misdemeanour': 'B'},
#   {'which': 'O'},
#   {',': 'O'},
#   {'by': 'O'},
#   {'nature': 'O'},
#   {',': 'O'},
#   {'represents': 'O'},
#   {'a': 'O'},
#   {'violation': 'B'},
#   {'of': 'I'},
#   {'professional': 'B'},
#   {'ethics': 'B'},
#   {'.': 'O'}],
#  [],
#  [],
#  [{'Other': 'O'},
#   {'actions': 'I'},
#   {'are': 'O'},
#   {'also': 'O'},
#   {'punishable': 'B'},
#   {'.': 'O'},
#   {'Thus': 'O'},
#   {'Article': 'O'},
#   {'314': 'O'},
#   {'of': 'O'},
#   {'the': 'O'},
#   {'Criminal': 'B'},
#   {'Code': 'B'},
#   {'punishes': 'B'},
#   {'restriction': 'O'},
#   {'of': 'O'},
#   {'the': 'O'},
#   {'freedom': 'I'},
#   {'of': 'I'},
#   {'bidding': 'I'},
#   {'or': 'O'},
#   {'of': 'I'},
#   {'registration': 'O'},
#   {'for': 'O'},
#   {'transfers': 'B'},
#   {'of': 'I'},
#   {'ownership': 'O'},
#   {',': 'O'},
#   {'usufruct': 'B'},
#   {'or': 'O'},
#   {'leasing': 'I'},
#   {'of': 'I'},
#   {'movable': 'B'},
#   {'or': 'O'},
#   {'immovable': 'B'},
#   {'property': 'I'},
#   {'of': 'O'},
#   {'a': 'O'},
#   {'company': 'B'},
#   {',': 'O'},
#   {'of': 'O'},
#   {'a': 'O'},
#   {'supply': 'O'},
#   {'etc': 'O'},
#   {'.': 'O'},
#   {'with': 'O'},
#   {'15': 'O'},
#   {'days': 'O'},
#   {'to': 'O'},
#   {'six': 'O'},
#   {'months': 'O'},
#   {'imprisonment': 'B'},
#   {'and': 'O'},
#   {'a': 'O'},
#   {'fine': 'B'},
#   {'of': 'O'},
#   {'100': 'O'},
#   {'to': 'O'},
#   {'3000': 'O'},
#   {'euros': 'O'},
#   {'.': 'O'}],
#  [],
#  [],
#  [{'The': 'O'},
#   {'tax': 'B'},
#   {'legislation': 'B'},
#   {'also': 'O'},
#   {'specifies': 'O'},
#   {'that': 'O'},
#   {'each': 'O'},
#   {'count': 'B'},
#   {'of': 'I'},
#   {'corruption': 'B'},
#   {',': 'O'},
#   {'liable': 'B'},
#   {'to': 'O'},
#   {'prosecution': 'B'},
#   {'under': 'O'},
#   {'the': 'O'},
#   {'Criminal': 'B'},
#   {'Code': 'B'},
#   {',': 'O'},
#   {'both': 'O'},
#   {'for': 'O'},
#   {'a': 'O'},
#   {'natural': 'B'},
#   {'and': 'O'},
#   {'for': 'O'},
#   {'a': 'O'},
#   {'legal': 'B'},
#   {'person': 'I'},
#   {',': 'O'},
#   {'can': 'O'},
#   {'not': 'O'},
#   {'be': 'O'},
#   {'deducted': 'I'},
#   {'from': 'O'},
#   {'the': 'O'},
#   {'basis': 'I'},
#   {'of': 'O'},
#   {'tax': 'B'},
#   {'assessment': 'I'},
#   {'.': 'O'},
#   {'Ex': 'B'},
#   {'officio': 'I'},
#   {',': 'O'},
#   {'a': 'O'},
#   {'separate': 'O'},
#   {'amount': 'O'},
#   {'of': 'I'},
#   {'309': 'O'},
#   {'%': 'O'},
#   {'of': 'O'},
#   {'the': 'O'},
#   {'value': 'I'},
#   {'of': 'O'},
#   {'the': 'O'},
#   {'count': 'B'},
#   {'of': 'I'},
#   {'corruption': 'B'},
#   {'is': 'O'},
#   {'levied': 'B'},
#   {'on': 'O'},
#   {'the': 'O'},
#   {'corporate': 'B'},
#   {'taxpayer': 'B'},
#   {'.': 'O'}],
#  [],
#  [],
#  [{'Plus': 'O'},
#   {'the': 'O'},
#   {'statutory': 'B'},
#   {"'": 'O'},
#   {'additional': 'O'},
#   {'tenths': 'I'},
#   {"'": 'O'},
#   {'.': 'O'},
#   {'The': 'O'},
#   {'fine': 'B'},
#   {'can': 'O'},
#   {'either': 'O'},
#   {'be': 'O'},
#   {'imposed': 'O'},
#   {'cumulatively': 'O'},
#   {'with': 'O'},
#   {'the': 'O'},
#   {'penalty': 'B'},
#   {'of': 'I'},
#   {'imprisonment': 'I'},
#   {',': 'O'},
#   {'or': 'O'},
#   {'separately': 'O'},
#   {'.': 'O'}],
#  [],
#  [{'Article': 'O'},
#   {'8': 'O'},
#   {'of': 'O'},
#   {'the': 'O'},
#   {'Law': 'B'},
#   {'of': 'O'},
#   {'10': 'O'},
#   {'February': 'O'},
#   {'1999': 'O'},
#   {'concerning': 'O'},
#   {'Penalties': 'B'},
#   {'for': 'O'},
#   {'Corruption': 'B'},
#   {',': 'O'},
#   {'Moniteur': 'O'},
# ...
#   {'34(2)(c': 'O'},
#   {')': 'O'},
#   {'thereof': 'O'},
#   {',': 'O'},
#   {'Having': 'O'},
#   {'regard': 'O'},
#   {'to': 'O'},
#   {'the': 'O'},
#   {'initiative': 'O'},
#   {'of': 'O'},
#   {'the': 'O'},
#   {'Federal': 'O'},
#   {'Republic': 'O'},
#   {'of': 'O'},
#   {'Germany': 'O'},
#   {',': 'O'},
#   {'Having': 'O'},
#   {'regard': 'O'},
#   {'to': 'O'},
#   {'the': 'O'},
#   {'opinion': 'I'},
#   {'of': 'O'},
#   {'the': 'O'},
#   {'European': 'O'},
#   {'Parliament': 'I'},
#   {',': 'O'},
#   {'Whereas': 'O'},
#   {':': 'O'}],
#  [],
#  [{'(': 'O'}, {'1': 'O'}, {')': 'O'}],
#  [],
#  [{'Article': 'O'},
#   {'29': 'O'},
#   {'of': 'O'},
#   {'the': 'O'},
#   {'Treaty': 'O'},
#   {'states': 'O'},
#   {'that': 'O'},
#   {'the': 'O'},
#   {'objective': 'O'},
#   {'of': 'O'},
#   {'the': 'O'},
#   {'Union': 'O'},
#   {'to': 'O'},
#   {'provide': 'O'},
#   {'citizens': 'O'},
#   {'with': 'O'},
#   {'a': 'O'},
#   {'high': 'O'},
#   {'level': 'O'},
#   {'of': 'O'},
#   {'safety': 'O'},
#   {'within': 'O'},
#   {'an': 'O'},
#   {'area': 'I'},
#   {'of': 'O'},
#   {'freedom': 'B'},
#   {',': 'O'},
#   {'security': 'O'},
#   {'and': 'O'},
#   {'justice': 'B'},
#   {'is': 'O'},
#   {'to': 'O'},
#   {'be': 'O'},
#   {'achieved': 'O'},
#   {'by': 'O'},
#   {'preventing': 'O'},
#   {'and': 'O'},
#   {'combating': 'B'},
#   {'crime': 'B'},
#   {',': 'O'},
#   {'organised': 'B'},
#   {'or': 'O'},
#   {'otherwise': 'O'},
#   {',': 'O'},
#   {'including': 'O'},
#   {'corruption': 'B'},
#   {'and': 'O'},
#   {'fraud': 'B'},
#   {'.': 'O'}],
#  [],
#  [{'(': 'O'}, {'2': 'O'}, {')': 'O'}],
#  [],
#  [{'The': 'O'},
#   {'European': 'O'},
#   {'Union': 'O'},
#   {'strategy': 'I'},
#   {'for': 'O'},
#   {'the': 'O'},
#   {'beginning': 'O'},
#   {'of': 'O'},
#   {'the': 'O'},
#   {'new': 'O'},
#   {'millennium': 'O'},
#   {'on': 'O'},
#   {'the': 'O'},
#   {'prevention': 'O'},
#   {'and': 'O'},
#   {'control': 'I'},
#   {'of': 'I'},
#   {'organised': 'B'},
#   {'crime': 'B'},
#   {'emphasises': 'O'},
#   {'the': 'O'},
#   {'need': 'O'},
#   {'to': 'O'},
#   {'develop': 'O'},
#   {'a': 'O'},
#   {'comprehensive': 'O'},
#   {'EU': 'O'},
#   {'policy': 'I'},
#   {'against': 'I'},
#   {'corruption': 'B'},
#   {'.': 'O'}],
#  [],
#  [{'(': 'O'}, {'3': 'O'}, {')': 'O'}],
#  [],
#  [{'In': 'O'},
#   {'its': 'O'},
#   {'Resolution': 'B'},
#   {'of': 'O'},
#   {'14': 'O'},
#   {'April': 'O'},
#   {'2005': 'O'},
#   {'concerning': 'O'},
#   {'a': 'O'},
#   {'comprehensive': 'O'},
#   {'EU': 'O'},
#   {'policy': 'I'},
#   {'against': 'I'},
#   {'corruption': 'B'},
#   {',': 'O'},
#   {'which': 'O'},
#   {'refers': 'O'},
#   {'to': 'O'},
#   {'the': 'O'},
#   {'communication': 'O'},
#   {'from': 'O'},
#   {'the': 'O'},
#   {'Commission': 'B'},
#   {'to': 'O'},
#   {'the': 'O'},
#   {'Council': 'O'},
#   {',': 'O'},
#   {'the': 'O'},
#   {'European': 'O'},
#   {'Parliament': 'I'},
#   {'and': 'O'},
#   {'the': 'O'},
#   {'European': 'O'},
#   {'Economic': 'B'},
#   {'and': 'O'},
#   {'Social': 'O'},
#   {'Committee': 'I'},
#   {'of': 'O'},
#   {'28': 'O'},
#   {'May': 'O'},
#   {'2003': 'O'},
#   {'on': 'O'},
#   {'a': 'O'},
#   {'Comprehensive': 'O'},
#   {'EU': 'O'},
#   {'Policy': 'I'},
#   {'against': 'I'},
#   {'Corruption': 'B'},
#   {',': 'O'},
#   {'the': 'O'},
#   {'Council': 'O'},
#   {'reaffirms': 'O'},
#   {'the': 'O'},
#   {'importance': 'O'},
#   {'of': 'O'},
#   {'the': 'O'},
#   {'role': 'O'},
#   {'and': 'O'},
#   {'work': 'O'},
#   {'of': 'O'},
#   {'the': 'O'},
#   {'Member': 'O'},
#   {'States': 'O'},
#   {'in': 'O'},
#   {'developing': 'O'},
#   {'a': 'O'},
#   {'comprehensive': 'O'},
#   {',': 'O'},
#   {'multi': 'O'},
#   {'-': 'O'},
#   {'faceted': 'O'},
#   {'policy': 'I'},
#   {'against': 'I'},
#   {'corruption': 'B'},
#   {'in': 'O'},
#   {'both': 'O'},
#   {'the': 'O'},
#   {'public': 'B'},
#   {'and': 'O'},
#   {'private': 'B'},
#   {'sectors': 'I'},
#   {',': 'O'},
#   {'in': 'O'},
#   {'partnership': 'O'},
#   {'with': 'O'},
#   {'all': 'O'},
#   {'relevant': 'O'},
#   {'players': 'O'},
#   {'from': 'O'},
#   {'civil': 'B'},
#   {'society': 'I'},
#   {'and': 'O'},
#   {'business': 'B'},
#   {'alike': 'O'},
#   {'.': 'O'}],
#  [],
#  [{'(': 'O'}, {'4': 'O'}, {')': 'O'}],
#  [],
#  [{'The': 'O'},
#   {'European': 'O'},
#   {'Council': 'I'},
#   {'welcomed': 'O'},
#   {'the': 'O'},
#   {'development': 'O'},
#   {'in': 'O'},
#   {'the': 'O'},
#   {'Hague': 'O'},
#   {'Programme': 'O'},
#   {'(': 'O'},
#   {'point': 'O'},
#   {'2.7': 'O'},
#   {')': 'O'},
#   {'of': 'O'},
#   {'a': 'O'},
#   {'strategic': 'O'},
#   {'concept': 'O'},
#   {'with': 'O'},
#   {'regard': 'O'},
#   {'to': 'O'},
#   {'cross': 'O'},
#   {'-': 'O'},
#   {'border': 'O'},
#   {'organised': 'B'},
#   {'crime': 'B'},
#   {'and': 'O'},
#   {'corruption': 'B'},
#   {'at': 'O'},
#   {'EU': 'O'},
#   {'level': 'O'},
#   {'and': 'O'},
#   {'asked': 'O'},
#   {'the': 'O'},
#   {'Council': 'O'},
#   {'and': 'O'},
#   {'the': 'O'},
#   {'Commission': 'B'},
#   {'to': 'O'},
#   {'develop': 'O'},
#   {'this': 'O'},
#   {'concept': 'O'},
#   {'further': 'O'},
#   {'and': 'O'},
#   {'make': 'O'},
#   {'it': 'O'},
#   {'operational': 'O'},
#   {'.': 'O'}],
#  [],
#  [{'(': 'O'}, {'5': 'O'}, {')': 'O'}],
#  [],
#  [{'The': 'O'},
#   {'heads': 'O'},
#   {'and': 'O'},
#   {'key': 'O'},
#   {'representatives': 'O'},
#   {'of': 'O'},
#   {'EU': 'O'},
#   {'Member': 'O'},
#   {'States': 'O'},
#   {"'": 'O'},
#   {'national': 'O'},
#   {'police': 'B'},
#   {'monitoring': 'B'},
#   {'and': 'O'},
#   {'inspection': 'I'},
#   {'bodies': 'I'},
#   {'and': 'O'},
#   {'those': 'O'},
#   {'of': 'O'},
#   {'their': 'O'},
#   {'anti': 'B'},
#   {'-': 'O'},
#   {'corruption': 'B'},
#   {'agencies': 'I'},
#   {'with': 'O'},
#   {'a': 'O'},
#   {'wider': 'O'},
#   {'remit': 'O'},
#   {'met': 'O'},
#   {'in': 'O'},
#   {'November': 'O'},
#   {'2004': 'O'},
#   {'in': 'O'},
#   {'Vienna': 'O'},
#   {'at': 'O'},
#   {'the': 'O'},
#   {'AGIS': 'O'},
#   {'conference': 'O'},
#   {'on': 'O'},
#   {'the': 'O'},
#   {'Enhancement': 'O'},
#   {'of': 'O'},
#   {'Operational': 'O'},
#   {'Cooperation': 'O'},
#   {'in': 'O'},
#   {'Fighting': 'B'},
#   {'Corruption': 'B'},
#   {'in': 'O'},
#   {'the': 'O'},
#   {'European': 'O'},
#   {'Union': 'O'},
#   {'.': 'O'},
#   {'They': 'O'},
#   {'emphasised': 'O'},
#   {'the': 'O'},
#   {'importance': 'O'},
#   {'of': 'O'},
#   {'further': 'O'},
#   {'enhancing': 'O'},
#   {'their': 'O'},
#   {'cooperation': 'O'},
#   {',': 'O'},
#   {'inter': 'O'},
#   {'alia': 'O'},
#   {',': 'O'},
#   {'through': 'O'},
#   {'annual': 'O'},
#   {'meetings': 'O'},
#   {',': 'O'},
#   {'and': 'O'},
#   {'welcomed': 'O'},
#   {'the': 'O'},
#   {'idea': 'O'},
#   {'of': 'O'},
#   {'a': 'O'},
#   {'European': 'O'},
#   {'anti': 'B'},
#   {'-': 'O'},
#   {'corruption': 'B'},
#   {'network': 'I'},
#   {'based': 'O'},
#   {'upon': 'O'},
#   {'existing': 'O'},
#   {'structures': 'I'},
#   {'.': 'O'},
#   {'In': 'O'},
#   {'the': 'O'},
#   {'wake': 'O'},
#   {'of': 'O'},
#   {'the': 'O'},
#   {'Vienna': 'O'},
#   {'conference': 'O'},
#   {'these': 'O'},
#   {'European': 'O'},
#   {'Partners': 'O'},
#   {'Against': 'I'},
#   {'Corruption': 'B'},
#   {'(': 'O'},
#   {'EPAC': 'B'},
#   {')': 'O'},
#   {'met': 'O'},
#   {'in': 'O'},
#   {'Budapest': 'O'},
#   {'in': 'O'},
#   {'November': 'O'},
#   {'2006': 'O'},
#   {'for': 'O'},
#   {'their': 'O'},
#   {'sixth': 'O'},
#   {'annual': 'O'},
#   {'meeting': 'O'},
#   {',': 'O'},
#   {'where': 'O'},
#   {'with': 'O'},
#   {'an': 'O'},
#   {'overwhelming': 'O'},
#   {'majority': 'O'},
#   {',': 'O'},
#   {'they': 'O'},
#   {'confirmed': 'O'},
#   {'their': 'O'},
#   {'commitment': 'O'},
#   {'to': 'O'},
#   {'supporting': 'O'},
#   {'the': 'O'},
#   {'initiative': 'O'},
#   {'on': 'O'},
#   {'setting': 'O'},
#   {'up': 'O'},
#   {'a': 'O'},
#   {'more': 'O'},
#   {'formal': 'O'},
#   {'anti': 'B'},
#   {'-': 'O'},
#   {'corruption': 'B'},
#   {'network': 'I'},
#   {'.': 'O'}],
#  [],
#  [{'(': 'O'}, {'6': 'O'}, {')': 'O'}],
#  [],
#  [{'In': 'O'},
#   {'order': 'O'},
#   {'to': 'O'},
#   {'build': 'O'},
#   {'upon': 'O'},
#   {'existing': 'O'},
#   {'structures': 'I'},
#   {',': 'O'},
#   {'the': 'O'},
#   {'authorities': 'B'},
#   {'and': 'O'},
#   {'agencies': 'I'},
#   {'to': 'O'},
#   {'form': 'O'},
#   {'part': 'O'},
#   {'of': 'O'},
#   {'the': 'O'},
#   {'European': 'O'},
#   {'anti': 'B'},
#   {'-': 'O'},
#   {'corruption': 'B'},
#   {'network': 'I'},
#   {'could': 'O'},
#   {'include': 'O'},
#   {'EPAC': 'B'},
#   {'member': 'O'},
#   {'organisations': 'I'},
#   {'.': 'O'}],
#  [],
#  [{'(': 'O'}, {'7': 'O'}, {')': 'O'}],
#  [],
#  [{'The': 'O'},
#   {'enhancement': 'O'},
#   {'of': 'O'},
#   {'international': 'O'},
#   {'cooperation': 'O'},
#   {'is': 'O'},
#   {'generally': 'O'},
#   {'recognised': 'O'},
#   {'as': 'O'},
#   {'a': 'O'},
#   {'key': 'O'},
#   {'issue': 'O'},
#   {'in': 'O'},
#   {'the': 'O'},
#   {'fight': 'B'},
#   {'against': 'I'},
#   {'corruption': 'B'},
#   {'.': 'O'},
#   {'The': 'O'},
#   {'fight': 'B'},
#   {'against': 'I'},
#   {'all': 'O'},
#   {'forms': 'I'},
#   {'of': 'I'},
#   {'corruption': 'B'},
#   {'should': 'O'},
#   {'be': 'O'},
#   {'improved': 'O'},
#   {'by': 'O'},
#   {'cooperating': 'O'},
#   {'effectively': 'O'},
#   {',': 'O'},
#   {'identifying': 'O'},
#   {'opportunities': 'O'},
#   {',': 'O'},
#   {'sharing': 'O'},
#   {'good': 'B'},
#   {'practices': 'I'},
#   {'and': 'O'},
#   {'developing': 'O'},
#   {'high': 'O'},
#   {'professional': 'O'},
#   {'standards': 'I'},
#   {'.': 'O'},
#   {'The': 'O'},
#   {'establishment': 'O'},
#   {'of': 'O'},
#   {'an': 'O'},
#   {'anti': 'B'},
#   {'-': 'O'},
#   {'corruption': 'B'},
#   {'network': 'I'},
#   {'at': 'O'},
#   {'EU': 'O'},
#   {'level': 'O'},
#   {'is': 'O'},
#   {'an': 'O'},
#   {'important': 'O'},
#   {'contribution': 'O'},
#   {'to': 'O'},
#   {'the': 'O'},
#   {'improvement': 'O'},
#   {'of': 'O'},
#   {'such': 'O'},
#   {'cooperation': 'O'},
#   {',': 'O'}],
#  [],
#  [{'HAS': 'O'}, {'DECIDED': 'O'}, {'AS': 'O'}, {'FOLLOWS': 'O'}, {':': 'O'}],
#  [],
#  [{'Article': 'O'}, {'1': 'O'}],
#  [],
#  [{'Objective': 'B'}],
#  [],
#  [{'In': 'O'},
#   {'order': 'O'},
#   {'to': 'O'},
#   {'improve': 'O'},
#   {'cooperation': 'O'},
#   {'between': 'O'},
#   {'authorities': 'B'},
#   {'and': 'O'},
#   {'agencies': 'I'},
#   {'to': 'O'},
#   {'prevent': 'O'},
#   {'and': 'O'},
#   {'combat': 'B'},
#   {'corruption': 'B'},
#   {'in': 'O'},
#   {'Europe': 'O'},
#   {'a': 'O'},
#   {'network': 'I'},
#   {'of': 'O'},
#   {'contact': 'O'},
#   {'points': 'O'},
#   {'of': 'O'},
#   {'the': 'O'},
#   {'Member': 'O'},
#   {'States': 'O'},
#   {'of': 'O'},
#   {'the': 'O'},
#   {'European': 'O'},
#   {'Union': 'O'},
#   {'shall': 'O'},
#   {'be': 'O'},
#   {'set': 'O'},
#   {'up': 'O'},
#   {'(': 'O'},
#   {'hereinafter': 'O'},
#   {'referred': 'O'},
#   {'to': 'O'},
#   {'as': 'O'},
#   {'the': 'O'},
#   {"'": 'O'},
#   {'network': 'I'},
#   {"'": 'O'},
#   {')': 'O'},
#   {'.': 'O'},
#   {'The': 'O'},
#   {'European': 'O'},
#   {'Commission': 'B'},
#   {',': 'O'},
#   {'Europol': 'O'},
#   {'and': 'O'},
#   {'Eurojust': 'O'},
#   {'shall': 'O'},
#   {'be': 'O'},
#   {'fully': 'O'},
#   {'associated': 'O'},
#   {'with': 'O'},
#   {'the': 'O'},
#   {'activities': 'O'},
#   {'of': 'O'},
#   {'the': 'O'},
#   {'Network': 'O'},
#   {'.': 'O'}],
#  [],
#  [{'Article': 'O'}, {'2': 'O'}],
#  [],
#  [{'Composition': 'O'}, {'of': 'O'}, {'the': 'B'}, {'network': 'B'}],
#  [],
#  [{'The': 'O'},
#   {'network': 'I'},
#   {'shall': 'O'},
#   {'consist': 'O'},
#   {'of': 'O'},
#   {'authorities': 'B'},
#   {'and': 'O'},
#   {'agencies': 'I'},
#   {'of': 'O'},
#   {'the': 'O'},
#   {'Member': 'O'},
#   {'States': 'O'},
#   {'of': 'O'},
#   {'the': 'O'},
#   {'European': 'O'},
#   {'Union': 'O'},
#   {'charged': 'O'},
#   {'with': 'O'},
#   {'preventing': 'O'},
#   {'or': 'O'},
#   {'combating': 'B'},
#   {'corruption': 'B'},
#   {'.': 'O'},
#   {'The': 'O'},
#   {'members': 'O'},
#   {'shall': 'O'},
#   {'be': 'O'},
#   {'designated': 'O'},
#   {'by': 'O'},
#   {'the': 'O'},
#   {'Member': 'O'},
#   {'States': 'O'},
#   {'.': 'O'},
#   {'The': 'O'},
#   {'Member': 'O'},
#   {'States': 'O'},
#   {'shall': 'O'},
#   {'each': 'O'},
#   {'designate': 'O'},
#   {'at': 'O'},
#   {'least': 'O'},
#   {'one': 'O'},
#   {',': 'O'},
#   {'but': 'O'},
#   {'not': 'O'},
#   {'more': 'O'},
#   {'than': 'O'},
#   {'three': 'O'},
#   {'organisations': 'I'},
#   {'.': 'O'},
#   {'The': 'O'},
#   {'European': 'O'},
#   {'Commission': 'B'},
#   {'shall': 'O'},
#   {'designate': 'O'},
#   {'its': 'O'},
#   {'representatives': 'O'},
#   {'.': 'O'},
#   {'Within': 'O'},
#   {'their': 'O'},
#   {'respective': 'O'},
#   {'competencies': 'O'},
#   {',': 'O'},
#   {'Europol': 'O'},
#   {'and': 'O'},
#   {'Eurojust': 'O'},
#   {'may': 'O'},
#   {'participate': 'O'},
#   {'in': 'O'},
#   {'the': 'O'},
#   {'activities': 'O'},
#   {'of': 'O'},
#   {'the': 'O'},
#   {'Network': 'O'},
#   {'.': 'O'}],
#  [],
#  [{'Article': 'B'}, {'3': 'O'}],
#  [],
#  [{'Tasks': 'O'}, {'of': 'O'}, {'the': 'B'}, {'network': 'B'}],
#  [],
#  [{'1': 'O'},
#   {'.': 'O'},
#   {'The': 'B'},
#   {'network': 'I'},
#   {'shall': 'O'},
#   {'in': 'O'},
#   {'particular': 'O'},
#   {'have': 'O'},
#   {'the': 'B'},
#   {'following': 'O'},
#   {'tasks': 'O'},
#   {':': 'O'}],
#  [],
#  [{'1': 'O'}, {'.': 'O'}],
#  [],
#  [{'it': 'O'},
#   {'shall': 'O'},
#   {'constitute': 'O'},
#   {'a': 'O'},
#   {'forum': 'I'},
#   {'for': 'O'},
#   {'the': 'O'},
#   {'exchange': 'O'},
#   {'throughout': 'O'},
#   {'the': 'O'},
#   {'EU': 'O'},
#   {'of': 'O'},
#   {'information': 'O'},
#   {'on': 'O'},
#   {'effective': 'O'},
#   {'measures': 'O'},
#   {'and': 'O'},
#   {'experience': 'O'},
#   {'in': 'O'},
#   {'the': 'O'},
#   {'prevention': 'O'},
#   {'and': 'O'},
#   {'combating': 'B'},
#   {'of': 'I'},
#   {'corruption': 'B'},
#   {';': 'O'}],
#  [],
#  [{'2': 'O'}, {'.': 'O'}],
#  [],
#  [{'it': 'O'},
#   {'shall': 'O'},
#   {'facilitate': 'O'},
#   {'the': 'O'},
#   {'establishment': 'O'},
#   {'and': 'O'},
#   {'active': 'O'},
#   {'maintenance': 'O'},
#   {'of': 'O'},
#   {'contacts': 'O'},
#   {'between': 'O'},
#   {'its': 'O'},
#   {'members': 'O'},
#   {'.': 'O'}],
#  [],
#  [{'To': 'O'},
#   {'these': 'O'},
#   {'ends': 'O'},
#   {',': 'O'},
#   {'inter': 'O'},
#   {'alia': 'O'},
#   {',': 'O'},
#   {'a': 'O'},
#   {'list': 'O'},
#   {'of': 'O'},
#   {'contact': 'O'},
#   {'points': 'O'},
#   {'shall': 'O'},
#   {'be': 'O'},
#   {'kept': 'O'},
#   {'up': 'O'},
#   {'-': 'O'},
#   {'to': 'O'},
#   {'-': 'O'},
#   {'date': 'O'},
#   {'and': 'O'},
#   {'a': 'O'},
#   {'web': 'O'},
#   {'site': 'O'},
#   {'operated': 'O'},
#   {'.': 'O'}],
#  [],
#  [{'2': 'O'},
#   {'.': 'O'},
#   {'The': 'O'},
#   {'members': 'O'},
#   {'of': 'O'},
#   {'the': 'O'},
#   {'network': 'O'},
#   {'shall': 'O'},
#   {',': 'O'},
#   {'for': 'O'},
#   {'the': 'O'},
#   {'accomplishment': 'O'},
#   {'of': 'O'},
#   {'their': 'O'},
#   {'tasks': 'O'},
#   {',': 'O'},
#   {'meet': 'O'},
#   {'at': 'O'},
#   {'least': 'O'},
#   {'once': 'O'},
#   {'a': 'O'},
#   {'year': 'O'},
#   {'.': 'O'}],
#  [],
#  [{'Article': 'B'}, {'4': 'O'}],
#  [],
#  [{'Scope': 'B'}],
#  [],
#  [{'Police': 'B'},
#   {'and': 'I'},
#   {'judicial': 'B'},
#   {'cooperation': 'O'},
#   {'between': 'O'},
#   {'the': 'O'},
#   {'Member': 'O'},
#   {'States': 'O'},
#   {'shall': 'O'},
#   {'be': 'O'},
#   {'governed': 'B'},
#   {'by': 'O'},
#   {'the': 'O'},
#   {'relevant': 'O'},
#   {'rules': 'B'},
#   {'.': 'O'},
#   {'The': 'O'},
#   {'setting': 'O'},
#   {'up': 'O'},
#   {'of': 'O'},
#   {'the': 'O'},
#   {'network': 'I'},
#   {'shall': 'O'},
#   {'be': 'O'},
#   {'without': 'O'},
#   {'prejudice': 'O'},
#   {'to': 'O'},
#   {'such': 'O'},
#   {'rules': 'B'},
#   {',': 'O'},
#   {'and': 'O'},
#   {'without': 'O'},
#   {'prejudice': 'O'},
#   {'to': 'O'},
#   {'the': 'O'},
#   {'role': 'O'},
#   {'of': 'O'},
#   {'CEPOL': 'B'},
#   {'.': 'O'}],
#  [],
#  [{'Article': 'B'}, {'5': 'O'}],
#  [],
#  [{'Organisation': 'O'}, {'of': 'O'}, {'the': 'B'}, {'network': 'B'}],
#  [],
#  [{'1': 'O'},
#   {'.': 'O'},
#   {'The': 'O'},
#   {'network': 'I'},
#   {'shall': 'O'},
#   {'organise': 'O'},
#   {'itself': 'O'},
#   {',': 'O'},
#   {'building': 'O'},
#   {'upon': 'O'},
#   {'existing': 'O'},
#   {'informal': 'O'},
#   {'collaboration': 'O'},
#   {'between': 'O'},
#   {'the': 'O'},
#   {'EPAC': 'B'},
#   {'.': 'O'}],
#  [],
#  [{'2': 'O'},
#   {'.': 'O'},
#   {'The': 'O'},
#   {'Member': 'O'},
#   {'States': 'O'},
#   {'and': 'O'},
#   {'the': 'O'},
#   {'European': 'O'},
#   {'Commission': 'B'},
#   {'shall': 'O'},
#   {'bear': 'O'},
#   {'all': 'O'},
#   {'expenses': 'B'},
#   {'of': 'I'},
#   {'the': 'O'},
#   {'members': 'O'},
#   {'or': 'O'},
#   {'representatives': 'O'},
#   {'designated': 'O'},
#   {'by': 'O'},
#   {'them': 'O'},
#   {'.': 'O'},
#   {'The': 'O'},
#   {'same': 'O'},
#   {'rule': 'B'},
#   {'shall': 'O'},
#   {'apply': 'O'},
#   {'to': 'O'},
#   {'Europol': 'O'},
#   {'and': 'O'},
#   {'Eurojust': 'O'},
#   {'.': 'O'}],
#  [],
#  [{'Article': 'B'}, {'6': 'O'}],
#  [],
#  [{'Entry': 'B'}, {'into': 'O'}, {'force': 'B'}],
#  [],
#  [{'This': 'O'},
#   {'Decision': 'B'},
#   {'shall': 'O'},
#   {'take': 'O'},
#   {'effect': 'O'},
#   {'on': 'O'},
#   {'the': 'O'},
#   {'day': 'O'},
#   {'following': 'O'},
#   {'that': 'O'},
#   {'of': 'O'},
#   {'its': 'O'},
#   {'adoption': 'O'},
#   {'.': 'O'}],
#  [],
#  [{'Done': 'B'},
#   {'at': 'O'},
#   {'Luxembourg': 'O'},
#   {',': 'O'},
#   {'24': 'O'},
#   {'October': 'O'},
#   {'2008': 'O'},
#   {'.': 'O'}],
#  ...]

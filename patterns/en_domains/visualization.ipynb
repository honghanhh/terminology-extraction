# %%
import pandas as pd

# %%
corp_equi_wind = pd.read_csv('./corp_equi_wind/en_iate_f1.csv').rename(columns={'Unnamed: 0':'Patterns'})
cols = ['ann_xlnet_htfl.pkl', 'ann_xlnet_wind.pkl',
       'ann_xlnet_equi.pkl', 'ann_xlnet_corp.pkl', 'nes_xlnet_htfl.pkl',
       'nes_xlnet_wind.pkl', 'nes_xlnet_equi.pkl', 'nes_xlnet_corp.pkl']
for col in cols:
    corp_equi_wind['percent_'+col] = round(corp_equi_wind[col]*100/corp_equi_wind[col].iloc[0],2)

# %%
corp_equi_wind_df = corp_equi_wind.filter(regex='percent_|Patterns')
corp_equi_wind_df
# Out:
#                     Patterns  percent_ann_xlnet_htfl.pkl  \
# 0             NON_PATTERN_F1                      100.00
# 1                ADJ_NOUN_F1                      105.35
# 2               NOUN_NOUN_F1                       97.88
# 3            ADJ_ADJ_NOUN_F1                      101.39
# 4           ADJ_NOUN_NOUN_F1                       99.60
# 5           NOUN_ADJ_NOUN_F1                      100.08
# 6          NOUN_NOUN_NOUN_F1                      100.20
# 7           NOUN_ADP_NOUN_F1                       96.92
# 8       NOUN_ADP_ADJ_NOUN_F1                       98.95
# 9       ADJ_NOUN_ADP_NOUN_F1                       99.26
# 10     NOUN_ADP_NOUN_NOUN_F1                       98.92
# 11  ADJ_NOUN_ADP_ADJ_NOUN_F1                       99.66
# 12           ADV_ADJ_NOUN_F1                       99.75
# 13              NOUN_PRON_F1                      100.17
# 14      ADJ_NOUN_ADJ_NOUN_F1                      100.00
#
#     percent_ann_xlnet_wind.pkl  percent_ann_xlnet_equi.pkl  \
# 0                       100.00                      100.00
# 1                        98.23                       90.07
# 2                        82.73                       89.17
# 3                        99.29                       98.85
# 4                        98.38                       99.02
# 5                        99.27                       99.36
# 6                        98.50                       99.28
# 7                        95.59                       95.26
# 8                        98.25                       98.69
# 9                        99.14                       99.44
# 10                       98.57                       99.44
# 11                       99.64                       99.78
# 12                       99.34                       98.89
# 13                       98.32                       99.12
# 14                       99.93                       99.96
#
#     percent_ann_xlnet_corp.pkl  percent_nes_xlnet_htfl.pkl  \
# 0                       100.00                      100.00
# 1                        97.42                      102.65
# 2                        87.95                       95.42
# 3                        98.67                      100.73
# 4                        99.43                       99.50
# 5                        99.23                       99.85
# 6                        99.37                       99.87
# 7                        94.17                       97.27
# 8                        98.18                       99.20
# 9                        98.81                       99.50
# 10                       98.67                       99.17
# 11                       99.78                       99.87
# 12                       99.56                       99.87
# 13                       99.78                      100.25
# 14                       99.90                      100.10
#
#     percent_nes_xlnet_wind.pkl  percent_nes_xlnet_equi.pkl  \
# 0                       100.00                      100.00
# 1                        98.19                       91.88
# 2                        87.00                       91.82
# 3                        99.58                       99.15
# 4                        99.26                       99.39
# 5                        99.43                       99.49
# 6                        98.97                       99.59
# 7                        97.55                       95.67
# 8                        98.95                       98.97
# 9                        99.58                       99.35
# 10                       99.15                       99.49
# 11                       99.89                       99.92
# 12                       99.50                       99.15
# 13                       98.84                       99.72
# 14                      100.00                       99.98
#
#     percent_nes_xlnet_corp.pkl
# 0                       100.00
# 1                        98.73
# 2                        90.08
# 3                        99.36
# 4                        99.58
# 5                        99.50
# 6                        99.56
# 7                        95.53
# 8                        98.65
# 9                        99.34
# 10                       99.34
# 11                       99.64
# 12                       99.62
# 13                       99.86
# 14                      100.00

# %%
corp_equi = pd.read_csv('./corp_equi/en_iate_f1.csv').rename(columns={'Unnamed: 0':'Patterns'})
corp_equi = corp_equi[corp_equi['Patterns'].str.endswith('_F1')]
for col in cols:
    corp_equi['percent_'+col] = round(corp_equi[col]*100/corp_equi[col].iloc[0],2)
corp_equi_df = corp_equi.filter(regex='percent_|Patterns')
corp_equi_df
# Out:
#                     Patterns  percent_ann_xlnet_htfl.pkl  \
# 2             NON_PATTERN_F1                      100.00
# 5                ADJ_NOUN_F1                      105.82
# 8               NOUN_NOUN_F1                      106.77
# 11           ADJ_ADJ_NOUN_F1                      101.52
# 14          ADJ_NOUN_NOUN_F1                      100.74
# 17          NOUN_ADJ_NOUN_F1                      100.17
# 20         NOUN_NOUN_NOUN_F1                       99.66
# 23          NOUN_ADP_NOUN_F1                       96.85
# 26      NOUN_ADP_ADJ_NOUN_F1                       99.22
# 29      ADJ_NOUN_ADP_NOUN_F1                       99.26
# 32     NOUN_ADP_NOUN_NOUN_F1                       98.88
# 35  ADJ_NOUN_ADP_ADJ_NOUN_F1                       99.76
# 38           ADV_ADJ_NOUN_F1                       99.76
# 41              NOUN_PRON_F1                       99.83
# 44      ADJ_NOUN_ADJ_NOUN_F1                      100.00
#
#     percent_ann_xlnet_wind.pkl  percent_ann_xlnet_equi.pkl  \
# 2                       100.00                      100.00
# 5                       102.82                       91.48
# 8                       124.91                       90.83
# 11                       99.61                       98.93
# 14                      102.13                       99.25
# 17                       99.87                       99.52
# 20                      102.60                       99.46
# 23                       97.79                       95.65
# 26                       99.09                       98.85
# 29                       99.18                       99.71
# 32                       98.96                       99.44
# 35                       99.83                       99.90
# 38                       99.48                       99.12
# 41                       98.44                       99.44
# 44                      100.00                       99.96
#
#     percent_ann_xlnet_corp.pkl  percent_nes_xlnet_htfl.pkl  \
# 2                       100.00                      100.00
# 5                        97.37                      103.71
# 8                        89.56                       98.98
# 11                       99.32                      101.02
# 14                       99.51                       99.14
# 17                       99.47                       99.87
# 20                       99.81                       99.92
# 23                       94.72                       96.64
# 26                       98.44                       99.08
# 29                       99.21                       99.24
# 32                       99.04                       98.83
# 35                       99.76                       99.69
# 38                       99.53                       99.75
# 41                       99.59                       99.90
# 44                       99.89                       99.97
#
#     percent_nes_xlnet_wind.pkl  percent_nes_xlnet_equi.pkl  \
# 2                       100.00                      100.00
# 5                       100.65                       92.39
# 8                       111.76                       93.13
# 11                       99.76                       99.15
# 14                      100.96                       99.23
# 17                       99.90                       99.60
# 20                      100.27                       99.60
# 23                       97.88                       96.09
# 26                       99.21                       98.93
# 29                       99.76                       99.56
# 32                       99.15                       99.42
# 35                       99.90                       99.80
# 38                       99.66                       99.05
# 41                       99.01                       99.64
# 44                      100.00                       99.98
#
#     percent_nes_xlnet_corp.pkl
# 2                       100.00
# 5                       101.21
# 8                        92.65
# 11                       99.60
# 14                       99.60
# 17                       99.47
# 20                       99.72
# 23                       96.32
# 26                       98.32
# 29                       99.30
# 32                       99.09
# 35                       99.66
# 38                       99.57
# 41                       99.85
# 44                      100.00

# %%
# corp_equi_df.to_csv('./corp_equi/en_iate_f1_.csv')

# %%
# corp_equi_df[(corp_equi_df.filter(regex='percent_').values > 100).any(axis=1)]

# %%
# corp_equi_df.filter(regex='Patterns|wind|htfl')

# %%
corp_wind = pd.read_csv('./corp_wind/en_iate_f1.csv').rename(columns={'Unnamed: 0':'Patterns'})
corp_wind = corp_wind[corp_wind['Patterns'].str.endswith('_F1')]
for col in cols:
    corp_wind['percent_'+col] = round(corp_wind[col]*100/corp_wind[col].iloc[0],2)
corp_wind_df = corp_wind.filter(regex='percent_|Patterns')
corp_wind_df
# Out:
#                     Patterns  percent_ann_xlnet_htfl.pkl  \
# 0             NON_PATTERN_F1                      100.00
# 1                ADJ_NOUN_F1                      104.65
# 2               NOUN_NOUN_F1                       96.55
# 3            ADJ_ADJ_NOUN_F1                      101.01
# 4           ADJ_NOUN_NOUN_F1                       99.35
# 5           NOUN_ADJ_NOUN_F1                      100.11
# 6          NOUN_NOUN_NOUN_F1                       99.95
# 7           NOUN_ADP_NOUN_F1                       97.09
# 8       NOUN_ADP_ADJ_NOUN_F1                       99.10
# 9       ADJ_NOUN_ADP_NOUN_F1                       99.29
# 10     NOUN_ADP_NOUN_NOUN_F1                       99.10
# 11  ADJ_NOUN_ADP_ADJ_NOUN_F1                       99.76
# 12           ADV_ADJ_NOUN_F1                       99.67
# 13              NOUN_PRON_F1                      100.22
# 14      ADJ_NOUN_ADJ_NOUN_F1                       99.97
#
#     percent_ann_xlnet_wind.pkl  percent_ann_xlnet_equi.pkl  \
# 0                       100.00                      100.00
# 1                        98.11                       96.61
# 2                        82.34                       94.05
# 3                        99.47                       99.63
# 4                        98.96                       99.40
# 5                        99.28                       99.80
# 6                        99.45                       99.77
# 7                        96.21                       97.82
# 8                        98.41                       99.43
# 9                        99.17                      100.00
# 10                       98.55                       99.63
# 11                       99.65                       99.91
# 12                       99.35                       99.51
# 13                       98.31                       99.40
# 14                       99.98                       99.97
#
#     percent_ann_xlnet_corp.pkl  percent_nes_xlnet_htfl.pkl  \
# 0                       100.00                      100.00
# 1                        97.18                      102.49
# 2                        89.20                       97.17
# 3                        99.11                      100.54
# 4                        99.37                       99.68
# 5                        99.41                       99.95
# 6                        99.59                      100.32
# 7                        95.64                       97.29
# 8                        98.54                       99.24
# 9                        98.89                       99.48
# 10                       98.93                       99.24
# 11                       99.82                       99.85
# 12                       99.55                       99.83
# 13                       99.78                      100.20
# 14                       99.96                      100.05
#
#     percent_nes_xlnet_wind.pkl  percent_nes_xlnet_equi.pkl  \
# 0                       100.00                      100.00
# 1                        98.92                       97.59
# 2                        88.78                       94.81
# 3                        99.31                       99.75
# 4                        98.75                       99.43
# 5                        99.31                       99.75
# 6                        99.31                       99.88
# 7                        97.18                       98.01
# 8                        98.70                       99.46
# 9                        99.57                       99.90
# 10                       98.84                       99.78
# 11                       99.69                       99.90
# 12                       99.51                       99.36
# 13                       98.95                       99.70
# 14                       99.93                       99.98
#
#     percent_nes_xlnet_corp.pkl
# 0                       100.00
# 1                        99.45
# 2                        91.51
# 3                        99.07
# 4                        99.43
# 5                        99.55
# 6                        99.75
# 7                        96.22
# 8                        98.71
# 9                        99.19
# 10                       99.09
# 11                       99.89
# 12                       99.66
# 13                       99.81
# 14                       99.96

# %%
corp_wind_df[(corp_wind_df.filter(regex='percent_').values > 100).any(axis=1)]
# corp_wind_df.to_csv('./corp_wind/en_iate_f1_.csv')
# Out:
#                 Patterns  percent_ann_xlnet_htfl.pkl  \
# 1            ADJ_NOUN_F1                      104.65
# 3        ADJ_ADJ_NOUN_F1                      101.01
# 5       NOUN_ADJ_NOUN_F1                      100.11
# 6      NOUN_NOUN_NOUN_F1                       99.95
# 13          NOUN_PRON_F1                      100.22
# 14  ADJ_NOUN_ADJ_NOUN_F1                       99.97
#
#     percent_ann_xlnet_wind.pkl  percent_ann_xlnet_equi.pkl  \
# 1                        98.11                       96.61
# 3                        99.47                       99.63
# 5                        99.28                       99.80
# 6                        99.45                       99.77
# 13                       98.31                       99.40
# 14                       99.98                       99.97
#
#     percent_ann_xlnet_corp.pkl  percent_nes_xlnet_htfl.pkl  \
# 1                        97.18                      102.49
# 3                        99.11                      100.54
# 5                        99.41                       99.95
# 6                        99.59                      100.32
# 13                       99.78                      100.20
# 14                       99.96                      100.05
#
#     percent_nes_xlnet_wind.pkl  percent_nes_xlnet_equi.pkl  \
# 1                        98.92                       97.59
# 3                        99.31                       99.75
# 5                        99.31                       99.75
# 6                        99.31                       99.88
# 13                       98.95                       99.70
# 14                       99.93                       99.98
#
#     percent_nes_xlnet_corp.pkl
# 1                        99.45
# 3                        99.07
# 5                        99.55
# 6                        99.75
# 13                       99.81
# 14                       99.96

# %%
equi_wind = pd.read_csv('./equi_wind/en_iate_f1.csv').rename(columns={'Unnamed: 0':'Patterns'})
equi_wind = equi_wind[equi_wind['Patterns'].str.endswith('_F1')]
for col in cols:
    equi_wind['percent_'+col] = round(equi_wind[col]*100/equi_wind[col].iloc[0],2)
equi_wind_df = equi_wind.filter(regex='percent_|Patterns')
equi_wind_df.to_csv('./equi_wind/en_iate_f1_.csv')

# %%
equi_wind_df[(equi_wind_df.filter(regex='percent_').values > 100).any(axis=1)]
# Out:
#              Patterns  percent_ann_xlnet_htfl.pkl  percent_ann_xlnet_wind.pkl  \
# 1         ADJ_NOUN_F1                      106.27                       97.59
# 2        NOUN_NOUN_F1                      103.82                       80.80
# 3     ADJ_ADJ_NOUN_F1                      101.71                       99.43
# 4    ADJ_NOUN_NOUN_F1                      100.52                       98.78
# 5    NOUN_ADJ_NOUN_F1                      100.26                       98.83
# 6   NOUN_NOUN_NOUN_F1                       99.77                       98.67
# 13       NOUN_PRON_F1                      100.26                       98.15
#
#     percent_ann_xlnet_equi.pkl  percent_ann_xlnet_corp.pkl  \
# 1                        90.84                      113.66
# 2                        90.03                      105.33
# 3                        98.70                       99.91
# 4                        98.80                      102.90
# 5                        99.37                       99.81
# 6                        99.37                      102.71
# 13                       99.21                       99.53
#
#     percent_nes_xlnet_htfl.pkl  percent_nes_xlnet_wind.pkl  \
# 1                       105.04                       98.64
# 2                        99.40                       87.02
# 3                       101.09                       99.60
# 4                        99.78                       98.93
# 5                       100.08                       99.33
# 6                        99.86                       99.15
# 13                      100.14                       98.95
#
#     percent_nes_xlnet_equi.pkl  percent_nes_xlnet_corp.pkl
# 1                        91.98                      100.35
# 2                        91.08                       92.08
# 3                        98.93                      100.00
# 4                        99.19                      100.79
# 5                        99.47                      100.00
# 6                        99.68                      100.35
# 13                       99.77                       99.85

# %%
 = pd.read_csv('./equi_wind/en_iate_f1.csv')
